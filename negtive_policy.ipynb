# %%
import os
import random
import numpy as np
import tensorflow as tf
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
from tqdm import tqdm, trange
from collections import defaultdict
from highway_layer import Highway
#匯入深度學習的框架函式庫：keras
import keras
from keras import backend as K
from keras.initializers import Constant
from keras.utils import plot_model
#keras用以建立模型架構的函數
from keras.models import Sequential, load_model, Model

#keras中建立深度學習layer的函數

from keras.layers import Dense, Dropout, BatchNormalization, Activation, Multiply, Add, Lambda, Input

#keras訓練演算法函數
from keras import regularizers
from keras.optimizers import Adam

#keras提早判停的函數
from keras.callbacks import EarlyStopping, ModelCheckpoint

#it's hard to reproduce results, so close all seeds
#os.environ['PYTHONHASHSEED'] = '0'
#np.random.seed(0)
#tf.set_random_seed(0)
#random.seed(0)

#to solve problem:Blas GEMM launch failed
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
#config = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
config.gpu_options.allocator_type = 'BFC' #A "Best-fit with coalescing" algorithm, simplified from a version of dlmalloc.
config.gpu_options.per_process_gpu_memory_fraction = 0.95
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config)) 


def fps_to_arr(fps):
    """Faster conversion to ndarray"""
    arrs = []
    for fp, info in zip(fps[0],fps[1]):
        onbits = list(fp.GetOnBits())
        arr = np.zeros(fp.GetNumBits())
        for onbit in onbits:
            arr[onbit] = len(info[onbit])
        arrs.append(arr)
    arrs = np.array(arrs)
    return arrs




def fingerprint_mols(mols, fp_dim):
    fps = []
    infos = []
    for mol in mols:
        mol = Chem.MolFromSmiles(mol)
        info={}
        # Necessary for fingerprinting
        # Chem.GetSymmSSSR(mol)

        # "When comparing the ECFP/FCFP fingerprints and
        # the Morgan fingerprints generated by the RDKit,
        # remember that the 4 in ECFP4 corresponds to the
        # diameter of the atom environments considered,
        # while the Morgan fingerprints take a radius parameter.
        # So the examples above, with radius=2, are roughly
        # equivalent to ECFP4 and FCFP4."
        # <http://www.rdkit.org/docs/GettingStartedInPython.html>
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=int(fp_dim), useChirality=1, bitInfo=info)
        # fold_factor = fp.GetNumBits()//fp_dim
        # fp = DataStructs.FoldFingerprint(fp, fold_factor)
        fps.append(fp)
        infos.append(info)
    return fps, infos

def preprocess(X, fp_dim, idx):
    # Compute fingerprints
    dataX = fps_to_arr(fingerprint_mols(X, fp_dim))
    # Apply variance threshold
    # return np.log(X[:,self.idx] + 1) 
    #FPs = np.log(dataX[:,idx]+1)
    #FPs = np.log(dataX+1)
    FPs = dataX
    return FPs
def smi_list_from_str(inchis):
    '''string separated by ++ to list of RDKit molecules'''
    return [inchi.strip() for inchi in inchis.split('++')]

def chunker(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def reducefn(a, b):
    n_a, mean_a, var_a = a
    n_b, mean_b, var_b = b
    n_ab = n_a + n_b
    mean_ab = ((mean_a * n_a) + (mean_b * n_b)) / n_ab
    var_ab = (((n_a * var_a) + (n_b * var_b)) / n_ab) + ((n_a * n_b) * ((mean_b - mean_a) / n_ab)**2)
    return n_ab, mean_ab, var_ab

def mapfn(chunk):
    exp_fp_dim = 1e6
    chunk = fingerprint_mols(chunk, exp_fp_dim)
    arrs = np.log(fps_to_arr(chunk) + 1)
    return len(arrs), np.mean(arrs, axis=0), np.var(arrs, axis=0)

class DataGenerator(keras.utils.Sequence):
    
    def __init__(self, X, y, idx, batch_size=1, shuffle=True, fp_dim=8192):
        self.batch_size = batch_size
        self.X = X
        self.y = y
        self.indexes = np.arange(len(self.X))
        self.shuffle = shuffle
        self.fp_dim = fp_dim
        self.idx = idx

    def __len__(self):
        #计算每一个epoch的迭代次数
        return int(np.floor(len(self.X) / int(self.batch_size)))

    def __getitem__(self, index):
        #生成每个batch数据，这里就根据自己对数据的读取方式进行发挥了
        # 生成batch_size个索引
        batch_indexs = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # 根据索引获取datas集合中的数据
        batch_datasX = [self.X[k] for k in batch_indexs]
        batch_datasy = [self.y[k] for k in batch_indexs]
        # 生成数据
        X = np.zeros((len(batch_datasX),self.fp_dim)) 
        for i,a in enumerate(batch_datasX):
            n = np.zeros((1,self.fp_dim))        
            for b in smi_list_from_str(a):
                n += preprocess([b], self.fp_dim, self.idx) 
            X[i] = n
        X = np.log(X+1)
        y = np.array(batch_datasy)
#        y = y.astype(np.int64)
        return X, y

    def on_epoch_end(self):
        #在每一次epoch结束是否需要进行一次随机，重新随机一下index
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

#    def fps_to_arr(fps):
        """Faster conversion to ndarray"""
#        arrs = []
#        for fp in fps:
#            onbits = list(fp.GetOnBits())
#            arr = np.zeros(fp.GetNumBits())
#            arr[onbits] = 1
#            arrs.append(arr)
#        arrs = np.array(arrs)
#        return arrs




#    def fingerprint_mols(self,mols):
#        fps = []
#        for mol in mols:
#            mol = Chem.MolFromSmiles(mol)

        # Necessary for fingerprinting
        # Chem.GetSymmSSSR(mol)

        # "When comparing the ECFP/FCFP fingerprints and
        # the Morgan fingerprints generated by the RDKit,
        # remember that the 4 in ECFP4 corresponds to the
        # diameter of the atom environments considered,
        # while the Morgan fingerprints take a radius parameter.
        # So the examples above, with radius=2, are roughly
        # equivalent to ECFP4 and FCFP4."
        # <http://www.rdkit.org/docs/GettingStartedInPython.html>
#            fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=int(self.fp_dim))
        # fold_factor = fp.GetNumBits()//fp_dim
        # fp = DataStructs.FoldFingerprint(fp, fold_factor)
#            fps.append(fp)
#        return fps

#    def preprocess(self,X):
    # Compute fingerprints
#        return self.fps_to_arr(self.fingerprint_mols(X, self.fp_dim))



print('Loading data...')
prod_to_rules = defaultdict(set)
with open('data/templates_expansion3.dat', 'r') as f:
    for l in tqdm(f, desc='products'):
        rule, prod, reac = l.strip().split('\t')
        prod_to_rules[reac].add(rule)

expansion_rules = {}
with open('data/expansion_expansion.dat', 'r') as f:
    for i, l in tqdm(enumerate(f), desc='expansion'):
        rule = l.strip()
        expansion_rules[rule] = i
# expansion training
print('expansion training...')
X, y = [], []

for prod, rules in tqdm(prod_to_rules.items(), desc='data prep'):
    rules = [r for r in rules if r in expansion_rules]
    if not rules: continue
    rules.sort()
    # Ideally trained as multilabel,
    # but multiclass, single label is easier atm
    for r in rules:
        id = expansion_rules[r]
        y.append(id)
        X.append(prod)
        
totrec = 0
for prod, rules in tqdm(prod_to_rules.items(), desc='total reactions'):
    totrec += len(prod_to_rules[prod])
#    totrec += len(rules) 
        
print('total products:', len(prod_to_rules))
print('total reactions:', totrec)
print('Training size:', len(X))

#設定訓練參數和訓練模型存放路徑
#batch_size = 1024
batch_size = 256
#num_classes = 6
#epochs = 2000
epochs = 100
seed=0
#validation spilt
spilt=0.1
#for variance threshold
#fp_dim=1e6
fp_dim=23086
n_rules=len(expansion_rules)
model_name = 'trained_model_negative_'+str(seed)
save_dir = os.path.join(os.getcwd(), 'saved_models')
idx = np.load(os.path.join(save_dir, 'expansion5e-5.idx.npy'))

# Shuffle
# p = np.random.permutation(len(X))
# X, y = X[p], y[p]
xy = list(zip(X, y))
xy.sort()
random.seed(seed)
random.shuffle(xy)
X, y = zip(*xy)
data_spilt= round(len(X)*(1-spilt))
x_train = X[:data_spilt]
x_test = X[data_spilt:]
y_train = y[:data_spilt]
y_test = y[data_spilt:]
print('shuffle is over...')

#將訓練資料轉成ndarray
#x_train=preprocess(X,fp_dim)
#y_train=np.array(y)
#print('preprocess is over...')
#for variance threshold
#visible = Input(shape=(len(idx),))
visible = Input(shape=(fp_dim,))
hidden = Dense(512, activation='elu')(visible)
hidden = Dropout(0.4)(hidden)

# only for expansion rule policynet
for _ in range(5):
    hidden = Highway()(hidden)
    hidden = Dropout(0.4)(hidden)
    
output = Dense(n_rules, activation='softmax')(hidden)
    
model = Model(inputs=visible, outputs=output)
# summarize layers
print(model.summary())
# plot graph
#plot_model(model, to_file='expansionpolicynet_graph.png')
# 初始化Adam optimizer
opt = keras.optimizers.Adam(lr=0.0001)

# 設定訓練方式，包含loss、optimizer..)
def acc_top50(y_true, y_pred):
    return keras.metrics.sparse_top_k_categorical_accuracy(y_true, y_pred, k=50)

def acc_top10(y_true, y_pred):
    return keras.metrics.sparse_top_k_categorical_accuracy(y_true, y_pred, k=10)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['sparse_categorical_accuracy',acc_top10 ,acc_top50])



# early stop存放模型設置


if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
checkpoint = ModelCheckpoint(model_path, monitor='val_acc_top50', save_best_only=True, verbose=1)

# early stop參數設定
earlystop = EarlyStopping(monitor='val_acc_top50', patience=6, verbose=1)

#continue training
#del model  # 删掉存在的模型

#返回一个编译好的模型
#与删掉的模型相同
#model = load_model(model_path, custom_objects={'acc_top10': acc_top10,'acc_top50': acc_top50, 'Highway': Highway})
##model.compile(loss='sparse_categorical_crossentropy',
##              optimizer=opt,
##              metrics=['sparse_categorical_accuracy',acc_top10,acc_top50])

# 開始訓練
training_generator = DataGenerator(X=x_train, y=y_train, batch_size=batch_size, shuffle=True, fp_dim=fp_dim, idx=idx)
validation_gen = DataGenerator(X=x_test, y=y_test, batch_size=batch_size, shuffle=True, fp_dim=fp_dim, idx=idx)
if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=1,
                    initial_epoch=0,
#                    workers=0, 
#                    use_multiprocessing=True, 
#                    shuffle=False,
#                    max_queue_size = 10, 
                    callbacks=[earlystop, checkpoint]
                    )

    #model_history = model.fit(x=x_train, 
#                    y=y_train,
#                    epochs=epochs,
#                    batch_size=batch_size,
#                    validation_split=0.2,
#                    verbose=1,
#                    callbacks=[earlystop, checkpoint])
# Out:
# RDKit WARNING: [19:58:15] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 709538it [00:02, 273206.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-24543eab850e> in <module>
#     196 prod_to_rules = defaultdict(set)
#     197 with open('data/templates_expansion3.dat', 'r') as f:
# --> 198     for l in tqdm(f, desc='products'):
#     199         rule, prod, reac = l.strip().split('\t')
#     200         prod_to_rules[reac].add(rule)
#
# KeyboardInterrupt:

# %%
from negative_policy import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=5, 
                    use_multiprocessing=True, 
                    max_queue_size = 5, 
#                    shuffle=False,
                    callbacks=[earlystop, checkpoint]
                    )
# Out:
# RDKit WARNING: [20:26:36] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 1157756it [00:04, 259233.82it/s]
# expansion: 55608it [00:00, 723861.49it/s]
# expansion training...
# data prep: 100%|██████████| 1136741/1136741 [00:00<00:00, 1170200.33it/s]
# total reactions: 100%|██████████| 1136741/1136741 [00:00<00:00, 2010221.50it/s]
# total products: 1136741
# total reactions: 1157285
# Training size: 1026999
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 23086)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               11820544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_1 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_2 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_3 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_4 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_5 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 55608)             28526904
# =================================================================
# Total params: 42,974,008
# Trainable params: 42,974,008
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/2000
#  - 749s - loss: 6.4319 - sparse_categorical_accuracy: 0.1222 - acc_top10: 0.3473 - acc_top50: 0.5186 - val_loss: 5.0951 - val_sparse_categorical_accuracy: 0.3039 - val_acc_top10: 0.5635 - val_acc_top50: 0.6834
#
# Epoch 00001: val_acc_top50 improved from -inf to 0.68344, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 2/2000
#  - 693s - loss: 4.4690 - sparse_categorical_accuracy: 0.3453 - acc_top10: 0.6187 - acc_top50: 0.7295 - val_loss: 3.5772 - val_sparse_categorical_accuracy: 0.4408 - val_acc_top10: 0.6996 - val_acc_top50: 0.7881
#
# Epoch 00002: val_acc_top50 improved from 0.68344 to 0.78810, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 3/2000
#  - 694s - loss: 3.7582 - sparse_categorical_accuracy: 0.4247 - acc_top10: 0.7009 - acc_top50: 0.7939 - val_loss: 3.3874 - val_sparse_categorical_accuracy: 0.4958 - val_acc_top10: 0.7542 - val_acc_top50: 0.8289
#
# Epoch 00003: val_acc_top50 improved from 0.78810 to 0.82890, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 4/2000
#  - 693s - loss: 3.3888 - sparse_categorical_accuracy: 0.4652 - acc_top10: 0.7419 - acc_top50: 0.8255 - val_loss: 3.0797 - val_sparse_categorical_accuracy: 0.5288 - val_acc_top10: 0.7872 - val_acc_top50: 0.8531
#
# Epoch 00004: val_acc_top50 improved from 0.82890 to 0.85307, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 5/2000
#  - 693s - loss: 3.1421 - sparse_categorical_accuracy: 0.4925 - acc_top10: 0.7679 - acc_top50: 0.8457 - val_loss: 2.6893 - val_sparse_categorical_accuracy: 0.5523 - val_acc_top10: 0.8075 - val_acc_top50: 0.8682
#
# Epoch 00005: val_acc_top50 improved from 0.85307 to 0.86823, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 6/2000
#  - 691s - loss: 2.9674 - sparse_categorical_accuracy: 0.5127 - acc_top10: 0.7870 - acc_top50: 0.8599 - val_loss: 2.6775 - val_sparse_categorical_accuracy: 0.5717 - val_acc_top10: 0.8236 - val_acc_top50: 0.8782
#
# Epoch 00006: val_acc_top50 improved from 0.86823 to 0.87819, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 7/2000
#  - 692s - loss: 2.8321 - sparse_categorical_accuracy: 0.5290 - acc_top10: 0.8010 - acc_top50: 0.8705 - val_loss: 2.5365 - val_sparse_categorical_accuracy: 0.5848 - val_acc_top10: 0.8334 - val_acc_top50: 0.8854
#
# Epoch 00007: val_acc_top50 improved from 0.87819 to 0.88539, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 8/2000
#  - 691s - loss: 2.7201 - sparse_categorical_accuracy: 0.5433 - acc_top10: 0.8133 - acc_top50: 0.8789 - val_loss: 2.6221 - val_sparse_categorical_accuracy: 0.5975 - val_acc_top10: 0.8424 - val_acc_top50: 0.8909
#
# Epoch 00008: val_acc_top50 improved from 0.88539 to 0.89091, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 9/2000
#  - 690s - loss: 2.6287 - sparse_categorical_accuracy: 0.5554 - acc_top10: 0.8224 - acc_top50: 0.8858 - val_loss: 2.4388 - val_sparse_categorical_accuracy: 0.6103 - val_acc_top10: 0.8508 - val_acc_top50: 0.8946
#
# Epoch 00009: val_acc_top50 improved from 0.89091 to 0.89456, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 10/2000
#  - 691s - loss: 2.5503 - sparse_categorical_accuracy: 0.5667 - acc_top10: 0.8309 - acc_top50: 0.8911 - val_loss: 2.2930 - val_sparse_categorical_accuracy: 0.6183 - val_acc_top10: 0.8564 - val_acc_top50: 0.8982
#
# Epoch 00010: val_acc_top50 improved from 0.89456 to 0.89815, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 11/2000
#  - 692s - loss: 2.4828 - sparse_categorical_accuracy: 0.5755 - acc_top10: 0.8379 - acc_top50: 0.8961 - val_loss: 2.4416 - val_sparse_categorical_accuracy: 0.6262 - val_acc_top10: 0.8607 - val_acc_top50: 0.9008
#
# Epoch 00011: val_acc_top50 improved from 0.89815 to 0.90082, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 12/2000
#  - 691s - loss: 2.4243 - sparse_categorical_accuracy: 0.5842 - acc_top10: 0.8439 - acc_top50: 0.8998 - val_loss: 2.3256 - val_sparse_categorical_accuracy: 0.6344 - val_acc_top10: 0.8650 - val_acc_top50: 0.9034
#
# Epoch 00012: val_acc_top50 improved from 0.90082 to 0.90344, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 13/2000
#  - 690s - loss: 2.3696 - sparse_categorical_accuracy: 0.5919 - acc_top10: 0.8495 - acc_top50: 0.9035 - val_loss: 2.0593 - val_sparse_categorical_accuracy: 0.6387 - val_acc_top10: 0.8690 - val_acc_top50: 0.9055
#
# Epoch 00013: val_acc_top50 improved from 0.90344 to 0.90548, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 14/2000
#  - 692s - loss: 2.3218 - sparse_categorical_accuracy: 0.5984 - acc_top10: 0.8545 - acc_top50: 0.9065 - val_loss: 2.1263 - val_sparse_categorical_accuracy: 0.6446 - val_acc_top10: 0.8724 - val_acc_top50: 0.9072
#
# Epoch 00014: val_acc_top50 improved from 0.90548 to 0.90721, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 15/2000
#  - 691s - loss: 2.2769 - sparse_categorical_accuracy: 0.6052 - acc_top10: 0.8590 - acc_top50: 0.9091 - val_loss: 2.0892 - val_sparse_categorical_accuracy: 0.6471 - val_acc_top10: 0.8753 - val_acc_top50: 0.9084
#
# Epoch 00015: val_acc_top50 improved from 0.90721 to 0.90839, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 16/2000
#  - 690s - loss: 2.2356 - sparse_categorical_accuracy: 0.6112 - acc_top10: 0.8632 - acc_top50: 0.9118 - val_loss: 2.3706 - val_sparse_categorical_accuracy: 0.6528 - val_acc_top10: 0.8778 - val_acc_top50: 0.9097
#
# Epoch 00016: val_acc_top50 improved from 0.90839 to 0.90971, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 17/2000
#  - 691s - loss: 2.1983 - sparse_categorical_accuracy: 0.6164 - acc_top10: 0.8667 - acc_top50: 0.9139 - val_loss: 2.3098 - val_sparse_categorical_accuracy: 0.6573 - val_acc_top10: 0.8805 - val_acc_top50: 0.9111
#
# Epoch 00017: val_acc_top50 improved from 0.90971 to 0.91113, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 18/2000
#  - 693s - loss: 2.1592 - sparse_categorical_accuracy: 0.6222 - acc_top10: 0.8702 - acc_top50: 0.9159 - val_loss: 2.1326 - val_sparse_categorical_accuracy: 0.6604 - val_acc_top10: 0.8817 - val_acc_top50: 0.9123
#
# Epoch 00018: val_acc_top50 improved from 0.91113 to 0.91233, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 19/2000
#  - 690s - loss: 2.1234 - sparse_categorical_accuracy: 0.6273 - acc_top10: 0.8731 - acc_top50: 0.9179 - val_loss: 1.9633 - val_sparse_categorical_accuracy: 0.6636 - val_acc_top10: 0.8837 - val_acc_top50: 0.9137
#
# Epoch 00019: val_acc_top50 improved from 0.91233 to 0.91365, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 20/2000
#  - 692s - loss: 2.0910 - sparse_categorical_accuracy: 0.6312 - acc_top10: 0.8762 - acc_top50: 0.9198 - val_loss: 2.0876 - val_sparse_categorical_accuracy: 0.6670 - val_acc_top10: 0.8857 - val_acc_top50: 0.9151
#
# Epoch 00020: val_acc_top50 improved from 0.91365 to 0.91512, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 21/2000
#  - 690s - loss: 2.0552 - sparse_categorical_accuracy: 0.6351 - acc_top10: 0.8791 - acc_top50: 0.9216 - val_loss: 1.9873 - val_sparse_categorical_accuracy: 0.6702 - val_acc_top10: 0.8868 - val_acc_top50: 0.9158
#
# Epoch 00021: val_acc_top50 improved from 0.91512 to 0.91578, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 22/2000
#  - 693s - loss: 2.0255 - sparse_categorical_accuracy: 0.6396 - acc_top10: 0.8819 - acc_top50: 0.9232 - val_loss: 1.9741 - val_sparse_categorical_accuracy: 0.6724 - val_acc_top10: 0.8881 - val_acc_top50: 0.9171
#
# Epoch 00022: val_acc_top50 improved from 0.91578 to 0.91711, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 23/2000
#  - 692s - loss: 1.9924 - sparse_categorical_accuracy: 0.6434 - acc_top10: 0.8843 - acc_top50: 0.9251 - val_loss: 2.0238 - val_sparse_categorical_accuracy: 0.6742 - val_acc_top10: 0.8898 - val_acc_top50: 0.9181
#
# Epoch 00023: val_acc_top50 improved from 0.91711 to 0.91812, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 24/2000
#  - 690s - loss: 1.9619 - sparse_categorical_accuracy: 0.6474 - acc_top10: 0.8867 - acc_top50: 0.9266 - val_loss: 2.2149 - val_sparse_categorical_accuracy: 0.6758 - val_acc_top10: 0.8912 - val_acc_top50: 0.9188
#
# Epoch 00024: val_acc_top50 improved from 0.91812 to 0.91879, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 25/2000
#  - 692s - loss: 1.9309 - sparse_categorical_accuracy: 0.6511 - acc_top10: 0.8891 - acc_top50: 0.9282 - val_loss: 2.1106 - val_sparse_categorical_accuracy: 0.6775 - val_acc_top10: 0.8922 - val_acc_top50: 0.9200
#
# Epoch 00025: val_acc_top50 improved from 0.91879 to 0.91999, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 26/2000
#  - 691s - loss: 1.9034 - sparse_categorical_accuracy: 0.6544 - acc_top10: 0.8910 - acc_top50: 0.9297 - val_loss: 2.0875 - val_sparse_categorical_accuracy: 0.6801 - val_acc_top10: 0.8938 - val_acc_top50: 0.9207
#
# Epoch 00026: val_acc_top50 improved from 0.91999 to 0.92073, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 27/2000
#  - 691s - loss: 1.8755 - sparse_categorical_accuracy: 0.6572 - acc_top10: 0.8930 - acc_top50: 0.9311 - val_loss: 1.9888 - val_sparse_categorical_accuracy: 0.6824 - val_acc_top10: 0.8944 - val_acc_top50: 0.9218
#
# Epoch 00027: val_acc_top50 improved from 0.92073 to 0.92184, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 28/2000
#  - 691s - loss: 1.8484 - sparse_categorical_accuracy: 0.6603 - acc_top10: 0.8950 - acc_top50: 0.9327 - val_loss: 2.0930 - val_sparse_categorical_accuracy: 0.6834 - val_acc_top10: 0.8955 - val_acc_top50: 0.9229
#
# Epoch 00028: val_acc_top50 improved from 0.92184 to 0.92285, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 29/2000
#  - 691s - loss: 1.8210 - sparse_categorical_accuracy: 0.6639 - acc_top10: 0.8972 - acc_top50: 0.9342 - val_loss: 1.9842 - val_sparse_categorical_accuracy: 0.6861 - val_acc_top10: 0.8972 - val_acc_top50: 0.9236
#
# Epoch 00029: val_acc_top50 improved from 0.92285 to 0.92362, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 30/2000
#  - 691s - loss: 1.8005 - sparse_categorical_accuracy: 0.6660 - acc_top10: 0.8985 - acc_top50: 0.9354 - val_loss: 1.7100 - val_sparse_categorical_accuracy: 0.6880 - val_acc_top10: 0.8976 - val_acc_top50: 0.9250
#
# Epoch 00030: val_acc_top50 improved from 0.92362 to 0.92496, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 31/2000
#  - 690s - loss: 1.7758 - sparse_categorical_accuracy: 0.6688 - acc_top10: 0.9003 - acc_top50: 0.9368 - val_loss: 1.8549 - val_sparse_categorical_accuracy: 0.6885 - val_acc_top10: 0.8991 - val_acc_top50: 0.9258
#
# Epoch 00031: val_acc_top50 improved from 0.92496 to 0.92577, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 32/2000
#  - 690s - loss: 1.7518 - sparse_categorical_accuracy: 0.6716 - acc_top10: 0.9018 - acc_top50: 0.9381 - val_loss: 1.9236 - val_sparse_categorical_accuracy: 0.6905 - val_acc_top10: 0.8999 - val_acc_top50: 0.9266
#
# Epoch 00032: val_acc_top50 improved from 0.92577 to 0.92658, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 33/2000
#  - 690s - loss: 1.7337 - sparse_categorical_accuracy: 0.6735 - acc_top10: 0.9032 - acc_top50: 0.9393 - val_loss: 1.9097 - val_sparse_categorical_accuracy: 0.6921 - val_acc_top10: 0.9008 - val_acc_top50: 0.9274
#
# Epoch 00033: val_acc_top50 improved from 0.92658 to 0.92739, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 34/2000
#  - 691s - loss: 1.7117 - sparse_categorical_accuracy: 0.6764 - acc_top10: 0.9050 - acc_top50: 0.9402 - val_loss: 1.7800 - val_sparse_categorical_accuracy: 0.6938 - val_acc_top10: 0.9014 - val_acc_top50: 0.9281
#
# Epoch 00034: val_acc_top50 improved from 0.92739 to 0.92808, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 35/2000
#  - 690s - loss: 1.6950 - sparse_categorical_accuracy: 0.6780 - acc_top10: 0.9062 - acc_top50: 0.9413 - val_loss: 1.9594 - val_sparse_categorical_accuracy: 0.6944 - val_acc_top10: 0.9021 - val_acc_top50: 0.9288
#
# Epoch 00035: val_acc_top50 improved from 0.92808 to 0.92884, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 36/2000
#  - 690s - loss: 1.6763 - sparse_categorical_accuracy: 0.6804 - acc_top10: 0.9073 - acc_top50: 0.9426 - val_loss: 1.8478 - val_sparse_categorical_accuracy: 0.6943 - val_acc_top10: 0.9031 - val_acc_top50: 0.9293
#
# Epoch 00036: val_acc_top50 improved from 0.92884 to 0.92934, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 37/2000
#  - 691s - loss: 1.6569 - sparse_categorical_accuracy: 0.6825 - acc_top10: 0.9087 - acc_top50: 0.9433 - val_loss: 1.7100 - val_sparse_categorical_accuracy: 0.6945 - val_acc_top10: 0.9040 - val_acc_top50: 0.9302
#
# Epoch 00037: val_acc_top50 improved from 0.92934 to 0.93019, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 38/2000
#  - 690s - loss: 1.6415 - sparse_categorical_accuracy: 0.6840 - acc_top10: 0.9100 - acc_top50: 0.9442 - val_loss: 1.8817 - val_sparse_categorical_accuracy: 0.6968 - val_acc_top10: 0.9044 - val_acc_top50: 0.9309
#
# Epoch 00038: val_acc_top50 improved from 0.93019 to 0.93094, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 39/2000
#  - 691s - loss: 1.6255 - sparse_categorical_accuracy: 0.6863 - acc_top10: 0.9113 - acc_top50: 0.9452 - val_loss: 1.8372 - val_sparse_categorical_accuracy: 0.6976 - val_acc_top10: 0.9049 - val_acc_top50: 0.9316
#
# Epoch 00039: val_acc_top50 improved from 0.93094 to 0.93161, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 40/2000
#  - 691s - loss: 1.6104 - sparse_categorical_accuracy: 0.6876 - acc_top10: 0.9123 - acc_top50: 0.9459 - val_loss: 1.7167 - val_sparse_categorical_accuracy: 0.6972 - val_acc_top10: 0.9053 - val_acc_top50: 0.9321
#
# Epoch 00040: val_acc_top50 improved from 0.93161 to 0.93207, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 41/2000
#  - 691s - loss: 1.5958 - sparse_categorical_accuracy: 0.6898 - acc_top10: 0.9136 - acc_top50: 0.9466 - val_loss: 1.8463 - val_sparse_categorical_accuracy: 0.6983 - val_acc_top10: 0.9065 - val_acc_top50: 0.9330
#
# Epoch 00041: val_acc_top50 improved from 0.93207 to 0.93296, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 42/2000
#  - 691s - loss: 1.5860 - sparse_categorical_accuracy: 0.6910 - acc_top10: 0.9141 - acc_top50: 0.9471 - val_loss: 1.8761 - val_sparse_categorical_accuracy: 0.7011 - val_acc_top10: 0.9069 - val_acc_top50: 0.9332
#
# Epoch 00042: val_acc_top50 improved from 0.93296 to 0.93317, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 43/2000
#  - 689s - loss: 1.5712 - sparse_categorical_accuracy: 0.6928 - acc_top10: 0.9151 - acc_top50: 0.9480 - val_loss: 1.7616 - val_sparse_categorical_accuracy: 0.6996 - val_acc_top10: 0.9076 - val_acc_top50: 0.9340
#
# Epoch 00043: val_acc_top50 improved from 0.93317 to 0.93404, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 44/2000
#  - 689s - loss: 1.5601 - sparse_categorical_accuracy: 0.6942 - acc_top10: 0.9159 - acc_top50: 0.9485 - val_loss: 1.7001 - val_sparse_categorical_accuracy: 0.6998 - val_acc_top10: 0.9080 - val_acc_top50: 0.9344
#
# Epoch 00044: val_acc_top50 improved from 0.93404 to 0.93437, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 45/2000
#  - 689s - loss: 1.5502 - sparse_categorical_accuracy: 0.6954 - acc_top10: 0.9167 - acc_top50: 0.9491 - val_loss: 1.7347 - val_sparse_categorical_accuracy: 0.7013 - val_acc_top10: 0.9082 - val_acc_top50: 0.9343
#
# Epoch 00045: val_acc_top50 did not improve from 0.93437
# Epoch 46/2000
#  - 690s - loss: 1.5383 - sparse_categorical_accuracy: 0.6967 - acc_top10: 0.9175 - acc_top50: 0.9498 - val_loss: 1.5144 - val_sparse_categorical_accuracy: 0.7030 - val_acc_top10: 0.9089 - val_acc_top50: 0.9350
#
# Epoch 00046: val_acc_top50 improved from 0.93437 to 0.93503, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 47/2000
#  - 692s - loss: 1.5284 - sparse_categorical_accuracy: 0.6983 - acc_top10: 0.9185 - acc_top50: 0.9502 - val_loss: 1.7433 - val_sparse_categorical_accuracy: 0.7033 - val_acc_top10: 0.9093 - val_acc_top50: 0.9351
#
# Epoch 00047: val_acc_top50 improved from 0.93503 to 0.93513, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 48/2000
#  - 690s - loss: 1.5193 - sparse_categorical_accuracy: 0.6996 - acc_top10: 0.9189 - acc_top50: 0.9506 - val_loss: 1.9161 - val_sparse_categorical_accuracy: 0.7035 - val_acc_top10: 0.9093 - val_acc_top50: 0.9357
#
# Epoch 00048: val_acc_top50 improved from 0.93513 to 0.93572, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 49/2000
#  - 691s - loss: 1.5098 - sparse_categorical_accuracy: 0.7012 - acc_top10: 0.9198 - acc_top50: 0.9512 - val_loss: 1.7461 - val_sparse_categorical_accuracy: 0.7033 - val_acc_top10: 0.9097 - val_acc_top50: 0.9359
#
# Epoch 00049: val_acc_top50 improved from 0.93572 to 0.93594, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 50/2000
#  - 689s - loss: 1.5001 - sparse_categorical_accuracy: 0.7023 - acc_top10: 0.9202 - acc_top50: 0.9517 - val_loss: 1.6936 - val_sparse_categorical_accuracy: 0.7038 - val_acc_top10: 0.9100 - val_acc_top50: 0.9362
#
# Epoch 00050: val_acc_top50 improved from 0.93594 to 0.93623, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 51/2000
#  - 691s - loss: 1.4924 - sparse_categorical_accuracy: 0.7032 - acc_top10: 0.9205 - acc_top50: 0.9519 - val_loss: 1.7755 - val_sparse_categorical_accuracy: 0.7041 - val_acc_top10: 0.9106 - val_acc_top50: 0.9366
#
# Epoch 00051: val_acc_top50 improved from 0.93623 to 0.93656, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 52/2000
#  - 691s - loss: 1.4847 - sparse_categorical_accuracy: 0.7050 - acc_top10: 0.9212 - acc_top50: 0.9525 - val_loss: 1.6561 - val_sparse_categorical_accuracy: 0.7057 - val_acc_top10: 0.9107 - val_acc_top50: 0.9370
#
# Epoch 00052: val_acc_top50 improved from 0.93656 to 0.93696, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 53/2000
#  - 691s - loss: 1.4781 - sparse_categorical_accuracy: 0.7053 - acc_top10: 0.9218 - acc_top50: 0.9530 - val_loss: 1.6738 - val_sparse_categorical_accuracy: 0.7063 - val_acc_top10: 0.9108 - val_acc_top50: 0.9374
#
# Epoch 00053: val_acc_top50 improved from 0.93696 to 0.93738, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 54/2000
#  - 689s - loss: 1.4682 - sparse_categorical_accuracy: 0.7068 - acc_top10: 0.9226 - acc_top50: 0.9536 - val_loss: 1.6031 - val_sparse_categorical_accuracy: 0.7067 - val_acc_top10: 0.9113 - val_acc_top50: 0.9375
#
# Epoch 00054: val_acc_top50 improved from 0.93738 to 0.93748, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 55/2000
#  - 689s - loss: 1.4632 - sparse_categorical_accuracy: 0.7071 - acc_top10: 0.9231 - acc_top50: 0.9538 - val_loss: 1.6109 - val_sparse_categorical_accuracy: 0.7047 - val_acc_top10: 0.9118 - val_acc_top50: 0.9380
#
# Epoch 00055: val_acc_top50 improved from 0.93748 to 0.93800, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 56/2000
#  - 691s - loss: 1.4546 - sparse_categorical_accuracy: 0.7094 - acc_top10: 0.9234 - acc_top50: 0.9540 - val_loss: 1.8092 - val_sparse_categorical_accuracy: 0.7062 - val_acc_top10: 0.9116 - val_acc_top50: 0.9379
#
# Epoch 00056: val_acc_top50 did not improve from 0.93800
# Epoch 57/2000
#  - 693s - loss: 1.4517 - sparse_categorical_accuracy: 0.7100 - acc_top10: 0.9233 - acc_top50: 0.9543 - val_loss: 1.9713 - val_sparse_categorical_accuracy: 0.7080 - val_acc_top10: 0.9121 - val_acc_top50: 0.9382
#
# Epoch 00057: val_acc_top50 improved from 0.93800 to 0.93817, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 58/2000
#  - 692s - loss: 1.4429 - sparse_categorical_accuracy: 0.7108 - acc_top10: 0.9243 - acc_top50: 0.9546 - val_loss: 1.7387 - val_sparse_categorical_accuracy: 0.7072 - val_acc_top10: 0.9114 - val_acc_top50: 0.9381
#
# Epoch 00058: val_acc_top50 did not improve from 0.93817
# Epoch 59/2000
#  - 691s - loss: 1.4399 - sparse_categorical_accuracy: 0.7110 - acc_top10: 0.9243 - acc_top50: 0.9548 - val_loss: 1.7182 - val_sparse_categorical_accuracy: 0.7088 - val_acc_top10: 0.9120 - val_acc_top50: 0.9383
#
# Epoch 00059: val_acc_top50 improved from 0.93817 to 0.93830, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 60/2000
#  - 689s - loss: 1.4317 - sparse_categorical_accuracy: 0.7123 - acc_top10: 0.9250 - acc_top50: 0.9552 - val_loss: 1.6722 - val_sparse_categorical_accuracy: 0.7091 - val_acc_top10: 0.9122 - val_acc_top50: 0.9383
#
# Epoch 00060: val_acc_top50 improved from 0.93830 to 0.93835, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 61/2000
#  - 690s - loss: 1.4273 - sparse_categorical_accuracy: 0.7136 - acc_top10: 0.9252 - acc_top50: 0.9555 - val_loss: 1.9616 - val_sparse_categorical_accuracy: 0.7074 - val_acc_top10: 0.9125 - val_acc_top50: 0.9385
#
# Epoch 00061: val_acc_top50 improved from 0.93835 to 0.93850, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 62/2000
#  - 692s - loss: 1.4207 - sparse_categorical_accuracy: 0.7144 - acc_top10: 0.9260 - acc_top50: 0.9560 - val_loss: 1.7584 - val_sparse_categorical_accuracy: 0.7083 - val_acc_top10: 0.9124 - val_acc_top50: 0.9386
#
# Epoch 00062: val_acc_top50 improved from 0.93850 to 0.93862, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 63/2000
#  - 691s - loss: 1.4164 - sparse_categorical_accuracy: 0.7153 - acc_top10: 0.9259 - acc_top50: 0.9560 - val_loss: 1.7316 - val_sparse_categorical_accuracy: 0.7069 - val_acc_top10: 0.9129 - val_acc_top50: 0.9388
#
# Epoch 00063: val_acc_top50 improved from 0.93862 to 0.93881, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 64/2000
#  - 689s - loss: 1.4136 - sparse_categorical_accuracy: 0.7157 - acc_top10: 0.9263 - acc_top50: 0.9561 - val_loss: 1.8540 - val_sparse_categorical_accuracy: 0.7093 - val_acc_top10: 0.9134 - val_acc_top50: 0.9390
#
# Epoch 00064: val_acc_top50 improved from 0.93881 to 0.93903, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 65/2000
#  - 690s - loss: 1.4090 - sparse_categorical_accuracy: 0.7158 - acc_top10: 0.9268 - acc_top50: 0.9565 - val_loss: 1.7018 - val_sparse_categorical_accuracy: 0.7096 - val_acc_top10: 0.9134 - val_acc_top50: 0.9390
#
# Epoch 00065: val_acc_top50 did not improve from 0.93903
# Epoch 66/2000
#  - 690s - loss: 1.4037 - sparse_categorical_accuracy: 0.7172 - acc_top10: 0.9270 - acc_top50: 0.9566 - val_loss: 1.7823 - val_sparse_categorical_accuracy: 0.7078 - val_acc_top10: 0.9132 - val_acc_top50: 0.9391
#
# Epoch 00066: val_acc_top50 improved from 0.93903 to 0.93905, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 67/2000
#  - 691s - loss: 1.3962 - sparse_categorical_accuracy: 0.7185 - acc_top10: 0.9276 - acc_top50: 0.9570 - val_loss: 1.8283 - val_sparse_categorical_accuracy: 0.7096 - val_acc_top10: 0.9134 - val_acc_top50: 0.9392
#
# Epoch 00067: val_acc_top50 improved from 0.93905 to 0.93919, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 68/2000
#  - 690s - loss: 1.3933 - sparse_categorical_accuracy: 0.7194 - acc_top10: 0.9276 - acc_top50: 0.9569 - val_loss: 1.6900 - val_sparse_categorical_accuracy: 0.7109 - val_acc_top10: 0.9141 - val_acc_top50: 0.9396
#
# Epoch 00068: val_acc_top50 improved from 0.93919 to 0.93965, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 69/2000
#  - 689s - loss: 1.3888 - sparse_categorical_accuracy: 0.7196 - acc_top10: 0.9279 - acc_top50: 0.9574 - val_loss: 1.7847 - val_sparse_categorical_accuracy: 0.7102 - val_acc_top10: 0.9135 - val_acc_top50: 0.9398
#
# Epoch 00069: val_acc_top50 improved from 0.93965 to 0.93984, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 70/2000
#  - 690s - loss: 1.3844 - sparse_categorical_accuracy: 0.7207 - acc_top10: 0.9283 - acc_top50: 0.9575 - val_loss: 1.8853 - val_sparse_categorical_accuracy: 0.7098 - val_acc_top10: 0.9135 - val_acc_top50: 0.9396
#
# Epoch 00070: val_acc_top50 did not improve from 0.93984
# Epoch 71/2000
#  - 690s - loss: 1.3826 - sparse_categorical_accuracy: 0.7207 - acc_top10: 0.9285 - acc_top50: 0.9576 - val_loss: 1.7661 - val_sparse_categorical_accuracy: 0.7105 - val_acc_top10: 0.9139 - val_acc_top50: 0.9396
#
# Epoch 00071: val_acc_top50 did not improve from 0.93984
# Epoch 72/2000
#  - 690s - loss: 1.3771 - sparse_categorical_accuracy: 0.7217 - acc_top10: 0.9287 - acc_top50: 0.9579 - val_loss: 1.7134 - val_sparse_categorical_accuracy: 0.7106 - val_acc_top10: 0.9139 - val_acc_top50: 0.9398
#
# Epoch 00072: val_acc_top50 did not improve from 0.93984
# Epoch 73/2000
#  - 691s - loss: 1.3729 - sparse_categorical_accuracy: 0.7227 - acc_top10: 0.9292 - acc_top50: 0.9580 - val_loss: 1.9443 - val_sparse_categorical_accuracy: 0.7105 - val_acc_top10: 0.9139 - val_acc_top50: 0.9398
#
# Epoch 00073: val_acc_top50 did not improve from 0.93984
# Epoch 74/2000
#  - 690s - loss: 1.3678 - sparse_categorical_accuracy: 0.7237 - acc_top10: 0.9294 - acc_top50: 0.9582 - val_loss: 1.6530 - val_sparse_categorical_accuracy: 0.7114 - val_acc_top10: 0.9142 - val_acc_top50: 0.9401
#
# Epoch 00074: val_acc_top50 improved from 0.93984 to 0.94013, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 75/2000
#  - 690s - loss: 1.3648 - sparse_categorical_accuracy: 0.7243 - acc_top10: 0.9296 - acc_top50: 0.9583 - val_loss: 1.6245 - val_sparse_categorical_accuracy: 0.7113 - val_acc_top10: 0.9142 - val_acc_top50: 0.9399
#
# Epoch 00075: val_acc_top50 did not improve from 0.94013
# Epoch 76/2000
#  - 691s - loss: 1.3626 - sparse_categorical_accuracy: 0.7244 - acc_top10: 0.9296 - acc_top50: 0.9585 - val_loss: 1.8449 - val_sparse_categorical_accuracy: 0.7118 - val_acc_top10: 0.9143 - val_acc_top50: 0.9399
#
# Epoch 00076: val_acc_top50 did not improve from 0.94013
# Epoch 77/2000
#  - 691s - loss: 1.3570 - sparse_categorical_accuracy: 0.7253 - acc_top10: 0.9300 - acc_top50: 0.9586 - val_loss: 2.0900 - val_sparse_categorical_accuracy: 0.7110 - val_acc_top10: 0.9152 - val_acc_top50: 0.9400
#
# Epoch 00077: val_acc_top50 did not improve from 0.94013
# Epoch 78/2000
#  - 691s - loss: 1.3546 - sparse_categorical_accuracy: 0.7262 - acc_top10: 0.9302 - acc_top50: 0.9586 - val_loss: 1.8277 - val_sparse_categorical_accuracy: 0.7118 - val_acc_top10: 0.9145 - val_acc_top50: 0.9401
#
# Epoch 00078: val_acc_top50 improved from 0.94013 to 0.94015, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 79/2000
#  - 691s - loss: 1.3516 - sparse_categorical_accuracy: 0.7264 - acc_top10: 0.9305 - acc_top50: 0.9590 - val_loss: 1.6747 - val_sparse_categorical_accuracy: 0.7119 - val_acc_top10: 0.9147 - val_acc_top50: 0.9403
#
# Epoch 00079: val_acc_top50 improved from 0.94015 to 0.94026, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 80/2000
#  - 689s - loss: 1.3478 - sparse_categorical_accuracy: 0.7273 - acc_top10: 0.9307 - acc_top50: 0.9592 - val_loss: 1.8017 - val_sparse_categorical_accuracy: 0.7114 - val_acc_top10: 0.9149 - val_acc_top50: 0.9399
#
# Epoch 00080: val_acc_top50 did not improve from 0.94026
# Epoch 81/2000
#  - 692s - loss: 1.3454 - sparse_categorical_accuracy: 0.7279 - acc_top10: 0.9306 - acc_top50: 0.9593 - val_loss: 1.8430 - val_sparse_categorical_accuracy: 0.7112 - val_acc_top10: 0.9146 - val_acc_top50: 0.9399
#
# Epoch 00081: val_acc_top50 did not improve from 0.94026
# Epoch 82/2000
#  - 691s - loss: 1.3443 - sparse_categorical_accuracy: 0.7279 - acc_top10: 0.9310 - acc_top50: 0.9591 - val_loss: 1.9164 - val_sparse_categorical_accuracy: 0.7112 - val_acc_top10: 0.9148 - val_acc_top50: 0.9402
#
# Epoch 00082: val_acc_top50 did not improve from 0.94026
# Epoch 83/2000
#  - 690s - loss: 1.3411 - sparse_categorical_accuracy: 0.7288 - acc_top10: 0.9311 - acc_top50: 0.9593 - val_loss: 1.9952 - val_sparse_categorical_accuracy: 0.7111 - val_acc_top10: 0.9147 - val_acc_top50: 0.9403
#
# Epoch 00083: val_acc_top50 did not improve from 0.94026
# Epoch 84/2000
#  - 691s - loss: 1.3357 - sparse_categorical_accuracy: 0.7298 - acc_top10: 0.9314 - acc_top50: 0.9594 - val_loss: 1.7537 - val_sparse_categorical_accuracy: 0.7103 - val_acc_top10: 0.9143 - val_acc_top50: 0.9398
#
# Epoch 00084: val_acc_top50 did not improve from 0.94026
# Epoch 85/2000
#  - 692s - loss: 1.3334 - sparse_categorical_accuracy: 0.7304 - acc_top10: 0.9317 - acc_top50: 0.9596 - val_loss: 1.7622 - val_sparse_categorical_accuracy: 0.7115 - val_acc_top10: 0.9145 - val_acc_top50: 0.9399
#
# Epoch 00085: val_acc_top50 did not improve from 0.94026
# Epoch 00085: early stopping

# %%
from negative_policy import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=5, 
                    use_multiprocessing=True, 
#                    max_queue_size = 5, 
#                    shuffle=False,
                    callbacks=[earlystop, checkpoint]
                    )
# Out:
# RDKit WARNING: [14:32:44] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 1157756it [00:04, 259467.08it/s]
# expansion: 55608it [00:00, 714582.46it/s]
# expansion training...
# data prep: 100%|██████████| 1136741/1136741 [00:00<00:00, 1163013.38it/s]
# total reactions: 100%|██████████| 1136741/1136741 [00:00<00:00, 2028086.78it/s]
# total products: 1136741
# total reactions: 1157285
# Training size: 1026999
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 23086)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               11820544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_1 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_2 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_3 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_4 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_5 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 55608)             28526904
# =================================================================
# Total params: 42,974,008
# Trainable params: 42,974,008
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/2000
#  - 752s - loss: 6.3925 - sparse_categorical_accuracy: 0.1282 - acc_top10: 0.3535 - acc_top50: 0.5235 - sparse_categorical_crossentropy: 6.3925 - val_loss: 5.1117 - val_sparse_categorical_accuracy: 0.3001 - val_acc_top10: 0.5648 - val_acc_top50: 0.6873 - val_sparse_categorical_crossentropy: 4.8392
#
# Epoch 00001: val_acc_top50 improved from -inf to 0.68728, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 2/2000
#  - 694s - loss: 4.5270 - sparse_categorical_accuracy: 0.3327 - acc_top10: 0.6102 - acc_top50: 0.7247 - sparse_categorical_crossentropy: 4.5270 - val_loss: 3.6793 - val_sparse_categorical_accuracy: 0.4272 - val_acc_top10: 0.6896 - val_acc_top50: 0.7792 - val_sparse_categorical_crossentropy: 3.8469
#
# Epoch 00002: val_acc_top50 improved from 0.68728 to 0.77917, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 3/2000
#  - 696s - loss: 3.8301 - sparse_categorical_accuracy: 0.4147 - acc_top10: 0.6925 - acc_top50: 0.7881 - sparse_categorical_crossentropy: 3.8301 - val_loss: 3.4211 - val_sparse_categorical_accuracy: 0.4858 - val_acc_top10: 0.7463 - val_acc_top50: 0.8256 - val_sparse_categorical_crossentropy: 3.3585
#
# Epoch 00003: val_acc_top50 improved from 0.77917 to 0.82562, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 4/2000
#  - 697s - loss: 3.4342 - sparse_categorical_accuracy: 0.4592 - acc_top10: 0.7363 - acc_top50: 0.8222 - sparse_categorical_crossentropy: 3.4342 - val_loss: 3.0091 - val_sparse_categorical_accuracy: 0.5247 - val_acc_top10: 0.7825 - val_acc_top50: 0.8500 - val_sparse_categorical_crossentropy: 3.0568
#
# Epoch 00004: val_acc_top50 improved from 0.82562 to 0.85000, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 5/2000
#  - 696s - loss: 3.1779 - sparse_categorical_accuracy: 0.4890 - acc_top10: 0.7635 - acc_top50: 0.8427 - sparse_categorical_crossentropy: 3.1779 - val_loss: 3.0723 - val_sparse_categorical_accuracy: 0.5502 - val_acc_top10: 0.8043 - val_acc_top50: 0.8650 - val_sparse_categorical_crossentropy: 2.8663
#
# Epoch 00005: val_acc_top50 improved from 0.85000 to 0.86497, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 6/2000
#  - 695s - loss: 2.9948 - sparse_categorical_accuracy: 0.5103 - acc_top10: 0.7828 - acc_top50: 0.8574 - sparse_categorical_crossentropy: 2.9948 - val_loss: 2.8402 - val_sparse_categorical_accuracy: 0.5687 - val_acc_top10: 0.8193 - val_acc_top50: 0.8753 - val_sparse_categorical_crossentropy: 2.7246
#
# Epoch 00006: val_acc_top50 improved from 0.86497 to 0.87531, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 7/2000
#  - 696s - loss: 2.8545 - sparse_categorical_accuracy: 0.5279 - acc_top10: 0.7981 - acc_top50: 0.8684 - sparse_categorical_crossentropy: 2.8545 - val_loss: 2.7747 - val_sparse_categorical_accuracy: 0.5832 - val_acc_top10: 0.8317 - val_acc_top50: 0.8828 - val_sparse_categorical_crossentropy: 2.6172
#
# Epoch 00007: val_acc_top50 improved from 0.87531 to 0.88276, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 8/2000
#  - 694s - loss: 2.7425 - sparse_categorical_accuracy: 0.5416 - acc_top10: 0.8101 - acc_top50: 0.8770 - sparse_categorical_crossentropy: 2.7425 - val_loss: 2.6602 - val_sparse_categorical_accuracy: 0.5939 - val_acc_top10: 0.8408 - val_acc_top50: 0.8883 - val_sparse_categorical_crossentropy: 2.5361
#
# Epoch 00008: val_acc_top50 improved from 0.88276 to 0.88833, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 9/2000
#  - 694s - loss: 2.6485 - sparse_categorical_accuracy: 0.5541 - acc_top10: 0.8203 - acc_top50: 0.8840 - sparse_categorical_crossentropy: 2.6485 - val_loss: 2.2950 - val_sparse_categorical_accuracy: 0.6072 - val_acc_top10: 0.8479 - val_acc_top50: 0.8929 - val_sparse_categorical_crossentropy: 2.4631
#
# Epoch 00009: val_acc_top50 improved from 0.88833 to 0.89293, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 10/2000
#  - 693s - loss: 2.5667 - sparse_categorical_accuracy: 0.5653 - acc_top10: 0.8288 - acc_top50: 0.8897 - sparse_categorical_crossentropy: 2.5667 - val_loss: 2.4398 - val_sparse_categorical_accuracy: 0.6160 - val_acc_top10: 0.8538 - val_acc_top50: 0.8970 - val_sparse_categorical_crossentropy: 2.4057
#
# Epoch 00010: val_acc_top50 improved from 0.89293 to 0.89701, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 11/2000
#  - 693s - loss: 2.4986 - sparse_categorical_accuracy: 0.5748 - acc_top10: 0.8358 - acc_top50: 0.8946 - sparse_categorical_crossentropy: 2.4986 - val_loss: 2.2484 - val_sparse_categorical_accuracy: 0.6222 - val_acc_top10: 0.8590 - val_acc_top50: 0.8998 - val_sparse_categorical_crossentropy: 2.3573
#
# Epoch 00011: val_acc_top50 improved from 0.89701 to 0.89979, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 12/2000
#  - 693s - loss: 2.4372 - sparse_categorical_accuracy: 0.5830 - acc_top10: 0.8424 - acc_top50: 0.8988 - sparse_categorical_crossentropy: 2.4372 - val_loss: 2.2395 - val_sparse_categorical_accuracy: 0.6306 - val_acc_top10: 0.8637 - val_acc_top50: 0.9023 - val_sparse_categorical_crossentropy: 2.3129
#
# Epoch 00012: val_acc_top50 improved from 0.89979 to 0.90232, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 13/2000
#  - 693s - loss: 2.3838 - sparse_categorical_accuracy: 0.5906 - acc_top10: 0.8482 - acc_top50: 0.9022 - sparse_categorical_crossentropy: 2.3838 - val_loss: 2.3521 - val_sparse_categorical_accuracy: 0.6370 - val_acc_top10: 0.8673 - val_acc_top50: 0.9047 - val_sparse_categorical_crossentropy: 2.2721
#
# Epoch 00013: val_acc_top50 improved from 0.90232 to 0.90468, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 14/2000
#  - 692s - loss: 2.3349 - sparse_categorical_accuracy: 0.5977 - acc_top10: 0.8530 - acc_top50: 0.9054 - sparse_categorical_crossentropy: 2.3349 - val_loss: 2.3495 - val_sparse_categorical_accuracy: 0.6432 - val_acc_top10: 0.8700 - val_acc_top50: 0.9060 - val_sparse_categorical_crossentropy: 2.2421
#
# Epoch 00014: val_acc_top50 improved from 0.90468 to 0.90600, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 15/2000
#  - 696s - loss: 2.2881 - sparse_categorical_accuracy: 0.6042 - acc_top10: 0.8577 - acc_top50: 0.9083 - sparse_categorical_crossentropy: 2.2881 - val_loss: 2.2182 - val_sparse_categorical_accuracy: 0.6473 - val_acc_top10: 0.8728 - val_acc_top50: 0.9079 - val_sparse_categorical_crossentropy: 2.2131
#
# Epoch 00015: val_acc_top50 improved from 0.90600 to 0.90787, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 16/2000
#  - 694s - loss: 2.2459 - sparse_categorical_accuracy: 0.6101 - acc_top10: 0.8620 - acc_top50: 0.9107 - sparse_categorical_crossentropy: 2.2459 - val_loss: 2.2252 - val_sparse_categorical_accuracy: 0.6513 - val_acc_top10: 0.8760 - val_acc_top50: 0.9097 - val_sparse_categorical_crossentropy: 2.1812
#
# Epoch 00016: val_acc_top50 improved from 0.90787 to 0.90971, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 17/2000
#  - 700s - loss: 2.2074 - sparse_categorical_accuracy: 0.6160 - acc_top10: 0.8653 - acc_top50: 0.9130 - sparse_categorical_crossentropy: 2.2074 - val_loss: 2.1462 - val_sparse_categorical_accuracy: 0.6560 - val_acc_top10: 0.8781 - val_acc_top50: 0.9106 - val_sparse_categorical_crossentropy: 2.1552
#
# Epoch 00017: val_acc_top50 improved from 0.90971 to 0.91062, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 18/2000
#  - 702s - loss: 2.1673 - sparse_categorical_accuracy: 0.6213 - acc_top10: 0.8693 - acc_top50: 0.9154 - sparse_categorical_crossentropy: 2.1673 - val_loss: 1.8504 - val_sparse_categorical_accuracy: 0.6594 - val_acc_top10: 0.8803 - val_acc_top50: 0.9123 - val_sparse_categorical_crossentropy: 2.1262
#
# Epoch 00018: val_acc_top50 improved from 0.91062 to 0.91230, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 19/2000

# %%
from negative_policy import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=18,
                    workers=2, 
                    use_multiprocessing=True, 
                    max_queue_size = 12, 
#                    shuffle=False,
                    callbacks=[earlystop, checkpoint]
                    )
# Out:
# RDKit WARNING: [18:19:30] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 1157756it [00:04, 258023.25it/s]
# expansion: 55608it [00:00, 723841.27it/s]
# expansion training...
# data prep: 100%|██████████| 1136741/1136741 [00:00<00:00, 1158320.83it/s]
# total reactions: 100%|██████████| 1136741/1136741 [00:00<00:00, 1965043.99it/s]
# total products: 1136741
# total reactions: 1157285
# Training size: 1026999
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 23086)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               11820544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_1 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_2 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_3 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_4 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_5 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 55608)             28526904
# =================================================================
# Total params: 42,974,008
# Trainable params: 42,974,008
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 19/2000
#  - 722s - loss: 2.1289 - sparse_categorical_accuracy: 0.6266 - acc_top10: 0.8727 - acc_top50: 0.9175 - sparse_categorical_crossentropy: 2.1289 - val_loss: 2.3462 - val_sparse_categorical_accuracy: 0.6633 - val_acc_top10: 0.8819 - val_acc_top50: 0.9138 - val_sparse_categorical_crossentropy: 2.1066
#
# Epoch 00019: val_acc_top50 improved from -inf to 0.91379, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 20/2000
#  - 687s - loss: 2.0957 - sparse_categorical_accuracy: 0.6310 - acc_top10: 0.8755 - acc_top50: 0.9195 - sparse_categorical_crossentropy: 2.0957 - val_loss: 2.2101 - val_sparse_categorical_accuracy: 0.6657 - val_acc_top10: 0.8841 - val_acc_top50: 0.9147 - val_sparse_categorical_crossentropy: 2.0778
#
# Epoch 00020: val_acc_top50 improved from 0.91379 to 0.91472, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 21/2000
#  - 687s - loss: 2.0619 - sparse_categorical_accuracy: 0.6349 - acc_top10: 0.8784 - acc_top50: 0.9214 - sparse_categorical_crossentropy: 2.0619 - val_loss: 2.0105 - val_sparse_categorical_accuracy: 0.6692 - val_acc_top10: 0.8859 - val_acc_top50: 0.9159 - val_sparse_categorical_crossentropy: 2.0583
#
# Epoch 00021: val_acc_top50 improved from 0.91472 to 0.91591, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 22/2000
#  - 689s - loss: 2.0305 - sparse_categorical_accuracy: 0.6391 - acc_top10: 0.8809 - acc_top50: 0.9230 - sparse_categorical_crossentropy: 2.0305 - val_loss: 2.0190 - val_sparse_categorical_accuracy: 0.6714 - val_acc_top10: 0.8872 - val_acc_top50: 0.9168 - val_sparse_categorical_crossentropy: 2.0350
#
# Epoch 00022: val_acc_top50 improved from 0.91591 to 0.91679, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 23/2000

# %%
from negative_policy import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=22,
                    workers=2, 
                    use_multiprocessing=True, 
                    max_queue_size = 12, 
#                    shuffle=False,
                    callbacks=[earlystop, checkpoint]
                    )
# Out:
# RDKit WARNING: [19:29:50] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 1157756it [00:04, 257679.82it/s]
# expansion: 55608it [00:00, 724115.43it/s]
# expansion training...
# data prep: 100%|██████████| 1136741/1136741 [00:00<00:00, 1160675.92it/s]
# total reactions: 100%|██████████| 1136741/1136741 [00:00<00:00, 1978793.37it/s]
# total products: 1136741
# total reactions: 1157285
# Training size: 1026999
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 23086)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               11820544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_1 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_2 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_3 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_4 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_5 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 55608)             28526904
# =================================================================
# Total params: 42,974,008
# Trainable params: 42,974,008
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 23/2000
#  - 722s - loss: 1.9966 - sparse_categorical_accuracy: 0.6429 - acc_top10: 0.8840 - acc_top50: 0.9250 - sparse_categorical_crossentropy: 1.9966 - val_loss: 2.2815 - val_sparse_categorical_accuracy: 0.6725 - val_acc_top10: 0.8889 - val_acc_top50: 0.9178 - val_sparse_categorical_crossentropy: 2.0194
#
# Epoch 00023: val_acc_top50 improved from -inf to 0.91777, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 24/2000
#  - 687s - loss: 1.9669 - sparse_categorical_accuracy: 0.6465 - acc_top10: 0.8863 - acc_top50: 0.9264 - sparse_categorical_crossentropy: 1.9668 - val_loss: 2.0348 - val_sparse_categorical_accuracy: 0.6759 - val_acc_top10: 0.8908 - val_acc_top50: 0.9189 - val_sparse_categorical_crossentropy: 1.9939
#
# Epoch 00024: val_acc_top50 improved from 0.91777 to 0.91894, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 25/2000
#  - 686s - loss: 1.9391 - sparse_categorical_accuracy: 0.6505 - acc_top10: 0.8887 - acc_top50: 0.9283 - sparse_categorical_crossentropy: 1.9391 - val_loss: 1.9595 - val_sparse_categorical_accuracy: 0.6784 - val_acc_top10: 0.8919 - val_acc_top50: 0.9199 - val_sparse_categorical_crossentropy: 1.9786
#
# Epoch 00025: val_acc_top50 improved from 0.91894 to 0.91987, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 26/2000
#  - 685s - loss: 1.9104 - sparse_categorical_accuracy: 0.6535 - acc_top10: 0.8908 - acc_top50: 0.9296 - sparse_categorical_crossentropy: 1.9104 - val_loss: 1.8922 - val_sparse_categorical_accuracy: 0.6804 - val_acc_top10: 0.8928 - val_acc_top50: 0.9207 - val_sparse_categorical_crossentropy: 1.9605
#
# Epoch 00026: val_acc_top50 improved from 0.91987 to 0.92073, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 27/2000
#  - 685s - loss: 1.8837 - sparse_categorical_accuracy: 0.6568 - acc_top10: 0.8931 - acc_top50: 0.9311 - sparse_categorical_crossentropy: 1.8837 - val_loss: 2.0491 - val_sparse_categorical_accuracy: 0.6823 - val_acc_top10: 0.8938 - val_acc_top50: 0.9217 - val_sparse_categorical_crossentropy: 1.9464
#
# Epoch 00027: val_acc_top50 improved from 0.92073 to 0.92171, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 28/2000
#  - 686s - loss: 1.8586 - sparse_categorical_accuracy: 0.6597 - acc_top10: 0.8946 - acc_top50: 0.9322 - sparse_categorical_crossentropy: 1.8586 - val_loss: 1.8001 - val_sparse_categorical_accuracy: 0.6825 - val_acc_top10: 0.8953 - val_acc_top50: 0.9227 - val_sparse_categorical_crossentropy: 1.9307
#
# Epoch 00028: val_acc_top50 improved from 0.92171 to 0.92269, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 29/2000
#  - 684s - loss: 1.8308 - sparse_categorical_accuracy: 0.6632 - acc_top10: 0.8967 - acc_top50: 0.9338 - sparse_categorical_crossentropy: 1.8308 - val_loss: 2.0572 - val_sparse_categorical_accuracy: 0.6850 - val_acc_top10: 0.8961 - val_acc_top50: 0.9235 - val_sparse_categorical_crossentropy: 1.9179
#
# Epoch 00029: val_acc_top50 improved from 0.92269 to 0.92348, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 30/2000
#  - 686s - loss: 1.8081 - sparse_categorical_accuracy: 0.6658 - acc_top10: 0.8982 - acc_top50: 0.9350 - sparse_categorical_crossentropy: 1.8081 - val_loss: 1.9933 - val_sparse_categorical_accuracy: 0.6872 - val_acc_top10: 0.8972 - val_acc_top50: 0.9243 - val_sparse_categorical_crossentropy: 1.9087
#
# Epoch 00030: val_acc_top50 improved from 0.92348 to 0.92433, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 31/2000
#  - 684s - loss: 1.7856 - sparse_categorical_accuracy: 0.6678 - acc_top10: 0.8998 - acc_top50: 0.9361 - sparse_categorical_crossentropy: 1.7856 - val_loss: 1.7378 - val_sparse_categorical_accuracy: 0.6879 - val_acc_top10: 0.8986 - val_acc_top50: 0.9249 - val_sparse_categorical_crossentropy: 1.8885
#
# Epoch 00031: val_acc_top50 improved from 0.92433 to 0.92489, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 32/2000
#  - 685s - loss: 1.7616 - sparse_categorical_accuracy: 0.6708 - acc_top10: 0.9017 - acc_top50: 0.9377 - sparse_categorical_crossentropy: 1.7616 - val_loss: 1.9956 - val_sparse_categorical_accuracy: 0.6906 - val_acc_top10: 0.8992 - val_acc_top50: 0.9259 - val_sparse_categorical_crossentropy: 1.8758
#
# Epoch 00032: val_acc_top50 improved from 0.92489 to 0.92590, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 33/2000
#  - 685s - loss: 1.7410 - sparse_categorical_accuracy: 0.6736 - acc_top10: 0.9034 - acc_top50: 0.9387 - sparse_categorical_crossentropy: 1.7410 - val_loss: 1.6258 - val_sparse_categorical_accuracy: 0.6918 - val_acc_top10: 0.9003 - val_acc_top50: 0.9270 - val_sparse_categorical_crossentropy: 1.8626
#
# Epoch 00033: val_acc_top50 improved from 0.92590 to 0.92700, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 34/2000
#  - 684s - loss: 1.7198 - sparse_categorical_accuracy: 0.6757 - acc_top10: 0.9048 - acc_top50: 0.9400 - sparse_categorical_crossentropy: 1.7198 - val_loss: 1.8850 - val_sparse_categorical_accuracy: 0.6926 - val_acc_top10: 0.9010 - val_acc_top50: 0.9276 - val_sparse_categorical_crossentropy: 1.8584
#
# Epoch 00034: val_acc_top50 improved from 0.92700 to 0.92761, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 35/2000
#  - 683s - loss: 1.6999 - sparse_categorical_accuracy: 0.6781 - acc_top10: 0.9061 - acc_top50: 0.9408 - sparse_categorical_crossentropy: 1.6999 - val_loss: 1.7589 - val_sparse_categorical_accuracy: 0.6928 - val_acc_top10: 0.9015 - val_acc_top50: 0.9284 - val_sparse_categorical_crossentropy: 1.8471
#
# Epoch 00035: val_acc_top50 improved from 0.92761 to 0.92838, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 36/2000
#  - 685s - loss: 1.6810 - sparse_categorical_accuracy: 0.6799 - acc_top10: 0.9076 - acc_top50: 0.9421 - sparse_categorical_crossentropy: 1.6810 - val_loss: 1.8681 - val_sparse_categorical_accuracy: 0.6939 - val_acc_top10: 0.9022 - val_acc_top50: 0.9292 - val_sparse_categorical_crossentropy: 1.8402
#
# Epoch 00036: val_acc_top50 improved from 0.92838 to 0.92919, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 37/2000
#  - 685s - loss: 1.6643 - sparse_categorical_accuracy: 0.6820 - acc_top10: 0.9085 - acc_top50: 0.9430 - sparse_categorical_crossentropy: 1.6643 - val_loss: 1.8827 - val_sparse_categorical_accuracy: 0.6944 - val_acc_top10: 0.9031 - val_acc_top50: 0.9298 - val_sparse_categorical_crossentropy: 1.8296
#
# Epoch 00037: val_acc_top50 improved from 0.92919 to 0.92983, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 38/2000
#  - 684s - loss: 1.6469 - sparse_categorical_accuracy: 0.6842 - acc_top10: 0.9098 - acc_top50: 0.9439 - sparse_categorical_crossentropy: 1.6469 - val_loss: 1.7355 - val_sparse_categorical_accuracy: 0.6967 - val_acc_top10: 0.9034 - val_acc_top50: 0.9304 - val_sparse_categorical_crossentropy: 1.8262
#
# Epoch 00038: val_acc_top50 improved from 0.92983 to 0.93035, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 39/2000
#  - 684s - loss: 1.6325 - sparse_categorical_accuracy: 0.6855 - acc_top10: 0.9111 - acc_top50: 0.9446 - sparse_categorical_crossentropy: 1.6325 - val_loss: 1.9100 - val_sparse_categorical_accuracy: 0.6978 - val_acc_top10: 0.9042 - val_acc_top50: 0.9309 - val_sparse_categorical_crossentropy: 1.8149
#
# Epoch 00039: val_acc_top50 improved from 0.93035 to 0.93089, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 40/2000
#  - 684s - loss: 1.6151 - sparse_categorical_accuracy: 0.6879 - acc_top10: 0.9126 - acc_top50: 0.9455 - sparse_categorical_crossentropy: 1.6151 - val_loss: 1.7324 - val_sparse_categorical_accuracy: 0.6983 - val_acc_top10: 0.9046 - val_acc_top50: 0.9315 - val_sparse_categorical_crossentropy: 1.8069
#
# Epoch 00040: val_acc_top50 improved from 0.93089 to 0.93149, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 41/2000
#  - 684s - loss: 1.6015 - sparse_categorical_accuracy: 0.6892 - acc_top10: 0.9134 - acc_top50: 0.9464 - sparse_categorical_crossentropy: 1.6015 - val_loss: 1.8519 - val_sparse_categorical_accuracy: 0.6984 - val_acc_top10: 0.9051 - val_acc_top50: 0.9324 - val_sparse_categorical_crossentropy: 1.8075
#
# Epoch 00041: val_acc_top50 improved from 0.93149 to 0.93242, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 42/2000
#  - 683s - loss: 1.5863 - sparse_categorical_accuracy: 0.6916 - acc_top10: 0.9146 - acc_top50: 0.9471 - sparse_categorical_crossentropy: 1.5863 - val_loss: 1.8528 - val_sparse_categorical_accuracy: 0.6997 - val_acc_top10: 0.9058 - val_acc_top50: 0.9330 - val_sparse_categorical_crossentropy: 1.8028
#
# Epoch 00042: val_acc_top50 improved from 0.93242 to 0.93297, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 43/2000
#  - 685s - loss: 1.5734 - sparse_categorical_accuracy: 0.6926 - acc_top10: 0.9153 - acc_top50: 0.9479 - sparse_categorical_crossentropy: 1.5734 - val_loss: 1.9644 - val_sparse_categorical_accuracy: 0.6996 - val_acc_top10: 0.9065 - val_acc_top50: 0.9333 - val_sparse_categorical_crossentropy: 1.7962
#
# Epoch 00043: val_acc_top50 improved from 0.93297 to 0.93327, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 44/2000
#  - 685s - loss: 1.5651 - sparse_categorical_accuracy: 0.6942 - acc_top10: 0.9160 - acc_top50: 0.9484 - sparse_categorical_crossentropy: 1.5651 - val_loss: 1.8937 - val_sparse_categorical_accuracy: 0.7019 - val_acc_top10: 0.9071 - val_acc_top50: 0.9341 - val_sparse_categorical_crossentropy: 1.7866
#
# Epoch 00044: val_acc_top50 improved from 0.93327 to 0.93405, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 45/2000
#  - 684s - loss: 1.5497 - sparse_categorical_accuracy: 0.6954 - acc_top10: 0.9170 - acc_top50: 0.9493 - sparse_categorical_crossentropy: 1.5497 - val_loss: 1.7291 - val_sparse_categorical_accuracy: 0.7003 - val_acc_top10: 0.9076 - val_acc_top50: 0.9347 - val_sparse_categorical_crossentropy: 1.7891
#
# Epoch 00045: val_acc_top50 improved from 0.93405 to 0.93466, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 46/2000
#  - 685s - loss: 1.5391 - sparse_categorical_accuracy: 0.6969 - acc_top10: 0.9181 - acc_top50: 0.9498 - sparse_categorical_crossentropy: 1.5391 - val_loss: 1.6973 - val_sparse_categorical_accuracy: 0.7026 - val_acc_top10: 0.9081 - val_acc_top50: 0.9348 - val_sparse_categorical_crossentropy: 1.7812
#
# Epoch 00046: val_acc_top50 improved from 0.93466 to 0.93479, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 47/2000
#  - 684s - loss: 1.5290 - sparse_categorical_accuracy: 0.6984 - acc_top10: 0.9186 - acc_top50: 0.9502 - sparse_categorical_crossentropy: 1.5290 - val_loss: 1.9711 - val_sparse_categorical_accuracy: 0.7032 - val_acc_top10: 0.9082 - val_acc_top50: 0.9351 - val_sparse_categorical_crossentropy: 1.7847
#
# Epoch 00047: val_acc_top50 improved from 0.93479 to 0.93510, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 48/2000
#  - 685s - loss: 1.5187 - sparse_categorical_accuracy: 0.7001 - acc_top10: 0.9192 - acc_top50: 0.9508 - sparse_categorical_crossentropy: 1.5187 - val_loss: 1.9020 - val_sparse_categorical_accuracy: 0.7040 - val_acc_top10: 0.9085 - val_acc_top50: 0.9358 - val_sparse_categorical_crossentropy: 1.7724
#
# Epoch 00048: val_acc_top50 improved from 0.93510 to 0.93580, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 49/2000
#  - 684s - loss: 1.5115 - sparse_categorical_accuracy: 0.7007 - acc_top10: 0.9200 - acc_top50: 0.9512 - sparse_categorical_crossentropy: 1.5115 - val_loss: 1.7631 - val_sparse_categorical_accuracy: 0.7042 - val_acc_top10: 0.9091 - val_acc_top50: 0.9362 - val_sparse_categorical_crossentropy: 1.7748
#
# Epoch 00049: val_acc_top50 improved from 0.93580 to 0.93625, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 50/2000
#  - 685s - loss: 1.5001 - sparse_categorical_accuracy: 0.7023 - acc_top10: 0.9205 - acc_top50: 0.9519 - sparse_categorical_crossentropy: 1.5001 - val_loss: 1.7521 - val_sparse_categorical_accuracy: 0.7042 - val_acc_top10: 0.9092 - val_acc_top50: 0.9363 - val_sparse_categorical_crossentropy: 1.7705
#
# Epoch 00050: val_acc_top50 improved from 0.93625 to 0.93633, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 51/2000
#  - 685s - loss: 1.4941 - sparse_categorical_accuracy: 0.7035 - acc_top10: 0.9210 - acc_top50: 0.9522 - sparse_categorical_crossentropy: 1.4941 - val_loss: 1.8950 - val_sparse_categorical_accuracy: 0.7047 - val_acc_top10: 0.9097 - val_acc_top50: 0.9369 - val_sparse_categorical_crossentropy: 1.7686
#
# Epoch 00051: val_acc_top50 improved from 0.93633 to 0.93687, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 52/2000
#  - 684s - loss: 1.4829 - sparse_categorical_accuracy: 0.7049 - acc_top10: 0.9216 - acc_top50: 0.9525 - sparse_categorical_crossentropy: 1.4829 - val_loss: 1.8128 - val_sparse_categorical_accuracy: 0.7054 - val_acc_top10: 0.9099 - val_acc_top50: 0.9371 - val_sparse_categorical_crossentropy: 1.7664
#
# Epoch 00052: val_acc_top50 improved from 0.93687 to 0.93710, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 53/2000
#  - 684s - loss: 1.4759 - sparse_categorical_accuracy: 0.7057 - acc_top10: 0.9225 - acc_top50: 0.9531 - sparse_categorical_crossentropy: 1.4759 - val_loss: 1.8485 - val_sparse_categorical_accuracy: 0.7058 - val_acc_top10: 0.9110 - val_acc_top50: 0.9372 - val_sparse_categorical_crossentropy: 1.7625
#
# Epoch 00053: val_acc_top50 improved from 0.93710 to 0.93718, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 54/2000
#  - 684s - loss: 1.4668 - sparse_categorical_accuracy: 0.7069 - acc_top10: 0.9229 - acc_top50: 0.9535 - sparse_categorical_crossentropy: 1.4668 - val_loss: 1.8067 - val_sparse_categorical_accuracy: 0.7074 - val_acc_top10: 0.9106 - val_acc_top50: 0.9375 - val_sparse_categorical_crossentropy: 1.7646
#
# Epoch 00054: val_acc_top50 improved from 0.93718 to 0.93753, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 55/2000
#  - 683s - loss: 1.4617 - sparse_categorical_accuracy: 0.7086 - acc_top10: 0.9231 - acc_top50: 0.9539 - sparse_categorical_crossentropy: 1.4617 - val_loss: 1.9746 - val_sparse_categorical_accuracy: 0.7072 - val_acc_top10: 0.9114 - val_acc_top50: 0.9380 - val_sparse_categorical_crossentropy: 1.7588
#
# Epoch 00055: val_acc_top50 improved from 0.93753 to 0.93804, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 56/2000
#  - 684s - loss: 1.4538 - sparse_categorical_accuracy: 0.7088 - acc_top10: 0.9240 - acc_top50: 0.9544 - sparse_categorical_crossentropy: 1.4538 - val_loss: 1.9582 - val_sparse_categorical_accuracy: 0.7079 - val_acc_top10: 0.9116 - val_acc_top50: 0.9377 - val_sparse_categorical_crossentropy: 1.7667
#
# Epoch 00056: val_acc_top50 did not improve from 0.93804
# Epoch 57/2000
#  - 683s - loss: 1.4493 - sparse_categorical_accuracy: 0.7098 - acc_top10: 0.9240 - acc_top50: 0.9544 - sparse_categorical_crossentropy: 1.4493 - val_loss: 1.7974 - val_sparse_categorical_accuracy: 0.7088 - val_acc_top10: 0.9120 - val_acc_top50: 0.9380 - val_sparse_categorical_crossentropy: 1.7562
#
# Epoch 00057: val_acc_top50 did not improve from 0.93804
# Epoch 58/2000
#  - 684s - loss: 1.4411 - sparse_categorical_accuracy: 0.7112 - acc_top10: 0.9247 - acc_top50: 0.9549 - sparse_categorical_crossentropy: 1.4411 - val_loss: 1.7670 - val_sparse_categorical_accuracy: 0.7085 - val_acc_top10: 0.9120 - val_acc_top50: 0.9384 - val_sparse_categorical_crossentropy: 1.7580
#
# Epoch 00058: val_acc_top50 improved from 0.93804 to 0.93838, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 59/2000
#  - 684s - loss: 1.4364 - sparse_categorical_accuracy: 0.7116 - acc_top10: 0.9249 - acc_top50: 0.9551 - sparse_categorical_crossentropy: 1.4364 - val_loss: 1.6745 - val_sparse_categorical_accuracy: 0.7076 - val_acc_top10: 0.9121 - val_acc_top50: 0.9384 - val_sparse_categorical_crossentropy: 1.7615
#
# Epoch 00059: val_acc_top50 did not improve from 0.93838
# Epoch 60/2000
#  - 683s - loss: 1.4317 - sparse_categorical_accuracy: 0.7123 - acc_top10: 0.9255 - acc_top50: 0.9557 - sparse_categorical_crossentropy: 1.4317 - val_loss: 1.9140 - val_sparse_categorical_accuracy: 0.7095 - val_acc_top10: 0.9127 - val_acc_top50: 0.9386 - val_sparse_categorical_crossentropy: 1.7533
#
# Epoch 00060: val_acc_top50 improved from 0.93838 to 0.93860, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 61/2000
#  - 684s - loss: 1.4237 - sparse_categorical_accuracy: 0.7139 - acc_top10: 0.9260 - acc_top50: 0.9559 - sparse_categorical_crossentropy: 1.4237 - val_loss: 1.9677 - val_sparse_categorical_accuracy: 0.7082 - val_acc_top10: 0.9124 - val_acc_top50: 0.9385 - val_sparse_categorical_crossentropy: 1.7584
#
# Epoch 00061: val_acc_top50 did not improve from 0.93860
# Epoch 62/2000
#  - 684s - loss: 1.4173 - sparse_categorical_accuracy: 0.7144 - acc_top10: 0.9269 - acc_top50: 0.9562 - sparse_categorical_crossentropy: 1.4173 - val_loss: 1.8192 - val_sparse_categorical_accuracy: 0.7095 - val_acc_top10: 0.9130 - val_acc_top50: 0.9391 - val_sparse_categorical_crossentropy: 1.7544
#
# Epoch 00062: val_acc_top50 improved from 0.93860 to 0.93906, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 63/2000
#  - 683s - loss: 1.4125 - sparse_categorical_accuracy: 0.7159 - acc_top10: 0.9268 - acc_top50: 0.9565 - sparse_categorical_crossentropy: 1.4125 - val_loss: 1.9137 - val_sparse_categorical_accuracy: 0.7097 - val_acc_top10: 0.9132 - val_acc_top50: 0.9388 - val_sparse_categorical_crossentropy: 1.7577
#
# Epoch 00063: val_acc_top50 did not improve from 0.93906
# Epoch 64/2000
#  - 684s - loss: 1.4101 - sparse_categorical_accuracy: 0.7160 - acc_top10: 0.9269 - acc_top50: 0.9568 - sparse_categorical_crossentropy: 1.4101 - val_loss: 1.7964 - val_sparse_categorical_accuracy: 0.7103 - val_acc_top10: 0.9135 - val_acc_top50: 0.9391 - val_sparse_categorical_crossentropy: 1.7511
#
# Epoch 00064: val_acc_top50 improved from 0.93906 to 0.93907, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 65/2000
#  - 684s - loss: 1.4053 - sparse_categorical_accuracy: 0.7171 - acc_top10: 0.9271 - acc_top50: 0.9569 - sparse_categorical_crossentropy: 1.4053 - val_loss: 1.6547 - val_sparse_categorical_accuracy: 0.7084 - val_acc_top10: 0.9131 - val_acc_top50: 0.9390 - val_sparse_categorical_crossentropy: 1.7598
#
# Epoch 00065: val_acc_top50 did not improve from 0.93907
# Epoch 66/2000
#  - 684s - loss: 1.3965 - sparse_categorical_accuracy: 0.7179 - acc_top10: 0.9278 - acc_top50: 0.9570 - sparse_categorical_crossentropy: 1.3965 - val_loss: 1.8874 - val_sparse_categorical_accuracy: 0.7096 - val_acc_top10: 0.9139 - val_acc_top50: 0.9396 - val_sparse_categorical_crossentropy: 1.7570
#
# Epoch 00066: val_acc_top50 improved from 0.93907 to 0.93961, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 67/2000
#  - 684s - loss: 1.3947 - sparse_categorical_accuracy: 0.7186 - acc_top10: 0.9281 - acc_top50: 0.9573 - sparse_categorical_crossentropy: 1.3947 - val_loss: 1.8200 - val_sparse_categorical_accuracy: 0.7092 - val_acc_top10: 0.9139 - val_acc_top50: 0.9393 - val_sparse_categorical_crossentropy: 1.7560
#
# Epoch 00067: val_acc_top50 did not improve from 0.93961
# Epoch 68/2000
#  - 684s - loss: 1.3895 - sparse_categorical_accuracy: 0.7196 - acc_top10: 0.9285 - acc_top50: 0.9577 - sparse_categorical_crossentropy: 1.3895 - val_loss: 1.6489 - val_sparse_categorical_accuracy: 0.7100 - val_acc_top10: 0.9138 - val_acc_top50: 0.9397 - val_sparse_categorical_crossentropy: 1.7580
#
# Epoch 00068: val_acc_top50 improved from 0.93961 to 0.93967, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 69/2000
#  - 684s - loss: 1.3865 - sparse_categorical_accuracy: 0.7196 - acc_top10: 0.9284 - acc_top50: 0.9576 - sparse_categorical_crossentropy: 1.3865 - val_loss: 1.7301 - val_sparse_categorical_accuracy: 0.7106 - val_acc_top10: 0.9143 - val_acc_top50: 0.9397 - val_sparse_categorical_crossentropy: 1.7576
#
# Epoch 00069: val_acc_top50 improved from 0.93967 to 0.93975, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 70/2000
#  - 683s - loss: 1.3786 - sparse_categorical_accuracy: 0.7218 - acc_top10: 0.9292 - acc_top50: 0.9580 - sparse_categorical_crossentropy: 1.3786 - val_loss: 1.6658 - val_sparse_categorical_accuracy: 0.7109 - val_acc_top10: 0.9140 - val_acc_top50: 0.9399 - val_sparse_categorical_crossentropy: 1.7601
#
# Epoch 00070: val_acc_top50 improved from 0.93975 to 0.93992, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 71/2000
#  - 684s - loss: 1.3761 - sparse_categorical_accuracy: 0.7213 - acc_top10: 0.9294 - acc_top50: 0.9582 - sparse_categorical_crossentropy: 1.3761 - val_loss: 1.9299 - val_sparse_categorical_accuracy: 0.7107 - val_acc_top10: 0.9146 - val_acc_top50: 0.9399 - val_sparse_categorical_crossentropy: 1.7585
#
# Epoch 00071: val_acc_top50 did not improve from 0.93992
# Epoch 72/2000
#  - 683s - loss: 1.3721 - sparse_categorical_accuracy: 0.7227 - acc_top10: 0.9297 - acc_top50: 0.9583 - sparse_categorical_crossentropy: 1.3721 - val_loss: 1.6705 - val_sparse_categorical_accuracy: 0.7116 - val_acc_top10: 0.9147 - val_acc_top50: 0.9399 - val_sparse_categorical_crossentropy: 1.7546
#
# Epoch 00072: val_acc_top50 did not improve from 0.93992
# Epoch 73/2000
#  - 684s - loss: 1.3672 - sparse_categorical_accuracy: 0.7227 - acc_top10: 0.9300 - acc_top50: 0.9586 - sparse_categorical_crossentropy: 1.3672 - val_loss: 1.7388 - val_sparse_categorical_accuracy: 0.7111 - val_acc_top10: 0.9145 - val_acc_top50: 0.9400 - val_sparse_categorical_crossentropy: 1.7555
#
# Epoch 00073: val_acc_top50 improved from 0.93992 to 0.93995, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 74/2000
#  - 684s - loss: 1.3635 - sparse_categorical_accuracy: 0.7244 - acc_top10: 0.9300 - acc_top50: 0.9586 - sparse_categorical_crossentropy: 1.3635 - val_loss: 1.8186 - val_sparse_categorical_accuracy: 0.7114 - val_acc_top10: 0.9142 - val_acc_top50: 0.9401 - val_sparse_categorical_crossentropy: 1.7603
#
# Epoch 00074: val_acc_top50 improved from 0.93995 to 0.94015, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 75/2000
#  - 685s - loss: 1.3613 - sparse_categorical_accuracy: 0.7247 - acc_top10: 0.9301 - acc_top50: 0.9589 - sparse_categorical_crossentropy: 1.3613 - val_loss: 1.6578 - val_sparse_categorical_accuracy: 0.7129 - val_acc_top10: 0.9145 - val_acc_top50: 0.9400 - val_sparse_categorical_crossentropy: 1.7572
#
# Epoch 00075: val_acc_top50 did not improve from 0.94015
# Epoch 76/2000
#  - 683s - loss: 1.3572 - sparse_categorical_accuracy: 0.7251 - acc_top10: 0.9304 - acc_top50: 0.9588 - sparse_categorical_crossentropy: 1.3572 - val_loss: 1.7140 - val_sparse_categorical_accuracy: 0.7115 - val_acc_top10: 0.9143 - val_acc_top50: 0.9398 - val_sparse_categorical_crossentropy: 1.7591
#
# Epoch 00076: val_acc_top50 did not improve from 0.94015
# Epoch 77/2000
#  - 684s - loss: 1.3540 - sparse_categorical_accuracy: 0.7258 - acc_top10: 0.9306 - acc_top50: 0.9590 - sparse_categorical_crossentropy: 1.3540 - val_loss: 1.7865 - val_sparse_categorical_accuracy: 0.7121 - val_acc_top10: 0.9144 - val_acc_top50: 0.9403 - val_sparse_categorical_crossentropy: 1.7539
#
# Epoch 00077: val_acc_top50 improved from 0.94015 to 0.94025, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 78/2000
#  - 685s - loss: 1.3503 - sparse_categorical_accuracy: 0.7265 - acc_top10: 0.9310 - acc_top50: 0.9592 - sparse_categorical_crossentropy: 1.3503 - val_loss: 1.9190 - val_sparse_categorical_accuracy: 0.7121 - val_acc_top10: 0.9140 - val_acc_top50: 0.9402 - val_sparse_categorical_crossentropy: 1.7646
#
# Epoch 00078: val_acc_top50 did not improve from 0.94025
# Epoch 79/2000
#  - 684s - loss: 1.3474 - sparse_categorical_accuracy: 0.7259 - acc_top10: 0.9313 - acc_top50: 0.9594 - sparse_categorical_crossentropy: 1.3474 - val_loss: 1.6837 - val_sparse_categorical_accuracy: 0.7119 - val_acc_top10: 0.9141 - val_acc_top50: 0.9403 - val_sparse_categorical_crossentropy: 1.7634
#
# Epoch 00079: val_acc_top50 improved from 0.94025 to 0.94034, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 80/2000
#  - 684s - loss: 1.3445 - sparse_categorical_accuracy: 0.7278 - acc_top10: 0.9314 - acc_top50: 0.9595 - sparse_categorical_crossentropy: 1.3445 - val_loss: 1.8879 - val_sparse_categorical_accuracy: 0.7128 - val_acc_top10: 0.9142 - val_acc_top50: 0.9402 - val_sparse_categorical_crossentropy: 1.7681
#
# Epoch 00080: val_acc_top50 did not improve from 0.94034
# Epoch 81/2000
#  - 685s - loss: 1.3386 - sparse_categorical_accuracy: 0.7290 - acc_top10: 0.9318 - acc_top50: 0.9597 - sparse_categorical_crossentropy: 1.3386 - val_loss: 1.6921 - val_sparse_categorical_accuracy: 0.7118 - val_acc_top10: 0.9148 - val_acc_top50: 0.9403 - val_sparse_categorical_crossentropy: 1.7675
#
# Epoch 00081: val_acc_top50 did not improve from 0.94034
# Epoch 82/2000
#  - 684s - loss: 1.3352 - sparse_categorical_accuracy: 0.7291 - acc_top10: 0.9322 - acc_top50: 0.9599 - sparse_categorical_crossentropy: 1.3352 - val_loss: 1.7556 - val_sparse_categorical_accuracy: 0.7117 - val_acc_top10: 0.9151 - val_acc_top50: 0.9406 - val_sparse_categorical_crossentropy: 1.7651
#
# Epoch 00082: val_acc_top50 improved from 0.94034 to 0.94063, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_negative_0
# Epoch 83/2000
#  - 684s - loss: 1.3327 - sparse_categorical_accuracy: 0.7300 - acc_top10: 0.9323 - acc_top50: 0.9599 - sparse_categorical_crossentropy: 1.3327 - val_loss: 1.9861 - val_sparse_categorical_accuracy: 0.7128 - val_acc_top10: 0.9147 - val_acc_top50: 0.9404 - val_sparse_categorical_crossentropy: 1.7638
#
# Epoch 00083: val_acc_top50 did not improve from 0.94063
# Epoch 84/2000
#  - 684s - loss: 1.3314 - sparse_categorical_accuracy: 0.7304 - acc_top10: 0.9321 - acc_top50: 0.9600 - sparse_categorical_crossentropy: 1.3314 - val_loss: 1.9852 - val_sparse_categorical_accuracy: 0.7114 - val_acc_top10: 0.9145 - val_acc_top50: 0.9404 - val_sparse_categorical_crossentropy: 1.7669
#
# Epoch 00084: val_acc_top50 did not improve from 0.94063
# Epoch 85/2000
#  - 684s - loss: 1.3253 - sparse_categorical_accuracy: 0.7311 - acc_top10: 0.9325 - acc_top50: 0.9601 - sparse_categorical_crossentropy: 1.3253 - val_loss: 1.8080 - val_sparse_categorical_accuracy: 0.7117 - val_acc_top10: 0.9149 - val_acc_top50: 0.9405 - val_sparse_categorical_crossentropy: 1.7642
#
# Epoch 00085: val_acc_top50 did not improve from 0.94063
# Epoch 86/2000
#  - 685s - loss: 1.3251 - sparse_categorical_accuracy: 0.7310 - acc_top10: 0.9327 - acc_top50: 0.9603 - sparse_categorical_crossentropy: 1.3251 - val_loss: 1.7417 - val_sparse_categorical_accuracy: 0.7132 - val_acc_top10: 0.9149 - val_acc_top50: 0.9405 - val_sparse_categorical_crossentropy: 1.7598
#
# Epoch 00086: val_acc_top50 did not improve from 0.94063
# Epoch 87/2000
#  - 684s - loss: 1.3190 - sparse_categorical_accuracy: 0.7320 - acc_top10: 0.9332 - acc_top50: 0.9604 - sparse_categorical_crossentropy: 1.3190 - val_loss: 2.0564 - val_sparse_categorical_accuracy: 0.7126 - val_acc_top10: 0.9149 - val_acc_top50: 0.9402 - val_sparse_categorical_crossentropy: 1.7677
#
# Epoch 00087: val_acc_top50 did not improve from 0.94063
# Epoch 88/2000
#  - 684s - loss: 1.3188 - sparse_categorical_accuracy: 0.7322 - acc_top10: 0.9329 - acc_top50: 0.9605 - sparse_categorical_crossentropy: 1.3188 - val_loss: 2.0100 - val_sparse_categorical_accuracy: 0.7135 - val_acc_top10: 0.9154 - val_acc_top50: 0.9404 - val_sparse_categorical_crossentropy: 1.7629
#
# Epoch 00088: val_acc_top50 did not improve from 0.94063
# Epoch 00088: early stopping
