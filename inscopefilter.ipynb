# %%
#Inscope改善方案:Learning rate, batch size1024 , 檔案先shuttle好不要放在porgram裡， fold重啟，+dropout，增worker降quene,改善FP反應物字典給值做法，改用簡單的reaction rules FP(rdkit內建版)
import os
import random
import numpy as np
import tensorflow as tf
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
from tqdm import tqdm, trange
from collections import defaultdict
from highway_layer import Highway
#匯入深度學習的框架函式庫：keras
import keras
from keras import backend as K
from keras.initializers import Constant
from keras.utils import plot_model
#keras用以建立模型架構的函數
from keras.models import Sequential, load_model, Model

#keras中建立深度學習layer的函數

from keras.layers import Dense, Dropout, BatchNormalization, Activation, Multiply, Add, Lambda, Input
from keras import metrics
#keras訓練演算法函數
from keras import regularizers
from keras.optimizers import Adam

#keras提早判停的函數
from keras.callbacks import EarlyStopping, ModelCheckpoint

#it's hard to reproduce results, so close all seeds
#os.environ['PYTHONHASHSEED'] = '0'
#np.random.seed(0)
#tf.set_random_seed(0)
#random.seed(0)

#to solve problem:Blas GEMM launch failed
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
#config = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
config.gpu_options.allocator_type = 'BFC' #A "Best-fit with coalescing" algorithm, simplified from a version of dlmalloc.
config.gpu_options.per_process_gpu_memory_fraction = 0.95
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config)) 


def fps_to_arr(fps):
    """Faster conversion to ndarray"""
    arrs = []
    for fp, info in zip(fps[0],fps[1]):
        onbits = list(fp.GetOnBits())
        arr = np.zeros(fp.GetNumBits())
        for onbit in onbits:
            arr[onbit] = len(info[onbit])
        arrs.append(arr)
    arrs = np.array(arrs)
    return arrs




def fingerprint_mols(mols, fp_dim):
    fps = []
    infos = []
    for mol in mols:
        mol = Chem.MolFromSmiles(mol)
        info={}
        # Necessary for fingerprinting
        # Chem.GetSymmSSSR(mol)

        # "When comparing the ECFP/FCFP fingerprints and
        # the Morgan fingerprints generated by the RDKit,
        # remember that the 4 in ECFP4 corresponds to the
        # diameter of the atom environments considered,
        # while the Morgan fingerprints take a radius parameter.
        # So the examples above, with radius=2, are roughly
        # equivalent to ECFP4 and FCFP4."
        # <http://www.rdkit.org/docs/GettingStartedInPython.html>
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=int(fp_dim), useChirality=1, bitInfo=info)
        # fold_factor = fp.GetNumBits()//fp_dim
        # fp = DataStructs.FoldFingerprint(fp, fold_factor)
        fps.append(fp)
        infos.append(info)
    return fps, infos

def preprocess(X, fp_dim):
    # Compute fingerprints
    FPs = fps_to_arr(fingerprint_mols(X, fp_dim))
    # Apply variance threshold
    # return np.log(X[:,self.idx] + 1) 
    #FPs = np.log(dataX[:,idx]+1)
#    FPs = np.log(dataX+1)
    return FPs
def smi_list_from_str(inchis):
    '''string separated by ++ to list of RDKit molecules'''
    return [inchi.strip() for inchi in inchis.split('++')]

class DataGenerator(keras.utils.Sequence):
    
    def __init__(self, X, y, z, batch_size=1, shuffle=True, fp_dim=16384, recfp_dim=2048):
        self.batch_size = batch_size
        self.X = X
        self.y = y
        self.z = z
        self.indexes = np.arange(len(self.X))
        self.shuffle = shuffle
        self.fp_dim = fp_dim
        self.recfp_dim = recfp_dim

    def __len__(self):
        #计算每一个epoch的迭代次数
        return int(np.floor(len(self.X) / int(self.batch_size)))

    def __getitem__(self, index):
        #生成每个batch数据，这里就根据自己对数据的读取方式进行发挥了
        # 生成batch_size个索引
        batch_indexs = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # 根据索引获取datas集合中的数据
        batch_datasX = [self.X[k] for k in batch_indexs]
        batch_datasy = [self.y[k] for k in batch_indexs]
        batch_datasz = [self.z[k] for k in batch_indexs]
        # 生成数据
        X = preprocess(batch_datasX, self.fp_dim)
        y = np.zeros((len(batch_datasy),self.recfp_dim))
        for i,a in enumerate(batch_datasy):
            n = np.zeros((1,self.recfp_dim))
            for b in smi_list_from_str(a):
                n += preprocess([b], self.recfp_dim)
            p = X[i].reshape((-1,self.recfp_dim))    
            y[i] = np.sum(p, 0, keepdims=True)- n
        z = np.array(batch_datasz)
#        y = y.astype(np.int64)
        return [X, y], [z]

    def on_epoch_end(self):
        #在每一次epoch结束是否需要进行一次随机，重新随机一下index
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

def fold(x):
    z=tf.subtract(x[0], x[1])
#    z_shape=tf.Tensor.shape(z)

#    z_shape=z.get_shape().as_list()
    zv=tf.reshape(z,[-1,8,2048])
    return tf.reduce_sum(zv, 1) 

def cosine(x):
    prod_net = x[0]
    react_net = x[1]
    prod_norm = tf.nn.l2_normalize(prod_net, axis=-1)
    react_norm = tf.nn.l2_normalize(react_net, axis=-1)
    cosine_sim = tf.reduce_sum(tf.multiply(prod_norm, react_norm), axis=-1,keepdims=True)
#    cosine_sim = tf.squeeze(cosine_sim,[1])
#    return tf.nn.sigmoid(cosine_sim)
    return cosine_sim
# get average auc between different batches over the epoch, so don't use. otherwise validation process always get wrong results
def auc2(y_true, y_pred):
    y_pred=tf.nn.sigmoid(y_pred)
    auc = tf.metrics.auc(y_true, y_pred)[1]
    K.get_session().run(tf.local_variables_initializer())
    return auc

# AUC for a binary classifier, this AUC is a little underestimated due to minimum areas.
def auc1(y_true, y_pred):
    ptas = tf.stack([binary_PTA(y_true,y_pred,k) for k in np.linspace(0, 1, 1000)],axis=0)
    pfas = tf.stack([binary_PFA(y_true,y_pred,k) for k in np.linspace(0, 1, 1000)],axis=0)
    pfas = tf.concat([tf.ones((1,)) ,pfas],axis=0)
    binSizes = -(pfas[1:]-pfas[:-1])
    s = ptas*binSizes
    return K.sum(s, axis=0)
#-----------------------------------------------------------------------------------------------------------------------------------------------------
# PFA, prob false alert for binary classifier(FPR)
def binary_PFA(y_true, y_pred, threshold=K.variable(value=0.5)):
    y_pred=tf.nn.sigmoid(y_pred)
    y_pred = K.cast(y_pred >= threshold, 'float32')
    # N = total number of negative labels
    N = K.sum(1 - y_true)
    # FP = total number of false alerts, alerts from the negative class labels
    FP = K.sum(y_pred - y_pred * y_true)
    return FP/N
#-----------------------------------------------------------------------------------------------------------------------------------------------------
# P_TA prob true alerts for binary classifier(TPR)
def binary_PTA(y_true, y_pred, threshold=K.variable(value=0.5)):
    y_pred=tf.nn.sigmoid(y_pred)
    y_pred = K.cast(y_pred >= threshold, 'float32')
    # P = total number of positive labels
    P = K.sum(y_true)
    # TP = total number of correct alerts, alerts from the positive class labels
    TP = K.sum(y_pred * y_true)
    return TP/P
# PFA, prob false alert for binary classifier(FPR)
def FPR(y_true, y_pred):
    y_pred=tf.nn.sigmoid(y_pred)
    u = tf.nn.sigmoid(0.9)
    y_pred = K.cast(y_pred >= u, 'float32')
    # N = total number of negative labels
    N = K.sum(1 - y_true)
    # FP = total number of false alerts, alerts from the negative class labels
    FP = K.sum(y_pred - y_pred * y_true)
    return FP/N
#-----------------------------------------------------------------------------------------------------------------------------------------------------
# P_TA prob true alerts for binary classifier(TPR)
def TPR(y_true, y_pred):
    y_pred=tf.nn.sigmoid(y_pred)
    u = tf.nn.sigmoid(0.9)
    y_pred = K.cast(y_pred >= u, 'float32')
    # P = total number of positive labels
    P = K.sum(y_true)
    # TP = total number of correct alerts, alerts from the positive class labels
    TP = K.sum(y_pred * y_true)
    return TP/P

# ACC= (TP + TN) / (P + N)
def ACCR(y_true, y_pred):
    y_pred=tf.nn.sigmoid(y_pred)
    u = tf.nn.sigmoid(0.9)
    y_pred = K.cast(y_pred >= u, 'float32')
    # P = total number of positive labels
    P = K.sum(y_true)
    # N = total number of negative labels
    N = K.sum(1 - y_true)    
    # TP = total number of correct alerts, alerts from the positive class labels
    TP = K.sum(y_pred * y_true)
    # TN = total number of correct alerts, alerts from the negtive class labels
    TN = K.sum((1-y_pred) * (1-y_true))    
    return (TP+TN)/(P+N)
def ACCR5(y_true, y_pred):
    y_pred=tf.nn.sigmoid(y_pred)
#    u = tf.nn.sigmoid(0.9)
    y_pred = K.cast(y_pred >= 0.5, 'float32')
    # P = total number of positive labels
    P = K.sum(y_true)
    # N = total number of negative labels
    N = K.sum(1 - y_true)    
    # TP = total number of correct alerts, alerts from the positive class labels
    TP = K.sum(y_pred * y_true)
    # TN = total number of correct alerts, alerts from the negtive class labels
    TN = K.sum((1-y_pred) * (1-y_true))    
    return (TP+TN)/(P+N)



            #設定訓練參數和訓練模型存放路徑
#batch_size = 3
batch_size = 512
#num_classes = 6
epochs = 2000
#epochs = 100
seed=0
#validation spilt
spilt=0.1
#for variance threshold
#fp_dim=1e6
fp_dim=16384
recfp_dim=2048
model_name = 'trained_model_inscope_'+str(seed)
save_dir = os.path.join(os.getcwd(), 'saved_models')




print('Loading data...')
tem_simp = set()
prods = []
reacs = []
labels = []
with open('data/inscopedata.dat', 'r') as f:
    for l in tqdm(f, desc='inscopedata'):
        tem_simp.add(l.strip())

with open('data/inscopedata2.dat', 'r') as f:
    for l in tqdm(f, desc='inscopedata'):
        tem_simp.add(l.strip()) 

for item in tem_simp:
    prod,reac,label = item.split('\t')
    prods.append(prod)
    reacs.append(reac)
    labels.append(float(label))

print('total samples:', len(tem_simp))    
# Shuffle
xyz = list(zip(prods, reacs, labels))
xyz.sort()
random.seed(seed)
random.shuffle(xyz)
prods, reacs, labels = zip(*xyz)
data_spilt= round(len(prods)*(1-spilt))
x_train = prods[:data_spilt]
x_test = prods[data_spilt:]
y_train = reacs[:data_spilt]
y_test = reacs[data_spilt:]
z_train = labels[:data_spilt]
z_test = labels[data_spilt:]

#print('traindata:',x_train[:2],y_train[:2],z_train[:2])
#print('testdata:',x_test[:2],y_test[:2],z_test[:2])

print('shuffle is over...')

#build model
visible = Input(shape=(fp_dim,))
hidden = Lambda(lambda x: tf.math.log(x+1))(visible)
hidden = Dense(1024, activation='elu')(hidden)
hidden = Dropout(0.3)(hidden)

# only for expansion rule policynet
for _ in range(5):
    hidden = Highway()(hidden)
#    hidden = Dropout(0.4)(hidden)
#another branch
#visible1 = Input(shape=(fp_dim,))
visible2 = Input(shape=(recfp_dim,))
#hidden1 = Lambda(fold)([visible, visible2])
hidden1 = Dense(1024, activation='elu')(visible2)

output = Lambda(cosine)([hidden, hidden1])
#,output_shape=(1,)
    
model = Model(inputs=[visible,visible2], outputs=output)
# summarize layers
print(model.summary())
# plot graph
#plot_model(model, to_file='expansionpolicynet_graph.png')
# 初始化Adam optimizer
opt = keras.optimizers.Adam(lr=0.001)

# 設定訓練方式，包含loss、optimizer..)

model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=[ACCR, ACCR5, auc2, auc1, TPR, FPR])
#metrics.binary_accuracy, ACCR, ACCR5, auc2, auc1, TPR, FPR
# early stop存放模型設置


if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
checkpoint = ModelCheckpoint(model_path, monitor='val_ACCR', save_best_only=True, verbose=1, mode='max')

# early stop參數設定
earlystop = EarlyStopping(monitor='val_ACCR', patience=6, verbose=1, mode='max')

#continue training
#del model  # 删掉存在的模型

#返回一个编译好的模型
#与删掉的模型相同
#model = load_model(model_path, custom_objects={'ACCR': ACCR,'ACCR5': ACCR5,'auc2': auc2,'auc1': auc1,'TPR': TPR, 'FPR': FPR,'Highway': Highway,'fold': fold,'cosine': cosine})
##model.compile(loss='binary_crossentropy',
##              optimizer=opt,
##              metrics=['binary_accuracy',ACCR, auc, auc1, TPR, FPR])

# 開始訓練
training_generator = DataGenerator(X=x_train, y=y_train, z=z_train, batch_size=batch_size, shuffle=True, fp_dim=fp_dim, recfp_dim=recfp_dim)
validation_gen = DataGenerator(X=x_test, y=y_test, z=z_test, batch_size=batch_size, shuffle=True, fp_dim=fp_dim, recfp_dim=recfp_dim)    
if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=1,
                    initial_epoch=0,
#                    workers=0, 
#                    use_multiprocessing=True, 
#                    shuffle=False,
#                    max_queue_size = 10, 
                    callbacks=[earlystop, checkpoint]
                    )
# Out:
# RDKit WARNING: [15:45:00] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Loading data...
# inscopedata: 1534410it [00:03, 508932.08it/s]
# inscopedata: 1789651it [00:04, 413748.68it/s]
# total samples: 3317345
# shuffle is over...
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 16384)        0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16384)        0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         16778240    lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# highway_1 (Highway)             (None, 1024)         2099200     dropout_1[0][0]
# __________________________________________________________________________________________________
# highway_2 (Highway)             (None, 1024)         2099200     highway_1[0][0]
# __________________________________________________________________________________________________
# highway_3 (Highway)             (None, 1024)         2099200     highway_2[0][0]
# __________________________________________________________________________________________________
# highway_4 (Highway)             (None, 1024)         2099200     highway_3[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 2048)         0
# __________________________________________________________________________________________________
# highway_5 (Highway)             (None, 1024)         2099200     highway_4[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1024)         2098176     input_2[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1)            0           highway_5[0][0]
#                                                                  dense_12[0][0]
# ==================================================================================================
# Total params: 29,372,416
# Trainable params: 29,372,416
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\metrics_impl.py:526: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\metrics_impl.py:788: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/2000
#   27/5831 [..............................] - ETA: 10:10:25 - loss: 0.6935 - binary_accuracy: 0.4766 - auc2: 0.4899 - auc1: 0.4718 - TPR: 0.0000e+00 - FPR: 0.0000e+0 - ETA: 5:12:22 - loss: 0.6812 - binary_accuracy: 0.6035 - auc2: 0.5711 - auc1: 0.6237 - TPR: 0.0000e+00 - FPR: 0.0000e+0 - ETA: 3:32:22 - loss: 0.6712 - binary_accuracy: 0.6484 - auc2: 0.6186 - auc1: 0.6825 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 2:43:41 - loss: 0.6653 - binary_accuracy: 0.6694 - auc2: 0.6460 - auc1: 0.7034 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 2:12:56 - loss: 0.6597 - binary_accuracy: 0.6797 - auc2: 0.6646 - auc1: 0.7192 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:52:24 - loss: 0.6549 - binary_accuracy: 0.6924 - auc2: 0.6786 - auc1: 0.7307 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:37:46 - loss: 0.6489 - binary_accuracy: 0.7056 - auc2: 0.6907 - auc1: 0.7454 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:27:58 - loss: 0.6445 - binary_accuracy: 0.7129 - auc2: 0.7006 - auc1: 0.7527 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:19:16 - loss: 0.6409 - binary_accuracy: 0.7166 - auc2: 0.7085 - auc1: 0.7581 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:12:21 - loss: 0.6377 - binary_accuracy: 0.7197 - auc2: 0.7151 - auc1: 0.7615 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:11:24 - loss: 0.6347 - binary_accuracy: 0.7221 - auc2: 0.7206 - auc1: 0.7649 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:11:39 - loss: 0.6329 - binary_accuracy: 0.7209 - auc2: 0.7249 - auc1: 0.7648 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:09:48 - loss: 0.6301 - binary_accuracy: 0.7222 - auc2: 0.7286 - auc1: 0.7674 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:08:13 - loss: 0.6269 - binary_accuracy: 0.7267 - auc2: 0.7321 - auc1: 0.7717 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:06:52 - loss: 0.6239 - binary_accuracy: 0.7301 - auc2: 0.7353 - auc1: 0.7745 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:05:39 - loss: 0.6214 - binary_accuracy: 0.7328 - auc2: 0.7382 - auc1: 0.7780 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:04:37 - loss: 0.6193 - binary_accuracy: 0.7330 - auc2: 0.7409 - auc1: 0.7797 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:03:44 - loss: 0.6167 - binary_accuracy: 0.7349 - auc2: 0.7433 - auc1: 0.7819 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:02:57 - loss: 0.6138 - binary_accuracy: 0.7380 - auc2: 0.7457 - auc1: 0.7855 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:02:06 - loss: 0.6122 - binary_accuracy: 0.7382 - auc2: 0.7478 - auc1: 0.7856 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:01:25 - loss: 0.6097 - binary_accuracy: 0.7401 - auc2: 0.7498 - auc1: 0.7880 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:00:52 - loss: 0.6078 - binary_accuracy: 0.7417 - auc2: 0.7516 - auc1: 0.7883 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 1:00:20 - loss: 0.6064 - binary_accuracy: 0.7419 - auc2: 0.7533 - auc1: 0.7891 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 59:50 - loss: 0.6038 - binary_accuracy: 0.7445 - auc2: 0.7549 - auc1: 0.7921 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - ETA: 59:20 - loss: 0.6017 - binary_accuracy: 0.7462 - auc2: 0.7565 - auc1: 0.7938 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 58:53 - loss: 0.6000 - binary_accuracy: 0.7473 - auc2: 0.7580 - auc1: 0.7949 - TPR: 0.0000e+00 - FPR: 0.0000e+ - ETA: 58:28 - loss: 0.5983 - binary_accuracy: 0.7478 - auc2: 0.7594 - auc1: 0.7970 - TPR: 0.0000e+00 - FPR: 0.0000e+00

# %%
from inscopefilter import*
if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=4, 
                    use_multiprocessing=True, 
#                    shuffle=False,
#                    max_queue_size = 10, 
                    callbacks=[earlystop, checkpoint]
                    )
# Out:
# RDKit WARNING: [10:40:49] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Loading data...
# inscopedata: 1534410it [00:02, 523483.16it/s]
# inscopedata: 1789651it [00:04, 426129.12it/s]
# total samples: 3317345
# shuffle is over...
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 16384)        0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16384)        0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         16778240    lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# highway_1 (Highway)             (None, 1024)         2099200     dropout_1[0][0]
# __________________________________________________________________________________________________
# highway_2 (Highway)             (None, 1024)         2099200     highway_1[0][0]
# __________________________________________________________________________________________________
# highway_3 (Highway)             (None, 1024)         2099200     highway_2[0][0]
# __________________________________________________________________________________________________
# highway_4 (Highway)             (None, 1024)         2099200     highway_3[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 2048)         0
# __________________________________________________________________________________________________
# highway_5 (Highway)             (None, 1024)         2099200     highway_4[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1024)         2098176     input_2[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1)            0           highway_5[0][0]
#                                                                  dense_12[0][0]
# ==================================================================================================
# Total params: 29,372,416
# Trainable params: 29,372,416
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\metrics_impl.py:526: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\metrics_impl.py:788: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/2000
#  - 1294s - loss: 0.2772 - binary_accuracy: 0.8914 - ACCR: 0.6979 - ACCR5: 0.7251 - auc2: 0.9345 - auc1: 0.9570 - TPR: 0.1330 - FPR: 0.0011 - val_loss: 0.2013 - val_binary_accuracy: 0.9146 - val_ACCR: 0.7371 - val_ACCR5: 0.7856 - val_auc2: 0.9595 - val_auc1: 0.9725 - val_TPR: 0.2472 - val_FPR: 0.0018
#
# Epoch 00001: val_ACCR improved from -inf to 0.73714, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 2/2000
#  - 1188s - loss: 0.2080 - binary_accuracy: 0.9214 - ACCR: 0.7550 - ACCR5: 0.7793 - auc2: 0.9650 - auc1: 0.9757 - TPR: 0.2992 - FPR: 0.0022 - val_loss: 0.1816 - val_binary_accuracy: 0.9232 - val_ACCR: 0.7707 - val_ACCR5: 0.7915 - val_auc2: 0.9683 - val_auc1: 0.9763 - val_TPR: 0.3458 - val_FPR: 0.0028
#
# Epoch 00002: val_ACCR improved from 0.73714 to 0.77066, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 3/2000
#  - 1210s - loss: 0.1852 - binary_accuracy: 0.9310 - ACCR: 0.7839 - ACCR5: 0.7999 - auc2: 0.9708 - auc1: 0.9803 - TPR: 0.3834 - FPR: 0.0027 - val_loss: 0.1857 - val_binary_accuracy: 0.9287 - val_ACCR: 0.7944 - val_ACCR5: 0.8058 - val_auc2: 0.9727 - val_auc1: 0.9790 - val_TPR: 0.4156 - val_FPR: 0.0037
#
# Epoch 00003: val_ACCR improved from 0.77066 to 0.79438, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 4/2000
#  - 1214s - loss: 0.1712 - binary_accuracy: 0.9367 - ACCR: 0.8039 - ACCR5: 0.8058 - auc2: 0.9743 - auc1: 0.9829 - TPR: 0.4418 - FPR: 0.0032 - val_loss: 0.1603 - val_binary_accuracy: 0.9272 - val_ACCR: 0.8044 - val_ACCR5: 0.7919 - val_auc2: 0.9754 - val_auc1: 0.9781 - val_TPR: 0.4452 - val_FPR: 0.0042
#
# Epoch 00004: val_ACCR improved from 0.79438 to 0.80439, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 5/2000
#  - 1188s - loss: 0.1602 - binary_accuracy: 0.9410 - ACCR: 0.8199 - ACCR5: 0.8137 - auc2: 0.9765 - auc1: 0.9848 - TPR: 0.4886 - FPR: 0.0036 - val_loss: 0.2084 - val_binary_accuracy: 0.9286 - val_ACCR: 0.8216 - val_ACCR5: 0.7946 - val_auc2: 0.9773 - val_auc1: 0.9787 - val_TPR: 0.4973 - val_FPR: 0.0054
#
# Epoch 00005: val_ACCR improved from 0.80439 to 0.82165, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 6/2000
#  - 1188s - loss: 0.1520 - binary_accuracy: 0.9445 - ACCR: 0.8299 - ACCR5: 0.8164 - auc2: 0.9782 - auc1: 0.9863 - TPR: 0.5174 - FPR: 0.0036 - val_loss: 0.1671 - val_binary_accuracy: 0.9297 - val_ACCR: 0.8338 - val_ACCR5: 0.8114 - val_auc2: 0.9789 - val_auc1: 0.9791 - val_TPR: 0.5339 - val_FPR: 0.0064
#
# Epoch 00006: val_ACCR improved from 0.82165 to 0.83377, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 7/2000
#  - 1188s - loss: 0.1440 - binary_accuracy: 0.9474 - ACCR: 0.8415 - ACCR5: 0.8219 - auc2: 0.9796 - auc1: 0.9875 - TPR: 0.5512 - FPR: 0.0038 - val_loss: 0.1907 - val_binary_accuracy: 0.9299 - val_ACCR: 0.8432 - val_ACCR5: 0.8087 - val_auc2: 0.9801 - val_auc1: 0.9792 - val_TPR: 0.5633 - val_FPR: 0.0076
#
# Epoch 00007: val_ACCR improved from 0.83377 to 0.84317, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 8/2000
#  - 1188s - loss: 0.1389 - binary_accuracy: 0.9494 - ACCR: 0.8498 - ACCR5: 0.8304 - auc2: 0.9806 - auc1: 0.9882 - TPR: 0.5754 - FPR: 0.0040 - val_loss: 0.1682 - val_binary_accuracy: 0.9294 - val_ACCR: 0.8466 - val_ACCR5: 0.8159 - val_auc2: 0.9811 - val_auc1: 0.9784 - val_TPR: 0.5737 - val_FPR: 0.0079
#
# Epoch 00008: val_ACCR improved from 0.84317 to 0.84659, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 9/2000
#  - 1190s - loss: 0.1355 - binary_accuracy: 0.9507 - ACCR: 0.8551 - ACCR5: 0.8293 - auc2: 0.9816 - auc1: 0.9888 - TPR: 0.5906 - FPR: 0.0041 - val_loss: 0.2109 - val_binary_accuracy: 0.9283 - val_ACCR: 0.8475 - val_ACCR5: 0.8219 - val_auc2: 0.9819 - val_auc1: 0.9777 - val_TPR: 0.5769 - val_FPR: 0.0083
#
# Epoch 00009: val_ACCR improved from 0.84659 to 0.84748, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 10/2000
#  - 1222s - loss: 0.1313 - binary_accuracy: 0.9525 - ACCR: 0.8603 - ACCR5: 0.8310 - auc2: 0.9823 - auc1: 0.9894 - TPR: 0.6056 - FPR: 0.0040 - val_loss: 0.2076 - val_binary_accuracy: 0.9286 - val_ACCR: 0.8586 - val_ACCR5: 0.8191 - val_auc2: 0.9827 - val_auc1: 0.9781 - val_TPR: 0.6119 - val_FPR: 0.0098
#
# Epoch 00010: val_ACCR improved from 0.84748 to 0.85862, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 11/2000
#  - 1213s - loss: 0.1287 - binary_accuracy: 0.9535 - ACCR: 0.8652 - ACCR5: 0.8364 - auc2: 0.9830 - auc1: 0.9898 - TPR: 0.6201 - FPR: 0.0042 - val_loss: 0.2153 - val_binary_accuracy: 0.9297 - val_ACCR: 0.8528 - val_ACCR5: 0.8378 - val_auc2: 0.9833 - val_auc1: 0.9778 - val_TPR: 0.5936 - val_FPR: 0.0091
#
# Epoch 00011: val_ACCR did not improve from 0.85862
# Epoch 12/2000
#  - 1214s - loss: 0.1276 - binary_accuracy: 0.9538 - ACCR: 0.8672 - ACCR5: 0.8386 - auc2: 0.9836 - auc1: 0.9900 - TPR: 0.6259 - FPR: 0.0042 - val_loss: 0.2297 - val_binary_accuracy: 0.9293 - val_ACCR: 0.8553 - val_ACCR5: 0.8252 - val_auc2: 0.9838 - val_auc1: 0.9784 - val_TPR: 0.6017 - val_FPR: 0.0094
#
# Epoch 00012: val_ACCR did not improve from 0.85862
# Epoch 13/2000
#  - 1200s - loss: 0.1225 - binary_accuracy: 0.9557 - ACCR: 0.8724 - ACCR5: 0.8435 - auc2: 0.9841 - auc1: 0.9906 - TPR: 0.6408 - FPR: 0.0042 - val_loss: 0.2044 - val_binary_accuracy: 0.9297 - val_ACCR: 0.8597 - val_ACCR5: 0.8232 - val_auc2: 0.9843 - val_auc1: 0.9785 - val_TPR: 0.6153 - val_FPR: 0.0101
#
# Epoch 00013: val_ACCR improved from 0.85862 to 0.85970, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 14/2000
#  - 1192s - loss: 0.1226 - binary_accuracy: 0.9556 - ACCR: 0.8734 - ACCR5: 0.8384 - auc2: 0.9846 - auc1: 0.9906 - TPR: 0.6436 - FPR: 0.0042 - val_loss: 0.2128 - val_binary_accuracy: 0.9275 - val_ACCR: 0.8601 - val_ACCR5: 0.8224 - val_auc2: 0.9847 - val_auc1: 0.9775 - val_TPR: 0.6173 - val_FPR: 0.0105
#
# Epoch 00014: val_ACCR improved from 0.85970 to 0.86007, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 15/2000
#  - 1186s - loss: 0.1224 - binary_accuracy: 0.9556 - ACCR: 0.8732 - ACCR5: 0.8392 - auc2: 0.9848 - auc1: 0.9907 - TPR: 0.6429 - FPR: 0.0041 - val_loss: 0.1398 - val_binary_accuracy: 0.9291 - val_ACCR: 0.8601 - val_ACCR5: 0.8312 - val_auc2: 0.9851 - val_auc1: 0.9779 - val_TPR: 0.6173 - val_FPR: 0.0104
#
# Epoch 00015: val_ACCR improved from 0.86007 to 0.86015, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 16/2000
#  - 1184s - loss: 0.1188 - binary_accuracy: 0.9567 - ACCR: 0.8788 - ACCR5: 0.8456 - auc2: 0.9852 - auc1: 0.9911 - TPR: 0.6594 - FPR: 0.0043 - val_loss: 0.2068 - val_binary_accuracy: 0.9290 - val_ACCR: 0.8681 - val_ACCR5: 0.8285 - val_auc2: 0.9854 - val_auc1: 0.9779 - val_TPR: 0.6427 - val_FPR: 0.0117
#
# Epoch 00016: val_ACCR improved from 0.86015 to 0.86811, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 17/2000
#  - 1201s - loss: 0.1158 - binary_accuracy: 0.9581 - ACCR: 0.8818 - ACCR5: 0.8512 - auc2: 0.9856 - auc1: 0.9915 - TPR: 0.6679 - FPR: 0.0042 - val_loss: 0.1783 - val_binary_accuracy: 0.9289 - val_ACCR: 0.8691 - val_ACCR5: 0.8415 - val_auc2: 0.9857 - val_auc1: 0.9773 - val_TPR: 0.6459 - val_FPR: 0.0121
#
# Epoch 00017: val_ACCR improved from 0.86811 to 0.86905, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 18/2000
#  - 1190s - loss: 0.1149 - binary_accuracy: 0.9585 - ACCR: 0.8833 - ACCR5: 0.8497 - auc2: 0.9858 - auc1: 0.9916 - TPR: 0.6719 - FPR: 0.0041 - val_loss: 0.1683 - val_binary_accuracy: 0.9288 - val_ACCR: 0.8661 - val_ACCR5: 0.8378 - val_auc2: 0.9860 - val_auc1: 0.9775 - val_TPR: 0.6364 - val_FPR: 0.0114
#
# Epoch 00018: val_ACCR did not improve from 0.86905
# Epoch 19/2000
#  - 1188s - loss: 0.1224 - binary_accuracy: 0.9551 - ACCR: 0.8763 - ACCR5: 0.8363 - auc2: 0.9861 - auc1: 0.9906 - TPR: 0.6523 - FPR: 0.0043 - val_loss: 0.1493 - val_binary_accuracy: 0.9273 - val_ACCR: 0.8648 - val_ACCR5: 0.8254 - val_auc2: 0.9862 - val_auc1: 0.9769 - val_TPR: 0.6334 - val_FPR: 0.0120
#
# Epoch 00019: val_ACCR did not improve from 0.86905
# Epoch 20/2000
#  - 1187s - loss: 0.1267 - binary_accuracy: 0.9533 - ACCR: 0.8721 - ACCR5: 0.8350 - auc2: 0.9863 - auc1: 0.9900 - TPR: 0.6403 - FPR: 0.0044 - val_loss: 0.1826 - val_binary_accuracy: 0.9264 - val_ACCR: 0.8591 - val_ACCR5: 0.8161 - val_auc2: 0.9863 - val_auc1: 0.9769 - val_TPR: 0.6158 - val_FPR: 0.0111
#
# Epoch 00020: val_ACCR did not improve from 0.86905
# Epoch 21/2000
#  - 1192s - loss: 0.1255 - binary_accuracy: 0.9538 - ACCR: 0.8750 - ACCR5: 0.8377 - auc2: 0.9863 - auc1: 0.9901 - TPR: 0.6487 - FPR: 0.0044 - val_loss: 0.2203 - val_binary_accuracy: 0.9273 - val_ACCR: 0.8707 - val_ACCR5: 0.8163 - val_auc2: 0.9864 - val_auc1: 0.9775 - val_TPR: 0.6518 - val_FPR: 0.0126
#
# Epoch 00021: val_ACCR improved from 0.86905 to 0.87073, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 22/2000
#  - 1211s - loss: 0.1223 - binary_accuracy: 0.9551 - ACCR: 0.8783 - ACCR5: 0.8424 - auc2: 0.9866 - auc1: 0.9906 - TPR: 0.6580 - FPR: 0.0044 - val_loss: 0.1661 - val_binary_accuracy: 0.9280 - val_ACCR: 0.8666 - val_ACCR5: 0.8238 - val_auc2: 0.9866 - val_auc1: 0.9776 - val_TPR: 0.6378 - val_FPR: 0.0115
#
# Epoch 00022: val_ACCR did not improve from 0.87073
# Epoch 23/2000
#  - 1190s - loss: 0.1203 - binary_accuracy: 0.9558 - ACCR: 0.8800 - ACCR5: 0.8409 - auc2: 0.9867 - auc1: 0.9909 - TPR: 0.6628 - FPR: 0.0043 - val_loss: 0.1687 - val_binary_accuracy: 0.9280 - val_ACCR: 0.8663 - val_ACCR5: 0.8320 - val_auc2: 0.9867 - val_auc1: 0.9773 - val_TPR: 0.6366 - val_FPR: 0.0112
#
# Epoch 00023: val_ACCR did not improve from 0.87073
# Epoch 24/2000
#  - 1213s - loss: 0.1191 - binary_accuracy: 0.9564 - ACCR: 0.8811 - ACCR5: 0.8443 - auc2: 0.9868 - auc1: 0.9910 - TPR: 0.6660 - FPR: 0.0043 - val_loss: 0.1980 - val_binary_accuracy: 0.9288 - val_ACCR: 0.8728 - val_ACCR5: 0.8234 - val_auc2: 0.9869 - val_auc1: 0.9779 - val_TPR: 0.6577 - val_FPR: 0.0126
#
# Epoch 00024: val_ACCR improved from 0.87073 to 0.87275, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 25/2000
#  - 1214s - loss: 0.1152 - binary_accuracy: 0.9580 - ACCR: 0.8849 - ACCR5: 0.8468 - auc2: 0.9869 - auc1: 0.9916 - TPR: 0.6767 - FPR: 0.0042 - val_loss: 0.2025 - val_binary_accuracy: 0.9283 - val_ACCR: 0.8711 - val_ACCR5: 0.8376 - val_auc2: 0.9870 - val_auc1: 0.9772 - val_TPR: 0.6519 - val_FPR: 0.0121
#
# Epoch 00025: val_ACCR did not improve from 0.87275
# Epoch 26/2000
#  - 1187s - loss: 0.1143 - binary_accuracy: 0.9581 - ACCR: 0.8867 - ACCR5: 0.8493 - auc2: 0.9871 - auc1: 0.9917 - TPR: 0.6819 - FPR: 0.0042 - val_loss: 0.2517 - val_binary_accuracy: 0.9283 - val_ACCR: 0.8640 - val_ACCR5: 0.8516 - val_auc2: 0.9871 - val_auc1: 0.9763 - val_TPR: 0.6288 - val_FPR: 0.0107
#
# Epoch 00026: val_ACCR did not improve from 0.87275
# Epoch 27/2000
#  - 1200s - loss: 0.1122 - binary_accuracy: 0.9590 - ACCR: 0.8899 - ACCR5: 0.8496 - auc2: 0.9873 - auc1: 0.9920 - TPR: 0.6912 - FPR: 0.0042 - val_loss: 0.2862 - val_binary_accuracy: 0.9294 - val_ACCR: 0.8776 - val_ACCR5: 0.8442 - val_auc2: 0.9873 - val_auc1: 0.9773 - val_TPR: 0.6717 - val_FPR: 0.0126
#
# Epoch 00027: val_ACCR improved from 0.87275 to 0.87764, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 28/2000
#  - 1201s - loss: 0.1081 - binary_accuracy: 0.9605 - ACCR: 0.8934 - ACCR5: 0.8575 - auc2: 0.9873 - auc1: 0.9925 - TPR: 0.7011 - FPR: 0.0041 - val_loss: 0.2125 - val_binary_accuracy: 0.9294 - val_ACCR: 0.8806 - val_ACCR5: 0.8431 - val_auc2: 0.9874 - val_auc1: 0.9772 - val_TPR: 0.6822 - val_FPR: 0.0137
#
# Epoch 00028: val_ACCR improved from 0.87764 to 0.88063, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 29/2000
#  - 1224s - loss: 0.1071 - binary_accuracy: 0.9607 - ACCR: 0.8952 - ACCR5: 0.8603 - auc2: 0.9876 - auc1: 0.9927 - TPR: 0.7063 - FPR: 0.0041 - val_loss: 0.2941 - val_binary_accuracy: 0.9294 - val_ACCR: 0.8775 - val_ACCR5: 0.8465 - val_auc2: 0.9876 - val_auc1: 0.9768 - val_TPR: 0.6716 - val_FPR: 0.0129
#
# Epoch 00029: val_ACCR did not improve from 0.88063
# Epoch 30/2000
#  - 1208s - loss: 0.1055 - binary_accuracy: 0.9615 - ACCR: 0.8970 - ACCR5: 0.8619 - auc2: 0.9877 - auc1: 0.9929 - TPR: 0.7112 - FPR: 0.0041 - val_loss: 0.2227 - val_binary_accuracy: 0.9294 - val_ACCR: 0.8828 - val_ACCR5: 0.8436 - val_auc2: 0.9877 - val_auc1: 0.9774 - val_TPR: 0.6891 - val_FPR: 0.0139
#
# Epoch 00030: val_ACCR improved from 0.88063 to 0.88281, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 31/2000
#  - 1201s - loss: 0.1049 - binary_accuracy: 0.9617 - ACCR: 0.8978 - ACCR5: 0.8633 - auc2: 0.9878 - auc1: 0.9930 - TPR: 0.7135 - FPR: 0.0041 - val_loss: 0.2616 - val_binary_accuracy: 0.9283 - val_ACCR: 0.8770 - val_ACCR5: 0.8396 - val_auc2: 0.9879 - val_auc1: 0.9767 - val_TPR: 0.6708 - val_FPR: 0.0131
#
# Epoch 00031: val_ACCR did not improve from 0.88281
# Epoch 32/2000
#  - 1190s - loss: 0.1027 - binary_accuracy: 0.9626 - ACCR: 0.8995 - ACCR5: 0.8647 - auc2: 0.9879 - auc1: 0.9932 - TPR: 0.7183 - FPR: 0.0040 - val_loss: 0.1749 - val_binary_accuracy: 0.9283 - val_ACCR: 0.8747 - val_ACCR5: 0.8501 - val_auc2: 0.9880 - val_auc1: 0.9761 - val_TPR: 0.6632 - val_FPR: 0.0125
#
# Epoch 00032: val_ACCR did not improve from 0.88281
# Epoch 33/2000
#  - 1188s - loss: 0.1020 - binary_accuracy: 0.9629 - ACCR: 0.9001 - ACCR5: 0.8610 - auc2: 0.9881 - auc1: 0.9933 - TPR: 0.7200 - FPR: 0.0039 - val_loss: 0.1949 - val_binary_accuracy: 0.9299 - val_ACCR: 0.8816 - val_ACCR5: 0.8467 - val_auc2: 0.9881 - val_auc1: 0.9768 - val_TPR: 0.6855 - val_FPR: 0.0138
#
# Epoch 00033: val_ACCR did not improve from 0.88281
# Epoch 34/2000
#  - 1216s - loss: 0.0996 - binary_accuracy: 0.9640 - ACCR: 0.9036 - ACCR5: 0.8673 - auc2: 0.9882 - auc1: 0.9936 - TPR: 0.7302 - FPR: 0.0040 - val_loss: 0.2054 - val_binary_accuracy: 0.9291 - val_ACCR: 0.8846 - val_ACCR5: 0.8497 - val_auc2: 0.9882 - val_auc1: 0.9758 - val_TPR: 0.6949 - val_FPR: 0.0144
#
# Epoch 00034: val_ACCR improved from 0.88281 to 0.88457, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 35/2000
#  - 1203s - loss: 0.0994 - binary_accuracy: 0.9639 - ACCR: 0.9045 - ACCR5: 0.8679 - auc2: 0.9883 - auc1: 0.9936 - TPR: 0.7325 - FPR: 0.0039 - val_loss: 0.1528 - val_binary_accuracy: 0.9298 - val_ACCR: 0.8873 - val_ACCR5: 0.8515 - val_auc2: 0.9884 - val_auc1: 0.9763 - val_TPR: 0.7038 - val_FPR: 0.0149
#
# Epoch 00035: val_ACCR improved from 0.88457 to 0.88732, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 36/2000
#  - 1223s - loss: 0.0974 - binary_accuracy: 0.9648 - ACCR: 0.9064 - ACCR5: 0.8705 - auc2: 0.9884 - auc1: 0.9938 - TPR: 0.7379 - FPR: 0.0039 - val_loss: 0.2674 - val_binary_accuracy: 0.9291 - val_ACCR: 0.8851 - val_ACCR5: 0.8507 - val_auc2: 0.9885 - val_auc1: 0.9758 - val_TPR: 0.6963 - val_FPR: 0.0143
#
# Epoch 00036: val_ACCR did not improve from 0.88732
# Epoch 37/2000
#  - 1196s - loss: 0.0965 - binary_accuracy: 0.9651 - ACCR: 0.9071 - ACCR5: 0.8682 - auc2: 0.9886 - auc1: 0.9939 - TPR: 0.7400 - FPR: 0.0038 - val_loss: 0.2634 - val_binary_accuracy: 0.9296 - val_ACCR: 0.8859 - val_ACCR5: 0.8482 - val_auc2: 0.9886 - val_auc1: 0.9766 - val_TPR: 0.6990 - val_FPR: 0.0144
#
# Epoch 00037: val_ACCR did not improve from 0.88732
# Epoch 38/2000
#  - 1198s - loss: 0.0958 - binary_accuracy: 0.9653 - ACCR: 0.9086 - ACCR5: 0.8711 - auc2: 0.9887 - auc1: 0.9940 - TPR: 0.7441 - FPR: 0.0038 - val_loss: 0.2718 - val_binary_accuracy: 0.9295 - val_ACCR: 0.8901 - val_ACCR5: 0.8494 - val_auc2: 0.9887 - val_auc1: 0.9763 - val_TPR: 0.7131 - val_FPR: 0.0156
#
# Epoch 00038: val_ACCR improved from 0.88732 to 0.89011, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 39/2000
#  - 1184s - loss: 0.0941 - binary_accuracy: 0.9659 - ACCR: 0.9109 - ACCR5: 0.8745 - auc2: 0.9888 - auc1: 0.9942 - TPR: 0.7507 - FPR: 0.0038 - val_loss: 0.2117 - val_binary_accuracy: 0.9304 - val_ACCR: 0.8873 - val_ACCR5: 0.8567 - val_auc2: 0.9888 - val_auc1: 0.9764 - val_TPR: 0.7039 - val_FPR: 0.0148
#
# Epoch 00039: val_ACCR did not improve from 0.89011
# Epoch 40/2000
#  - 1186s - loss: 0.0926 - binary_accuracy: 0.9665 - ACCR: 0.9122 - ACCR5: 0.8766 - auc2: 0.9888 - auc1: 0.9944 - TPR: 0.7546 - FPR: 0.0038 - val_loss: 0.2027 - val_binary_accuracy: 0.9300 - val_ACCR: 0.8892 - val_ACCR5: 0.8537 - val_auc2: 0.9889 - val_auc1: 0.9763 - val_TPR: 0.7100 - val_FPR: 0.0153
#
# Epoch 00040: val_ACCR did not improve from 0.89011
# Epoch 41/2000
#  - 1208s - loss: 0.0924 - binary_accuracy: 0.9667 - ACCR: 0.9127 - ACCR5: 0.8782 - auc2: 0.9891 - auc1: 0.9944 - TPR: 0.7559 - FPR: 0.0037 - val_loss: 0.1527 - val_binary_accuracy: 0.9290 - val_ACCR: 0.8873 - val_ACCR5: 0.8486 - val_auc2: 0.9890 - val_auc1: 0.9753 - val_TPR: 0.7049 - val_FPR: 0.0154
#
# Epoch 00041: val_ACCR did not improve from 0.89011
# Epoch 42/2000
#  - 1184s - loss: 0.0918 - binary_accuracy: 0.9669 - ACCR: 0.9140 - ACCR5: 0.8782 - auc2: 0.9891 - auc1: 0.9945 - TPR: 0.7595 - FPR: 0.0037 - val_loss: 0.1983 - val_binary_accuracy: 0.9296 - val_ACCR: 0.8891 - val_ACCR5: 0.8570 - val_auc2: 0.9891 - val_auc1: 0.9755 - val_TPR: 0.7097 - val_FPR: 0.0153
#
# Epoch 00042: val_ACCR did not improve from 0.89011
# Epoch 43/2000
#  - 1201s - loss: 0.0923 - binary_accuracy: 0.9665 - ACCR: 0.9141 - ACCR5: 0.8771 - auc2: 0.9892 - auc1: 0.9944 - TPR: 0.7600 - FPR: 0.0037 - val_loss: 0.3196 - val_binary_accuracy: 0.9293 - val_ACCR: 0.8883 - val_ACCR5: 0.8593 - val_auc2: 0.9892 - val_auc1: 0.9755 - val_TPR: 0.7070 - val_FPR: 0.0150
#
# Epoch 00043: val_ACCR did not improve from 0.89011
# Epoch 44/2000
#  - 1190s - loss: 0.0908 - binary_accuracy: 0.9671 - ACCR: 0.9149 - ACCR5: 0.8795 - auc2: 0.9893 - auc1: 0.9946 - TPR: 0.7618 - FPR: 0.0036 - val_loss: 0.1742 - val_binary_accuracy: 0.9283 - val_ACCR: 0.8953 - val_ACCR5: 0.8503 - val_auc2: 0.9893 - val_auc1: 0.9759 - val_TPR: 0.7311 - val_FPR: 0.0171
#
# Epoch 00044: val_ACCR improved from 0.89011 to 0.89528, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 45/2000
#  - 1204s - loss: 0.0889 - binary_accuracy: 0.9679 - ACCR: 0.9169 - ACCR5: 0.8813 - auc2: 0.9893 - auc1: 0.9948 - TPR: 0.7677 - FPR: 0.0036 - val_loss: 0.2224 - val_binary_accuracy: 0.9293 - val_ACCR: 0.8908 - val_ACCR5: 0.8609 - val_auc2: 0.9894 - val_auc1: 0.9755 - val_TPR: 0.7151 - val_FPR: 0.0155
#
# Epoch 00045: val_ACCR did not improve from 0.89528
# Epoch 46/2000
#  - 1210s - loss: 0.0882 - binary_accuracy: 0.9682 - ACCR: 0.9174 - ACCR5: 0.8824 - auc2: 0.9895 - auc1: 0.9949 - TPR: 0.7691 - FPR: 0.0036 - val_loss: 0.1582 - val_binary_accuracy: 0.9288 - val_ACCR: 0.8941 - val_ACCR5: 0.8556 - val_auc2: 0.9895 - val_auc1: 0.9758 - val_TPR: 0.7277 - val_FPR: 0.0170
#
# Epoch 00046: val_ACCR did not improve from 0.89528
# Epoch 47/2000
#  - 1202s - loss: 0.0869 - binary_accuracy: 0.9686 - ACCR: 0.9193 - ACCR5: 0.8829 - auc2: 0.9896 - auc1: 0.9950 - TPR: 0.7746 - FPR: 0.0036 - val_loss: 0.1820 - val_binary_accuracy: 0.9292 - val_ACCR: 0.8937 - val_ACCR5: 0.8576 - val_auc2: 0.9896 - val_auc1: 0.9756 - val_TPR: 0.7259 - val_FPR: 0.0167
#
# Epoch 00047: val_ACCR did not improve from 0.89528
# Epoch 48/2000
#  - 1200s - loss: 0.0849 - binary_accuracy: 0.9696 - ACCR: 0.9210 - ACCR5: 0.8856 - auc2: 0.9897 - auc1: 0.9952 - TPR: 0.7794 - FPR: 0.0035 - val_loss: 0.1343 - val_binary_accuracy: 0.9299 - val_ACCR: 0.8921 - val_ACCR5: 0.8580 - val_auc2: 0.9897 - val_auc1: 0.9756 - val_TPR: 0.7194 - val_FPR: 0.0158
#
# Epoch 00048: val_ACCR did not improve from 0.89528
# Epoch 49/2000
#  - 1188s - loss: 0.0849 - binary_accuracy: 0.9696 - ACCR: 0.9213 - ACCR5: 0.8821 - auc2: 0.9897 - auc1: 0.9952 - TPR: 0.7802 - FPR: 0.0035 - val_loss: 0.1572 - val_binary_accuracy: 0.9295 - val_ACCR: 0.8954 - val_ACCR5: 0.8608 - val_auc2: 0.9898 - val_auc1: 0.9756 - val_TPR: 0.7308 - val_FPR: 0.0168
#
# Epoch 00049: val_ACCR improved from 0.89528 to 0.89544, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 50/2000
#  - 1185s - loss: 0.0836 - binary_accuracy: 0.9700 - ACCR: 0.9226 - ACCR5: 0.8875 - auc2: 0.9898 - auc1: 0.9954 - TPR: 0.7838 - FPR: 0.0035 - val_loss: 0.1727 - val_binary_accuracy: 0.9296 - val_ACCR: 0.8945 - val_ACCR5: 0.8667 - val_auc2: 0.9899 - val_auc1: 0.9747 - val_TPR: 0.7283 - val_FPR: 0.0169
#
# Epoch 00050: val_ACCR did not improve from 0.89544
# Epoch 51/2000
#  - 1194s - loss: 0.0824 - binary_accuracy: 0.9704 - ACCR: 0.9238 - ACCR5: 0.8884 - auc2: 0.9899 - auc1: 0.9955 - TPR: 0.7872 - FPR: 0.0034 - val_loss: 0.1968 - val_binary_accuracy: 0.9294 - val_ACCR: 0.8927 - val_ACCR5: 0.8669 - val_auc2: 0.9900 - val_auc1: 0.9744 - val_TPR: 0.7219 - val_FPR: 0.0163
#
# Epoch 00051: val_ACCR did not improve from 0.89544
# Epoch 52/2000
#  - 1204s - loss: 0.0819 - binary_accuracy: 0.9706 - ACCR: 0.9247 - ACCR5: 0.8893 - auc2: 0.9901 - auc1: 0.9955 - TPR: 0.7897 - FPR: 0.0034 - val_loss: 0.1683 - val_binary_accuracy: 0.9293 - val_ACCR: 0.8953 - val_ACCR5: 0.8675 - val_auc2: 0.9900 - val_auc1: 0.9743 - val_TPR: 0.7304 - val_FPR: 0.0167
#
# Epoch 00052: val_ACCR did not improve from 0.89544
# Epoch 53/2000
#  - 1193s - loss: 0.0817 - binary_accuracy: 0.9706 - ACCR: 0.9255 - ACCR5: 0.8890 - auc2: 0.9901 - auc1: 0.9955 - TPR: 0.7922 - FPR: 0.0034 - val_loss: 0.2789 - val_binary_accuracy: 0.9289 - val_ACCR: 0.8983 - val_ACCR5: 0.8567 - val_auc2: 0.9901 - val_auc1: 0.9744 - val_TPR: 0.7414 - val_FPR: 0.0181
#
# Epoch 00053: val_ACCR improved from 0.89544 to 0.89830, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 54/2000
#  - 1202s - loss: 0.0804 - binary_accuracy: 0.9712 - ACCR: 0.9263 - ACCR5: 0.8863 - auc2: 0.9902 - auc1: 0.9957 - TPR: 0.7941 - FPR: 0.0033 - val_loss: 0.1818 - val_binary_accuracy: 0.9291 - val_ACCR: 0.8969 - val_ACCR5: 0.8497 - val_auc2: 0.9902 - val_auc1: 0.9757 - val_TPR: 0.7369 - val_FPR: 0.0178
#
# Epoch 00054: val_ACCR did not improve from 0.89830
# Epoch 55/2000
#  - 1197s - loss: 0.0804 - binary_accuracy: 0.9711 - ACCR: 0.9265 - ACCR5: 0.8875 - auc2: 0.9902 - auc1: 0.9957 - TPR: 0.7949 - FPR: 0.0034 - val_loss: 0.2290 - val_binary_accuracy: 0.9295 - val_ACCR: 0.9017 - val_ACCR5: 0.8594 - val_auc2: 0.9903 - val_auc1: 0.9753 - val_TPR: 0.7527 - val_FPR: 0.0189
#
# Epoch 00055: val_ACCR improved from 0.89830 to 0.90170, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 56/2000
#  - 1189s - loss: 0.0786 - binary_accuracy: 0.9719 - ACCR: 0.9284 - ACCR5: 0.8921 - auc2: 0.9902 - auc1: 0.9958 - TPR: 0.8003 - FPR: 0.0033 - val_loss: 0.2580 - val_binary_accuracy: 0.9288 - val_ACCR: 0.8967 - val_ACCR5: 0.8695 - val_auc2: 0.9904 - val_auc1: 0.9728 - val_TPR: 0.7358 - val_FPR: 0.0175
#
# Epoch 00056: val_ACCR did not improve from 0.90170
# Epoch 57/2000
#  - 1186s - loss: 0.0776 - binary_accuracy: 0.9722 - ACCR: 0.9297 - ACCR5: 0.8930 - auc2: 0.9904 - auc1: 0.9959 - TPR: 0.8038 - FPR: 0.0032 - val_loss: 0.1849 - val_binary_accuracy: 0.9290 - val_ACCR: 0.8981 - val_ACCR5: 0.8675 - val_auc2: 0.9904 - val_auc1: 0.9739 - val_TPR: 0.7405 - val_FPR: 0.0179
#
# Epoch 00057: val_ACCR did not improve from 0.90170
# Epoch 58/2000
#  - 1215s - loss: 0.0777 - binary_accuracy: 0.9720 - ACCR: 0.9297 - ACCR5: 0.8887 - auc2: 0.9905 - auc1: 0.9959 - TPR: 0.8038 - FPR: 0.0032 - val_loss: 0.3865 - val_binary_accuracy: 0.9291 - val_ACCR: 0.8985 - val_ACCR5: 0.8681 - val_auc2: 0.9905 - val_auc1: 0.9742 - val_TPR: 0.7416 - val_FPR: 0.0178
#
# Epoch 00058: val_ACCR did not improve from 0.90170
# Epoch 59/2000
#  - 1191s - loss: 0.0766 - binary_accuracy: 0.9725 - ACCR: 0.9314 - ACCR5: 0.8939 - auc2: 0.9905 - auc1: 0.9960 - TPR: 0.8086 - FPR: 0.0032 - val_loss: 0.2038 - val_binary_accuracy: 0.9288 - val_ACCR: 0.8999 - val_ACCR5: 0.8626 - val_auc2: 0.9906 - val_auc1: 0.9745 - val_TPR: 0.7459 - val_FPR: 0.0180
#
# Epoch 00059: val_ACCR did not improve from 0.90170
# Epoch 60/2000
#  - 1206s - loss: 0.0753 - binary_accuracy: 0.9729 - ACCR: 0.9320 - ACCR5: 0.8951 - auc2: 0.9906 - auc1: 0.9962 - TPR: 0.8105 - FPR: 0.0032 - val_loss: 0.1287 - val_binary_accuracy: 0.9291 - val_ACCR: 0.8983 - val_ACCR5: 0.8674 - val_auc2: 0.9906 - val_auc1: 0.9738 - val_TPR: 0.7418 - val_FPR: 0.0183
#
# Epoch 00060: val_ACCR did not improve from 0.90170
# Epoch 61/2000
#  - 1206s - loss: 0.0751 - binary_accuracy: 0.9731 - ACCR: 0.9330 - ACCR5: 0.8965 - auc2: 0.9907 - auc1: 0.9962 - TPR: 0.8131 - FPR: 0.0032 - val_loss: 0.2280 - val_binary_accuracy: 0.9292 - val_ACCR: 0.8982 - val_ACCR5: 0.8689 - val_auc2: 0.9907 - val_auc1: 0.9733 - val_TPR: 0.7410 - val_FPR: 0.0181
#
# Epoch 00061: val_ACCR did not improve from 0.90170
# Epoch 00061: early stopping

# %%
from inscopefilter import*
if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=4, 
                    use_multiprocessing=True, 
#                    shuffle=False,
#                    max_queue_size = 5, 
                    callbacks=[earlystop, checkpoint]
#                    callbacks=[checkpoint]
                    )
# Out:
# RDKit WARNING: [10:15:42] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Loading data...
# inscopedata: 1534410it [00:02, 524372.62it/s]
# inscopedata: 1789651it [00:04, 426333.71it/s]
# total samples: 3317345
# shuffle is over...
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 16384)        0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16384)        0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         16778240    lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# highway_1 (Highway)             (None, 1024)         2099200     dropout_1[0][0]
# __________________________________________________________________________________________________
# highway_2 (Highway)             (None, 1024)         2099200     highway_1[0][0]
# __________________________________________________________________________________________________
# highway_3 (Highway)             (None, 1024)         2099200     highway_2[0][0]
# __________________________________________________________________________________________________
# highway_4 (Highway)             (None, 1024)         2099200     highway_3[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 2048)         0
# __________________________________________________________________________________________________
# highway_5 (Highway)             (None, 1024)         2099200     highway_4[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1024)         2098176     input_2[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1)            0           highway_5[0][0]
#                                                                  dense_12[0][0]
# ==================================================================================================
# Total params: 29,372,416
# Trainable params: 29,372,416
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\metrics_impl.py:526: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\metrics_impl.py:788: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/2000
#  - 1643s - loss: 0.0779 - binary_accuracy: 0.9719 - ACCR: 0.9291 - ACCR5: 0.8885 - auc2: 0.9959 - auc1: 0.9959 - TPR: 0.8020 - FPR: 0.0032 - val_loss: 0.1852 - val_binary_accuracy: 0.9293 - val_ACCR: 0.9008 - val_ACCR5: 0.8589 - val_auc2: 0.9949 - val_auc1: 0.9751 - val_TPR: 0.7496 - val_FPR: 0.0187
#
# Epoch 00001: val_ACCR improved from -inf to 0.90076, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 2/2000
#  - 1492s - loss: 0.0761 - binary_accuracy: 0.9726 - ACCR: 0.9311 - ACCR5: 0.8926 - auc2: 0.9947 - auc1: 0.9961 - TPR: 0.8077 - FPR: 0.0032 - val_loss: 0.3268 - val_binary_accuracy: 0.9289 - val_ACCR: 0.9003 - val_ACCR5: 0.8682 - val_auc2: 0.9945 - val_auc1: 0.9743 - val_TPR: 0.7473 - val_FPR: 0.0182
#
# Epoch 00002: val_ACCR did not improve from 0.90076
# Epoch 3/2000
#  - 1485s - loss: 0.0753 - binary_accuracy: 0.9728 - ACCR: 0.9320 - ACCR5: 0.8916 - auc2: 0.9944 - auc1: 0.9962 - TPR: 0.8103 - FPR: 0.0032 - val_loss: 0.1482 - val_binary_accuracy: 0.9296 - val_ACCR: 0.8996 - val_ACCR5: 0.8665 - val_auc2: 0.9944 - val_auc1: 0.9740 - val_TPR: 0.7451 - val_FPR: 0.0181
#
# Epoch 00003: val_ACCR did not improve from 0.90076
# Epoch 4/2000
#  - 1481s - loss: 0.0749 - binary_accuracy: 0.9732 - ACCR: 0.9320 - ACCR5: 0.8926 - auc2: 0.9944 - auc1: 0.9962 - TPR: 0.8104 - FPR: 0.0031 - val_loss: 0.2563 - val_binary_accuracy: 0.9287 - val_ACCR: 0.9016 - val_ACCR5: 0.8637 - val_auc2: 0.9944 - val_auc1: 0.9739 - val_TPR: 0.7528 - val_FPR: 0.0190
#
# Epoch 00004: val_ACCR improved from 0.90076 to 0.90162, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 5/2000
#  - 1489s - loss: 0.0746 - binary_accuracy: 0.9733 - ACCR: 0.9334 - ACCR5: 0.8952 - auc2: 0.9944 - auc1: 0.9962 - TPR: 0.8142 - FPR: 0.0031 - val_loss: 0.1980 - val_binary_accuracy: 0.9292 - val_ACCR: 0.9024 - val_ACCR5: 0.8605 - val_auc2: 0.9943 - val_auc1: 0.9741 - val_TPR: 0.7550 - val_FPR: 0.0190
#
# Epoch 00005: val_ACCR improved from 0.90162 to 0.90236, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 6/2000
#  - 1479s - loss: 0.0737 - binary_accuracy: 0.9736 - ACCR: 0.9340 - ACCR5: 0.8927 - auc2: 0.9944 - auc1: 0.9963 - TPR: 0.8161 - FPR: 0.0031 - val_loss: 0.3257 - val_binary_accuracy: 0.9292 - val_ACCR: 0.9016 - val_ACCR5: 0.8658 - val_auc2: 0.9943 - val_auc1: 0.9736 - val_TPR: 0.7531 - val_FPR: 0.0193
#
# Epoch 00006: val_ACCR did not improve from 0.90236
# Epoch 7/2000
#  - 1500s - loss: 0.0731 - binary_accuracy: 0.9738 - ACCR: 0.9346 - ACCR5: 0.8959 - auc2: 0.9944 - auc1: 0.9964 - TPR: 0.8175 - FPR: 0.0031 - val_loss: 0.1839 - val_binary_accuracy: 0.9290 - val_ACCR: 0.8996 - val_ACCR5: 0.8639 - val_auc2: 0.9943 - val_auc1: 0.9740 - val_TPR: 0.7459 - val_FPR: 0.0184
#
# Epoch 00007: val_ACCR did not improve from 0.90236
# Epoch 8/2000
#  - 1512s - loss: 0.0715 - binary_accuracy: 0.9744 - ACCR: 0.9357 - ACCR5: 0.9019 - auc2: 0.9944 - auc1: 0.9965 - TPR: 0.8207 - FPR: 0.0030 - val_loss: 0.2796 - val_binary_accuracy: 0.9287 - val_ACCR: 0.9000 - val_ACCR5: 0.8696 - val_auc2: 0.9943 - val_auc1: 0.9731 - val_TPR: 0.7482 - val_FPR: 0.0191
#
# Epoch 00008: val_ACCR did not improve from 0.90236
# Epoch 9/2000
#  - 1499s - loss: 0.0711 - binary_accuracy: 0.9745 - ACCR: 0.9373 - ACCR5: 0.9002 - auc2: 0.9944 - auc1: 0.9965 - TPR: 0.8253 - FPR: 0.0031 - val_loss: 0.2191 - val_binary_accuracy: 0.9285 - val_ACCR: 0.9010 - val_ACCR5: 0.8679 - val_auc2: 0.9944 - val_auc1: 0.9731 - val_TPR: 0.7510 - val_FPR: 0.0192
#
# Epoch 00009: val_ACCR did not improve from 0.90236
# Epoch 10/2000
#  - 1500s - loss: 0.0698 - binary_accuracy: 0.9750 - ACCR: 0.9380 - ACCR5: 0.9027 - auc2: 0.9944 - auc1: 0.9966 - TPR: 0.8273 - FPR: 0.0030 - val_loss: 0.2122 - val_binary_accuracy: 0.9288 - val_ACCR: 0.9027 - val_ACCR5: 0.8750 - val_auc2: 0.9944 - val_auc1: 0.9725 - val_TPR: 0.7571 - val_FPR: 0.0197
#
# Epoch 00010: val_ACCR improved from 0.90236 to 0.90272, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 11/2000
#  - 1489s - loss: 0.0700 - binary_accuracy: 0.9751 - ACCR: 0.9384 - ACCR5: 0.9013 - auc2: 0.9944 - auc1: 0.9966 - TPR: 0.8284 - FPR: 0.0030 - val_loss: 0.2808 - val_binary_accuracy: 0.9289 - val_ACCR: 0.9050 - val_ACCR5: 0.8637 - val_auc2: 0.9944 - val_auc1: 0.9736 - val_TPR: 0.7655 - val_FPR: 0.0207
#
# Epoch 00011: val_ACCR improved from 0.90272 to 0.90500, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 12/2000
#  - 1507s - loss: 0.0690 - binary_accuracy: 0.9754 - ACCR: 0.9390 - ACCR5: 0.9010 - auc2: 0.9944 - auc1: 0.9967 - TPR: 0.8301 - FPR: 0.0029 - val_loss: 0.2943 - val_binary_accuracy: 0.9287 - val_ACCR: 0.9043 - val_ACCR5: 0.8729 - val_auc2: 0.9944 - val_auc1: 0.9727 - val_TPR: 0.7635 - val_FPR: 0.0206
#
# Epoch 00012: val_ACCR did not improve from 0.90500
# Epoch 13/2000
#  - 1499s - loss: 0.0679 - binary_accuracy: 0.9757 - ACCR: 0.9403 - ACCR5: 0.9044 - auc2: 0.9944 - auc1: 0.9968 - TPR: 0.8337 - FPR: 0.0029 - val_loss: 0.2340 - val_binary_accuracy: 0.9288 - val_ACCR: 0.9049 - val_ACCR5: 0.8725 - val_auc2: 0.9944 - val_auc1: 0.9724 - val_TPR: 0.7650 - val_FPR: 0.0205
#
# Epoch 00013: val_ACCR did not improve from 0.90500
# Epoch 14/2000
#  - 1498s - loss: 0.0676 - binary_accuracy: 0.9759 - ACCR: 0.9406 - ACCR5: 0.9056 - auc2: 0.9945 - auc1: 0.9968 - TPR: 0.8344 - FPR: 0.0028 - val_loss: 0.1792 - val_binary_accuracy: 0.9285 - val_ACCR: 0.9058 - val_ACCR5: 0.8731 - val_auc2: 0.9944 - val_auc1: 0.9728 - val_TPR: 0.7678 - val_FPR: 0.0207
#
# Epoch 00014: val_ACCR improved from 0.90500 to 0.90578, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 15/2000
#  - 1498s - loss: 0.0670 - binary_accuracy: 0.9761 - ACCR: 0.9413 - ACCR5: 0.9067 - auc2: 0.9945 - auc1: 0.9969 - TPR: 0.8364 - FPR: 0.0028 - val_loss: 0.3294 - val_binary_accuracy: 0.9281 - val_ACCR: 0.9042 - val_ACCR5: 0.8769 - val_auc2: 0.9945 - val_auc1: 0.9712 - val_TPR: 0.7631 - val_FPR: 0.0206
#
# Epoch 00015: val_ACCR did not improve from 0.90578
# Epoch 16/2000
#  - 1499s - loss: 0.0663 - binary_accuracy: 0.9762 - ACCR: 0.9418 - ACCR5: 0.9064 - auc2: 0.9945 - auc1: 0.9969 - TPR: 0.8380 - FPR: 0.0029 - val_loss: 0.2292 - val_binary_accuracy: 0.9289 - val_ACCR: 0.9056 - val_ACCR5: 0.8678 - val_auc2: 0.9945 - val_auc1: 0.9734 - val_TPR: 0.7686 - val_FPR: 0.0214
#
# Epoch 00016: val_ACCR did not improve from 0.90578
# Epoch 17/2000
#  - 1525s - loss: 0.0653 - binary_accuracy: 0.9767 - ACCR: 0.9427 - ACCR5: 0.9077 - auc2: 0.9945 - auc1: 0.9970 - TPR: 0.8402 - FPR: 0.0027 - val_loss: 0.2577 - val_binary_accuracy: 0.9288 - val_ACCR: 0.9049 - val_ACCR5: 0.8772 - val_auc2: 0.9945 - val_auc1: 0.9718 - val_TPR: 0.7654 - val_FPR: 0.0208
#
# Epoch 00017: val_ACCR did not improve from 0.90578
# Epoch 18/2000
#  - 1500s - loss: 0.0645 - binary_accuracy: 0.9768 - ACCR: 0.9438 - ACCR5: 0.9076 - auc2: 0.9945 - auc1: 0.9971 - TPR: 0.8435 - FPR: 0.0027 - val_loss: 0.2071 - val_binary_accuracy: 0.9280 - val_ACCR: 0.9040 - val_ACCR5: 0.8744 - val_auc2: 0.9945 - val_auc1: 0.9714 - val_TPR: 0.7624 - val_FPR: 0.0204
#
# Epoch 00018: val_ACCR did not improve from 0.90578
# Epoch 19/2000
#  - 1504s - loss: 0.0641 - binary_accuracy: 0.9772 - ACCR: 0.9443 - ACCR5: 0.9093 - auc2: 0.9946 - auc1: 0.9971 - TPR: 0.8448 - FPR: 0.0027 - val_loss: 0.2291 - val_binary_accuracy: 0.9280 - val_ACCR: 0.9052 - val_ACCR5: 0.8770 - val_auc2: 0.9945 - val_auc1: 0.9708 - val_TPR: 0.7665 - val_FPR: 0.0209
#
# Epoch 00019: val_ACCR did not improve from 0.90578
# Epoch 20/2000
#  - 1497s - loss: 0.0638 - binary_accuracy: 0.9772 - ACCR: 0.9446 - ACCR5: 0.9097 - auc2: 0.9946 - auc1: 0.9972 - TPR: 0.8458 - FPR: 0.0027 - val_loss: 0.2892 - val_binary_accuracy: 0.9281 - val_ACCR: 0.9072 - val_ACCR5: 0.8749 - val_auc2: 0.9946 - val_auc1: 0.9717 - val_TPR: 0.7733 - val_FPR: 0.0215
#
# Epoch 00020: val_ACCR improved from 0.90578 to 0.90717, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 21/2000
#  - 1488s - loss: 0.0628 - binary_accuracy: 0.9776 - ACCR: 0.9453 - ACCR5: 0.9091 - auc2: 0.9946 - auc1: 0.9972 - TPR: 0.8475 - FPR: 0.0027 - val_loss: 0.1366 - val_binary_accuracy: 0.9284 - val_ACCR: 0.9067 - val_ACCR5: 0.8732 - val_auc2: 0.9946 - val_auc1: 0.9717 - val_TPR: 0.7720 - val_FPR: 0.0215
#
# Epoch 00021: val_ACCR did not improve from 0.90717
# Epoch 22/2000
#  - 1493s - loss: 0.0624 - binary_accuracy: 0.9777 - ACCR: 0.9461 - ACCR5: 0.9111 - auc2: 0.9946 - auc1: 0.9973 - TPR: 0.8501 - FPR: 0.0027 - val_loss: 0.1912 - val_binary_accuracy: 0.9283 - val_ACCR: 0.9067 - val_ACCR5: 0.8775 - val_auc2: 0.9946 - val_auc1: 0.9705 - val_TPR: 0.7717 - val_FPR: 0.0213
#
# Epoch 00022: val_ACCR did not improve from 0.90717
# Epoch 23/2000
#  - 1496s - loss: 0.0618 - binary_accuracy: 0.9780 - ACCR: 0.9466 - ACCR5: 0.9121 - auc2: 0.9946 - auc1: 0.9973 - TPR: 0.8512 - FPR: 0.0026 - val_loss: 0.2100 - val_binary_accuracy: 0.9281 - val_ACCR: 0.9068 - val_ACCR5: 0.8756 - val_auc2: 0.9946 - val_auc1: 0.9713 - val_TPR: 0.7732 - val_FPR: 0.0220
#
# Epoch 00023: val_ACCR did not improve from 0.90717
# Epoch 24/2000
#  - 1507s - loss: 0.0611 - binary_accuracy: 0.9783 - ACCR: 0.9471 - ACCR5: 0.9117 - auc2: 0.9946 - auc1: 0.9973 - TPR: 0.8529 - FPR: 0.0026 - val_loss: 0.2249 - val_binary_accuracy: 0.9279 - val_ACCR: 0.9080 - val_ACCR5: 0.8752 - val_auc2: 0.9946 - val_auc1: 0.9715 - val_TPR: 0.7771 - val_FPR: 0.0223
#
# Epoch 00024: val_ACCR improved from 0.90717 to 0.90797, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 25/2000
#  - 1493s - loss: 0.0606 - binary_accuracy: 0.9784 - ACCR: 0.9480 - ACCR5: 0.9130 - auc2: 0.9946 - auc1: 0.9974 - TPR: 0.8551 - FPR: 0.0026 - val_loss: 0.3551 - val_binary_accuracy: 0.9281 - val_ACCR: 0.9060 - val_ACCR5: 0.8803 - val_auc2: 0.9947 - val_auc1: 0.9704 - val_TPR: 0.7697 - val_FPR: 0.0213
#
# Epoch 00025: val_ACCR did not improve from 0.90797
# Epoch 26/2000
#  - 1491s - loss: 0.0606 - binary_accuracy: 0.9786 - ACCR: 0.9482 - ACCR5: 0.9120 - auc2: 0.9946 - auc1: 0.9974 - TPR: 0.8559 - FPR: 0.0026 - val_loss: 0.2044 - val_binary_accuracy: 0.9277 - val_ACCR: 0.9086 - val_ACCR5: 0.8811 - val_auc2: 0.9947 - val_auc1: 0.9694 - val_TPR: 0.7787 - val_FPR: 0.0222
#
# Epoch 00026: val_ACCR improved from 0.90797 to 0.90862, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 27/2000
#  - 1493s - loss: 0.0595 - binary_accuracy: 0.9788 - ACCR: 0.9491 - ACCR5: 0.9147 - auc2: 0.9946 - auc1: 0.9975 - TPR: 0.8583 - FPR: 0.0025 - val_loss: 0.3419 - val_binary_accuracy: 0.9275 - val_ACCR: 0.9078 - val_ACCR5: 0.8731 - val_auc2: 0.9947 - val_auc1: 0.9704 - val_TPR: 0.7764 - val_FPR: 0.0223
#
# Epoch 00027: val_ACCR did not improve from 0.90862
# Epoch 28/2000
#  - 1486s - loss: 0.0589 - binary_accuracy: 0.9791 - ACCR: 0.9496 - ACCR5: 0.9145 - auc2: 0.9946 - auc1: 0.9975 - TPR: 0.8596 - FPR: 0.0025 - val_loss: 0.2700 - val_binary_accuracy: 0.9280 - val_ACCR: 0.9068 - val_ACCR5: 0.8781 - val_auc2: 0.9947 - val_auc1: 0.9707 - val_TPR: 0.7732 - val_FPR: 0.0218
#
# Epoch 00028: val_ACCR did not improve from 0.90862
# Epoch 29/2000
#  - 1497s - loss: 0.0578 - binary_accuracy: 0.9794 - ACCR: 0.9505 - ACCR5: 0.9148 - auc2: 0.9946 - auc1: 0.9976 - TPR: 0.8622 - FPR: 0.0025 - val_loss: 0.2504 - val_binary_accuracy: 0.9281 - val_ACCR: 0.9099 - val_ACCR5: 0.8800 - val_auc2: 0.9947 - val_auc1: 0.9705 - val_TPR: 0.7848 - val_FPR: 0.0235
#
# Epoch 00029: val_ACCR improved from 0.90862 to 0.90991, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 30/2000
#  - 1494s - loss: 0.0581 - binary_accuracy: 0.9793 - ACCR: 0.9505 - ACCR5: 0.9165 - auc2: 0.9947 - auc1: 0.9976 - TPR: 0.8622 - FPR: 0.0025 - val_loss: 0.3428 - val_binary_accuracy: 0.9276 - val_ACCR: 0.9082 - val_ACCR5: 0.8792 - val_auc2: 0.9947 - val_auc1: 0.9695 - val_TPR: 0.7779 - val_FPR: 0.0223
#
# Epoch 00030: val_ACCR did not improve from 0.90991
# Epoch 31/2000
#  - 1497s - loss: 0.0572 - binary_accuracy: 0.9796 - ACCR: 0.9513 - ACCR5: 0.9174 - auc2: 0.9947 - auc1: 0.9976 - TPR: 0.8645 - FPR: 0.0024 - val_loss: 0.2161 - val_binary_accuracy: 0.9276 - val_ACCR: 0.9102 - val_ACCR5: 0.8762 - val_auc2: 0.9948 - val_auc1: 0.9698 - val_TPR: 0.7858 - val_FPR: 0.0235
#
# Epoch 00031: val_ACCR improved from 0.90991 to 0.91019, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 32/2000
#  - 1506s - loss: 0.0568 - binary_accuracy: 0.9798 - ACCR: 0.9517 - ACCR5: 0.9171 - auc2: 0.9947 - auc1: 0.9977 - TPR: 0.8657 - FPR: 0.0024 - val_loss: 0.3621 - val_binary_accuracy: 0.9272 - val_ACCR: 0.9089 - val_ACCR5: 0.8769 - val_auc2: 0.9948 - val_auc1: 0.9700 - val_TPR: 0.7828 - val_FPR: 0.0239
#
# Epoch 00032: val_ACCR did not improve from 0.91019
# Epoch 33/2000
#  - 1489s - loss: 0.0565 - binary_accuracy: 0.9798 - ACCR: 0.9520 - ACCR5: 0.9163 - auc2: 0.9948 - auc1: 0.9977 - TPR: 0.8663 - FPR: 0.0024 - val_loss: 0.1778 - val_binary_accuracy: 0.9273 - val_ACCR: 0.9077 - val_ACCR5: 0.8763 - val_auc2: 0.9948 - val_auc1: 0.9707 - val_TPR: 0.7772 - val_FPR: 0.0228
#
# Epoch 00033: val_ACCR did not improve from 0.91019
# Epoch 34/2000
#  - 1507s - loss: 0.0559 - binary_accuracy: 0.9801 - ACCR: 0.9527 - ACCR5: 0.9147 - auc2: 0.9948 - auc1: 0.9977 - TPR: 0.8682 - FPR: 0.0023 - val_loss: 0.1988 - val_binary_accuracy: 0.9274 - val_ACCR: 0.9094 - val_ACCR5: 0.8788 - val_auc2: 0.9948 - val_auc1: 0.9700 - val_TPR: 0.7838 - val_FPR: 0.0236
#
# Epoch 00034: val_ACCR did not improve from 0.91019
# Epoch 35/2000
#  - 1486s - loss: 0.0552 - binary_accuracy: 0.9805 - ACCR: 0.9533 - ACCR5: 0.9172 - auc2: 0.9948 - auc1: 0.9978 - TPR: 0.8700 - FPR: 0.0023 - val_loss: 0.3329 - val_binary_accuracy: 0.9265 - val_ACCR: 0.9062 - val_ACCR5: 0.8838 - val_auc2: 0.9948 - val_auc1: 0.9686 - val_TPR: 0.7722 - val_FPR: 0.0223
#
# Epoch 00035: val_ACCR did not improve from 0.91019
# Epoch 36/2000
#  - 1512s - loss: 0.0552 - binary_accuracy: 0.9805 - ACCR: 0.9533 - ACCR5: 0.9156 - auc2: 0.9948 - auc1: 0.9978 - TPR: 0.8699 - FPR: 0.0023 - val_loss: 0.2930 - val_binary_accuracy: 0.9272 - val_ACCR: 0.9090 - val_ACCR5: 0.8810 - val_auc2: 0.9948 - val_auc1: 0.9693 - val_TPR: 0.7824 - val_FPR: 0.0235
#
# Epoch 00036: val_ACCR did not improve from 0.91019
# Epoch 37/2000
#  - 1499s - loss: 0.0544 - binary_accuracy: 0.9807 - ACCR: 0.9541 - ACCR5: 0.9187 - auc2: 0.9948 - auc1: 0.9978 - TPR: 0.8722 - FPR: 0.0023 - val_loss: 0.3976 - val_binary_accuracy: 0.9271 - val_ACCR: 0.9102 - val_ACCR5: 0.8711 - val_auc2: 0.9948 - val_auc1: 0.9696 - val_TPR: 0.7861 - val_FPR: 0.0237
#
# Epoch 00037: val_ACCR did not improve from 0.91019
# Epoch 38/2000
#  - 1505s - loss: 0.0534 - binary_accuracy: 0.9811 - ACCR: 0.9548 - ACCR5: 0.9128 - auc2: 0.9949 - auc1: 0.9979 - TPR: 0.8742 - FPR: 0.0022 - val_loss: 0.2849 - val_binary_accuracy: 0.9276 - val_ACCR: 0.9115 - val_ACCR5: 0.8652 - val_auc2: 0.9949 - val_auc1: 0.9712 - val_TPR: 0.7921 - val_FPR: 0.0249
#
# Epoch 00038: val_ACCR improved from 0.91019 to 0.91146, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 39/2000
#  - 1494s - loss: 0.0532 - binary_accuracy: 0.9811 - ACCR: 0.9553 - ACCR5: 0.9149 - auc2: 0.9949 - auc1: 0.9979 - TPR: 0.8756 - FPR: 0.0022 - val_loss: 0.3393 - val_binary_accuracy: 0.9272 - val_ACCR: 0.9095 - val_ACCR5: 0.8810 - val_auc2: 0.9949 - val_auc1: 0.9687 - val_TPR: 0.7842 - val_FPR: 0.0238
#
# Epoch 00039: val_ACCR did not improve from 0.91146
# Epoch 40/2000
#  - 1487s - loss: 0.0526 - binary_accuracy: 0.9814 - ACCR: 0.9559 - ACCR5: 0.9158 - auc2: 0.9949 - auc1: 0.9979 - TPR: 0.8774 - FPR: 0.0022 - val_loss: 0.2978 - val_binary_accuracy: 0.9268 - val_ACCR: 0.9094 - val_ACCR5: 0.8794 - val_auc2: 0.9949 - val_auc1: 0.9685 - val_TPR: 0.7840 - val_FPR: 0.0238
#
# Epoch 00040: val_ACCR did not improve from 0.91146
# Epoch 41/2000
#  - 1507s - loss: 0.0525 - binary_accuracy: 0.9814 - ACCR: 0.9562 - ACCR5: 0.9184 - auc2: 0.9949 - auc1: 0.9980 - TPR: 0.8782 - FPR: 0.0022 - val_loss: 0.2539 - val_binary_accuracy: 0.9259 - val_ACCR: 0.9073 - val_ACCR5: 0.8832 - val_auc2: 0.9949 - val_auc1: 0.9679 - val_TPR: 0.7767 - val_FPR: 0.0231
#
# Epoch 00041: val_ACCR did not improve from 0.91146
# Epoch 42/2000
#  - 1497s - loss: 0.0523 - binary_accuracy: 0.9815 - ACCR: 0.9565 - ACCR5: 0.9218 - auc2: 0.9949 - auc1: 0.9980 - TPR: 0.8788 - FPR: 0.0022 - val_loss: 0.2703 - val_binary_accuracy: 0.9267 - val_ACCR: 0.9111 - val_ACCR5: 0.8784 - val_auc2: 0.9949 - val_auc1: 0.9685 - val_TPR: 0.7911 - val_FPR: 0.0249
#
# Epoch 00042: val_ACCR did not improve from 0.91146
# Epoch 43/2000
#  - 1500s - loss: 0.0516 - binary_accuracy: 0.9818 - ACCR: 0.9572 - ACCR5: 0.9208 - auc2: 0.9950 - auc1: 0.9980 - TPR: 0.8809 - FPR: 0.0022 - val_loss: 0.1661 - val_binary_accuracy: 0.9256 - val_ACCR: 0.9073 - val_ACCR5: 0.8839 - val_auc2: 0.9949 - val_auc1: 0.9676 - val_TPR: 0.7775 - val_FPR: 0.0234
#
# Epoch 00043: val_ACCR did not improve from 0.91146
# Epoch 44/2000
#  - 1483s - loss: 0.0511 - binary_accuracy: 0.9819 - ACCR: 0.9574 - ACCR5: 0.9203 - auc2: 0.9950 - auc1: 0.9980 - TPR: 0.8814 - FPR: 0.0021 - val_loss: 0.4184 - val_binary_accuracy: 0.9268 - val_ACCR: 0.9103 - val_ACCR5: 0.8797 - val_auc2: 0.9950 - val_auc1: 0.9675 - val_TPR: 0.7871 - val_FPR: 0.0241
#
# Epoch 00044: val_ACCR did not improve from 0.91146
# Epoch 45/2000
#  - 1513s - loss: 0.0505 - binary_accuracy: 0.9822 - ACCR: 0.9577 - ACCR5: 0.9211 - auc2: 0.9950 - auc1: 0.9981 - TPR: 0.8822 - FPR: 0.0021 - val_loss: 0.3345 - val_binary_accuracy: 0.9265 - val_ACCR: 0.9094 - val_ACCR5: 0.8813 - val_auc2: 0.9950 - val_auc1: 0.9676 - val_TPR: 0.7845 - val_FPR: 0.0240
#
# Epoch 00045: val_ACCR did not improve from 0.91146
# Epoch 46/2000
#  - 1499s - loss: 0.0498 - binary_accuracy: 0.9824 - ACCR: 0.9585 - ACCR5: 0.9229 - auc2: 0.9950 - auc1: 0.9981 - TPR: 0.8846 - FPR: 0.0020 - val_loss: 0.2754 - val_binary_accuracy: 0.9264 - val_ACCR: 0.9112 - val_ACCR5: 0.8829 - val_auc2: 0.9950 - val_auc1: 0.9669 - val_TPR: 0.7916 - val_FPR: 0.0250
#
# Epoch 00046: val_ACCR did not improve from 0.91146
# Epoch 47/2000
#  - 1530s - loss: 0.0500 - binary_accuracy: 0.9824 - ACCR: 0.9585 - ACCR5: 0.9252 - auc2: 0.9950 - auc1: 0.9981 - TPR: 0.8846 - FPR: 0.0021 - val_loss: 0.3647 - val_binary_accuracy: 0.9266 - val_ACCR: 0.9109 - val_ACCR5: 0.8799 - val_auc2: 0.9950 - val_auc1: 0.9679 - val_TPR: 0.7900 - val_FPR: 0.0246
#
# Epoch 00047: val_ACCR did not improve from 0.91146
# Epoch 48/2000
#  - 1516s - loss: 0.0492 - binary_accuracy: 0.9826 - ACCR: 0.9591 - ACCR5: 0.9236 - auc2: 0.9951 - auc1: 0.9982 - TPR: 0.8863 - FPR: 0.0020 - val_loss: 0.1942 - val_binary_accuracy: 0.9265 - val_ACCR: 0.9105 - val_ACCR5: 0.8733 - val_auc2: 0.9950 - val_auc1: 0.9690 - val_TPR: 0.7897 - val_FPR: 0.0251
#
# Epoch 00048: val_ACCR did not improve from 0.91146
# Epoch 49/2000
#  - 1489s - loss: 0.0492 - binary_accuracy: 0.9826 - ACCR: 0.9592 - ACCR5: 0.9226 - auc2: 0.9951 - auc1: 0.9982 - TPR: 0.8862 - FPR: 0.0020 - val_loss: 0.4119 - val_binary_accuracy: 0.9257 - val_ACCR: 0.9103 - val_ACCR5: 0.8855 - val_auc2: 0.9950 - val_auc1: 0.9667 - val_TPR: 0.7885 - val_FPR: 0.0248
#
# Epoch 00049: val_ACCR did not improve from 0.91146
# Epoch 50/2000
#  - 1502s - loss: 0.0488 - binary_accuracy: 0.9829 - ACCR: 0.9598 - ACCR5: 0.9269 - auc2: 0.9951 - auc1: 0.9982 - TPR: 0.8880 - FPR: 0.0020 - val_loss: 0.2293 - val_binary_accuracy: 0.9270 - val_ACCR: 0.9118 - val_ACCR5: 0.8781 - val_auc2: 0.9950 - val_auc1: 0.9676 - val_TPR: 0.7934 - val_FPR: 0.0251
#
# Epoch 00050: val_ACCR improved from 0.91146 to 0.91181, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 51/2000

# %%
from inscopefilter import*
if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=4, 
                    use_multiprocessing=True, 
#                    shuffle=False,
#                    max_queue_size = 5, 
#                    callbacks=[earlystop, checkpoint]
                    callbacks=[checkpoint]
                    )
# Out:
# RDKit WARNING: [09:52:40] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Loading data...
# inscopedata: 1534410it [00:02, 524912.06it/s]
# inscopedata: 1789651it [00:04, 426940.07it/s]
# total samples: 3317345
# shuffle is over...
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 16384)        0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16384)        0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         16778240    lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# highway_1 (Highway)             (None, 1024)         2099200     dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           highway_1[0][0]
# __________________________________________________________________________________________________
# highway_2 (Highway)             (None, 1024)         2099200     dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1024)         0           highway_2[0][0]
# __________________________________________________________________________________________________
# highway_3 (Highway)             (None, 1024)         2099200     dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           highway_3[0][0]
# __________________________________________________________________________________________________
# highway_4 (Highway)             (None, 1024)         2099200     dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 1024)         0           highway_4[0][0]
# __________________________________________________________________________________________________
# highway_5 (Highway)             (None, 1024)         2099200     dropout_5[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 2048)         0
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 1024)         0           highway_5[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1024)         2098176     input_2[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 1)            0           dropout_6[0][0]
#                                                                  dense_12[0][0]
# ==================================================================================================
# Total params: 29,372,416
# Trainable params: 29,372,416
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/2000
#  - 1306s - loss: 0.3421 - binary_accuracy: 0.8717 - ACCR: 0.6524 - ACCR5: 0.6844 - auc1: 0.9428 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2650 - val_binary_accuracy: 0.8855 - val_ACCR: 0.7979 - val_ACCR5: 0.7369 - val_auc1: 0.9617 - val_TPR: 0.4406 - val_FPR: 0.0117
#
# Epoch 00001: val_ACCR improved from -inf to 0.79790, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 2/2000
#  - 1172s - loss: 0.2782 - binary_accuracy: 0.9038 - ACCR: 0.6524 - ACCR5: 0.7316 - auc1: 0.9632 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2611 - val_binary_accuracy: 0.8981 - val_ACCR: 0.8385 - val_ACCR5: 0.7447 - val_auc1: 0.9662 - val_TPR: 0.5673 - val_FPR: 0.0171
#
# Epoch 00002: val_ACCR improved from 0.79790 to 0.83847, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 3/2000
#  - 1181s - loss: 0.2704 - binary_accuracy: 0.9065 - ACCR: 0.6524 - ACCR5: 0.7249 - auc1: 0.9648 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2579 - val_binary_accuracy: 0.9002 - val_ACCR: 0.8445 - val_ACCR5: 0.7205 - val_auc1: 0.9656 - val_TPR: 0.5886 - val_FPR: 0.0190
#
# Epoch 00003: val_ACCR improved from 0.83847 to 0.84450, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 4/2000
#  - 1181s - loss: 0.2688 - binary_accuracy: 0.9070 - ACCR: 0.6524 - ACCR5: 0.7243 - auc1: 0.9652 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2505 - val_binary_accuracy: 0.8957 - val_ACCR: 0.8589 - val_ACCR5: 0.7083 - val_auc1: 0.9651 - val_TPR: 0.6396 - val_FPR: 0.0242
#
# Epoch 00004: val_ACCR improved from 0.84450 to 0.85886, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 5/2000
#  - 1180s - loss: 0.2657 - binary_accuracy: 0.9081 - ACCR: 0.6524 - ACCR5: 0.7233 - auc1: 0.9657 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2620 - val_binary_accuracy: 0.8915 - val_ACCR: 0.8619 - val_ACCR5: 0.7064 - val_auc1: 0.9633 - val_TPR: 0.6528 - val_FPR: 0.0266
#
# Epoch 00005: val_ACCR improved from 0.85886 to 0.86189, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 6/2000
#  - 1181s - loss: 0.2642 - binary_accuracy: 0.9086 - ACCR: 0.6524 - ACCR5: 0.7243 - auc1: 0.9660 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1946 - val_binary_accuracy: 0.9013 - val_ACCR: 0.8593 - val_ACCR5: 0.7224 - val_auc1: 0.9661 - val_TPR: 0.6386 - val_FPR: 0.0231
#
# Epoch 00006: val_ACCR did not improve from 0.86189
# Epoch 7/2000
#  - 1180s - loss: 0.2633 - binary_accuracy: 0.9083 - ACCR: 0.6524 - ACCR5: 0.7242 - auc1: 0.9658 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2905 - val_binary_accuracy: 0.9020 - val_ACCR: 0.8596 - val_ACCR5: 0.7356 - val_auc1: 0.9658 - val_TPR: 0.6396 - val_FPR: 0.0232
#
# Epoch 00007: val_ACCR did not improve from 0.86189
# Epoch 8/2000
#  - 1184s - loss: 0.2591 - binary_accuracy: 0.9108 - ACCR: 0.6524 - ACCR5: 0.7308 - auc1: 0.9670 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2415 - val_binary_accuracy: 0.9029 - val_ACCR: 0.8619 - val_ACCR5: 0.7336 - val_auc1: 0.9668 - val_TPR: 0.6465 - val_FPR: 0.0233
#
# Epoch 00008: val_ACCR did not improve from 0.86189
# Epoch 9/2000
#  - 1182s - loss: 0.2583 - binary_accuracy: 0.9111 - ACCR: 0.6524 - ACCR5: 0.7295 - auc1: 0.9672 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2108 - val_binary_accuracy: 0.9033 - val_ACCR: 0.8652 - val_ACCR5: 0.7340 - val_auc1: 0.9669 - val_TPR: 0.6566 - val_FPR: 0.0237
#
# Epoch 00009: val_ACCR improved from 0.86189 to 0.86520, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 10/2000
#  - 1176s - loss: 0.2564 - binary_accuracy: 0.9114 - ACCR: 0.6524 - ACCR5: 0.7300 - auc1: 0.9677 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2884 - val_binary_accuracy: 0.9040 - val_ACCR: 0.8692 - val_ACCR5: 0.7281 - val_auc1: 0.9675 - val_TPR: 0.6720 - val_FPR: 0.0257
#
# Epoch 00010: val_ACCR improved from 0.86520 to 0.86921, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 11/2000
#  - 1183s - loss: 0.2524 - binary_accuracy: 0.9133 - ACCR: 0.6524 - ACCR5: 0.7354 - auc1: 0.9687 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2611 - val_binary_accuracy: 0.9051 - val_ACCR: 0.8722 - val_ACCR5: 0.7336 - val_auc1: 0.9682 - val_TPR: 0.6787 - val_FPR: 0.0248
#
# Epoch 00011: val_ACCR improved from 0.86921 to 0.87217, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 12/2000
#  - 1178s - loss: 0.2505 - binary_accuracy: 0.9150 - ACCR: 0.6524 - ACCR5: 0.7380 - auc1: 0.9693 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1928 - val_binary_accuracy: 0.9064 - val_ACCR: 0.8688 - val_ACCR5: 0.7388 - val_auc1: 0.9688 - val_TPR: 0.6669 - val_FPR: 0.0237
#
# Epoch 00012: val_ACCR did not improve from 0.87217
# Epoch 13/2000
#  - 1182s - loss: 0.2475 - binary_accuracy: 0.9168 - ACCR: 0.6524 - ACCR5: 0.7452 - auc1: 0.9702 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1936 - val_binary_accuracy: 0.9083 - val_ACCR: 0.8716 - val_ACCR5: 0.7416 - val_auc1: 0.9694 - val_TPR: 0.6760 - val_FPR: 0.0241
#
# Epoch 00013: val_ACCR did not improve from 0.87217
# Epoch 14/2000
#  - 1184s - loss: 0.2454 - binary_accuracy: 0.9181 - ACCR: 0.6524 - ACCR5: 0.7513 - auc1: 0.9707 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2035 - val_binary_accuracy: 0.9059 - val_ACCR: 0.8811 - val_ACCR5: 0.7435 - val_auc1: 0.9688 - val_TPR: 0.7095 - val_FPR: 0.0273
#
# Epoch 00014: val_ACCR improved from 0.87217 to 0.88110, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 15/2000
#  - 1178s - loss: 0.2437 - binary_accuracy: 0.9191 - ACCR: 0.6524 - ACCR5: 0.7534 - auc1: 0.9712 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2644 - val_binary_accuracy: 0.9127 - val_ACCR: 0.8622 - val_ACCR5: 0.7537 - val_auc1: 0.9695 - val_TPR: 0.6432 - val_FPR: 0.0211
#
# Epoch 00015: val_ACCR did not improve from 0.88110
# Epoch 16/2000
#  - 1182s - loss: 0.2423 - binary_accuracy: 0.9196 - ACCR: 0.6524 - ACCR5: 0.7512 - auc1: 0.9715 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2265 - val_binary_accuracy: 0.9077 - val_ACCR: 0.8800 - val_ACCR5: 0.7277 - val_auc1: 0.9698 - val_TPR: 0.7034 - val_FPR: 0.0259
#
# Epoch 00016: val_ACCR did not improve from 0.88110
# Epoch 17/2000
#  - 1202s - loss: 0.2406 - binary_accuracy: 0.9210 - ACCR: 0.6524 - ACCR5: 0.7523 - auc1: 0.9721 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2039 - val_binary_accuracy: 0.9126 - val_ACCR: 0.8723 - val_ACCR5: 0.7571 - val_auc1: 0.9702 - val_TPR: 0.6745 - val_FPR: 0.0223
#
# Epoch 00017: val_ACCR did not improve from 0.88110
# Epoch 18/2000
#  - 1179s - loss: 0.2399 - binary_accuracy: 0.9212 - ACCR: 0.6524 - ACCR5: 0.7515 - auc1: 0.9724 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2860 - val_binary_accuracy: 0.9079 - val_ACCR: 0.8857 - val_ACCR5: 0.7430 - val_auc1: 0.9700 - val_TPR: 0.7233 - val_FPR: 0.0277
#
# Epoch 00018: val_ACCR improved from 0.88110 to 0.88573, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 19/2000
#  - 1185s - loss: 0.2384 - binary_accuracy: 0.9225 - ACCR: 0.6524 - ACCR5: 0.7547 - auc1: 0.9728 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1737 - val_binary_accuracy: 0.9096 - val_ACCR: 0.8879 - val_ACCR5: 0.7397 - val_auc1: 0.9708 - val_TPR: 0.7293 - val_FPR: 0.0275
#
# Epoch 00019: val_ACCR improved from 0.88573 to 0.88794, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 20/2000
#  - 1185s - loss: 0.2369 - binary_accuracy: 0.9234 - ACCR: 0.6524 - ACCR5: 0.7568 - auc1: 0.9731 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2258 - val_binary_accuracy: 0.9111 - val_ACCR: 0.8859 - val_ACCR5: 0.7521 - val_auc1: 0.9709 - val_TPR: 0.7203 - val_FPR: 0.0259
#
# Epoch 00020: val_ACCR did not improve from 0.88794
# Epoch 21/2000
#  - 1180s - loss: 0.2352 - binary_accuracy: 0.9242 - ACCR: 0.6524 - ACCR5: 0.7600 - auc1: 0.9736 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1991 - val_binary_accuracy: 0.9164 - val_ACCR: 0.8650 - val_ACCR5: 0.7656 - val_auc1: 0.9702 - val_TPR: 0.6500 - val_FPR: 0.0204
#
# Epoch 00021: val_ACCR did not improve from 0.88794
# Epoch 22/2000
#  - 1182s - loss: 0.2331 - binary_accuracy: 0.9249 - ACCR: 0.6524 - ACCR5: 0.7598 - auc1: 0.9740 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1805 - val_binary_accuracy: 0.9124 - val_ACCR: 0.8908 - val_ACCR5: 0.7507 - val_auc1: 0.9718 - val_TPR: 0.7364 - val_FPR: 0.0270
#
# Epoch 00022: val_ACCR improved from 0.88794 to 0.89076, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 23/2000
#  - 1183s - loss: 0.2323 - binary_accuracy: 0.9255 - ACCR: 0.6524 - ACCR5: 0.7606 - auc1: 0.9744 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1731 - val_binary_accuracy: 0.9143 - val_ACCR: 0.8866 - val_ACCR5: 0.7570 - val_auc1: 0.9715 - val_TPR: 0.7205 - val_FPR: 0.0250
#
# Epoch 00023: val_ACCR did not improve from 0.89076
# Epoch 24/2000
#  - 1176s - loss: 0.2303 - binary_accuracy: 0.9265 - ACCR: 0.6524 - ACCR5: 0.7640 - auc1: 0.9748 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1934 - val_binary_accuracy: 0.9151 - val_ACCR: 0.8894 - val_ACCR5: 0.7537 - val_auc1: 0.9721 - val_TPR: 0.7288 - val_FPR: 0.0251
#
# Epoch 00024: val_ACCR did not improve from 0.89076
# Epoch 25/2000
#  - 1185s - loss: 0.2295 - binary_accuracy: 0.9272 - ACCR: 0.6524 - ACCR5: 0.7621 - auc1: 0.9751 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2886 - val_binary_accuracy: 0.9149 - val_ACCR: 0.8894 - val_ACCR5: 0.7574 - val_auc1: 0.9720 - val_TPR: 0.7286 - val_FPR: 0.0249
#
# Epoch 00025: val_ACCR did not improve from 0.89076
# Epoch 26/2000
#  - 1178s - loss: 0.2275 - binary_accuracy: 0.9284 - ACCR: 0.6524 - ACCR5: 0.7641 - auc1: 0.9756 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1833 - val_binary_accuracy: 0.9155 - val_ACCR: 0.8922 - val_ACCR5: 0.7593 - val_auc1: 0.9723 - val_TPR: 0.7383 - val_FPR: 0.0259
#
# Epoch 00026: val_ACCR improved from 0.89076 to 0.89218, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 27/2000
#  - 1176s - loss: 0.2264 - binary_accuracy: 0.9293 - ACCR: 0.6524 - ACCR5: 0.7666 - auc1: 0.9760 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1950 - val_binary_accuracy: 0.9165 - val_ACCR: 0.8926 - val_ACCR5: 0.7700 - val_auc1: 0.9724 - val_TPR: 0.7382 - val_FPR: 0.0250
#
# Epoch 00027: val_ACCR improved from 0.89218 to 0.89260, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 28/2000
#  - 1196s - loss: 0.2246 - binary_accuracy: 0.9301 - ACCR: 0.6524 - ACCR5: 0.7691 - auc1: 0.9765 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2884 - val_binary_accuracy: 0.9157 - val_ACCR: 0.8972 - val_ACCR5: 0.7584 - val_auc1: 0.9727 - val_TPR: 0.7552 - val_FPR: 0.0270
#
# Epoch 00028: val_ACCR improved from 0.89260 to 0.89725, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 29/2000
#  - 1184s - loss: 0.2234 - binary_accuracy: 0.9307 - ACCR: 0.6524 - ACCR5: 0.7700 - auc1: 0.9768 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2198 - val_binary_accuracy: 0.9185 - val_ACCR: 0.8923 - val_ACCR5: 0.7707 - val_auc1: 0.9732 - val_TPR: 0.7360 - val_FPR: 0.0244
#
# Epoch 00029: val_ACCR did not improve from 0.89725
# Epoch 30/2000
#  - 1183s - loss: 0.2213 - binary_accuracy: 0.9320 - ACCR: 0.6524 - ACCR5: 0.7729 - auc1: 0.9774 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1876 - val_binary_accuracy: 0.9188 - val_ACCR: 0.8948 - val_ACCR5: 0.7695 - val_auc1: 0.9736 - val_TPR: 0.7429 - val_FPR: 0.0243
#
# Epoch 00030: val_ACCR did not improve from 0.89725
# Epoch 31/2000
#  - 1180s - loss: 0.2192 - binary_accuracy: 0.9331 - ACCR: 0.6524 - ACCR5: 0.7780 - auc1: 0.9776 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1876 - val_binary_accuracy: 0.9194 - val_ACCR: 0.8966 - val_ACCR5: 0.7784 - val_auc1: 0.9733 - val_TPR: 0.7493 - val_FPR: 0.0249
#
# Epoch 00031: val_ACCR did not improve from 0.89725
# Epoch 32/2000
#  - 1182s - loss: 0.2173 - binary_accuracy: 0.9344 - ACCR: 0.6524 - ACCR5: 0.7782 - auc1: 0.9782 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2218 - val_binary_accuracy: 0.9206 - val_ACCR: 0.8916 - val_ACCR5: 0.7734 - val_auc1: 0.9738 - val_TPR: 0.7317 - val_FPR: 0.0232
#
# Epoch 00032: val_ACCR did not improve from 0.89725
# Epoch 33/2000
#  - 1180s - loss: 0.2146 - binary_accuracy: 0.9357 - ACCR: 0.6524 - ACCR5: 0.7831 - auc1: 0.9787 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2183 - val_binary_accuracy: 0.9196 - val_ACCR: 0.9000 - val_ACCR5: 0.7755 - val_auc1: 0.9738 - val_TPR: 0.7604 - val_FPR: 0.0256
#
# Epoch 00033: val_ACCR improved from 0.89725 to 0.90003, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 34/2000
#  - 1193s - loss: 0.2136 - binary_accuracy: 0.9362 - ACCR: 0.6524 - ACCR5: 0.7851 - auc1: 0.9789 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1914 - val_binary_accuracy: 0.9195 - val_ACCR: 0.9011 - val_ACCR5: 0.7737 - val_auc1: 0.9739 - val_TPR: 0.7642 - val_FPR: 0.0259
#
# Epoch 00034: val_ACCR improved from 0.90003 to 0.90107, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 35/2000
#  - 1178s - loss: 0.2111 - binary_accuracy: 0.9373 - ACCR: 0.6524 - ACCR5: 0.7889 - auc1: 0.9794 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1931 - val_binary_accuracy: 0.9202 - val_ACCR: 0.9027 - val_ACCR5: 0.7772 - val_auc1: 0.9739 - val_TPR: 0.7696 - val_FPR: 0.0264
#
# Epoch 00035: val_ACCR improved from 0.90107 to 0.90274, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 36/2000
#  - 1184s - loss: 0.2093 - binary_accuracy: 0.9381 - ACCR: 0.6524 - ACCR5: 0.7912 - auc1: 0.9798 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1610 - val_binary_accuracy: 0.9208 - val_ACCR: 0.9039 - val_ACCR5: 0.7860 - val_auc1: 0.9737 - val_TPR: 0.7734 - val_FPR: 0.0266
#
# Epoch 00036: val_ACCR improved from 0.90274 to 0.90389, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 37/2000
#  - 1180s - loss: 0.2078 - binary_accuracy: 0.9388 - ACCR: 0.6524 - ACCR5: 0.7945 - auc1: 0.9801 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2081 - val_binary_accuracy: 0.9214 - val_ACCR: 0.9042 - val_ACCR5: 0.7848 - val_auc1: 0.9739 - val_TPR: 0.7742 - val_FPR: 0.0265
#
# Epoch 00037: val_ACCR improved from 0.90389 to 0.90423, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 38/2000
#  - 1180s - loss: 0.2066 - binary_accuracy: 0.9395 - ACCR: 0.6524 - ACCR5: 0.7959 - auc1: 0.9804 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2462 - val_binary_accuracy: 0.9215 - val_ACCR: 0.9053 - val_ACCR5: 0.7899 - val_auc1: 0.9736 - val_TPR: 0.7775 - val_FPR: 0.0266
#
# Epoch 00038: val_ACCR improved from 0.90423 to 0.90528, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 39/2000
#  - 1176s - loss: 0.2052 - binary_accuracy: 0.9403 - ACCR: 0.6524 - ACCR5: 0.7966 - auc1: 0.9808 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2279 - val_binary_accuracy: 0.9222 - val_ACCR: 0.9036 - val_ACCR5: 0.7953 - val_auc1: 0.9733 - val_TPR: 0.7707 - val_FPR: 0.0256
#
# Epoch 00039: val_ACCR did not improve from 0.90528
# Epoch 40/2000
#  - 1181s - loss: 0.2033 - binary_accuracy: 0.9413 - ACCR: 0.6524 - ACCR5: 0.7999 - auc1: 0.9811 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2500 - val_binary_accuracy: 0.9225 - val_ACCR: 0.9054 - val_ACCR5: 0.7977 - val_auc1: 0.9735 - val_TPR: 0.7768 - val_FPR: 0.0261
#
# Epoch 00040: val_ACCR improved from 0.90528 to 0.90535, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 41/2000
#  - 1177s - loss: 0.2023 - binary_accuracy: 0.9420 - ACCR: 0.6524 - ACCR5: 0.8018 - auc1: 0.9814 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1981 - val_binary_accuracy: 0.9223 - val_ACCR: 0.9077 - val_ACCR5: 0.7906 - val_auc1: 0.9739 - val_TPR: 0.7844 - val_FPR: 0.0267
#
# Epoch 00041: val_ACCR improved from 0.90535 to 0.90766, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 42/2000
#  - 1178s - loss: 0.2004 - binary_accuracy: 0.9428 - ACCR: 0.6524 - ACCR5: 0.8016 - auc1: 0.9818 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2342 - val_binary_accuracy: 0.9216 - val_ACCR: 0.9103 - val_ACCR5: 0.7857 - val_auc1: 0.9737 - val_TPR: 0.7947 - val_FPR: 0.0282
#
# Epoch 00042: val_ACCR improved from 0.90766 to 0.91026, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 43/2000
#  - 1181s - loss: 0.1994 - binary_accuracy: 0.9433 - ACCR: 0.6524 - ACCR5: 0.8036 - auc1: 0.9819 - TPR: 9.4229e-07 - FPR: 0.0000e+00 - val_loss: 0.1692 - val_binary_accuracy: 0.9238 - val_ACCR: 0.9061 - val_ACCR5: 0.7958 - val_auc1: 0.9738 - val_TPR: 0.7775 - val_FPR: 0.0255
#
# Epoch 00043: val_ACCR did not improve from 0.91026
# Epoch 44/2000
#  - 1178s - loss: 0.1975 - binary_accuracy: 0.9443 - ACCR: 0.6524 - ACCR5: 0.8057 - auc1: 0.9824 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1849 - val_binary_accuracy: 0.9235 - val_ACCR: 0.9077 - val_ACCR5: 0.8030 - val_auc1: 0.9732 - val_TPR: 0.7842 - val_FPR: 0.0265
#
# Epoch 00044: val_ACCR did not improve from 0.91026
# Epoch 45/2000
#  - 1180s - loss: 0.1967 - binary_accuracy: 0.9447 - ACCR: 0.6524 - ACCR5: 0.8076 - auc1: 0.9825 - TPR: 9.8562e-07 - FPR: 0.0000e+00 - val_loss: 0.2408 - val_binary_accuracy: 0.9240 - val_ACCR: 0.9076 - val_ACCR5: 0.8070 - val_auc1: 0.9734 - val_TPR: 0.7826 - val_FPR: 0.0258
#
# Epoch 00045: val_ACCR did not improve from 0.91026
# Epoch 46/2000
#  - 1180s - loss: 0.1951 - binary_accuracy: 0.9456 - ACCR: 0.6524 - ACCR5: 0.8122 - auc1: 0.9828 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.1881 - val_binary_accuracy: 0.9233 - val_ACCR: 0.9114 - val_ACCR5: 0.8022 - val_auc1: 0.9735 - val_TPR: 0.7969 - val_FPR: 0.0275
#
# Epoch 00046: val_ACCR improved from 0.91026 to 0.91140, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 47/2000
#  - 1178s - loss: 0.1940 - binary_accuracy: 0.9462 - ACCR: 0.6524 - ACCR5: 0.8117 - auc1: 0.9830 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2721 - val_binary_accuracy: 0.9242 - val_ACCR: 0.9111 - val_ACCR5: 0.8063 - val_auc1: 0.9731 - val_TPR: 0.7950 - val_FPR: 0.0270
#
# Epoch 00047: val_ACCR did not improve from 0.91140
# Epoch 48/2000
#  - 1199s - loss: 0.1929 - binary_accuracy: 0.9466 - ACCR: 0.6524 - ACCR5: 0.8126 - auc1: 0.9833 - TPR: 9.8562e-07 - FPR: 0.0000e+00 - val_loss: 0.1762 - val_binary_accuracy: 0.9247 - val_ACCR: 0.9101 - val_ACCR5: 0.8089 - val_auc1: 0.9734 - val_TPR: 0.7908 - val_FPR: 0.0263
#
# Epoch 00048: val_ACCR did not improve from 0.91140
# Epoch 49/2000
#  - 1176s - loss: 0.1917 - binary_accuracy: 0.9473 - ACCR: 0.6524 - ACCR5: 0.8162 - auc1: 0.9835 - TPR: 1.8546e-06 - FPR: 0.0000e+00 - val_loss: 0.1947 - val_binary_accuracy: 0.9241 - val_ACCR: 0.9127 - val_ACCR5: 0.8027 - val_auc1: 0.9735 - val_TPR: 0.8006 - val_FPR: 0.0275
#
# Epoch 00049: val_ACCR improved from 0.91140 to 0.91273, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 50/2000
#  - 1188s - loss: 0.1912 - binary_accuracy: 0.9475 - ACCR: 0.6524 - ACCR5: 0.8161 - auc1: 0.9835 - TPR: 8.7947e-07 - FPR: 0.0000e+00 - val_loss: 0.2464 - val_binary_accuracy: 0.9247 - val_ACCR: 0.9126 - val_ACCR5: 0.8139 - val_auc1: 0.9730 - val_TPR: 0.7996 - val_FPR: 0.0272
#
# Epoch 00050: val_ACCR did not improve from 0.91273
# Epoch 51/2000
#  - 1184s - loss: 0.1904 - binary_accuracy: 0.9481 - ACCR: 0.6524 - ACCR5: 0.8215 - auc1: 0.9837 - TPR: 9.4750e-07 - FPR: 0.0000e+00 - val_loss: 0.1862 - val_binary_accuracy: 0.9245 - val_ACCR: 0.9139 - val_ACCR5: 0.8128 - val_auc1: 0.9731 - val_TPR: 0.8055 - val_FPR: 0.0283
#
# Epoch 00051: val_ACCR improved from 0.91273 to 0.91390, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 52/2000
#  - 1182s - loss: 0.1894 - binary_accuracy: 0.9485 - ACCR: 0.6524 - ACCR5: 0.8212 - auc1: 0.9839 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2724 - val_binary_accuracy: 0.9244 - val_ACCR: 0.9148 - val_ACCR5: 0.8070 - val_auc1: 0.9736 - val_TPR: 0.8082 - val_FPR: 0.0284
#
# Epoch 00052: val_ACCR improved from 0.91390 to 0.91482, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 53/2000
#  - 1177s - loss: 0.1892 - binary_accuracy: 0.9487 - ACCR: 0.6524 - ACCR5: 0.8205 - auc1: 0.9840 - TPR: 1.0029e-06 - FPR: 0.0000e+00 - val_loss: 0.2741 - val_binary_accuracy: 0.9249 - val_ACCR: 0.9141 - val_ACCR5: 0.8116 - val_auc1: 0.9734 - val_TPR: 0.8053 - val_FPR: 0.0279
#
# Epoch 00053: val_ACCR did not improve from 0.91482
# Epoch 54/2000
#  - 1182s - loss: 0.1882 - binary_accuracy: 0.9491 - ACCR: 0.6524 - ACCR5: 0.8221 - auc1: 0.9842 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2148 - val_binary_accuracy: 0.9249 - val_ACCR: 0.9139 - val_ACCR5: 0.8108 - val_auc1: 0.9732 - val_TPR: 0.8050 - val_FPR: 0.0280
#
# Epoch 00054: val_ACCR did not improve from 0.91482
# Epoch 55/2000
#  - 1178s - loss: 0.1870 - binary_accuracy: 0.9498 - ACCR: 0.6524 - ACCR5: 0.8215 - auc1: 0.9844 - TPR: 1.8342e-06 - FPR: 0.0000e+00 - val_loss: 0.1945 - val_binary_accuracy: 0.9246 - val_ACCR: 0.9158 - val_ACCR5: 0.8138 - val_auc1: 0.9728 - val_TPR: 0.8119 - val_FPR: 0.0288
#
# Epoch 00055: val_ACCR improved from 0.91482 to 0.91581, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 56/2000
#  - 1190s - loss: 0.1862 - binary_accuracy: 0.9501 - ACCR: 0.6524 - ACCR5: 0.8269 - auc1: 0.9846 - TPR: 2.0486e-06 - FPR: 0.0000e+00 - val_loss: 0.1531 - val_binary_accuracy: 0.9249 - val_ACCR: 0.9172 - val_ACCR5: 0.8065 - val_auc1: 0.9740 - val_TPR: 0.8173 - val_FPR: 0.0295
#
# Epoch 00056: val_ACCR improved from 0.91581 to 0.91724, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 57/2000
#  - 1180s - loss: 0.1855 - binary_accuracy: 0.9505 - ACCR: 0.6524 - ACCR5: 0.8263 - auc1: 0.9847 - TPR: 4.8955e-06 - FPR: 4.8446e-07 - val_loss: 0.3563 - val_binary_accuracy: 0.9245 - val_ACCR: 0.9177 - val_ACCR5: 0.8100 - val_auc1: 0.9731 - val_TPR: 0.8191 - val_FPR: 0.0297
#
# Epoch 00057: val_ACCR improved from 0.91724 to 0.91767, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 58/2000
#  - 1179s - loss: 0.1842 - binary_accuracy: 0.9513 - ACCR: 0.6524 - ACCR5: 0.8261 - auc1: 0.9850 - TPR: 0.0000e+00 - FPR: 0.0000e+00 - val_loss: 0.2438 - val_binary_accuracy: 0.9252 - val_ACCR: 0.9165 - val_ACCR5: 0.8145 - val_auc1: 0.9727 - val_TPR: 0.8125 - val_FPR: 0.0281
#
# Epoch 00058: val_ACCR did not improve from 0.91767
# Epoch 59/2000
#  - 1180s - loss: 0.1830 - binary_accuracy: 0.9518 - ACCR: 0.6524 - ACCR5: 0.8272 - auc1: 0.9852 - TPR: 9.9708e-07 - FPR: 0.0000e+00 - val_loss: 0.3240 - val_binary_accuracy: 0.9254 - val_ACCR: 0.9170 - val_ACCR5: 0.8181 - val_auc1: 0.9726 - val_TPR: 0.8147 - val_FPR: 0.0284
#
# Epoch 00059: val_ACCR did not improve from 0.91767
# Epoch 60/2000
#  - 1179s - loss: 0.1822 - binary_accuracy: 0.9523 - ACCR: 0.6524 - ACCR5: 0.8301 - auc1: 0.9853 - TPR: 2.1381e-06 - FPR: 0.0000e+00 - val_loss: 0.2679 - val_binary_accuracy: 0.9252 - val_ACCR: 0.9158 - val_ACCR5: 0.8155 - val_auc1: 0.9728 - val_TPR: 0.8108 - val_FPR: 0.0282
#
# Epoch 00060: val_ACCR did not improve from 0.91767
# Epoch 61/2000
#  - 1177s - loss: 0.1814 - binary_accuracy: 0.9526 - ACCR: 0.6524 - ACCR5: 0.8289 - auc1: 0.9855 - TPR: 1.9777e-06 - FPR: 0.0000e+00 - val_loss: 0.1896 - val_binary_accuracy: 0.9257 - val_ACCR: 0.9147 - val_ACCR5: 0.8135 - val_auc1: 0.9726 - val_TPR: 0.8063 - val_FPR: 0.0274
#
# Epoch 00061: val_ACCR did not improve from 0.91767
# Epoch 62/2000
#  - 1182s - loss: 0.1806 - binary_accuracy: 0.9532 - ACCR: 0.6524 - ACCR5: 0.8311 - auc1: 0.9856 - TPR: 2.8158e-06 - FPR: 0.0000e+00 - val_loss: 0.2075 - val_binary_accuracy: 0.9256 - val_ACCR: 0.9167 - val_ACCR5: 0.8213 - val_auc1: 0.9728 - val_TPR: 0.8137 - val_FPR: 0.0283
#
# Epoch 00062: val_ACCR did not improve from 0.91767
# Epoch 63/2000
#  - 1177s - loss: 0.1801 - binary_accuracy: 0.9533 - ACCR: 0.6524 - ACCR5: 0.8334 - auc1: 0.9857 - TPR: 2.9158e-06 - FPR: 0.0000e+00 - val_loss: 0.2331 - val_binary_accuracy: 0.9258 - val_ACCR: 0.9161 - val_ACCR5: 0.8211 - val_auc1: 0.9722 - val_TPR: 0.8109 - val_FPR: 0.0279
#
# Epoch 00063: val_ACCR did not improve from 0.91767
# Epoch 64/2000
#  - 1180s - loss: 0.1794 - binary_accuracy: 0.9537 - ACCR: 0.6524 - ACCR5: 0.8343 - auc1: 0.9858 - TPR: 2.9558e-06 - FPR: 0.0000e+00 - val_loss: 0.1256 - val_binary_accuracy: 0.9256 - val_ACCR: 0.9169 - val_ACCR5: 0.8249 - val_auc1: 0.9720 - val_TPR: 0.8144 - val_FPR: 0.0285
#
# Epoch 00064: val_ACCR did not improve from 0.91767
# Epoch 65/2000
#  - 1181s - loss: 0.1785 - binary_accuracy: 0.9542 - ACCR: 0.6524 - ACCR5: 0.8335 - auc1: 0.9860 - TPR: 1.9327e-06 - FPR: 0.0000e+00 - val_loss: 0.1630 - val_binary_accuracy: 0.9260 - val_ACCR: 0.9173 - val_ACCR5: 0.8233 - val_auc1: 0.9721 - val_TPR: 0.8156 - val_FPR: 0.0286
#
# Epoch 00065: val_ACCR did not improve from 0.91767
# Epoch 66/2000
#  - 1182s - loss: 0.1777 - binary_accuracy: 0.9547 - ACCR: 0.6524 - ACCR5: 0.8359 - auc1: 0.9862 - TPR: 3.7096e-06 - FPR: 0.0000e+00 - val_loss: 0.2774 - val_binary_accuracy: 0.9252 - val_ACCR: 0.9169 - val_ACCR5: 0.8292 - val_auc1: 0.9712 - val_TPR: 0.8151 - val_FPR: 0.0288
#
# Epoch 00066: val_ACCR did not improve from 0.91767
# Epoch 67/2000
#  - 1177s - loss: 0.1771 - binary_accuracy: 0.9550 - ACCR: 0.6524 - ACCR5: 0.8379 - auc1: 0.9863 - TPR: 4.8666e-06 - FPR: 0.0000e+00 - val_loss: 0.2183 - val_binary_accuracy: 0.9255 - val_ACCR: 0.9204 - val_ACCR5: 0.8210 - val_auc1: 0.9726 - val_TPR: 0.8278 - val_FPR: 0.0303
#
# Epoch 00067: val_ACCR improved from 0.91767 to 0.92036, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 68/2000
#  - 1179s - loss: 0.1763 - binary_accuracy: 0.9554 - ACCR: 0.6524 - ACCR5: 0.8374 - auc1: 0.9864 - TPR: 1.9343e-06 - FPR: 0.0000e+00 - val_loss: 0.3192 - val_binary_accuracy: 0.9259 - val_ACCR: 0.9188 - val_ACCR5: 0.8259 - val_auc1: 0.9717 - val_TPR: 0.8211 - val_FPR: 0.0291
#
# Epoch 00068: val_ACCR did not improve from 0.92036
# Epoch 69/2000
#  - 1184s - loss: 0.1754 - binary_accuracy: 0.9558 - ACCR: 0.6524 - ACCR5: 0.8372 - auc1: 0.9866 - TPR: 1.9048e-06 - FPR: 0.0000e+00 - val_loss: 0.2740 - val_binary_accuracy: 0.9260 - val_ACCR: 0.9185 - val_ACCR5: 0.8243 - val_auc1: 0.9720 - val_TPR: 0.8194 - val_FPR: 0.0287
#
# Epoch 00069: val_ACCR did not improve from 0.92036
# Epoch 70/2000
#  - 1182s - loss: 0.1748 - binary_accuracy: 0.9561 - ACCR: 0.6524 - ACCR5: 0.8334 - auc1: 0.9867 - TPR: 2.9224e-06 - FPR: 0.0000e+00 - val_loss: 0.2074 - val_binary_accuracy: 0.9256 - val_ACCR: 0.9202 - val_ACCR5: 0.8168 - val_auc1: 0.9728 - val_TPR: 0.8269 - val_FPR: 0.0302
#
# Epoch 00070: val_ACCR did not improve from 0.92036
# Epoch 71/2000
#  - 1185s - loss: 0.1744 - binary_accuracy: 0.9564 - ACCR: 0.6524 - ACCR5: 0.8359 - auc1: 0.9868 - TPR: 6.5312e-06 - FPR: 0.0000e+00 - val_loss: 0.1685 - val_binary_accuracy: 0.9257 - val_ACCR: 0.9207 - val_ACCR5: 0.8212 - val_auc1: 0.9720 - val_TPR: 0.8283 - val_FPR: 0.0301
#
# Epoch 00071: val_ACCR improved from 0.92036 to 0.92066, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 72/2000
#  - 1183s - loss: 0.1737 - binary_accuracy: 0.9566 - ACCR: 0.6524 - ACCR5: 0.8400 - auc1: 0.9869 - TPR: 2.9181e-06 - FPR: 0.0000e+00 - val_loss: 0.2741 - val_binary_accuracy: 0.9260 - val_ACCR: 0.9202 - val_ACCR5: 0.8245 - val_auc1: 0.9722 - val_TPR: 0.8261 - val_FPR: 0.0296
#
# Epoch 00072: val_ACCR did not improve from 0.92066
# Epoch 73/2000
#  - 1178s - loss: 0.1727 - binary_accuracy: 0.9571 - ACCR: 0.6524 - ACCR5: 0.8398 - auc1: 0.9870 - TPR: 1.0029e-06 - FPR: 0.0000e+00 - val_loss: 0.1800 - val_binary_accuracy: 0.9260 - val_ACCR: 0.9195 - val_ACCR5: 0.8228 - val_auc1: 0.9719 - val_TPR: 0.8236 - val_FPR: 0.0293
#
# Epoch 00073: val_ACCR did not improve from 0.92066
# Epoch 74/2000
#  - 1179s - loss: 0.1720 - binary_accuracy: 0.9575 - ACCR: 0.6524 - ACCR5: 0.8426 - auc1: 0.9871 - TPR: 3.7317e-06 - FPR: 0.0000e+00 - val_loss: 0.3215 - val_binary_accuracy: 0.9260 - val_ACCR: 0.9206 - val_ACCR5: 0.8320 - val_auc1: 0.9710 - val_TPR: 0.8275 - val_FPR: 0.0298
#
# Epoch 00074: val_ACCR did not improve from 0.92066
# Epoch 75/2000
#  - 1182s - loss: 0.1714 - binary_accuracy: 0.9578 - ACCR: 0.6524 - ACCR5: 0.8456 - auc1: 0.9872 - TPR: 6.9460e-06 - FPR: 0.0000e+00 - val_loss: 0.1849 - val_binary_accuracy: 0.9262 - val_ACCR: 0.9194 - val_ACCR5: 0.8316 - val_auc1: 0.9718 - val_TPR: 0.8230 - val_FPR: 0.0292
#
# Epoch 00075: val_ACCR did not improve from 0.92066
# Epoch 76/2000
#  - 1181s - loss: 0.1710 - binary_accuracy: 0.9580 - ACCR: 0.6524 - ACCR5: 0.8434 - auc1: 0.9873 - TPR: 8.8483e-06 - FPR: 0.0000e+00 - val_loss: 0.1929 - val_binary_accuracy: 0.9261 - val_ACCR: 0.9201 - val_ACCR5: 0.8290 - val_auc1: 0.9713 - val_TPR: 0.8260 - val_FPR: 0.0298
#
# Epoch 00076: val_ACCR did not improve from 0.92066
# Epoch 77/2000
#  - 1182s - loss: 0.1708 - binary_accuracy: 0.9582 - ACCR: 0.6524 - ACCR5: 0.8441 - auc1: 0.9873 - TPR: 7.6113e-06 - FPR: 0.0000e+00 - val_loss: 0.3052 - val_binary_accuracy: 0.9265 - val_ACCR: 0.9185 - val_ACCR5: 0.8322 - val_auc1: 0.9711 - val_TPR: 0.8197 - val_FPR: 0.0288
#
# Epoch 00077: val_ACCR did not improve from 0.92066
# Epoch 78/2000
#  - 1182s - loss: 0.1703 - binary_accuracy: 0.9585 - ACCR: 0.6524 - ACCR5: 0.8419 - auc1: 0.9875 - TPR: 2.9892e-06 - FPR: 0.0000e+00 - val_loss: 0.2777 - val_binary_accuracy: 0.9266 - val_ACCR: 0.9202 - val_ACCR5: 0.8289 - val_auc1: 0.9719 - val_TPR: 0.8261 - val_FPR: 0.0296
#
# Epoch 00078: val_ACCR did not improve from 0.92066
# Epoch 79/2000
#  - 1181s - loss: 0.1697 - binary_accuracy: 0.9587 - ACCR: 0.6524 - ACCR5: 0.8485 - auc1: 0.9875 - TPR: 1.0243e-05 - FPR: 0.0000e+00 - val_loss: 0.4043 - val_binary_accuracy: 0.9260 - val_ACCR: 0.9166 - val_ACCR5: 0.8314 - val_auc1: 0.9701 - val_TPR: 0.8116 - val_FPR: 0.0275
#
# Epoch 00079: val_ACCR did not improve from 0.92066
# Epoch 80/2000
#  - 1180s - loss: 0.1694 - binary_accuracy: 0.9590 - ACCR: 0.6524 - ACCR5: 0.8408 - auc1: 0.9876 - TPR: 1.5115e-05 - FPR: 0.0000e+00 - val_loss: 0.2447 - val_binary_accuracy: 0.9259 - val_ACCR: 0.9186 - val_ACCR5: 0.8287 - val_auc1: 0.9708 - val_TPR: 0.8209 - val_FPR: 0.0293
#
# Epoch 00080: val_ACCR did not improve from 0.92066
# Epoch 81/2000
#  - 1181s - loss: 0.1693 - binary_accuracy: 0.9591 - ACCR: 0.6524 - ACCR5: 0.8420 - auc1: 0.9876 - TPR: 1.0333e-05 - FPR: 5.2286e-07 - val_loss: 0.1848 - val_binary_accuracy: 0.9263 - val_ACCR: 0.9209 - val_ACCR5: 0.8298 - val_auc1: 0.9708 - val_TPR: 0.8285 - val_FPR: 0.0298
#
# Epoch 00081: val_ACCR improved from 0.92066 to 0.92092, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 82/2000
#  - 1187s - loss: 0.1691 - binary_accuracy: 0.9593 - ACCR: 0.6524 - ACCR5: 0.8487 - auc1: 0.9877 - TPR: 9.5336e-06 - FPR: 0.0000e+00 - val_loss: 0.2858 - val_binary_accuracy: 0.9263 - val_ACCR: 0.9208 - val_ACCR5: 0.8362 - val_auc1: 0.9708 - val_TPR: 0.8283 - val_FPR: 0.0299
#
# Epoch 00082: val_ACCR did not improve from 0.92092
# Epoch 83/2000
#  - 1181s - loss: 0.1681 - binary_accuracy: 0.9597 - ACCR: 0.6524 - ACCR5: 0.8494 - auc1: 0.9878 - TPR: 1.9055e-05 - FPR: 0.0000e+00 - val_loss: 0.2306 - val_binary_accuracy: 0.9264 - val_ACCR: 0.9205 - val_ACCR5: 0.8346 - val_auc1: 0.9709 - val_TPR: 0.8270 - val_FPR: 0.0297
#
# Epoch 00083: val_ACCR did not improve from 0.92092
# Epoch 84/2000
#  - 1185s - loss: 0.1674 - binary_accuracy: 0.9601 - ACCR: 0.6524 - ACCR5: 0.8452 - auc1: 0.9880 - TPR: 1.3529e-05 - FPR: 0.0000e+00 - val_loss: 0.2916 - val_binary_accuracy: 0.9263 - val_ACCR: 0.9195 - val_ACCR5: 0.8293 - val_auc1: 0.9714 - val_TPR: 0.8228 - val_FPR: 0.0289
#
# Epoch 00084: val_ACCR did not improve from 0.92092
# Epoch 85/2000
#  - 1179s - loss: 0.1670 - binary_accuracy: 0.9603 - ACCR: 0.6524 - ACCR5: 0.8429 - auc1: 0.9881 - TPR: 1.3307e-05 - FPR: 0.0000e+00 - val_loss: 0.2854 - val_binary_accuracy: 0.9266 - val_ACCR: 0.9206 - val_ACCR5: 0.8347 - val_auc1: 0.9707 - val_TPR: 0.8267 - val_FPR: 0.0294
#
# Epoch 00085: val_ACCR did not improve from 0.92092
# Epoch 86/2000
#  - 1185s - loss: 0.1664 - binary_accuracy: 0.9606 - ACCR: 0.6524 - ACCR5: 0.8493 - auc1: 0.9881 - TPR: 1.7277e-05 - FPR: 0.0000e+00 - val_loss: 0.2275 - val_binary_accuracy: 0.9263 - val_ACCR: 0.9208 - val_ACCR5: 0.8360 - val_auc1: 0.9705 - val_TPR: 0.8287 - val_FPR: 0.0300
#
# Epoch 00086: val_ACCR did not improve from 0.92092
# Epoch 87/2000
#  - 1183s - loss: 0.1660 - binary_accuracy: 0.9609 - ACCR: 0.6524 - ACCR5: 0.8513 - auc1: 0.9882 - TPR: 1.7192e-05 - FPR: 0.0000e+00 - val_loss: 0.2494 - val_binary_accuracy: 0.9261 - val_ACCR: 0.9215 - val_ACCR5: 0.8364 - val_auc1: 0.9705 - val_TPR: 0.8311 - val_FPR: 0.0302
#
# Epoch 00087: val_ACCR improved from 0.92092 to 0.92152, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 88/2000
#  - 1181s - loss: 0.1653 - binary_accuracy: 0.9611 - ACCR: 0.6524 - ACCR5: 0.8507 - auc1: 0.9883 - TPR: 2.1640e-05 - FPR: 5.3761e-07 - val_loss: 0.2166 - val_binary_accuracy: 0.9262 - val_ACCR: 0.9212 - val_ACCR5: 0.8327 - val_auc1: 0.9709 - val_TPR: 0.8297 - val_FPR: 0.0300
#
# Epoch 00088: val_ACCR did not improve from 0.92152
# Epoch 89/2000
#  - 1180s - loss: 0.1649 - binary_accuracy: 0.9614 - ACCR: 0.6524 - ACCR5: 0.8560 - auc1: 0.9884 - TPR: 2.4687e-05 - FPR: 0.0000e+00 - val_loss: 0.2271 - val_binary_accuracy: 0.9266 - val_ACCR: 0.9206 - val_ACCR5: 0.8453 - val_auc1: 0.9696 - val_TPR: 0.8275 - val_FPR: 0.0297
#
# Epoch 00089: val_ACCR did not improve from 0.92152
# Epoch 90/2000
#  - 1195s - loss: 0.1645 - binary_accuracy: 0.9616 - ACCR: 0.6524 - ACCR5: 0.8529 - auc1: 0.9884 - TPR: 2.2427e-05 - FPR: 0.0000e+00 - val_loss: 0.3836 - val_binary_accuracy: 0.9264 - val_ACCR: 0.9214 - val_ACCR5: 0.8416 - val_auc1: 0.9695 - val_TPR: 0.8306 - val_FPR: 0.0302
#
# Epoch 00090: val_ACCR did not improve from 0.92152
# Epoch 91/2000
#  - 1186s - loss: 0.1643 - binary_accuracy: 0.9617 - ACCR: 0.6524 - ACCR5: 0.8515 - auc1: 0.9885 - TPR: 2.5339e-05 - FPR: 0.0000e+00 - val_loss: 0.2667 - val_binary_accuracy: 0.9257 - val_ACCR: 0.9209 - val_ACCR5: 0.8375 - val_auc1: 0.9698 - val_TPR: 0.8299 - val_FPR: 0.0305
#
# Epoch 00091: val_ACCR did not improve from 0.92152
# Epoch 92/2000
#  - 1180s - loss: 0.1635 - binary_accuracy: 0.9621 - ACCR: 0.6524 - ACCR5: 0.8551 - auc1: 0.9885 - TPR: 3.9455e-05 - FPR: 0.0000e+00 - val_loss: 0.3152 - val_binary_accuracy: 0.9260 - val_ACCR: 0.9228 - val_ACCR5: 0.8344 - val_auc1: 0.9705 - val_TPR: 0.8375 - val_FPR: 0.0317
#
# Epoch 00092: val_ACCR improved from 0.92152 to 0.92283, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_inscope_0
# Epoch 93/2000
