# %%
import os
import random
import numpy as np
import tensorflow as tf
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
from tqdm import tqdm, trange
from collections import defaultdict
from highway_layer import Highway
#匯入深度學習的框架函式庫：keras
import keras
from keras import backend as K
from keras.initializers import Constant
from keras.utils import plot_model
#keras用以建立模型架構的函數
from keras.models import Sequential, load_model, Model

#keras中建立深度學習layer的函數

from keras.layers import Dense, Dropout, BatchNormalization, Activation, Multiply, Add, Lambda, Input

#keras訓練演算法函數
from keras import regularizers
from keras.optimizers import Adam

#keras提早判停的函數
from keras.callbacks import EarlyStopping, ModelCheckpoint

#it's hard to reproduce results, so close all seeds
#os.environ['PYTHONHASHSEED'] = '0'
#np.random.seed(0)
#tf.set_random_seed(0)
#random.seed(0)

#to solve problem:Blas GEMM launch failed
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
#config = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
config.gpu_options.allocator_type = 'BFC' #A "Best-fit with coalescing" algorithm, simplified from a version of dlmalloc.
config.gpu_options.per_process_gpu_memory_fraction = 0.95
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config)) 


def fps_to_arr(fps):
    """Faster conversion to ndarray"""
    arrs = []
    for fp, info in zip(fps[0],fps[1]):
        onbits = list(fp.GetOnBits())
        arr = np.zeros(fp.GetNumBits())
        for onbit in onbits:
            arr[onbit] = len(info[onbit])
        arrs.append(arr)
    arrs = np.array(arrs)
    return arrs




def fingerprint_mols(mols, fp_dim):
    fps = []
    infos = []
    for mol in mols:
        mol = Chem.MolFromSmiles(mol)
        info={}
        # Necessary for fingerprinting
        # Chem.GetSymmSSSR(mol)

        # "When comparing the ECFP/FCFP fingerprints and
        # the Morgan fingerprints generated by the RDKit,
        # remember that the 4 in ECFP4 corresponds to the
        # diameter of the atom environments considered,
        # while the Morgan fingerprints take a radius parameter.
        # So the examples above, with radius=2, are roughly
        # equivalent to ECFP4 and FCFP4."
        # <http://www.rdkit.org/docs/GettingStartedInPython.html>
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=int(fp_dim), useChirality=1, bitInfo=info)
        # fold_factor = fp.GetNumBits()//fp_dim
        # fp = DataStructs.FoldFingerprint(fp, fold_factor)
        fps.append(fp)
        infos.append(info)
    return fps, infos

def preprocess(X, fp_dim, idx):
    # Compute fingerprints
    dataX = fps_to_arr(fingerprint_mols(X, fp_dim))
    # Apply variance threshold
    # return np.log(X[:,self.idx] + 1) 
    #FPs = np.log(dataX[:,idx]+1)
    FPs = np.log(dataX+1)
    return FPs

def chunker(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def reducefn(a, b):
    n_a, mean_a, var_a = a
    n_b, mean_b, var_b = b
    n_ab = n_a + n_b
    mean_ab = ((mean_a * n_a) + (mean_b * n_b)) / n_ab
    var_ab = (((n_a * var_a) + (n_b * var_b)) / n_ab) + ((n_a * n_b) * ((mean_b - mean_a) / n_ab)**2)
    return n_ab, mean_ab, var_ab

def mapfn(chunk):
    exp_fp_dim = 1e6
    chunk = fingerprint_mols(chunk, exp_fp_dim)
    arrs = np.log(fps_to_arr(chunk) + 1)
    return len(arrs), np.mean(arrs, axis=0), np.var(arrs, axis=0)

class DataGenerator(keras.utils.Sequence):
    
    def __init__(self, X, y, idx, batch_size=1, shuffle=True, fp_dim=8192):
        self.batch_size = batch_size
        self.X = X
        self.y = y
        self.indexes = np.arange(len(self.X))
        self.shuffle = shuffle
        self.fp_dim = fp_dim
        self.idx = idx

    def __len__(self):
        #计算每一个epoch的迭代次数
        return int(np.floor(len(self.X) / int(self.batch_size)))

    def __getitem__(self, index):
        #生成每个batch数据，这里就根据自己对数据的读取方式进行发挥了
        # 生成batch_size个索引
        batch_indexs = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # 根据索引获取datas集合中的数据
        batch_datasX = [self.X[k] for k in batch_indexs]
        batch_datasy = [self.y[k] for k in batch_indexs]
        # 生成数据
        X = preprocess(batch_datasX, self.fp_dim, self.idx)
        y = np.array(batch_datasy)
#        y = y.astype(np.int64)
        return X, y

    def on_epoch_end(self):
        #在每一次epoch结束是否需要进行一次随机，重新随机一下index
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

#    def fps_to_arr(fps):
        """Faster conversion to ndarray"""
#        arrs = []
#        for fp in fps:
#            onbits = list(fp.GetOnBits())
#            arr = np.zeros(fp.GetNumBits())
#            arr[onbits] = 1
#            arrs.append(arr)
#        arrs = np.array(arrs)
#        return arrs




#    def fingerprint_mols(self,mols):
#        fps = []
#        for mol in mols:
#            mol = Chem.MolFromSmiles(mol)

        # Necessary for fingerprinting
        # Chem.GetSymmSSSR(mol)

        # "When comparing the ECFP/FCFP fingerprints and
        # the Morgan fingerprints generated by the RDKit,
        # remember that the 4 in ECFP4 corresponds to the
        # diameter of the atom environments considered,
        # while the Morgan fingerprints take a radius parameter.
        # So the examples above, with radius=2, are roughly
        # equivalent to ECFP4 and FCFP4."
        # <http://www.rdkit.org/docs/GettingStartedInPython.html>
#            fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=int(self.fp_dim))
        # fold_factor = fp.GetNumBits()//fp_dim
        # fp = DataStructs.FoldFingerprint(fp, fold_factor)
#            fps.append(fp)
#        return fps

#    def preprocess(self,X):
    # Compute fingerprints
#        return self.fps_to_arr(self.fingerprint_mols(X, self.fp_dim))



print('Loading data...')
prod_to_rules = defaultdict(set)
with open('data/templates_expansion.dat', 'r') as f:
    for l in tqdm(f, desc='products'):
        rule, prod = l.strip().split('\t')
        prod_to_rules[prod].add(rule)

expansion_rules = {}
with open('data/expansion_expansion.dat', 'r') as f:
    for i, l in tqdm(enumerate(f), desc='expansion'):
        rule = l.strip()
        expansion_rules[rule] = i
# expansion training
print('expansion training...')
X, y = [], []

for prod, rules in tqdm(prod_to_rules.items(), desc='data prep'):
    rules = [r for r in rules if r in expansion_rules]
    if not rules: continue
    rules.sort()
    # Ideally trained as multilabel,
    # but multiclass, single label is easier atm
    for r in rules:
        id = expansion_rules[r]
        y.append(id)
        X.append(prod)
        
totrec = 0
for prod, rules in tqdm(prod_to_rules.items(), desc='total reactions'):
    totrec += len(prod_to_rules[prod])
#    totrec += len(rules) 
        
print('total products:', len(prod_to_rules))
print('total reactions:', totrec)
print('Training size:', len(X))

#設定訓練參數和訓練模型存放路徑
#batch_size = 1024
batch_size = 256
#num_classes = 6
#epochs = 2000
epochs = 100
seed=0
#validation spilt
spilt=0.1
#for variance threshold
#fp_dim=1e6
fp_dim=23086
n_rules=len(expansion_rules)
model_name = 'trained_model_expansion_'+str(seed)
save_dir = os.path.join(os.getcwd(), 'saved_models')
idx = np.load(os.path.join(save_dir, 'expansion5e-5.idx.npy'))

# Shuffle
# p = np.random.permutation(len(X))
# X, y = X[p], y[p]
xy = list(zip(X, y))
xy.sort()
random.seed(seed)
random.shuffle(xy)
X, y = zip(*xy)
data_spilt= round(len(X)*(1-spilt))
x_train = X[:data_spilt]
x_test = X[data_spilt:]
y_train = y[:data_spilt]
y_test = y[data_spilt:]
print('shuffle is over...')

#將訓練資料轉成ndarray
#x_train=preprocess(X,fp_dim)
#y_train=np.array(y)
#print('preprocess is over...')
#for variance threshold
#visible = Input(shape=(len(idx),))
visible = Input(shape=(fp_dim,))
hidden = Dense(512, activation='elu')(visible)
hidden = Dropout(0.4)(hidden)

# only for expansion rule policynet
for _ in range(5):
    hidden = Highway()(hidden)
    hidden = Dropout(0.4)(hidden)
    
output = Dense(n_rules, activation='softmax')(hidden)
    
model = Model(inputs=visible, outputs=output)
# summarize layers
print(model.summary())
# plot graph
#plot_model(model, to_file='expansionpolicynet_graph.png')
# 初始化Adam optimizer
opt = keras.optimizers.Adam(lr=0.0001)

# 設定訓練方式，包含loss、optimizer..)
def acc_top50(y_true, y_pred):
    return keras.metrics.sparse_top_k_categorical_accuracy(y_true, y_pred, k=50)

def acc_top10(y_true, y_pred):
    return keras.metrics.sparse_top_k_categorical_accuracy(y_true, y_pred, k=10)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['sparse_categorical_accuracy',acc_top10 ,acc_top50])



# early stop存放模型設置


if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
checkpoint = ModelCheckpoint(model_path, monitor='val_acc_top50', save_best_only=True, verbose=1)

# early stop參數設定
earlystop = EarlyStopping(monitor='val_acc_top50', patience=6, verbose=1)

#continue training
#del model  # 删掉存在的模型

#返回一个编译好的模型
#与删掉的模型相同
#model = load_model(model_path, custom_objects={'acc_top10': acc_top10,'acc_top50': acc_top50, 'Highway': Highway})
##model.compile(loss='sparse_categorical_crossentropy',
##              optimizer=opt,
##              metrics=['sparse_categorical_accuracy',acc_top10,acc_top50])

# 開始訓練
training_generator = DataGenerator(X=x_train, y=y_train, batch_size=batch_size, shuffle=True, fp_dim=fp_dim, idx=idx)
validation_gen = DataGenerator(X=x_test, y=y_test, batch_size=batch_size, shuffle=True, fp_dim=fp_dim, idx=idx)
if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=1,
                    initial_epoch=0,
#                    workers=0, 
#                    use_multiprocessing=True, 
#                    shuffle=False,
#                    max_queue_size = 10, 
                    callbacks=[earlystop, checkpoint]
                    )

    #model_history = model.fit(x=x_train, 
#                    y=y_train,
#                    epochs=epochs,
#                    batch_size=batch_size,
#                    validation_split=0.2,
#                    verbose=1,
#                    callbacks=[earlystop, checkpoint])
# Out:
# RDKit WARNING: [09:23:13] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 3143138it [00:07, 414839.22it/s]
# expansion: 55608it [00:00, 724115.43it/s]
# expansion training...
# data prep: 100%|██████████| 1093208/1093208 [00:00<00:00, 1300277.53it/s]
# total reactions: 100%|██████████| 1093208/1093208 [00:00<00:00, 2060400.73it/s]
# total products: 1093208
# total reactions: 1157488
# Training size: 1027181
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 23086)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               11820544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_1 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_2 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_3 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_4 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_5 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 55608)             28526904
# =================================================================
# Total params: 42,974,008
# Trainable params: 42,974,008
# Non-trainable params: 0
# _________________________________________________________________
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1176c5037665> in <module>
#     324 #                    shuffle=False,
#     325 #                    max_queue_size = 10,
# --> 326                     callbacks=[earlystop, checkpoint]
#     327                     )
#     328
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     178         epoch_logs = {}
#     179         while epoch < epochs:
# --> 180             model.reset_metrics()
#     181             callbacks.on_epoch_begin(epoch)
#     182             steps_done = 0
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in reset_metrics(self)
#     278         metrics = self._get_training_eval_metrics()
#     279         for m in metrics:
# --> 280             m.reset_states()
#     281
#     282     def _check_trainable_weights_consistency(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\metrics.py in reset_states(self)
#     103         when a metric is evaluated during training.
#     104         """
# --> 105         K.batch_set_value([(v, 0) for v in self.weights])
#     106
#     107     @abc.abstractmethod
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in batch_set_value(tuples)
#    2958             `value` should be a Numpy array.
#    2959     """
# -> 2960     tf_keras_backend.batch_set_value(tuples)
#    2961
#    2962
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in batch_set_value(tuples)
#    2878           assign_ops.append(assign_op)
#    2879           feed_dict[assign_placeholder] = value
# -> 2880         get_session().run(assign_ops, feed_dict=feed_dict)
#    2881
#    2882
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1315     def _run_fn(feed_dict, fetch_list, target_list, options, run_metadata):
#    1316       # Ensure any changes to the graph are reflected in the runtime.
# -> 1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
#    1319           options, feed_dict, fetch_list, target_list, run_metadata)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in _extend_graph(self)
#    1350   def _extend_graph(self):
#    1351     with self._graph._session_run_lock():  # pylint: disable=protected-access
# -> 1352       tf_session.ExtendSession(self._session)
#    1353
#    1354   # The threshold to run garbage collection to delete dead tensors.
#
# KeyboardInterrupt:

# %%
from expansion_policy_fn import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=2, 
                    use_multiprocessing=True, 
                    max_queue_size = 12, 
#                    shuffle=False,
                    callbacks=[earlystop, checkpoint]
                    )
# Out:
# RDKit WARNING: [10:02:31] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 3143138it [00:07, 416210.60it/s]
# expansion: 55608it [00:00, 705540.45it/s]
# expansion training...
# data prep: 100%|██████████| 1093208/1093208 [00:00<00:00, 1200584.39it/s]
# total reactions: 100%|██████████| 1093208/1093208 [00:00<00:00, 2761042.48it/s]
# total products: 1093208
# total reactions: 1157488
# Training size: 1027181
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 23086)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               11820544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_1 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_2 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_3 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_4 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_5 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 55608)             28526904
# =================================================================
# Total params: 42,974,008
# Trainable params: 42,974,008
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/2000
#  - 711s - loss: 7.0282 - sparse_categorical_accuracy: 0.0721 - acc_top10: 0.2630 - acc_top50: 0.4539 - sparse_categorical_crossentropy: 7.0282 - val_loss: 6.0041 - val_sparse_categorical_accuracy: 0.1545 - val_acc_top10: 0.4051 - val_acc_top50: 0.5571 - val_sparse_categorical_crossentropy: 6.1305
#
# Epoch 00001: val_acc_top50 improved from -inf to 0.55711, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 2/2000
#  - 678s - loss: 5.7876 - sparse_categorical_accuracy: 0.1869 - acc_top10: 0.4572 - acc_top50: 0.6045 - sparse_categorical_crossentropy: 5.7876 - val_loss: 5.0926 - val_sparse_categorical_accuracy: 0.2300 - val_acc_top10: 0.5171 - val_acc_top50: 0.6541 - val_sparse_categorical_crossentropy: 5.3319
#
# Epoch 00002: val_acc_top50 improved from 0.55711 to 0.65412, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 3/2000
#  - 678s - loss: 5.2710 - sparse_categorical_accuracy: 0.2267 - acc_top10: 0.5215 - acc_top50: 0.6636 - sparse_categorical_crossentropy: 5.2709 - val_loss: 4.7968 - val_sparse_categorical_accuracy: 0.2605 - val_acc_top10: 0.5654 - val_acc_top50: 0.6983 - val_sparse_categorical_crossentropy: 4.9575
#
# Epoch 00003: val_acc_top50 improved from 0.65412 to 0.69833, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 4/2000
#  - 677s - loss: 4.9444 - sparse_categorical_accuracy: 0.2539 - acc_top10: 0.5617 - acc_top50: 0.6989 - sparse_categorical_crossentropy: 4.9444 - val_loss: 4.6636 - val_sparse_categorical_accuracy: 0.2878 - val_acc_top10: 0.5997 - val_acc_top50: 0.7276 - val_sparse_categorical_crossentropy: 4.6903
#
# Epoch 00004: val_acc_top50 improved from 0.69833 to 0.72759, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 5/2000
#  - 677s - loss: 4.7108 - sparse_categorical_accuracy: 0.2737 - acc_top10: 0.5884 - acc_top50: 0.7236 - sparse_categorical_crossentropy: 4.7108 - val_loss: 4.3047 - val_sparse_categorical_accuracy: 0.3054 - val_acc_top10: 0.6227 - val_acc_top50: 0.7472 - val_sparse_categorical_crossentropy: 4.5025
#
# Epoch 00005: val_acc_top50 improved from 0.72759 to 0.74725, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 6/2000
#  - 677s - loss: 4.5461 - sparse_categorical_accuracy: 0.2866 - acc_top10: 0.6065 - acc_top50: 0.7410 - sparse_categorical_crossentropy: 4.5461 - val_loss: 4.3169 - val_sparse_categorical_accuracy: 0.3167 - val_acc_top10: 0.6373 - val_acc_top50: 0.7604 - val_sparse_categorical_crossentropy: 4.3791
#
# Epoch 00006: val_acc_top50 improved from 0.74725 to 0.76035, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 7/2000
#  - 676s - loss: 4.4200 - sparse_categorical_accuracy: 0.2978 - acc_top10: 0.6198 - acc_top50: 0.7532 - sparse_categorical_crossentropy: 4.4200 - val_loss: 4.3674 - val_sparse_categorical_accuracy: 0.3284 - val_acc_top10: 0.6489 - val_acc_top50: 0.7717 - val_sparse_categorical_crossentropy: 4.2792
#
# Epoch 00007: val_acc_top50 improved from 0.76035 to 0.77165, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 8/2000
#  - 676s - loss: 4.3146 - sparse_categorical_accuracy: 0.3068 - acc_top10: 0.6316 - acc_top50: 0.7635 - sparse_categorical_crossentropy: 4.3146 - val_loss: 4.0954 - val_sparse_categorical_accuracy: 0.3377 - val_acc_top10: 0.6593 - val_acc_top50: 0.7794 - val_sparse_categorical_crossentropy: 4.2010
#
# Epoch 00008: val_acc_top50 improved from 0.77165 to 0.77938, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 9/2000
#  - 676s - loss: 4.2254 - sparse_categorical_accuracy: 0.3149 - acc_top10: 0.6417 - acc_top50: 0.7729 - sparse_categorical_crossentropy: 4.2254 - val_loss: 3.9715 - val_sparse_categorical_accuracy: 0.3462 - val_acc_top10: 0.6678 - val_acc_top50: 0.7864 - val_sparse_categorical_crossentropy: 4.1267
#
# Epoch 00009: val_acc_top50 improved from 0.77938 to 0.78641, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 10/2000
#  - 675s - loss: 4.1456 - sparse_categorical_accuracy: 0.3232 - acc_top10: 0.6503 - acc_top50: 0.7808 - sparse_categorical_crossentropy: 4.1456 - val_loss: 4.0975 - val_sparse_categorical_accuracy: 0.3538 - val_acc_top10: 0.6765 - val_acc_top50: 0.7933 - val_sparse_categorical_crossentropy: 4.0635
#
# Epoch 00010: val_acc_top50 improved from 0.78641 to 0.79325, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 11/2000
#  - 676s - loss: 4.0714 - sparse_categorical_accuracy: 0.3303 - acc_top10: 0.6591 - acc_top50: 0.7883 - sparse_categorical_crossentropy: 4.0714 - val_loss: 4.1429 - val_sparse_categorical_accuracy: 0.3613 - val_acc_top10: 0.6838 - val_acc_top50: 0.7979 - val_sparse_categorical_crossentropy: 4.0058
#
# Epoch 00011: val_acc_top50 improved from 0.79325 to 0.79794, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 12/2000
#  - 675s - loss: 4.0044 - sparse_categorical_accuracy: 0.3369 - acc_top10: 0.6673 - acc_top50: 0.7952 - sparse_categorical_crossentropy: 4.0044 - val_loss: 3.9532 - val_sparse_categorical_accuracy: 0.3681 - val_acc_top10: 0.6891 - val_acc_top50: 0.8033 - val_sparse_categorical_crossentropy: 3.9586
#
# Epoch 00012: val_acc_top50 improved from 0.79794 to 0.80330, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 13/2000
#  - 675s - loss: 3.9417 - sparse_categorical_accuracy: 0.3442 - acc_top10: 0.6750 - acc_top50: 0.8012 - sparse_categorical_crossentropy: 3.9417 - val_loss: 3.8597 - val_sparse_categorical_accuracy: 0.3732 - val_acc_top10: 0.6963 - val_acc_top50: 0.8079 - val_sparse_categorical_crossentropy: 3.9060
#
# Epoch 00013: val_acc_top50 improved from 0.80330 to 0.80795, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 14/2000
#  - 675s - loss: 3.8832 - sparse_categorical_accuracy: 0.3506 - acc_top10: 0.6814 - acc_top50: 0.8068 - sparse_categorical_crossentropy: 3.8832 - val_loss: 3.6489 - val_sparse_categorical_accuracy: 0.3775 - val_acc_top10: 0.7013 - val_acc_top50: 0.8121 - val_sparse_categorical_crossentropy: 3.8692
#
# Epoch 00014: val_acc_top50 improved from 0.80795 to 0.81212, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 15/2000
#  - 675s - loss: 3.8304 - sparse_categorical_accuracy: 0.3560 - acc_top10: 0.6882 - acc_top50: 0.8124 - sparse_categorical_crossentropy: 3.8304 - val_loss: 3.7425 - val_sparse_categorical_accuracy: 0.3835 - val_acc_top10: 0.7075 - val_acc_top50: 0.8155 - val_sparse_categorical_crossentropy: 3.8278
#
# Epoch 00015: val_acc_top50 improved from 0.81212 to 0.81549, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 16/2000
#  - 675s - loss: 3.7791 - sparse_categorical_accuracy: 0.3613 - acc_top10: 0.6940 - acc_top50: 0.8169 - sparse_categorical_crossentropy: 3.7791 - val_loss: 3.7090 - val_sparse_categorical_accuracy: 0.3875 - val_acc_top10: 0.7111 - val_acc_top50: 0.8191 - val_sparse_categorical_crossentropy: 3.7923
#
# Epoch 00016: val_acc_top50 improved from 0.81549 to 0.81912, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 17/2000
#  - 675s - loss: 3.7322 - sparse_categorical_accuracy: 0.3661 - acc_top10: 0.6997 - acc_top50: 0.8222 - sparse_categorical_crossentropy: 3.7322 - val_loss: 3.6695 - val_sparse_categorical_accuracy: 0.3934 - val_acc_top10: 0.7159 - val_acc_top50: 0.8223 - val_sparse_categorical_crossentropy: 3.7604
#
# Epoch 00017: val_acc_top50 improved from 0.81912 to 0.82228, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 18/2000
#  - 674s - loss: 3.6879 - sparse_categorical_accuracy: 0.3714 - acc_top10: 0.7048 - acc_top50: 0.8258 - sparse_categorical_crossentropy: 3.6879 - val_loss: 3.8015 - val_sparse_categorical_accuracy: 0.3968 - val_acc_top10: 0.7196 - val_acc_top50: 0.8252 - val_sparse_categorical_crossentropy: 3.7248
#
# Epoch 00018: val_acc_top50 improved from 0.82228 to 0.82521, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 19/2000
#  - 674s - loss: 3.6469 - sparse_categorical_accuracy: 0.3758 - acc_top10: 0.7100 - acc_top50: 0.8300 - sparse_categorical_crossentropy: 3.6469 - val_loss: 3.5165 - val_sparse_categorical_accuracy: 0.4004 - val_acc_top10: 0.7226 - val_acc_top50: 0.8271 - val_sparse_categorical_crossentropy: 3.7063
#
# Epoch 00019: val_acc_top50 improved from 0.82521 to 0.82714, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 20/2000
#  - 674s - loss: 3.6077 - sparse_categorical_accuracy: 0.3801 - acc_top10: 0.7145 - acc_top50: 0.8339 - sparse_categorical_crossentropy: 3.6077 - val_loss: 3.5478 - val_sparse_categorical_accuracy: 0.4043 - val_acc_top10: 0.7251 - val_acc_top50: 0.8286 - val_sparse_categorical_crossentropy: 3.6845
#
# Epoch 00020: val_acc_top50 improved from 0.82714 to 0.82856, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 21/2000
#  - 675s - loss: 3.5708 - sparse_categorical_accuracy: 0.3844 - acc_top10: 0.7188 - acc_top50: 0.8371 - sparse_categorical_crossentropy: 3.5708 - val_loss: 3.7338 - val_sparse_categorical_accuracy: 0.4062 - val_acc_top10: 0.7281 - val_acc_top50: 0.8310 - val_sparse_categorical_crossentropy: 3.6676
#
# Epoch 00021: val_acc_top50 improved from 0.82856 to 0.83104, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 22/2000
#  - 675s - loss: 3.5355 - sparse_categorical_accuracy: 0.3878 - acc_top10: 0.7226 - acc_top50: 0.8403 - sparse_categorical_crossentropy: 3.5355 - val_loss: 3.6866 - val_sparse_categorical_accuracy: 0.4092 - val_acc_top10: 0.7308 - val_acc_top50: 0.8330 - val_sparse_categorical_crossentropy: 3.6483
#
# Epoch 00022: val_acc_top50 improved from 0.83104 to 0.83298, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 23/2000
#  - 675s - loss: 3.5034 - sparse_categorical_accuracy: 0.3921 - acc_top10: 0.7264 - acc_top50: 0.8433 - sparse_categorical_crossentropy: 3.5034 - val_loss: 3.6472 - val_sparse_categorical_accuracy: 0.4130 - val_acc_top10: 0.7337 - val_acc_top50: 0.8346 - val_sparse_categorical_crossentropy: 3.6183
#
# Epoch 00023: val_acc_top50 improved from 0.83298 to 0.83459, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 24/2000
#  - 675s - loss: 3.4725 - sparse_categorical_accuracy: 0.3951 - acc_top10: 0.7302 - acc_top50: 0.8457 - sparse_categorical_crossentropy: 3.4725 - val_loss: 3.5972 - val_sparse_categorical_accuracy: 0.4149 - val_acc_top10: 0.7362 - val_acc_top50: 0.8364 - val_sparse_categorical_crossentropy: 3.6020
#
# Epoch 00024: val_acc_top50 improved from 0.83459 to 0.83641, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 25/2000
#  - 674s - loss: 3.4419 - sparse_categorical_accuracy: 0.3982 - acc_top10: 0.7339 - acc_top50: 0.8489 - sparse_categorical_crossentropy: 3.4419 - val_loss: 3.4007 - val_sparse_categorical_accuracy: 0.4172 - val_acc_top10: 0.7379 - val_acc_top50: 0.8370 - val_sparse_categorical_crossentropy: 3.5876
#
# Epoch 00025: val_acc_top50 improved from 0.83641 to 0.83701, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 26/2000
#  - 675s - loss: 3.4152 - sparse_categorical_accuracy: 0.4021 - acc_top10: 0.7363 - acc_top50: 0.8514 - sparse_categorical_crossentropy: 3.4152 - val_loss: 3.5293 - val_sparse_categorical_accuracy: 0.4186 - val_acc_top10: 0.7400 - val_acc_top50: 0.8390 - val_sparse_categorical_crossentropy: 3.5764
#
# Epoch 00026: val_acc_top50 improved from 0.83701 to 0.83899, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 27/2000
#  - 675s - loss: 3.3890 - sparse_categorical_accuracy: 0.4058 - acc_top10: 0.7398 - acc_top50: 0.8532 - sparse_categorical_crossentropy: 3.3890 - val_loss: 3.5907 - val_sparse_categorical_accuracy: 0.4210 - val_acc_top10: 0.7413 - val_acc_top50: 0.8400 - val_sparse_categorical_crossentropy: 3.5633
#
# Epoch 00027: val_acc_top50 improved from 0.83899 to 0.83995, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 28/2000
#  - 675s - loss: 3.3614 - sparse_categorical_accuracy: 0.4076 - acc_top10: 0.7434 - acc_top50: 0.8560 - sparse_categorical_crossentropy: 3.3614 - val_loss: 3.8000 - val_sparse_categorical_accuracy: 0.4229 - val_acc_top10: 0.7435 - val_acc_top50: 0.8408 - val_sparse_categorical_crossentropy: 3.5548
#
# Epoch 00028: val_acc_top50 improved from 0.83995 to 0.84079, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 29/2000
#  - 674s - loss: 3.3375 - sparse_categorical_accuracy: 0.4108 - acc_top10: 0.7457 - acc_top50: 0.8578 - sparse_categorical_crossentropy: 3.3375 - val_loss: 3.5770 - val_sparse_categorical_accuracy: 0.4243 - val_acc_top10: 0.7441 - val_acc_top50: 0.8419 - val_sparse_categorical_crossentropy: 3.5456
#
# Epoch 00029: val_acc_top50 improved from 0.84079 to 0.84192, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 30/2000
#  - 675s - loss: 3.3130 - sparse_categorical_accuracy: 0.4142 - acc_top10: 0.7491 - acc_top50: 0.8594 - sparse_categorical_crossentropy: 3.3130 - val_loss: 3.5377 - val_sparse_categorical_accuracy: 0.4275 - val_acc_top10: 0.7464 - val_acc_top50: 0.8424 - val_sparse_categorical_crossentropy: 3.5348
#
# Epoch 00030: val_acc_top50 improved from 0.84192 to 0.84238, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 31/2000
#  - 674s - loss: 3.2886 - sparse_categorical_accuracy: 0.4167 - acc_top10: 0.7513 - acc_top50: 0.8623 - sparse_categorical_crossentropy: 3.2886 - val_loss: 3.4579 - val_sparse_categorical_accuracy: 0.4276 - val_acc_top10: 0.7474 - val_acc_top50: 0.8435 - val_sparse_categorical_crossentropy: 3.5286
#
# Epoch 00031: val_acc_top50 improved from 0.84238 to 0.84353, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 32/2000
#  - 675s - loss: 3.2672 - sparse_categorical_accuracy: 0.4191 - acc_top10: 0.7540 - acc_top50: 0.8640 - sparse_categorical_crossentropy: 3.2672 - val_loss: 3.2374 - val_sparse_categorical_accuracy: 0.4301 - val_acc_top10: 0.7483 - val_acc_top50: 0.8452 - val_sparse_categorical_crossentropy: 3.5143
#
# Epoch 00032: val_acc_top50 improved from 0.84353 to 0.84516, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 33/2000
#  - 674s - loss: 3.2457 - sparse_categorical_accuracy: 0.4222 - acc_top10: 0.7567 - acc_top50: 0.8655 - sparse_categorical_crossentropy: 3.2457 - val_loss: 3.3711 - val_sparse_categorical_accuracy: 0.4307 - val_acc_top10: 0.7496 - val_acc_top50: 0.8458 - val_sparse_categorical_crossentropy: 3.5088
#
# Epoch 00033: val_acc_top50 improved from 0.84516 to 0.84575, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 34/2000
#  - 674s - loss: 3.2247 - sparse_categorical_accuracy: 0.4252 - acc_top10: 0.7585 - acc_top50: 0.8674 - sparse_categorical_crossentropy: 3.2247 - val_loss: 3.7060 - val_sparse_categorical_accuracy: 0.4329 - val_acc_top10: 0.7502 - val_acc_top50: 0.8463 - val_sparse_categorical_crossentropy: 3.5022
#
# Epoch 00034: val_acc_top50 improved from 0.84575 to 0.84628, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 35/2000
#  - 674s - loss: 3.2072 - sparse_categorical_accuracy: 0.4269 - acc_top10: 0.7603 - acc_top50: 0.8690 - sparse_categorical_crossentropy: 3.2072 - val_loss: 3.3558 - val_sparse_categorical_accuracy: 0.4338 - val_acc_top10: 0.7517 - val_acc_top50: 0.8475 - val_sparse_categorical_crossentropy: 3.4973
#
# Epoch 00035: val_acc_top50 improved from 0.84628 to 0.84747, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 36/2000
#  - 674s - loss: 3.1897 - sparse_categorical_accuracy: 0.4289 - acc_top10: 0.7630 - acc_top50: 0.8701 - sparse_categorical_crossentropy: 3.1897 - val_loss: 3.6061 - val_sparse_categorical_accuracy: 0.4360 - val_acc_top10: 0.7533 - val_acc_top50: 0.8482 - val_sparse_categorical_crossentropy: 3.4835
#
# Epoch 00036: val_acc_top50 improved from 0.84747 to 0.84815, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 37/2000
#  - 674s - loss: 3.1714 - sparse_categorical_accuracy: 0.4316 - acc_top10: 0.7647 - acc_top50: 0.8716 - sparse_categorical_crossentropy: 3.1714 - val_loss: 3.5221 - val_sparse_categorical_accuracy: 0.4375 - val_acc_top10: 0.7529 - val_acc_top50: 0.8479 - val_sparse_categorical_crossentropy: 3.4794
#
# Epoch 00037: val_acc_top50 did not improve from 0.84815
# Epoch 38/2000
#  - 674s - loss: 3.1540 - sparse_categorical_accuracy: 0.4339 - acc_top10: 0.7667 - acc_top50: 0.8732 - sparse_categorical_crossentropy: 3.1540 - val_loss: 3.5109 - val_sparse_categorical_accuracy: 0.4386 - val_acc_top10: 0.7551 - val_acc_top50: 0.8494 - val_sparse_categorical_crossentropy: 3.4691
#
# Epoch 00038: val_acc_top50 improved from 0.84815 to 0.84938, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 39/2000
#  - 673s - loss: 3.1358 - sparse_categorical_accuracy: 0.4359 - acc_top10: 0.7690 - acc_top50: 0.8741 - sparse_categorical_crossentropy: 3.1359 - val_loss: 3.5833 - val_sparse_categorical_accuracy: 0.4405 - val_acc_top10: 0.7564 - val_acc_top50: 0.8498 - val_sparse_categorical_crossentropy: 3.4614
#
# Epoch 00039: val_acc_top50 improved from 0.84938 to 0.84979, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 40/2000
#  - 674s - loss: 3.1201 - sparse_categorical_accuracy: 0.4383 - acc_top10: 0.7711 - acc_top50: 0.8756 - sparse_categorical_crossentropy: 3.1201 - val_loss: 3.4101 - val_sparse_categorical_accuracy: 0.4417 - val_acc_top10: 0.7566 - val_acc_top50: 0.8499 - val_sparse_categorical_crossentropy: 3.4618
#
# Epoch 00040: val_acc_top50 improved from 0.84979 to 0.84994, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 41/2000
#  - 674s - loss: 3.1036 - sparse_categorical_accuracy: 0.4405 - acc_top10: 0.7726 - acc_top50: 0.8767 - sparse_categorical_crossentropy: 3.1036 - val_loss: 3.3811 - val_sparse_categorical_accuracy: 0.4417 - val_acc_top10: 0.7567 - val_acc_top50: 0.8505 - val_sparse_categorical_crossentropy: 3.4591
#
# Epoch 00041: val_acc_top50 improved from 0.84994 to 0.85054, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 42/2000
#  - 674s - loss: 3.0879 - sparse_categorical_accuracy: 0.4425 - acc_top10: 0.7749 - acc_top50: 0.8781 - sparse_categorical_crossentropy: 3.0879 - val_loss: 3.4672 - val_sparse_categorical_accuracy: 0.4422 - val_acc_top10: 0.7573 - val_acc_top50: 0.8508 - val_sparse_categorical_crossentropy: 3.4605
#
# Epoch 00042: val_acc_top50 improved from 0.85054 to 0.85081, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 43/2000
#  - 674s - loss: 3.0766 - sparse_categorical_accuracy: 0.4443 - acc_top10: 0.7760 - acc_top50: 0.8786 - sparse_categorical_crossentropy: 3.0766 - val_loss: 3.4798 - val_sparse_categorical_accuracy: 0.4429 - val_acc_top10: 0.7588 - val_acc_top50: 0.8510 - val_sparse_categorical_crossentropy: 3.4542
#
# Epoch 00043: val_acc_top50 improved from 0.85081 to 0.85101, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 44/2000
#  - 674s - loss: 3.0596 - sparse_categorical_accuracy: 0.4455 - acc_top10: 0.7779 - acc_top50: 0.8806 - sparse_categorical_crossentropy: 3.0596 - val_loss: 3.6448 - val_sparse_categorical_accuracy: 0.4446 - val_acc_top10: 0.7581 - val_acc_top50: 0.8511 - val_sparse_categorical_crossentropy: 3.4462
#
# Epoch 00044: val_acc_top50 improved from 0.85101 to 0.85113, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 45/2000
#  - 674s - loss: 3.0457 - sparse_categorical_accuracy: 0.4483 - acc_top10: 0.7793 - acc_top50: 0.8811 - sparse_categorical_crossentropy: 3.0457 - val_loss: 3.4564 - val_sparse_categorical_accuracy: 0.4466 - val_acc_top10: 0.7599 - val_acc_top50: 0.8523 - val_sparse_categorical_crossentropy: 3.4423
#
# Epoch 00045: val_acc_top50 improved from 0.85113 to 0.85232, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 46/2000
#  - 675s - loss: 3.0317 - sparse_categorical_accuracy: 0.4495 - acc_top10: 0.7810 - acc_top50: 0.8823 - sparse_categorical_crossentropy: 3.0317 - val_loss: 3.4881 - val_sparse_categorical_accuracy: 0.4477 - val_acc_top10: 0.7606 - val_acc_top50: 0.8525 - val_sparse_categorical_crossentropy: 3.4404
#
# Epoch 00046: val_acc_top50 improved from 0.85232 to 0.85245, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 47/2000
#  - 674s - loss: 3.0180 - sparse_categorical_accuracy: 0.4513 - acc_top10: 0.7824 - acc_top50: 0.8834 - sparse_categorical_crossentropy: 3.0180 - val_loss: 3.4990 - val_sparse_categorical_accuracy: 0.4464 - val_acc_top10: 0.7607 - val_acc_top50: 0.8527 - val_sparse_categorical_crossentropy: 3.4380
#
# Epoch 00047: val_acc_top50 improved from 0.85245 to 0.85271, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 48/2000
#  - 674s - loss: 3.0062 - sparse_categorical_accuracy: 0.4532 - acc_top10: 0.7840 - acc_top50: 0.8846 - sparse_categorical_crossentropy: 3.0062 - val_loss: 3.2094 - val_sparse_categorical_accuracy: 0.4478 - val_acc_top10: 0.7613 - val_acc_top50: 0.8529 - val_sparse_categorical_crossentropy: 3.4307
#
# Epoch 00048: val_acc_top50 improved from 0.85271 to 0.85293, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 49/2000
#  - 675s - loss: 2.9923 - sparse_categorical_accuracy: 0.4549 - acc_top10: 0.7852 - acc_top50: 0.8854 - sparse_categorical_crossentropy: 2.9923 - val_loss: 3.4534 - val_sparse_categorical_accuracy: 0.4491 - val_acc_top10: 0.7614 - val_acc_top50: 0.8529 - val_sparse_categorical_crossentropy: 3.4339
#
# Epoch 00049: val_acc_top50 did not improve from 0.85293
# Epoch 50/2000
#  - 674s - loss: 2.9809 - sparse_categorical_accuracy: 0.4562 - acc_top10: 0.7862 - acc_top50: 0.8862 - sparse_categorical_crossentropy: 2.9809 - val_loss: 3.5381 - val_sparse_categorical_accuracy: 0.4486 - val_acc_top10: 0.7619 - val_acc_top50: 0.8532 - val_sparse_categorical_crossentropy: 3.4353
#
# Epoch 00050: val_acc_top50 improved from 0.85293 to 0.85321, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 51/2000
#  - 673s - loss: 2.9697 - sparse_categorical_accuracy: 0.4585 - acc_top10: 0.7880 - acc_top50: 0.8869 - sparse_categorical_crossentropy: 2.9697 - val_loss: 3.2687 - val_sparse_categorical_accuracy: 0.4506 - val_acc_top10: 0.7630 - val_acc_top50: 0.8541 - val_sparse_categorical_crossentropy: 3.4258
#
# Epoch 00051: val_acc_top50 improved from 0.85321 to 0.85408, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 52/2000
#  - 675s - loss: 2.9560 - sparse_categorical_accuracy: 0.4601 - acc_top10: 0.7896 - acc_top50: 0.8879 - sparse_categorical_crossentropy: 2.9560 - val_loss: 3.5221 - val_sparse_categorical_accuracy: 0.4520 - val_acc_top10: 0.7633 - val_acc_top50: 0.8542 - val_sparse_categorical_crossentropy: 3.4242
#
# Epoch 00052: val_acc_top50 improved from 0.85408 to 0.85416, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 53/2000
#  - 674s - loss: 2.9463 - sparse_categorical_accuracy: 0.4624 - acc_top10: 0.7905 - acc_top50: 0.8887 - sparse_categorical_crossentropy: 2.9463 - val_loss: 3.4628 - val_sparse_categorical_accuracy: 0.4528 - val_acc_top10: 0.7639 - val_acc_top50: 0.8546 - val_sparse_categorical_crossentropy: 3.4220
#
# Epoch 00053: val_acc_top50 improved from 0.85416 to 0.85461, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 54/2000
#  - 674s - loss: 2.9350 - sparse_categorical_accuracy: 0.4629 - acc_top10: 0.7916 - acc_top50: 0.8900 - sparse_categorical_crossentropy: 2.9350 - val_loss: 3.4501 - val_sparse_categorical_accuracy: 0.4546 - val_acc_top10: 0.7638 - val_acc_top50: 0.8542 - val_sparse_categorical_crossentropy: 3.4271
#
# Epoch 00054: val_acc_top50 did not improve from 0.85461
# Epoch 55/2000
#  - 674s - loss: 2.9239 - sparse_categorical_accuracy: 0.4645 - acc_top10: 0.7931 - acc_top50: 0.8902 - sparse_categorical_crossentropy: 2.9239 - val_loss: 3.2245 - val_sparse_categorical_accuracy: 0.4543 - val_acc_top10: 0.7642 - val_acc_top50: 0.8549 - val_sparse_categorical_crossentropy: 3.4179
#
# Epoch 00055: val_acc_top50 improved from 0.85461 to 0.85490, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 56/2000
#  - 674s - loss: 2.9133 - sparse_categorical_accuracy: 0.4661 - acc_top10: 0.7942 - acc_top50: 0.8913 - sparse_categorical_crossentropy: 2.9133 - val_loss: 3.5057 - val_sparse_categorical_accuracy: 0.4534 - val_acc_top10: 0.7643 - val_acc_top50: 0.8548 - val_sparse_categorical_crossentropy: 3.4176
#
# Epoch 00056: val_acc_top50 did not improve from 0.85490
# Epoch 57/2000
#  - 673s - loss: 2.9043 - sparse_categorical_accuracy: 0.4662 - acc_top10: 0.7957 - acc_top50: 0.8921 - sparse_categorical_crossentropy: 2.9043 - val_loss: 3.3051 - val_sparse_categorical_accuracy: 0.4537 - val_acc_top10: 0.7652 - val_acc_top50: 0.8553 - val_sparse_categorical_crossentropy: 3.4138
#
# Epoch 00057: val_acc_top50 improved from 0.85490 to 0.85527, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 58/2000
#  - 673s - loss: 2.8914 - sparse_categorical_accuracy: 0.4692 - acc_top10: 0.7968 - acc_top50: 0.8928 - sparse_categorical_crossentropy: 2.8914 - val_loss: 3.6424 - val_sparse_categorical_accuracy: 0.4551 - val_acc_top10: 0.7653 - val_acc_top50: 0.8552 - val_sparse_categorical_crossentropy: 3.4181
#
# Epoch 00058: val_acc_top50 did not improve from 0.85527
# Epoch 59/2000
#  - 674s - loss: 2.8821 - sparse_categorical_accuracy: 0.4697 - acc_top10: 0.7982 - acc_top50: 0.8933 - sparse_categorical_crossentropy: 2.8821 - val_loss: 3.5013 - val_sparse_categorical_accuracy: 0.4566 - val_acc_top10: 0.7659 - val_acc_top50: 0.8562 - val_sparse_categorical_crossentropy: 3.4090
#
# Epoch 00059: val_acc_top50 improved from 0.85527 to 0.85625, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 60/2000
#  - 674s - loss: 2.8733 - sparse_categorical_accuracy: 0.4713 - acc_top10: 0.7985 - acc_top50: 0.8941 - sparse_categorical_crossentropy: 2.8733 - val_loss: 3.3688 - val_sparse_categorical_accuracy: 0.4574 - val_acc_top10: 0.7660 - val_acc_top50: 0.8563 - val_sparse_categorical_crossentropy: 3.4160
#
# Epoch 00060: val_acc_top50 improved from 0.85625 to 0.85630, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 61/2000
#  - 674s - loss: 2.8625 - sparse_categorical_accuracy: 0.4731 - acc_top10: 0.7999 - acc_top50: 0.8951 - sparse_categorical_crossentropy: 2.8625 - val_loss: 3.4104 - val_sparse_categorical_accuracy: 0.4565 - val_acc_top10: 0.7661 - val_acc_top50: 0.8571 - val_sparse_categorical_crossentropy: 3.4080
#
# Epoch 00061: val_acc_top50 improved from 0.85630 to 0.85706, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 62/2000
#  - 673s - loss: 2.8517 - sparse_categorical_accuracy: 0.4747 - acc_top10: 0.8011 - acc_top50: 0.8953 - sparse_categorical_crossentropy: 2.8517 - val_loss: 3.4465 - val_sparse_categorical_accuracy: 0.4575 - val_acc_top10: 0.7665 - val_acc_top50: 0.8566 - val_sparse_categorical_crossentropy: 3.4038
#
# Epoch 00062: val_acc_top50 did not improve from 0.85706
# Epoch 63/2000
#  - 673s - loss: 2.8441 - sparse_categorical_accuracy: 0.4751 - acc_top10: 0.8016 - acc_top50: 0.8962 - sparse_categorical_crossentropy: 2.8441 - val_loss: 3.5037 - val_sparse_categorical_accuracy: 0.4570 - val_acc_top10: 0.7668 - val_acc_top50: 0.8573 - val_sparse_categorical_crossentropy: 3.4072
#
# Epoch 00063: val_acc_top50 improved from 0.85706 to 0.85732, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 64/2000
#  - 674s - loss: 2.8344 - sparse_categorical_accuracy: 0.4766 - acc_top10: 0.8029 - acc_top50: 0.8965 - sparse_categorical_crossentropy: 2.8344 - val_loss: 3.3821 - val_sparse_categorical_accuracy: 0.4580 - val_acc_top10: 0.7673 - val_acc_top50: 0.8572 - val_sparse_categorical_crossentropy: 3.4024
#
# Epoch 00064: val_acc_top50 did not improve from 0.85732
# Epoch 65/2000
#  - 674s - loss: 2.8268 - sparse_categorical_accuracy: 0.4773 - acc_top10: 0.8038 - acc_top50: 0.8971 - sparse_categorical_crossentropy: 2.8268 - val_loss: 3.3989 - val_sparse_categorical_accuracy: 0.4591 - val_acc_top10: 0.7670 - val_acc_top50: 0.8569 - val_sparse_categorical_crossentropy: 3.4069
#
# Epoch 00065: val_acc_top50 did not improve from 0.85732
# Epoch 66/2000
#  - 674s - loss: 2.8163 - sparse_categorical_accuracy: 0.4784 - acc_top10: 0.8051 - acc_top50: 0.8980 - sparse_categorical_crossentropy: 2.8163 - val_loss: 3.4654 - val_sparse_categorical_accuracy: 0.4593 - val_acc_top10: 0.7676 - val_acc_top50: 0.8574 - val_sparse_categorical_crossentropy: 3.3983
#
# Epoch 00066: val_acc_top50 improved from 0.85732 to 0.85735, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 67/2000
#  - 674s - loss: 2.8069 - sparse_categorical_accuracy: 0.4805 - acc_top10: 0.8056 - acc_top50: 0.8984 - sparse_categorical_crossentropy: 2.8069 - val_loss: 3.3222 - val_sparse_categorical_accuracy: 0.4590 - val_acc_top10: 0.7669 - val_acc_top50: 0.8567 - val_sparse_categorical_crossentropy: 3.4090
#
# Epoch 00067: val_acc_top50 did not improve from 0.85735
# Epoch 68/2000
#  - 674s - loss: 2.7978 - sparse_categorical_accuracy: 0.4806 - acc_top10: 0.8071 - acc_top50: 0.8996 - sparse_categorical_crossentropy: 2.7978 - val_loss: 3.1927 - val_sparse_categorical_accuracy: 0.4593 - val_acc_top10: 0.7685 - val_acc_top50: 0.8575 - val_sparse_categorical_crossentropy: 3.3998
#
# Epoch 00068: val_acc_top50 improved from 0.85735 to 0.85745, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 69/2000
#  - 674s - loss: 2.7908 - sparse_categorical_accuracy: 0.4822 - acc_top10: 0.8077 - acc_top50: 0.8997 - sparse_categorical_crossentropy: 2.7908 - val_loss: 3.1409 - val_sparse_categorical_accuracy: 0.4604 - val_acc_top10: 0.7680 - val_acc_top50: 0.8577 - val_sparse_categorical_crossentropy: 3.3993
#
# Epoch 00069: val_acc_top50 improved from 0.85745 to 0.85766, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 70/2000
#  - 674s - loss: 2.7809 - sparse_categorical_accuracy: 0.4838 - acc_top10: 0.8089 - acc_top50: 0.9004 - sparse_categorical_crossentropy: 2.7809 - val_loss: 3.2726 - val_sparse_categorical_accuracy: 0.4594 - val_acc_top10: 0.7682 - val_acc_top50: 0.8577 - val_sparse_categorical_crossentropy: 3.3945
#
# Epoch 00070: val_acc_top50 did not improve from 0.85766
# Epoch 71/2000
#  - 674s - loss: 2.7708 - sparse_categorical_accuracy: 0.4842 - acc_top10: 0.8093 - acc_top50: 0.9008 - sparse_categorical_crossentropy: 2.7708 - val_loss: 3.2735 - val_sparse_categorical_accuracy: 0.4613 - val_acc_top10: 0.7687 - val_acc_top50: 0.8577 - val_sparse_categorical_crossentropy: 3.4007
#
# Epoch 00071: val_acc_top50 improved from 0.85766 to 0.85771, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 72/2000
#  - 674s - loss: 2.7650 - sparse_categorical_accuracy: 0.4853 - acc_top10: 0.8105 - acc_top50: 0.9016 - sparse_categorical_crossentropy: 2.7650 - val_loss: 3.4361 - val_sparse_categorical_accuracy: 0.4612 - val_acc_top10: 0.7685 - val_acc_top50: 0.8577 - val_sparse_categorical_crossentropy: 3.4033
#
# Epoch 00072: val_acc_top50 did not improve from 0.85771
# Epoch 73/2000
#  - 674s - loss: 2.7556 - sparse_categorical_accuracy: 0.4866 - acc_top10: 0.8113 - acc_top50: 0.9019 - sparse_categorical_crossentropy: 2.7556 - val_loss: 3.3946 - val_sparse_categorical_accuracy: 0.4600 - val_acc_top10: 0.7690 - val_acc_top50: 0.8582 - val_sparse_categorical_crossentropy: 3.4005
#
# Epoch 00073: val_acc_top50 improved from 0.85771 to 0.85816, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 74/2000
#  - 674s - loss: 2.7467 - sparse_categorical_accuracy: 0.4874 - acc_top10: 0.8121 - acc_top50: 0.9030 - sparse_categorical_crossentropy: 2.7467 - val_loss: 3.3107 - val_sparse_categorical_accuracy: 0.4628 - val_acc_top10: 0.7692 - val_acc_top50: 0.8583 - val_sparse_categorical_crossentropy: 3.3961
#
# Epoch 00074: val_acc_top50 improved from 0.85816 to 0.85834, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 75/2000
#  - 674s - loss: 2.7408 - sparse_categorical_accuracy: 0.4884 - acc_top10: 0.8123 - acc_top50: 0.9026 - sparse_categorical_crossentropy: 2.7408 - val_loss: 3.3886 - val_sparse_categorical_accuracy: 0.4634 - val_acc_top10: 0.7692 - val_acc_top50: 0.8581 - val_sparse_categorical_crossentropy: 3.3995
#
# Epoch 00075: val_acc_top50 did not improve from 0.85834
# Epoch 76/2000
#  - 674s - loss: 2.7306 - sparse_categorical_accuracy: 0.4895 - acc_top10: 0.8135 - acc_top50: 0.9036 - sparse_categorical_crossentropy: 2.7306 - val_loss: 3.4693 - val_sparse_categorical_accuracy: 0.4628 - val_acc_top10: 0.7700 - val_acc_top50: 0.8580 - val_sparse_categorical_crossentropy: 3.4009
#
# Epoch 00076: val_acc_top50 did not improve from 0.85834
# Epoch 77/2000
#  - 674s - loss: 2.7238 - sparse_categorical_accuracy: 0.4901 - acc_top10: 0.8142 - acc_top50: 0.9037 - sparse_categorical_crossentropy: 2.7238 - val_loss: 3.6521 - val_sparse_categorical_accuracy: 0.4634 - val_acc_top10: 0.7688 - val_acc_top50: 0.8587 - val_sparse_categorical_crossentropy: 3.3973
#
# Epoch 00077: val_acc_top50 improved from 0.85834 to 0.85872, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 78/2000
#  - 674s - loss: 2.7152 - sparse_categorical_accuracy: 0.4912 - acc_top10: 0.8150 - acc_top50: 0.9043 - sparse_categorical_crossentropy: 2.7152 - val_loss: 3.3463 - val_sparse_categorical_accuracy: 0.4629 - val_acc_top10: 0.7703 - val_acc_top50: 0.8586 - val_sparse_categorical_crossentropy: 3.3958
#
# Epoch 00078: val_acc_top50 did not improve from 0.85872
# Epoch 79/2000
#  - 674s - loss: 2.7115 - sparse_categorical_accuracy: 0.4921 - acc_top10: 0.8151 - acc_top50: 0.9044 - sparse_categorical_crossentropy: 2.7115 - val_loss: 3.2977 - val_sparse_categorical_accuracy: 0.4625 - val_acc_top10: 0.7693 - val_acc_top50: 0.8588 - val_sparse_categorical_crossentropy: 3.4001
#
# Epoch 00079: val_acc_top50 improved from 0.85872 to 0.85879, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 80/2000
#  - 674s - loss: 2.7023 - sparse_categorical_accuracy: 0.4930 - acc_top10: 0.8163 - acc_top50: 0.9052 - sparse_categorical_crossentropy: 2.7023 - val_loss: 3.4590 - val_sparse_categorical_accuracy: 0.4619 - val_acc_top10: 0.7702 - val_acc_top50: 0.8583 - val_sparse_categorical_crossentropy: 3.3911
#
# Epoch 00080: val_acc_top50 did not improve from 0.85879
# Epoch 81/2000
#  - 674s - loss: 2.6940 - sparse_categorical_accuracy: 0.4939 - acc_top10: 0.8167 - acc_top50: 0.9055 - sparse_categorical_crossentropy: 2.6940 - val_loss: 3.1798 - val_sparse_categorical_accuracy: 0.4641 - val_acc_top10: 0.7708 - val_acc_top50: 0.8590 - val_sparse_categorical_crossentropy: 3.3958
#
# Epoch 00081: val_acc_top50 improved from 0.85879 to 0.85899, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 82/2000
#  - 674s - loss: 2.6875 - sparse_categorical_accuracy: 0.4949 - acc_top10: 0.8177 - acc_top50: 0.9060 - sparse_categorical_crossentropy: 2.6875 - val_loss: 3.5957 - val_sparse_categorical_accuracy: 0.4639 - val_acc_top10: 0.7706 - val_acc_top50: 0.8589 - val_sparse_categorical_crossentropy: 3.3879
#
# Epoch 00082: val_acc_top50 did not improve from 0.85899
# Epoch 83/2000
#  - 674s - loss: 2.6782 - sparse_categorical_accuracy: 0.4954 - acc_top10: 0.8188 - acc_top50: 0.9065 - sparse_categorical_crossentropy: 2.6782 - val_loss: 3.2060 - val_sparse_categorical_accuracy: 0.4649 - val_acc_top10: 0.7710 - val_acc_top50: 0.8597 - val_sparse_categorical_crossentropy: 3.3933
#
# Epoch 00083: val_acc_top50 improved from 0.85899 to 0.85967, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 84/2000
#  - 674s - loss: 2.6737 - sparse_categorical_accuracy: 0.4966 - acc_top10: 0.8187 - acc_top50: 0.9068 - sparse_categorical_crossentropy: 2.6737 - val_loss: 3.1923 - val_sparse_categorical_accuracy: 0.4648 - val_acc_top10: 0.7711 - val_acc_top50: 0.8594 - val_sparse_categorical_crossentropy: 3.3861
#
# Epoch 00084: val_acc_top50 did not improve from 0.85967
# Epoch 85/2000
#  - 675s - loss: 2.6673 - sparse_categorical_accuracy: 0.4968 - acc_top10: 0.8195 - acc_top50: 0.9070 - sparse_categorical_crossentropy: 2.6673 - val_loss: 3.3256 - val_sparse_categorical_accuracy: 0.4643 - val_acc_top10: 0.7707 - val_acc_top50: 0.8598 - val_sparse_categorical_crossentropy: 3.3895
#
# Epoch 00085: val_acc_top50 improved from 0.85967 to 0.85984, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 86/2000
#  - 674s - loss: 2.6587 - sparse_categorical_accuracy: 0.4984 - acc_top10: 0.8198 - acc_top50: 0.9074 - sparse_categorical_crossentropy: 2.6587 - val_loss: 3.4492 - val_sparse_categorical_accuracy: 0.4667 - val_acc_top10: 0.7709 - val_acc_top50: 0.8597 - val_sparse_categorical_crossentropy: 3.3882
#
# Epoch 00086: val_acc_top50 did not improve from 0.85984
# Epoch 87/2000
#  - 674s - loss: 2.6535 - sparse_categorical_accuracy: 0.4983 - acc_top10: 0.8202 - acc_top50: 0.9081 - sparse_categorical_crossentropy: 2.6535 - val_loss: 3.4192 - val_sparse_categorical_accuracy: 0.4659 - val_acc_top10: 0.7707 - val_acc_top50: 0.8599 - val_sparse_categorical_crossentropy: 3.3918
#
# Epoch 00087: val_acc_top50 improved from 0.85984 to 0.85987, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 88/2000
#  - 673s - loss: 2.6445 - sparse_categorical_accuracy: 0.4997 - acc_top10: 0.8215 - acc_top50: 0.9084 - sparse_categorical_crossentropy: 2.6445 - val_loss: 3.2994 - val_sparse_categorical_accuracy: 0.4660 - val_acc_top10: 0.7707 - val_acc_top50: 0.8591 - val_sparse_categorical_crossentropy: 3.4029
#
# Epoch 00088: val_acc_top50 did not improve from 0.85987
# Epoch 89/2000
#  - 674s - loss: 2.6387 - sparse_categorical_accuracy: 0.5006 - acc_top10: 0.8220 - acc_top50: 0.9089 - sparse_categorical_crossentropy: 2.6387 - val_loss: 3.1914 - val_sparse_categorical_accuracy: 0.4659 - val_acc_top10: 0.7707 - val_acc_top50: 0.8595 - val_sparse_categorical_crossentropy: 3.3983
#
# Epoch 00089: val_acc_top50 did not improve from 0.85987
# Epoch 90/2000
#  - 674s - loss: 2.6322 - sparse_categorical_accuracy: 0.5017 - acc_top10: 0.8224 - acc_top50: 0.9089 - sparse_categorical_crossentropy: 2.6322 - val_loss: 3.4840 - val_sparse_categorical_accuracy: 0.4668 - val_acc_top10: 0.7715 - val_acc_top50: 0.8598 - val_sparse_categorical_crossentropy: 3.3873
#
# Epoch 00090: val_acc_top50 did not improve from 0.85987
# Epoch 91/2000
#  - 674s - loss: 2.6257 - sparse_categorical_accuracy: 0.5021 - acc_top10: 0.8227 - acc_top50: 0.9094 - sparse_categorical_crossentropy: 2.6257 - val_loss: 3.2869 - val_sparse_categorical_accuracy: 0.4647 - val_acc_top10: 0.7712 - val_acc_top50: 0.8593 - val_sparse_categorical_crossentropy: 3.3939
#
# Epoch 00091: val_acc_top50 did not improve from 0.85987
# Epoch 92/2000
#  - 673s - loss: 2.6180 - sparse_categorical_accuracy: 0.5025 - acc_top10: 0.8236 - acc_top50: 0.9099 - sparse_categorical_crossentropy: 2.6180 - val_loss: 3.3070 - val_sparse_categorical_accuracy: 0.4657 - val_acc_top10: 0.7714 - val_acc_top50: 0.8597 - val_sparse_categorical_crossentropy: 3.3911
#
# Epoch 00092: val_acc_top50 did not improve from 0.85987
# Epoch 93/2000
#  - 674s - loss: 2.6139 - sparse_categorical_accuracy: 0.5036 - acc_top10: 0.8238 - acc_top50: 0.9104 - sparse_categorical_crossentropy: 2.6139 - val_loss: 3.4195 - val_sparse_categorical_accuracy: 0.4667 - val_acc_top10: 0.7714 - val_acc_top50: 0.8601 - val_sparse_categorical_crossentropy: 3.3919
#
# Epoch 00093: val_acc_top50 improved from 0.85987 to 0.86010, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 94/2000
#  - 673s - loss: 2.6090 - sparse_categorical_accuracy: 0.5045 - acc_top10: 0.8246 - acc_top50: 0.9103 - sparse_categorical_crossentropy: 2.6090 - val_loss: 3.4540 - val_sparse_categorical_accuracy: 0.4665 - val_acc_top10: 0.7714 - val_acc_top50: 0.8600 - val_sparse_categorical_crossentropy: 3.3904
#
# Epoch 00094: val_acc_top50 did not improve from 0.86010
# Epoch 95/2000
#  - 674s - loss: 2.6026 - sparse_categorical_accuracy: 0.5041 - acc_top10: 0.8255 - acc_top50: 0.9111 - sparse_categorical_crossentropy: 2.6026 - val_loss: 3.4159 - val_sparse_categorical_accuracy: 0.4666 - val_acc_top10: 0.7719 - val_acc_top50: 0.8600 - val_sparse_categorical_crossentropy: 3.3987
#
# Epoch 00095: val_acc_top50 did not improve from 0.86010
# Epoch 96/2000
#  - 674s - loss: 2.5979 - sparse_categorical_accuracy: 0.5050 - acc_top10: 0.8255 - acc_top50: 0.9109 - sparse_categorical_crossentropy: 2.5979 - val_loss: 3.3066 - val_sparse_categorical_accuracy: 0.4669 - val_acc_top10: 0.7720 - val_acc_top50: 0.8606 - val_sparse_categorical_crossentropy: 3.3917
#
# Epoch 00096: val_acc_top50 improved from 0.86010 to 0.86062, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 97/2000
#  - 674s - loss: 2.5892 - sparse_categorical_accuracy: 0.5064 - acc_top10: 0.8267 - acc_top50: 0.9117 - sparse_categorical_crossentropy: 2.5892 - val_loss: 3.4429 - val_sparse_categorical_accuracy: 0.4668 - val_acc_top10: 0.7724 - val_acc_top50: 0.8600 - val_sparse_categorical_crossentropy: 3.3940
#
# Epoch 00097: val_acc_top50 did not improve from 0.86062
# Epoch 98/2000
#  - 674s - loss: 2.5851 - sparse_categorical_accuracy: 0.5067 - acc_top10: 0.8264 - acc_top50: 0.9119 - sparse_categorical_crossentropy: 2.5851 - val_loss: 3.4033 - val_sparse_categorical_accuracy: 0.4667 - val_acc_top10: 0.7722 - val_acc_top50: 0.8602 - val_sparse_categorical_crossentropy: 3.3832
#
# Epoch 00098: val_acc_top50 did not improve from 0.86062
# Epoch 99/2000
#  - 674s - loss: 2.5810 - sparse_categorical_accuracy: 0.5074 - acc_top10: 0.8266 - acc_top50: 0.9118 - sparse_categorical_crossentropy: 2.5810 - val_loss: 3.4620 - val_sparse_categorical_accuracy: 0.4666 - val_acc_top10: 0.7725 - val_acc_top50: 0.8600 - val_sparse_categorical_crossentropy: 3.3945
#
# Epoch 00099: val_acc_top50 did not improve from 0.86062
# Epoch 100/2000
#  - 674s - loss: 2.5768 - sparse_categorical_accuracy: 0.5074 - acc_top10: 0.8270 - acc_top50: 0.9124 - sparse_categorical_crossentropy: 2.5768 - val_loss: 3.4558 - val_sparse_categorical_accuracy: 0.4668 - val_acc_top10: 0.7722 - val_acc_top50: 0.8604 - val_sparse_categorical_crossentropy: 3.3902
#
# Epoch 00100: val_acc_top50 did not improve from 0.86062
# Epoch 101/2000
#  - 674s - loss: 2.5692 - sparse_categorical_accuracy: 0.5083 - acc_top10: 0.8282 - acc_top50: 0.9127 - sparse_categorical_crossentropy: 2.5692 - val_loss: 3.3761 - val_sparse_categorical_accuracy: 0.4667 - val_acc_top10: 0.7718 - val_acc_top50: 0.8602 - val_sparse_categorical_crossentropy: 3.4013
#
# Epoch 00101: val_acc_top50 did not improve from 0.86062
# Epoch 102/2000
#  - 674s - loss: 2.5684 - sparse_categorical_accuracy: 0.5088 - acc_top10: 0.8281 - acc_top50: 0.9126 - sparse_categorical_crossentropy: 2.5684 - val_loss: 3.5927 - val_sparse_categorical_accuracy: 0.4673 - val_acc_top10: 0.7728 - val_acc_top50: 0.8607 - val_sparse_categorical_crossentropy: 3.3928
#
# Epoch 00102: val_acc_top50 improved from 0.86062 to 0.86067, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 103/2000
#  - 674s - loss: 2.5614 - sparse_categorical_accuracy: 0.5101 - acc_top10: 0.8288 - acc_top50: 0.9129 - sparse_categorical_crossentropy: 2.5614 - val_loss: 3.3096 - val_sparse_categorical_accuracy: 0.4670 - val_acc_top10: 0.7722 - val_acc_top50: 0.8603 - val_sparse_categorical_crossentropy: 3.3954
#
# Epoch 00103: val_acc_top50 did not improve from 0.86067
# Epoch 104/2000
#  - 674s - loss: 2.5569 - sparse_categorical_accuracy: 0.5097 - acc_top10: 0.8291 - acc_top50: 0.9135 - sparse_categorical_crossentropy: 2.5569 - val_loss: 3.6428 - val_sparse_categorical_accuracy: 0.4670 - val_acc_top10: 0.7716 - val_acc_top50: 0.8603 - val_sparse_categorical_crossentropy: 3.3980
#
# Epoch 00104: val_acc_top50 did not improve from 0.86067
# Epoch 105/2000
#  - 674s - loss: 2.5491 - sparse_categorical_accuracy: 0.5110 - acc_top10: 0.8296 - acc_top50: 0.9137 - sparse_categorical_crossentropy: 2.5491 - val_loss: 3.3244 - val_sparse_categorical_accuracy: 0.4669 - val_acc_top10: 0.7725 - val_acc_top50: 0.8609 - val_sparse_categorical_crossentropy: 3.3904
#
# Epoch 00105: val_acc_top50 improved from 0.86067 to 0.86095, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 106/2000
#  - 673s - loss: 2.5451 - sparse_categorical_accuracy: 0.5111 - acc_top10: 0.8297 - acc_top50: 0.9138 - sparse_categorical_crossentropy: 2.5451 - val_loss: 3.5497 - val_sparse_categorical_accuracy: 0.4689 - val_acc_top10: 0.7726 - val_acc_top50: 0.8610 - val_sparse_categorical_crossentropy: 3.3915
#
# Epoch 00106: val_acc_top50 improved from 0.86095 to 0.86099, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 107/2000
#  - 673s - loss: 2.5422 - sparse_categorical_accuracy: 0.5113 - acc_top10: 0.8304 - acc_top50: 0.9145 - sparse_categorical_crossentropy: 2.5422 - val_loss: 3.2063 - val_sparse_categorical_accuracy: 0.4689 - val_acc_top10: 0.7728 - val_acc_top50: 0.8609 - val_sparse_categorical_crossentropy: 3.3906
#
# Epoch 00107: val_acc_top50 did not improve from 0.86099
# Epoch 108/2000
#  - 674s - loss: 2.5370 - sparse_categorical_accuracy: 0.5127 - acc_top10: 0.8306 - acc_top50: 0.9143 - sparse_categorical_crossentropy: 2.5370 - val_loss: 3.4441 - val_sparse_categorical_accuracy: 0.4688 - val_acc_top10: 0.7730 - val_acc_top50: 0.8606 - val_sparse_categorical_crossentropy: 3.3907
#
# Epoch 00108: val_acc_top50 did not improve from 0.86099
# Epoch 109/2000
#  - 673s - loss: 2.5292 - sparse_categorical_accuracy: 0.5136 - acc_top10: 0.8313 - acc_top50: 0.9150 - sparse_categorical_crossentropy: 2.5292 - val_loss: 3.6121 - val_sparse_categorical_accuracy: 0.4676 - val_acc_top10: 0.7726 - val_acc_top50: 0.8604 - val_sparse_categorical_crossentropy: 3.4004
#
# Epoch 00109: val_acc_top50 did not improve from 0.86099
# Epoch 110/2000
#  - 673s - loss: 2.5251 - sparse_categorical_accuracy: 0.5134 - acc_top10: 0.8318 - acc_top50: 0.9152 - sparse_categorical_crossentropy: 2.5251 - val_loss: 3.4391 - val_sparse_categorical_accuracy: 0.4675 - val_acc_top10: 0.7723 - val_acc_top50: 0.8607 - val_sparse_categorical_crossentropy: 3.4007
#
# Epoch 00110: val_acc_top50 did not improve from 0.86099
# Epoch 111/2000
#  - 673s - loss: 2.5230 - sparse_categorical_accuracy: 0.5140 - acc_top10: 0.8315 - acc_top50: 0.9153 - sparse_categorical_crossentropy: 2.5230 - val_loss: 3.3286 - val_sparse_categorical_accuracy: 0.4680 - val_acc_top10: 0.7735 - val_acc_top50: 0.8614 - val_sparse_categorical_crossentropy: 3.3879
#
# Epoch 00111: val_acc_top50 improved from 0.86099 to 0.86137, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 112/2000
#  - 673s - loss: 2.5180 - sparse_categorical_accuracy: 0.5151 - acc_top10: 0.8325 - acc_top50: 0.9155 - sparse_categorical_crossentropy: 2.5180 - val_loss: 3.3872 - val_sparse_categorical_accuracy: 0.4685 - val_acc_top10: 0.7730 - val_acc_top50: 0.8605 - val_sparse_categorical_crossentropy: 3.3975
#
# Epoch 00112: val_acc_top50 did not improve from 0.86137
# Epoch 113/2000
#  - 674s - loss: 2.5123 - sparse_categorical_accuracy: 0.5154 - acc_top10: 0.8328 - acc_top50: 0.9160 - sparse_categorical_crossentropy: 2.5123 - val_loss: 3.2895 - val_sparse_categorical_accuracy: 0.4681 - val_acc_top10: 0.7726 - val_acc_top50: 0.8607 - val_sparse_categorical_crossentropy: 3.3905
#
# Epoch 00113: val_acc_top50 did not improve from 0.86137
# Epoch 114/2000
#  - 674s - loss: 2.5099 - sparse_categorical_accuracy: 0.5158 - acc_top10: 0.8331 - acc_top50: 0.9160 - sparse_categorical_crossentropy: 2.5099 - val_loss: 3.3710 - val_sparse_categorical_accuracy: 0.4681 - val_acc_top10: 0.7734 - val_acc_top50: 0.8610 - val_sparse_categorical_crossentropy: 3.3985
#
# Epoch 00114: val_acc_top50 did not improve from 0.86137
# Epoch 115/2000
#  - 674s - loss: 2.5048 - sparse_categorical_accuracy: 0.5165 - acc_top10: 0.8335 - acc_top50: 0.9163 - sparse_categorical_crossentropy: 2.5048 - val_loss: 3.3584 - val_sparse_categorical_accuracy: 0.4681 - val_acc_top10: 0.7727 - val_acc_top50: 0.8612 - val_sparse_categorical_crossentropy: 3.3945
#
# Epoch 00115: val_acc_top50 did not improve from 0.86137
# Epoch 116/2000
#  - 674s - loss: 2.5024 - sparse_categorical_accuracy: 0.5165 - acc_top10: 0.8338 - acc_top50: 0.9166 - sparse_categorical_crossentropy: 2.5024 - val_loss: 3.2306 - val_sparse_categorical_accuracy: 0.4670 - val_acc_top10: 0.7727 - val_acc_top50: 0.8604 - val_sparse_categorical_crossentropy: 3.4038
#
# Epoch 00116: val_acc_top50 did not improve from 0.86137
# Epoch 117/2000
#  - 674s - loss: 2.4980 - sparse_categorical_accuracy: 0.5168 - acc_top10: 0.8343 - acc_top50: 0.9168 - sparse_categorical_crossentropy: 2.4980 - val_loss: 3.3929 - val_sparse_categorical_accuracy: 0.4675 - val_acc_top10: 0.7723 - val_acc_top50: 0.8606 - val_sparse_categorical_crossentropy: 3.4070
#
# Epoch 00117: val_acc_top50 did not improve from 0.86137
# Epoch 00117: early stopping

# %%
#test for all rules:176756
from expansion_policy_fn import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=3, 
                    use_multiprocessing=True, 
                    max_queue_size = 7, 
#                    shuffle=False,
                    callbacks=[earlystop, checkpoint]
                    )
# Out:
# RDKit WARNING: [13:47:13] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 3143138it [00:08, 389609.72it/s]
# expansion: 176756it [00:00, 649125.69it/s]
# expansion training...
# data prep: 100%|██████████| 1093208/1093208 [00:01<00:00, 1086328.42it/s]
# total reactions: 100%|██████████| 1093208/1093208 [00:00<00:00, 2775023.76it/s]
# total products: 1093208
# total reactions: 1157488
# Training size: 1157488
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 16384)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               8389120
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_1 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_2 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_3 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_4 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_5 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 176756)            90675828
# =================================================================
# Total params: 101,691,508
# Trainable params: 101,691,508
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/2000
#  - 2126s - loss: 8.0260 - sparse_categorical_accuracy: 0.0606 - acc_top10: 0.2267 - acc_top50: 0.4004 - sparse_categorical_crossentropy: 8.0260 - val_loss: 7.5223 - val_sparse_categorical_accuracy: 0.1315 - val_acc_top10: 0.3420 - val_acc_top50: 0.4828 - val_sparse_categorical_crossentropy: 7.2862
#
# Epoch 00001: val_acc_top50 improved from -inf to 0.48277, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 2/2000
#  - 2071s - loss: 7.0089 - sparse_categorical_accuracy: 0.1509 - acc_top10: 0.3836 - acc_top50: 0.5170 - sparse_categorical_crossentropy: 7.0089 - val_loss: 6.7076 - val_sparse_categorical_accuracy: 0.1896 - val_acc_top10: 0.4387 - val_acc_top50: 0.5626 - val_sparse_categorical_crossentropy: 6.6616
#
# Epoch 00002: val_acc_top50 improved from 0.48277 to 0.56262, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 3/2000
#  - 2069s - loss: 6.5067 - sparse_categorical_accuracy: 0.1927 - acc_top10: 0.4506 - acc_top50: 0.5761 - sparse_categorical_crossentropy: 6.5067 - val_loss: 6.4954 - val_sparse_categorical_accuracy: 0.2216 - val_acc_top10: 0.4905 - val_acc_top50: 0.6079 - val_sparse_categorical_crossentropy: 6.2886
#
# Epoch 00003: val_acc_top50 improved from 0.56262 to 0.60795, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 4/2000
#  - 2063s - loss: 6.2080 - sparse_categorical_accuracy: 0.2157 - acc_top10: 0.4861 - acc_top50: 0.6082 - sparse_categorical_crossentropy: 6.2080 - val_loss: 5.7556 - val_sparse_categorical_accuracy: 0.2413 - val_acc_top10: 0.5186 - val_acc_top50: 0.6330 - val_sparse_categorical_crossentropy: 6.0641
#
# Epoch 00004: val_acc_top50 improved from 0.60795 to 0.63304, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 5/2000
#  - 2062s - loss: 6.0115 - sparse_categorical_accuracy: 0.2311 - acc_top10: 0.5077 - acc_top50: 0.6285 - sparse_categorical_crossentropy: 6.0115 - val_loss: 5.6144 - val_sparse_categorical_accuracy: 0.2553 - val_acc_top10: 0.5379 - val_acc_top50: 0.6507 - val_sparse_categorical_crossentropy: 5.9064
#
# Epoch 00005: val_acc_top50 improved from 0.63304 to 0.65068, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 6/2000
#  - 2059s - loss: 5.8617 - sparse_categorical_accuracy: 0.2434 - acc_top10: 0.5241 - acc_top50: 0.6432 - sparse_categorical_crossentropy: 5.8618 - val_loss: 5.3790 - val_sparse_categorical_accuracy: 0.2681 - val_acc_top10: 0.5535 - val_acc_top50: 0.6643 - val_sparse_categorical_crossentropy: 5.7822
#
# Epoch 00006: val_acc_top50 improved from 0.65068 to 0.66430, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 7/2000
#  - 2061s - loss: 5.7355 - sparse_categorical_accuracy: 0.2543 - acc_top10: 0.5376 - acc_top50: 0.6557 - sparse_categorical_crossentropy: 5.7355 - val_loss: 5.1091 - val_sparse_categorical_accuracy: 0.2801 - val_acc_top10: 0.5667 - val_acc_top50: 0.6765 - val_sparse_categorical_crossentropy: 5.6760
#
# Epoch 00007: val_acc_top50 improved from 0.66430 to 0.67653, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 8/2000
#  - 2059s - loss: 5.6295 - sparse_categorical_accuracy: 0.2633 - acc_top10: 0.5490 - acc_top50: 0.6667 - sparse_categorical_crossentropy: 5.6295 - val_loss: 5.3674 - val_sparse_categorical_accuracy: 0.2876 - val_acc_top10: 0.5777 - val_acc_top50: 0.6864 - val_sparse_categorical_crossentropy: 5.5901
#
# Epoch 00008: val_acc_top50 improved from 0.67653 to 0.68638, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 9/2000
#  - 2058s - loss: 5.5390 - sparse_categorical_accuracy: 0.2713 - acc_top10: 0.5597 - acc_top50: 0.6754 - sparse_categorical_crossentropy: 5.5390 - val_loss: 5.4089 - val_sparse_categorical_accuracy: 0.2973 - val_acc_top10: 0.5881 - val_acc_top50: 0.6945 - val_sparse_categorical_crossentropy: 5.5139
#
# Epoch 00009: val_acc_top50 improved from 0.68638 to 0.69447, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 10/2000
#  - 2057s - loss: 5.4600 - sparse_categorical_accuracy: 0.2785 - acc_top10: 0.5680 - acc_top50: 0.6838 - sparse_categorical_crossentropy: 5.4600 - val_loss: 5.6269 - val_sparse_categorical_accuracy: 0.3036 - val_acc_top10: 0.5955 - val_acc_top50: 0.7010 - val_sparse_categorical_crossentropy: 5.4504
#
# Epoch 00010: val_acc_top50 improved from 0.69447 to 0.70103, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 11/2000
#  - 2055s - loss: 5.3908 - sparse_categorical_accuracy: 0.2844 - acc_top10: 0.5756 - acc_top50: 0.6906 - sparse_categorical_crossentropy: 5.3908 - val_loss: 5.4892 - val_sparse_categorical_accuracy: 0.3110 - val_acc_top10: 0.6028 - val_acc_top50: 0.7068 - val_sparse_categorical_crossentropy: 5.3941
#
# Epoch 00011: val_acc_top50 improved from 0.70103 to 0.70679, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 12/2000
#  - 2058s - loss: 5.3282 - sparse_categorical_accuracy: 0.2900 - acc_top10: 0.5823 - acc_top50: 0.6971 - sparse_categorical_crossentropy: 5.3282 - val_loss: 5.4780 - val_sparse_categorical_accuracy: 0.3159 - val_acc_top10: 0.6081 - val_acc_top50: 0.7120 - val_sparse_categorical_crossentropy: 5.3423
#
# Epoch 00012: val_acc_top50 improved from 0.70679 to 0.71197, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 13/2000
#  - 2055s - loss: 5.2713 - sparse_categorical_accuracy: 0.2957 - acc_top10: 0.5888 - acc_top50: 0.7024 - sparse_categorical_crossentropy: 5.2713 - val_loss: 5.6970 - val_sparse_categorical_accuracy: 0.3216 - val_acc_top10: 0.6133 - val_acc_top50: 0.7155 - val_sparse_categorical_crossentropy: 5.3020
#
# Epoch 00013: val_acc_top50 improved from 0.71197 to 0.71554, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 14/2000
#  - 2055s - loss: 5.2187 - sparse_categorical_accuracy: 0.3009 - acc_top10: 0.5945 - acc_top50: 0.7074 - sparse_categorical_crossentropy: 5.2187 - val_loss: 5.5626 - val_sparse_categorical_accuracy: 0.3270 - val_acc_top10: 0.6192 - val_acc_top50: 0.7195 - val_sparse_categorical_crossentropy: 5.2581
#
# Epoch 00014: val_acc_top50 improved from 0.71554 to 0.71949, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 15/2000
#  - 2055s - loss: 5.1716 - sparse_categorical_accuracy: 0.3054 - acc_top10: 0.5994 - acc_top50: 0.7120 - sparse_categorical_crossentropy: 5.1716 - val_loss: 5.6967 - val_sparse_categorical_accuracy: 0.3293 - val_acc_top10: 0.6234 - val_acc_top50: 0.7223 - val_sparse_categorical_crossentropy: 5.2322
#
# Epoch 00015: val_acc_top50 improved from 0.71949 to 0.72225, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 16/2000
#  - 2056s - loss: 5.1286 - sparse_categorical_accuracy: 0.3100 - acc_top10: 0.6045 - acc_top50: 0.7158 - sparse_categorical_crossentropy: 5.1286 - val_loss: 4.7527 - val_sparse_categorical_accuracy: 0.3348 - val_acc_top10: 0.6281 - val_acc_top50: 0.7263 - val_sparse_categorical_crossentropy: 5.1918
#
# Epoch 00016: val_acc_top50 improved from 0.72225 to 0.72626, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 17/2000
#  - 2056s - loss: 5.0864 - sparse_categorical_accuracy: 0.3139 - acc_top10: 0.6092 - acc_top50: 0.7198 - sparse_categorical_crossentropy: 5.0864 - val_loss: 5.3370 - val_sparse_categorical_accuracy: 0.3396 - val_acc_top10: 0.6307 - val_acc_top50: 0.7284 - val_sparse_categorical_crossentropy: 5.1652
#
# Epoch 00017: val_acc_top50 improved from 0.72626 to 0.72837, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 18/2000
#  - 2054s - loss: 5.0491 - sparse_categorical_accuracy: 0.3171 - acc_top10: 0.6134 - acc_top50: 0.7232 - sparse_categorical_crossentropy: 5.0491 - val_loss: 4.6687 - val_sparse_categorical_accuracy: 0.3417 - val_acc_top10: 0.6342 - val_acc_top50: 0.7311 - val_sparse_categorical_crossentropy: 5.1402
#
# Epoch 00018: val_acc_top50 improved from 0.72837 to 0.73113, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 19/2000
#  - 2054s - loss: 5.0103 - sparse_categorical_accuracy: 0.3215 - acc_top10: 0.6171 - acc_top50: 0.7264 - sparse_categorical_crossentropy: 5.0103 - val_loss: 5.2415 - val_sparse_categorical_accuracy: 0.3444 - val_acc_top10: 0.6377 - val_acc_top50: 0.7336 - val_sparse_categorical_crossentropy: 5.1112
#
# Epoch 00019: val_acc_top50 improved from 0.73113 to 0.73361, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 20/2000
#  - 2056s - loss: 4.9757 - sparse_categorical_accuracy: 0.3245 - acc_top10: 0.6211 - acc_top50: 0.7297 - sparse_categorical_crossentropy: 4.9757 - val_loss: 5.1187 - val_sparse_categorical_accuracy: 0.3483 - val_acc_top10: 0.6409 - val_acc_top50: 0.7352 - val_sparse_categorical_crossentropy: 5.0917
#
# Epoch 00020: val_acc_top50 improved from 0.73361 to 0.73516, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 21/2000
#  - 2054s - loss: 4.9425 - sparse_categorical_accuracy: 0.3284 - acc_top10: 0.6248 - acc_top50: 0.7327 - sparse_categorical_crossentropy: 4.9425 - val_loss: 4.9663 - val_sparse_categorical_accuracy: 0.3517 - val_acc_top10: 0.6437 - val_acc_top50: 0.7378 - val_sparse_categorical_crossentropy: 5.0701
#
# Epoch 00021: val_acc_top50 improved from 0.73516 to 0.73777, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 22/2000
#  - 2054s - loss: 4.9100 - sparse_categorical_accuracy: 0.3312 - acc_top10: 0.6281 - acc_top50: 0.7356 - sparse_categorical_crossentropy: 4.9100 - val_loss: 5.0101 - val_sparse_categorical_accuracy: 0.3540 - val_acc_top10: 0.6459 - val_acc_top50: 0.7397 - val_sparse_categorical_crossentropy: 5.0468
#
# Epoch 00022: val_acc_top50 improved from 0.73777 to 0.73972, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 23/2000
#  - 2053s - loss: 4.8811 - sparse_categorical_accuracy: 0.3345 - acc_top10: 0.6315 - acc_top50: 0.7382 - sparse_categorical_crossentropy: 4.8811 - val_loss: 5.3081 - val_sparse_categorical_accuracy: 0.3570 - val_acc_top10: 0.6487 - val_acc_top50: 0.7409 - val_sparse_categorical_crossentropy: 5.0264
#
# Epoch 00023: val_acc_top50 improved from 0.73972 to 0.74087, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 24/2000
#  - 2057s - loss: 4.8530 - sparse_categorical_accuracy: 0.3374 - acc_top10: 0.6342 - acc_top50: 0.7406 - sparse_categorical_crossentropy: 4.8530 - val_loss: 5.0606 - val_sparse_categorical_accuracy: 0.3583 - val_acc_top10: 0.6501 - val_acc_top50: 0.7421 - val_sparse_categorical_crossentropy: 5.0173
#
# Epoch 00024: val_acc_top50 improved from 0.74087 to 0.74214, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 25/2000
#  - 2054s - loss: 4.8245 - sparse_categorical_accuracy: 0.3399 - acc_top10: 0.6380 - acc_top50: 0.7431 - sparse_categorical_crossentropy: 4.8245 - val_loss: 4.9077 - val_sparse_categorical_accuracy: 0.3610 - val_acc_top10: 0.6530 - val_acc_top50: 0.7436 - val_sparse_categorical_crossentropy: 4.9978
#
# Epoch 00025: val_acc_top50 improved from 0.74214 to 0.74359, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 26/2000
#  - 2054s - loss: 4.7988 - sparse_categorical_accuracy: 0.3426 - acc_top10: 0.6402 - acc_top50: 0.7451 - sparse_categorical_crossentropy: 4.7988 - val_loss: 5.0520 - val_sparse_categorical_accuracy: 0.3641 - val_acc_top10: 0.6556 - val_acc_top50: 0.7451 - val_sparse_categorical_crossentropy: 4.9852
#
# Epoch 00026: val_acc_top50 improved from 0.74359 to 0.74506, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 27/2000
#  - 2053s - loss: 4.7718 - sparse_categorical_accuracy: 0.3448 - acc_top10: 0.6430 - acc_top50: 0.7476 - sparse_categorical_crossentropy: 4.7718 - val_loss: 4.9342 - val_sparse_categorical_accuracy: 0.3653 - val_acc_top10: 0.6560 - val_acc_top50: 0.7459 - val_sparse_categorical_crossentropy: 4.9693
#
# Epoch 00027: val_acc_top50 improved from 0.74506 to 0.74595, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 28/2000
#  - 2054s - loss: 4.7478 - sparse_categorical_accuracy: 0.3473 - acc_top10: 0.6456 - acc_top50: 0.7491 - sparse_categorical_crossentropy: 4.7478 - val_loss: 5.0892 - val_sparse_categorical_accuracy: 0.3668 - val_acc_top10: 0.6578 - val_acc_top50: 0.7473 - val_sparse_categorical_crossentropy: 4.9595
#
# Epoch 00028: val_acc_top50 improved from 0.74595 to 0.74728, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 29/2000
#  - 2054s - loss: 4.7214 - sparse_categorical_accuracy: 0.3502 - acc_top10: 0.6484 - acc_top50: 0.7518 - sparse_categorical_crossentropy: 4.7214 - val_loss: 5.0145 - val_sparse_categorical_accuracy: 0.3679 - val_acc_top10: 0.6593 - val_acc_top50: 0.7483 - val_sparse_categorical_crossentropy: 4.9487
#
# Epoch 00029: val_acc_top50 improved from 0.74728 to 0.74827, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 30/2000
#  - 2053s - loss: 4.6963 - sparse_categorical_accuracy: 0.3521 - acc_top10: 0.6507 - acc_top50: 0.7541 - sparse_categorical_crossentropy: 4.6963 - val_loss: 5.1023 - val_sparse_categorical_accuracy: 0.3701 - val_acc_top10: 0.6611 - val_acc_top50: 0.7493 - val_sparse_categorical_crossentropy: 4.9377
#
# Epoch 00030: val_acc_top50 improved from 0.74827 to 0.74927, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 31/2000
#  - 2052s - loss: 4.6739 - sparse_categorical_accuracy: 0.3552 - acc_top10: 0.6530 - acc_top50: 0.7558 - sparse_categorical_crossentropy: 4.6739 - val_loss: 5.2659 - val_sparse_categorical_accuracy: 0.3713 - val_acc_top10: 0.6619 - val_acc_top50: 0.7498 - val_sparse_categorical_crossentropy: 4.9322
#
# Epoch 00031: val_acc_top50 improved from 0.74927 to 0.74983, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 32/2000
#  - 2054s - loss: 4.6542 - sparse_categorical_accuracy: 0.3565 - acc_top10: 0.6553 - acc_top50: 0.7571 - sparse_categorical_crossentropy: 4.6542 - val_loss: 5.3159 - val_sparse_categorical_accuracy: 0.3738 - val_acc_top10: 0.6634 - val_acc_top50: 0.7509 - val_sparse_categorical_crossentropy: 4.9203
#
# Epoch 00032: val_acc_top50 improved from 0.74983 to 0.75086, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 33/2000
#  - 2052s - loss: 4.6341 - sparse_categorical_accuracy: 0.3590 - acc_top10: 0.6569 - acc_top50: 0.7587 - sparse_categorical_crossentropy: 4.6341 - val_loss: 4.9428 - val_sparse_categorical_accuracy: 0.3758 - val_acc_top10: 0.6647 - val_acc_top50: 0.7517 - val_sparse_categorical_crossentropy: 4.9104
#
# Epoch 00033: val_acc_top50 improved from 0.75086 to 0.75169, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 34/2000
#  - 2052s - loss: 4.6117 - sparse_categorical_accuracy: 0.3610 - acc_top10: 0.6593 - acc_top50: 0.7607 - sparse_categorical_crossentropy: 4.6117 - val_loss: 4.9104 - val_sparse_categorical_accuracy: 0.3764 - val_acc_top10: 0.6662 - val_acc_top50: 0.7525 - val_sparse_categorical_crossentropy: 4.9017
#
# Epoch 00034: val_acc_top50 improved from 0.75169 to 0.75253, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 35/2000
#  - 2052s - loss: 4.5945 - sparse_categorical_accuracy: 0.3625 - acc_top10: 0.6611 - acc_top50: 0.7623 - sparse_categorical_crossentropy: 4.5945 - val_loss: 5.1391 - val_sparse_categorical_accuracy: 0.3772 - val_acc_top10: 0.6673 - val_acc_top50: 0.7529 - val_sparse_categorical_crossentropy: 4.8923
#
# Epoch 00035: val_acc_top50 improved from 0.75253 to 0.75288, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 36/2000
#  - 2054s - loss: 4.5758 - sparse_categorical_accuracy: 0.3641 - acc_top10: 0.6631 - acc_top50: 0.7637 - sparse_categorical_crossentropy: 4.5759 - val_loss: 4.9921 - val_sparse_categorical_accuracy: 0.3797 - val_acc_top10: 0.6684 - val_acc_top50: 0.7535 - val_sparse_categorical_crossentropy: 4.8857
#
# Epoch 00036: val_acc_top50 improved from 0.75288 to 0.75347, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 37/2000
#  - 2053s - loss: 4.5540 - sparse_categorical_accuracy: 0.3666 - acc_top10: 0.6650 - acc_top50: 0.7654 - sparse_categorical_crossentropy: 4.5539 - val_loss: 4.7949 - val_sparse_categorical_accuracy: 0.3810 - val_acc_top10: 0.6687 - val_acc_top50: 0.7538 - val_sparse_categorical_crossentropy: 4.8823
#
# Epoch 00037: val_acc_top50 improved from 0.75347 to 0.75385, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 38/2000
#  - 2052s - loss: 4.5336 - sparse_categorical_accuracy: 0.3686 - acc_top10: 0.6670 - acc_top50: 0.7668 - sparse_categorical_crossentropy: 4.5336 - val_loss: 5.1786 - val_sparse_categorical_accuracy: 0.3819 - val_acc_top10: 0.6699 - val_acc_top50: 0.7546 - val_sparse_categorical_crossentropy: 4.8732
#
# Epoch 00038: val_acc_top50 improved from 0.75385 to 0.75457, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 39/2000
#  - 2051s - loss: 4.5166 - sparse_categorical_accuracy: 0.3697 - acc_top10: 0.6680 - acc_top50: 0.7683 - sparse_categorical_crossentropy: 4.5166 - val_loss: 4.7346 - val_sparse_categorical_accuracy: 0.3825 - val_acc_top10: 0.6705 - val_acc_top50: 0.7555 - val_sparse_categorical_crossentropy: 4.8686
#
# Epoch 00039: val_acc_top50 improved from 0.75457 to 0.75550, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 40/2000
#  - 2053s - loss: 4.4945 - sparse_categorical_accuracy: 0.3715 - acc_top10: 0.6700 - acc_top50: 0.7697 - sparse_categorical_crossentropy: 4.4945 - val_loss: 5.5893 - val_sparse_categorical_accuracy: 0.3832 - val_acc_top10: 0.6713 - val_acc_top50: 0.7556 - val_sparse_categorical_crossentropy: 4.8636
#
# Epoch 00040: val_acc_top50 improved from 0.75550 to 0.75557, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 41/2000
#  - 2052s - loss: 4.4776 - sparse_categorical_accuracy: 0.3733 - acc_top10: 0.6721 - acc_top50: 0.7711 - sparse_categorical_crossentropy: 4.4776 - val_loss: 5.5378 - val_sparse_categorical_accuracy: 0.3840 - val_acc_top10: 0.6719 - val_acc_top50: 0.7563 - val_sparse_categorical_crossentropy: 4.8606
#
# Epoch 00041: val_acc_top50 improved from 0.75557 to 0.75630, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 42/2000
#  - 2051s - loss: 4.4599 - sparse_categorical_accuracy: 0.3743 - acc_top10: 0.6734 - acc_top50: 0.7722 - sparse_categorical_crossentropy: 4.4599 - val_loss: 4.8340 - val_sparse_categorical_accuracy: 0.3845 - val_acc_top10: 0.6729 - val_acc_top50: 0.7565 - val_sparse_categorical_crossentropy: 4.8547
#
# Epoch 00042: val_acc_top50 improved from 0.75630 to 0.75646, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 43/2000
#  - 2050s - loss: 4.4422 - sparse_categorical_accuracy: 0.3762 - acc_top10: 0.6749 - acc_top50: 0.7733 - sparse_categorical_crossentropy: 4.4422 - val_loss: 4.8835 - val_sparse_categorical_accuracy: 0.3865 - val_acc_top10: 0.6733 - val_acc_top50: 0.7572 - val_sparse_categorical_crossentropy: 4.8446
#
# Epoch 00043: val_acc_top50 improved from 0.75646 to 0.75716, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 44/2000
#  - 2053s - loss: 4.4263 - sparse_categorical_accuracy: 0.3777 - acc_top10: 0.6765 - acc_top50: 0.7743 - sparse_categorical_crossentropy: 4.4263 - val_loss: 4.2872 - val_sparse_categorical_accuracy: 0.3876 - val_acc_top10: 0.6741 - val_acc_top50: 0.7578 - val_sparse_categorical_crossentropy: 4.8440
#
# Epoch 00044: val_acc_top50 improved from 0.75716 to 0.75776, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 45/2000
#  - 2052s - loss: 4.4101 - sparse_categorical_accuracy: 0.3791 - acc_top10: 0.6779 - acc_top50: 0.7753 - sparse_categorical_crossentropy: 4.4101 - val_loss: 5.1314 - val_sparse_categorical_accuracy: 0.3873 - val_acc_top10: 0.6753 - val_acc_top50: 0.7580 - val_sparse_categorical_crossentropy: 4.8421
#
# Epoch 00045: val_acc_top50 improved from 0.75776 to 0.75797, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 46/2000
#  - 2052s - loss: 4.3924 - sparse_categorical_accuracy: 0.3806 - acc_top10: 0.6793 - acc_top50: 0.7767 - sparse_categorical_crossentropy: 4.3925 - val_loss: 5.2594 - val_sparse_categorical_accuracy: 0.3889 - val_acc_top10: 0.6749 - val_acc_top50: 0.7585 - val_sparse_categorical_crossentropy: 4.8356
#
# Epoch 00046: val_acc_top50 improved from 0.75797 to 0.75846, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 47/2000
#  - 2052s - loss: 4.3790 - sparse_categorical_accuracy: 0.3816 - acc_top10: 0.6805 - acc_top50: 0.7774 - sparse_categorical_crossentropy: 4.3790 - val_loss: 5.4894 - val_sparse_categorical_accuracy: 0.3889 - val_acc_top10: 0.6760 - val_acc_top50: 0.7588 - val_sparse_categorical_crossentropy: 4.8441
#
# Epoch 00047: val_acc_top50 improved from 0.75846 to 0.75875, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 48/2000
#  - 2053s - loss: 4.3638 - sparse_categorical_accuracy: 0.3829 - acc_top10: 0.6819 - acc_top50: 0.7787 - sparse_categorical_crossentropy: 4.3638 - val_loss: 4.7194 - val_sparse_categorical_accuracy: 0.3905 - val_acc_top10: 0.6766 - val_acc_top50: 0.7597 - val_sparse_categorical_crossentropy: 4.8307
#
# Epoch 00048: val_acc_top50 improved from 0.75875 to 0.75965, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 49/2000
#  - 2051s - loss: 4.3497 - sparse_categorical_accuracy: 0.3841 - acc_top10: 0.6829 - acc_top50: 0.7795 - sparse_categorical_crossentropy: 4.3497 - val_loss: 4.9171 - val_sparse_categorical_accuracy: 0.3906 - val_acc_top10: 0.6765 - val_acc_top50: 0.7592 - val_sparse_categorical_crossentropy: 4.8322
#
# Epoch 00049: val_acc_top50 did not improve from 0.75965
# Epoch 50/2000
#  - 2050s - loss: 4.3332 - sparse_categorical_accuracy: 0.3849 - acc_top10: 0.6839 - acc_top50: 0.7803 - sparse_categorical_crossentropy: 4.3333 - val_loss: 5.0771 - val_sparse_categorical_accuracy: 0.3913 - val_acc_top10: 0.6776 - val_acc_top50: 0.7599 - val_sparse_categorical_crossentropy: 4.8242
#
# Epoch 00050: val_acc_top50 improved from 0.75965 to 0.75990, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 51/2000
#  - 2050s - loss: 4.3202 - sparse_categorical_accuracy: 0.3864 - acc_top10: 0.6853 - acc_top50: 0.7809 - sparse_categorical_crossentropy: 4.3202 - val_loss: 4.7612 - val_sparse_categorical_accuracy: 0.3923 - val_acc_top10: 0.6780 - val_acc_top50: 0.7601 - val_sparse_categorical_crossentropy: 4.8229
#
# Epoch 00051: val_acc_top50 improved from 0.75990 to 0.76015, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 52/2000
#  - 2051s - loss: 4.3057 - sparse_categorical_accuracy: 0.3876 - acc_top10: 0.6863 - acc_top50: 0.7818 - sparse_categorical_crossentropy: 4.3057 - val_loss: 4.3447 - val_sparse_categorical_accuracy: 0.3914 - val_acc_top10: 0.6786 - val_acc_top50: 0.7604 - val_sparse_categorical_crossentropy: 4.8272
#
# Epoch 00052: val_acc_top50 improved from 0.76015 to 0.76040, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 53/2000
#  - 2049s - loss: 4.2907 - sparse_categorical_accuracy: 0.3884 - acc_top10: 0.6871 - acc_top50: 0.7825 - sparse_categorical_crossentropy: 4.2907 - val_loss: 5.1265 - val_sparse_categorical_accuracy: 0.3929 - val_acc_top10: 0.6794 - val_acc_top50: 0.7609 - val_sparse_categorical_crossentropy: 4.8162
#
# Epoch 00053: val_acc_top50 improved from 0.76040 to 0.76088, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 54/2000
#  - 2049s - loss: 4.2771 - sparse_categorical_accuracy: 0.3896 - acc_top10: 0.6882 - acc_top50: 0.7833 - sparse_categorical_crossentropy: 4.2771 - val_loss: 5.3148 - val_sparse_categorical_accuracy: 0.3930 - val_acc_top10: 0.6801 - val_acc_top50: 0.7610 - val_sparse_categorical_crossentropy: 4.8082
#
# Epoch 00054: val_acc_top50 improved from 0.76088 to 0.76102, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 55/2000
#  - 2048s - loss: 4.2627 - sparse_categorical_accuracy: 0.3911 - acc_top10: 0.6889 - acc_top50: 0.7841 - sparse_categorical_crossentropy: 4.2627 - val_loss: 4.3673 - val_sparse_categorical_accuracy: 0.3930 - val_acc_top10: 0.6795 - val_acc_top50: 0.7613 - val_sparse_categorical_crossentropy: 4.8119
#
# Epoch 00055: val_acc_top50 improved from 0.76102 to 0.76125, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 56/2000
#  - 2051s - loss: 4.2486 - sparse_categorical_accuracy: 0.3917 - acc_top10: 0.6902 - acc_top50: 0.7847 - sparse_categorical_crossentropy: 4.2486 - val_loss: 4.9355 - val_sparse_categorical_accuracy: 0.3945 - val_acc_top10: 0.6799 - val_acc_top50: 0.7613 - val_sparse_categorical_crossentropy: 4.8048
#
# Epoch 00056: val_acc_top50 improved from 0.76125 to 0.76129, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 57/2000
#  - 2049s - loss: 4.2357 - sparse_categorical_accuracy: 0.3928 - acc_top10: 0.6910 - acc_top50: 0.7852 - sparse_categorical_crossentropy: 4.2357 - val_loss: 5.1397 - val_sparse_categorical_accuracy: 0.3948 - val_acc_top10: 0.6808 - val_acc_top50: 0.7620 - val_sparse_categorical_crossentropy: 4.8045
#
# Epoch 00057: val_acc_top50 improved from 0.76129 to 0.76201, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 58/2000
#  - 2048s - loss: 4.2214 - sparse_categorical_accuracy: 0.3939 - acc_top10: 0.6919 - acc_top50: 0.7859 - sparse_categorical_crossentropy: 4.2214 - val_loss: 4.2756 - val_sparse_categorical_accuracy: 0.3933 - val_acc_top10: 0.6799 - val_acc_top50: 0.7620 - val_sparse_categorical_crossentropy: 4.8042
#
# Epoch 00058: val_acc_top50 did not improve from 0.76201
# Epoch 59/2000
#  - 2047s - loss: 4.2054 - sparse_categorical_accuracy: 0.3949 - acc_top10: 0.6928 - acc_top50: 0.7870 - sparse_categorical_crossentropy: 4.2054 - val_loss: 4.3815 - val_sparse_categorical_accuracy: 0.3954 - val_acc_top10: 0.6810 - val_acc_top50: 0.7624 - val_sparse_categorical_crossentropy: 4.8037
#
# Epoch 00059: val_acc_top50 improved from 0.76201 to 0.76243, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 60/2000
#  - 2050s - loss: 4.1963 - sparse_categorical_accuracy: 0.3960 - acc_top10: 0.6935 - acc_top50: 0.7872 - sparse_categorical_crossentropy: 4.1963 - val_loss: 4.1686 - val_sparse_categorical_accuracy: 0.3953 - val_acc_top10: 0.6812 - val_acc_top50: 0.7625 - val_sparse_categorical_crossentropy: 4.7958
#
# Epoch 00060: val_acc_top50 improved from 0.76243 to 0.76251, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 61/2000
#  - 2048s - loss: 4.1839 - sparse_categorical_accuracy: 0.3962 - acc_top10: 0.6942 - acc_top50: 0.7879 - sparse_categorical_crossentropy: 4.1839 - val_loss: 4.4158 - val_sparse_categorical_accuracy: 0.3960 - val_acc_top10: 0.6816 - val_acc_top50: 0.7630 - val_sparse_categorical_crossentropy: 4.7922
#
# Epoch 00061: val_acc_top50 improved from 0.76251 to 0.76305, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 62/2000
#  - 2048s - loss: 4.1708 - sparse_categorical_accuracy: 0.3967 - acc_top10: 0.6952 - acc_top50: 0.7885 - sparse_categorical_crossentropy: 4.1708 - val_loss: 4.7870 - val_sparse_categorical_accuracy: 0.3962 - val_acc_top10: 0.6818 - val_acc_top50: 0.7631 - val_sparse_categorical_crossentropy: 4.7895
#
# Epoch 00062: val_acc_top50 improved from 0.76305 to 0.76312, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 63/2000
#  - 2047s - loss: 4.1623 - sparse_categorical_accuracy: 0.3974 - acc_top10: 0.6952 - acc_top50: 0.7886 - sparse_categorical_crossentropy: 4.1623 - val_loss: 4.8099 - val_sparse_categorical_accuracy: 0.3975 - val_acc_top10: 0.6824 - val_acc_top50: 0.7634 - val_sparse_categorical_crossentropy: 4.7836
#
# Epoch 00063: val_acc_top50 improved from 0.76312 to 0.76336, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 64/2000
#  - 2050s - loss: 4.1467 - sparse_categorical_accuracy: 0.3986 - acc_top10: 0.6960 - acc_top50: 0.7898 - sparse_categorical_crossentropy: 4.1467 - val_loss: 4.9400 - val_sparse_categorical_accuracy: 0.3970 - val_acc_top10: 0.6825 - val_acc_top50: 0.7630 - val_sparse_categorical_crossentropy: 4.7826
#
# Epoch 00064: val_acc_top50 did not improve from 0.76336
# Epoch 65/2000
#  - 2048s - loss: 4.1360 - sparse_categorical_accuracy: 0.3993 - acc_top10: 0.6965 - acc_top50: 0.7899 - sparse_categorical_crossentropy: 4.1360 - val_loss: 4.6390 - val_sparse_categorical_accuracy: 0.3968 - val_acc_top10: 0.6830 - val_acc_top50: 0.7634 - val_sparse_categorical_crossentropy: 4.7834
#
# Epoch 00065: val_acc_top50 improved from 0.76336 to 0.76341, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 66/2000
#  - 2048s - loss: 4.1240 - sparse_categorical_accuracy: 0.4001 - acc_top10: 0.6975 - acc_top50: 0.7909 - sparse_categorical_crossentropy: 4.1240 - val_loss: 4.5544 - val_sparse_categorical_accuracy: 0.3975 - val_acc_top10: 0.6832 - val_acc_top50: 0.7638 - val_sparse_categorical_crossentropy: 4.7825
#
# Epoch 00066: val_acc_top50 improved from 0.76341 to 0.76376, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 67/2000
#  - 2046s - loss: 4.1123 - sparse_categorical_accuracy: 0.4004 - acc_top10: 0.6983 - acc_top50: 0.7917 - sparse_categorical_crossentropy: 4.1123 - val_loss: 5.2019 - val_sparse_categorical_accuracy: 0.3977 - val_acc_top10: 0.6828 - val_acc_top50: 0.7637 - val_sparse_categorical_crossentropy: 4.7755
#
# Epoch 00067: val_acc_top50 did not improve from 0.76376
# Epoch 68/2000
#  - 2048s - loss: 4.1039 - sparse_categorical_accuracy: 0.4009 - acc_top10: 0.6988 - acc_top50: 0.7915 - sparse_categorical_crossentropy: 4.1039 - val_loss: 5.2606 - val_sparse_categorical_accuracy: 0.3981 - val_acc_top10: 0.6837 - val_acc_top50: 0.7638 - val_sparse_categorical_crossentropy: 4.7743
#
# Epoch 00068: val_acc_top50 did not improve from 0.76376
# Epoch 69/2000
#  - 2046s - loss: 4.0904 - sparse_categorical_accuracy: 0.4019 - acc_top10: 0.6994 - acc_top50: 0.7922 - sparse_categorical_crossentropy: 4.0904 - val_loss: 4.2901 - val_sparse_categorical_accuracy: 0.3990 - val_acc_top10: 0.6841 - val_acc_top50: 0.7642 - val_sparse_categorical_crossentropy: 4.7757
#
# Epoch 00069: val_acc_top50 improved from 0.76376 to 0.76418, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 70/2000
#  - 2046s - loss: 4.0813 - sparse_categorical_accuracy: 0.4021 - acc_top10: 0.7001 - acc_top50: 0.7931 - sparse_categorical_crossentropy: 4.0813 - val_loss: 4.8729 - val_sparse_categorical_accuracy: 0.3989 - val_acc_top10: 0.6843 - val_acc_top50: 0.7642 - val_sparse_categorical_crossentropy: 4.7745
#
# Epoch 00070: val_acc_top50 improved from 0.76418 to 0.76423, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 71/2000
#  - 2046s - loss: 4.0683 - sparse_categorical_accuracy: 0.4035 - acc_top10: 0.7005 - acc_top50: 0.7934 - sparse_categorical_crossentropy: 4.0683 - val_loss: 4.7980 - val_sparse_categorical_accuracy: 0.3980 - val_acc_top10: 0.6839 - val_acc_top50: 0.7648 - val_sparse_categorical_crossentropy: 4.7691
#
# Epoch 00071: val_acc_top50 improved from 0.76423 to 0.76476, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 72/2000
#  - 2049s - loss: 4.0620 - sparse_categorical_accuracy: 0.4041 - acc_top10: 0.7009 - acc_top50: 0.7936 - sparse_categorical_crossentropy: 4.0620 - val_loss: 4.3939 - val_sparse_categorical_accuracy: 0.3984 - val_acc_top10: 0.6842 - val_acc_top50: 0.7645 - val_sparse_categorical_crossentropy: 4.7647
#
# Epoch 00072: val_acc_top50 did not improve from 0.76476
# Epoch 73/2000
#  - 2047s - loss: 4.0535 - sparse_categorical_accuracy: 0.4047 - acc_top10: 0.7013 - acc_top50: 0.7941 - sparse_categorical_crossentropy: 4.0535 - val_loss: 4.1113 - val_sparse_categorical_accuracy: 0.3997 - val_acc_top10: 0.6838 - val_acc_top50: 0.7645 - val_sparse_categorical_crossentropy: 4.7667
#
# Epoch 00073: val_acc_top50 did not improve from 0.76476
# Epoch 74/2000
#  - 2046s - loss: 4.0442 - sparse_categorical_accuracy: 0.4048 - acc_top10: 0.7022 - acc_top50: 0.7949 - sparse_categorical_crossentropy: 4.0442 - val_loss: 4.3260 - val_sparse_categorical_accuracy: 0.3998 - val_acc_top10: 0.6844 - val_acc_top50: 0.7647 - val_sparse_categorical_crossentropy: 4.7659
#
# Epoch 00074: val_acc_top50 did not improve from 0.76476
# Epoch 75/2000
#  - 2046s - loss: 4.0365 - sparse_categorical_accuracy: 0.4047 - acc_top10: 0.7026 - acc_top50: 0.7951 - sparse_categorical_crossentropy: 4.0365 - val_loss: 5.0703 - val_sparse_categorical_accuracy: 0.3998 - val_acc_top10: 0.6843 - val_acc_top50: 0.7649 - val_sparse_categorical_crossentropy: 4.7688
#
# Epoch 00075: val_acc_top50 improved from 0.76476 to 0.76491, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 76/2000
#  - 2049s - loss: 4.0285 - sparse_categorical_accuracy: 0.4058 - acc_top10: 0.7030 - acc_top50: 0.7956 - sparse_categorical_crossentropy: 4.0285 - val_loss: 5.2208 - val_sparse_categorical_accuracy: 0.3992 - val_acc_top10: 0.6846 - val_acc_top50: 0.7646 - val_sparse_categorical_crossentropy: 4.7677
#
# Epoch 00076: val_acc_top50 did not improve from 0.76491
# Epoch 77/2000
#  - 2046s - loss: 4.0204 - sparse_categorical_accuracy: 0.4061 - acc_top10: 0.7033 - acc_top50: 0.7961 - sparse_categorical_crossentropy: 4.0204 - val_loss: 4.7840 - val_sparse_categorical_accuracy: 0.4004 - val_acc_top10: 0.6846 - val_acc_top50: 0.7649 - val_sparse_categorical_crossentropy: 4.7663
#
# Epoch 00077: val_acc_top50 did not improve from 0.76491
# Epoch 78/2000
#  - 2046s - loss: 4.0090 - sparse_categorical_accuracy: 0.4073 - acc_top10: 0.7043 - acc_top50: 0.7966 - sparse_categorical_crossentropy: 4.0090 - val_loss: 5.5242 - val_sparse_categorical_accuracy: 0.4004 - val_acc_top10: 0.6850 - val_acc_top50: 0.7655 - val_sparse_categorical_crossentropy: 4.7611
#
# Epoch 00078: val_acc_top50 improved from 0.76491 to 0.76552, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 79/2000
#  - 2045s - loss: 4.0029 - sparse_categorical_accuracy: 0.4075 - acc_top10: 0.7047 - acc_top50: 0.7974 - sparse_categorical_crossentropy: 4.0029 - val_loss: 4.2034 - val_sparse_categorical_accuracy: 0.4005 - val_acc_top10: 0.6852 - val_acc_top50: 0.7657 - val_sparse_categorical_crossentropy: 4.7631
#
# Epoch 00079: val_acc_top50 improved from 0.76552 to 0.76566, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 80/2000
#  - 2047s - loss: 3.9966 - sparse_categorical_accuracy: 0.4085 - acc_top10: 0.7046 - acc_top50: 0.7975 - sparse_categorical_crossentropy: 3.9966 - val_loss: 4.7885 - val_sparse_categorical_accuracy: 0.4005 - val_acc_top10: 0.6847 - val_acc_top50: 0.7655 - val_sparse_categorical_crossentropy: 4.7628
#
# Epoch 00080: val_acc_top50 did not improve from 0.76566
# Epoch 81/2000
#  - 2046s - loss: 3.9913 - sparse_categorical_accuracy: 0.4083 - acc_top10: 0.7049 - acc_top50: 0.7973 - sparse_categorical_crossentropy: 3.9913 - val_loss: 4.9550 - val_sparse_categorical_accuracy: 0.4009 - val_acc_top10: 0.6852 - val_acc_top50: 0.7656 - val_sparse_categorical_crossentropy: 4.7652
#
# Epoch 00081: val_acc_top50 did not improve from 0.76566
# Epoch 82/2000
#  - 2045s - loss: 3.9816 - sparse_categorical_accuracy: 0.4088 - acc_top10: 0.7057 - acc_top50: 0.7984 - sparse_categorical_crossentropy: 3.9816 - val_loss: 3.9556 - val_sparse_categorical_accuracy: 0.4015 - val_acc_top10: 0.6855 - val_acc_top50: 0.7652 - val_sparse_categorical_crossentropy: 4.7640
#
# Epoch 00082: val_acc_top50 did not improve from 0.76566
# Epoch 83/2000
#  - 2045s - loss: 3.9778 - sparse_categorical_accuracy: 0.4094 - acc_top10: 0.7057 - acc_top50: 0.7985 - sparse_categorical_crossentropy: 3.9778 - val_loss: 4.4971 - val_sparse_categorical_accuracy: 0.4011 - val_acc_top10: 0.6849 - val_acc_top50: 0.7657 - val_sparse_categorical_crossentropy: 4.7634
#
# Epoch 00083: val_acc_top50 improved from 0.76566 to 0.76571, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 84/2000
#  - 2048s - loss: 3.9700 - sparse_categorical_accuracy: 0.4098 - acc_top10: 0.7065 - acc_top50: 0.7995 - sparse_categorical_crossentropy: 3.9700 - val_loss: 4.8703 - val_sparse_categorical_accuracy: 0.4010 - val_acc_top10: 0.6852 - val_acc_top50: 0.7660 - val_sparse_categorical_crossentropy: 4.7548
#
# Epoch 00084: val_acc_top50 improved from 0.76571 to 0.76601, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 85/2000
#  - 2045s - loss: 3.9653 - sparse_categorical_accuracy: 0.4103 - acc_top10: 0.7065 - acc_top50: 0.7995 - sparse_categorical_crossentropy: 3.9653 - val_loss: 4.2106 - val_sparse_categorical_accuracy: 0.4014 - val_acc_top10: 0.6854 - val_acc_top50: 0.7658 - val_sparse_categorical_crossentropy: 4.7596
#
# Epoch 00085: val_acc_top50 did not improve from 0.76601
# Epoch 86/2000
#  - 2045s - loss: 3.9595 - sparse_categorical_accuracy: 0.4109 - acc_top10: 0.7073 - acc_top50: 0.7997 - sparse_categorical_crossentropy: 3.9595 - val_loss: 4.7279 - val_sparse_categorical_accuracy: 0.4013 - val_acc_top10: 0.6850 - val_acc_top50: 0.7656 - val_sparse_categorical_crossentropy: 4.7579
#
# Epoch 00086: val_acc_top50 did not improve from 0.76601
# Epoch 87/2000
#  - 2044s - loss: 3.9505 - sparse_categorical_accuracy: 0.4117 - acc_top10: 0.7078 - acc_top50: 0.8001 - sparse_categorical_crossentropy: 3.9505 - val_loss: 5.0859 - val_sparse_categorical_accuracy: 0.4018 - val_acc_top10: 0.6852 - val_acc_top50: 0.7660 - val_sparse_categorical_crossentropy: 4.7584
#
# Epoch 00087: val_acc_top50 did not improve from 0.76601
# Epoch 88/2000
#  - 2047s - loss: 3.9489 - sparse_categorical_accuracy: 0.4117 - acc_top10: 0.7077 - acc_top50: 0.8001 - sparse_categorical_crossentropy: 3.9489 - val_loss: 4.8497 - val_sparse_categorical_accuracy: 0.4013 - val_acc_top10: 0.6856 - val_acc_top50: 0.7661 - val_sparse_categorical_crossentropy: 4.7598
#
# Epoch 00088: val_acc_top50 improved from 0.76601 to 0.76611, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 89/2000
#  - 2045s - loss: 3.9417 - sparse_categorical_accuracy: 0.4116 - acc_top10: 0.7081 - acc_top50: 0.8012 - sparse_categorical_crossentropy: 3.9417 - val_loss: 4.3866 - val_sparse_categorical_accuracy: 0.4017 - val_acc_top10: 0.6852 - val_acc_top50: 0.7664 - val_sparse_categorical_crossentropy: 4.7522
#
# Epoch 00089: val_acc_top50 improved from 0.76611 to 0.76641, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 90/2000
#  - 2046s - loss: 3.9365 - sparse_categorical_accuracy: 0.4120 - acc_top10: 0.7086 - acc_top50: 0.8011 - sparse_categorical_crossentropy: 3.9365 - val_loss: 4.5132 - val_sparse_categorical_accuracy: 0.4023 - val_acc_top10: 0.6859 - val_acc_top50: 0.7667 - val_sparse_categorical_crossentropy: 4.7517
#
# Epoch 00090: val_acc_top50 improved from 0.76641 to 0.76670, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 91/2000
#  - 2044s - loss: 3.9299 - sparse_categorical_accuracy: 0.4125 - acc_top10: 0.7092 - acc_top50: 0.8019 - sparse_categorical_crossentropy: 3.9299 - val_loss: 4.8951 - val_sparse_categorical_accuracy: 0.4014 - val_acc_top10: 0.6862 - val_acc_top50: 0.7666 - val_sparse_categorical_crossentropy: 4.7548
#
# Epoch 00091: val_acc_top50 did not improve from 0.76670
# Epoch 92/2000
#  - 2047s - loss: 3.9244 - sparse_categorical_accuracy: 0.4126 - acc_top10: 0.7093 - acc_top50: 0.8022 - sparse_categorical_crossentropy: 3.9245 - val_loss: 4.9732 - val_sparse_categorical_accuracy: 0.4025 - val_acc_top10: 0.6855 - val_acc_top50: 0.7666 - val_sparse_categorical_crossentropy: 4.7546
#
# Epoch 00092: val_acc_top50 did not improve from 0.76670
# Epoch 93/2000
#  - 2045s - loss: 3.9180 - sparse_categorical_accuracy: 0.4131 - acc_top10: 0.7099 - acc_top50: 0.8025 - sparse_categorical_crossentropy: 3.9180 - val_loss: 5.2429 - val_sparse_categorical_accuracy: 0.4026 - val_acc_top10: 0.6853 - val_acc_top50: 0.7667 - val_sparse_categorical_crossentropy: 4.7571
#
# Epoch 00093: val_acc_top50 did not improve from 0.76670
# Epoch 94/2000
#  - 2045s - loss: 3.9134 - sparse_categorical_accuracy: 0.4141 - acc_top10: 0.7103 - acc_top50: 0.8031 - sparse_categorical_crossentropy: 3.9134 - val_loss: 4.3441 - val_sparse_categorical_accuracy: 0.4024 - val_acc_top10: 0.6856 - val_acc_top50: 0.7669 - val_sparse_categorical_crossentropy: 4.7553
#
# Epoch 00094: val_acc_top50 improved from 0.76670 to 0.76689, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 95/2000
#  - 2045s - loss: 3.9110 - sparse_categorical_accuracy: 0.4140 - acc_top10: 0.7101 - acc_top50: 0.8031 - sparse_categorical_crossentropy: 3.9109 - val_loss: 5.0699 - val_sparse_categorical_accuracy: 0.4024 - val_acc_top10: 0.6860 - val_acc_top50: 0.7670 - val_sparse_categorical_crossentropy: 4.7563
#
# Epoch 00095: val_acc_top50 improved from 0.76689 to 0.76704, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 96/2000
#  - 2047s - loss: 3.9053 - sparse_categorical_accuracy: 0.4145 - acc_top10: 0.7110 - acc_top50: 0.8035 - sparse_categorical_crossentropy: 3.9053 - val_loss: 4.7328 - val_sparse_categorical_accuracy: 0.4027 - val_acc_top10: 0.6862 - val_acc_top50: 0.7670 - val_sparse_categorical_crossentropy: 4.7537
#
# Epoch 00096: val_acc_top50 did not improve from 0.76704
# Epoch 97/2000
#  - 2046s - loss: 3.9009 - sparse_categorical_accuracy: 0.4149 - acc_top10: 0.7111 - acc_top50: 0.8036 - sparse_categorical_crossentropy: 3.9009 - val_loss: 4.5964 - val_sparse_categorical_accuracy: 0.4027 - val_acc_top10: 0.6860 - val_acc_top50: 0.7667 - val_sparse_categorical_crossentropy: 4.7608
#
# Epoch 00097: val_acc_top50 did not improve from 0.76704
# Epoch 98/2000
#  - 2046s - loss: 3.8959 - sparse_categorical_accuracy: 0.4151 - acc_top10: 0.7111 - acc_top50: 0.8041 - sparse_categorical_crossentropy: 3.8959 - val_loss: 5.4287 - val_sparse_categorical_accuracy: 0.4028 - val_acc_top10: 0.6865 - val_acc_top50: 0.7665 - val_sparse_categorical_crossentropy: 4.7547
#
# Epoch 00098: val_acc_top50 did not improve from 0.76704
# Epoch 99/2000
#  - 2044s - loss: 3.8916 - sparse_categorical_accuracy: 0.4161 - acc_top10: 0.7120 - acc_top50: 0.8042 - sparse_categorical_crossentropy: 3.8916 - val_loss: 4.6905 - val_sparse_categorical_accuracy: 0.4020 - val_acc_top10: 0.6869 - val_acc_top50: 0.7664 - val_sparse_categorical_crossentropy: 4.7561
#
# Epoch 00099: val_acc_top50 did not improve from 0.76704
# Epoch 100/2000
#  - 2048s - loss: 3.8885 - sparse_categorical_accuracy: 0.4154 - acc_top10: 0.7118 - acc_top50: 0.8046 - sparse_categorical_crossentropy: 3.8885 - val_loss: 4.8332 - val_sparse_categorical_accuracy: 0.4023 - val_acc_top10: 0.6863 - val_acc_top50: 0.7668 - val_sparse_categorical_crossentropy: 4.7546
#
# Epoch 00100: val_acc_top50 did not improve from 0.76704
# Epoch 101/2000
#  - 2045s - loss: 3.8812 - sparse_categorical_accuracy: 0.4163 - acc_top10: 0.7124 - acc_top50: 0.8049 - sparse_categorical_crossentropy: 3.8812 - val_loss: 4.8745 - val_sparse_categorical_accuracy: 0.4030 - val_acc_top10: 0.6867 - val_acc_top50: 0.7665 - val_sparse_categorical_crossentropy: 4.7555
#
# Epoch 00101: val_acc_top50 did not improve from 0.76704
# Epoch 00101: early stopping

# %%
from expansion_policy_fn import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=98,
                    
#                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=2, 
                    use_multiprocessing=True, 
#                    max_queue_size = 12, 
#                    shuffle=False,
#                    callbacks=[earlystop, checkpoint]
                    callbacks=[checkpoint]
                    )
# Out:
# RDKit WARNING: [13:08:23] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 3143138it [00:07, 408815.00it/s]
# expansion: 55608it [00:00, 733645.34it/s]
# expansion training...
# data prep: 100%|██████████| 1093208/1093208 [00:00<00:00, 1200550.13it/s]
# total reactions: 100%|██████████| 1093208/1093208 [00:00<00:00, 2699848.20it/s]
# total products: 1093208
# total reactions: 1157488
# Training size: 1027181
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 23086)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               11820544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_1 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_2 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_3 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_4 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_5 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 55608)             28526904
# =================================================================
# Total params: 42,974,008
# Trainable params: 42,974,008
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/98
#  - 725s - loss: 6.9447 - sparse_categorical_accuracy: 0.0815 - acc_top10: 0.2773 - acc_top50: 0.4657 - sparse_categorical_crossentropy: 6.9447
#
# Epoch 00001: acc_top50 improved from -inf to 0.46568, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 2/98
#  - 715s - loss: 5.6928 - sparse_categorical_accuracy: 0.1933 - acc_top10: 0.4703 - acc_top50: 0.6174 - sparse_categorical_crossentropy: 5.6928
#
# Epoch 00002: acc_top50 improved from 0.46568 to 0.61740, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 3/98
#  - 1100s - loss: 5.1678 - sparse_categorical_accuracy: 0.2363 - acc_top10: 0.5368 - acc_top50: 0.6762 - sparse_categorical_crossentropy: 5.1678
#
# Epoch 00003: acc_top50 improved from 0.61740 to 0.67621, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 4/98
#  - 866s - loss: 4.8447 - sparse_categorical_accuracy: 0.2639 - acc_top10: 0.5751 - acc_top50: 0.7107 - sparse_categorical_crossentropy: 4.8447
#
# Epoch 00004: acc_top50 improved from 0.67621 to 0.71075, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 5/98
#  - 868s - loss: 4.6293 - sparse_categorical_accuracy: 0.2821 - acc_top10: 0.5990 - acc_top50: 0.7327 - sparse_categorical_crossentropy: 4.6293
#
# Epoch 00005: acc_top50 improved from 0.71075 to 0.73271, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 6/98
#  - 887s - loss: 4.4755 - sparse_categorical_accuracy: 0.2955 - acc_top10: 0.6154 - acc_top50: 0.7482 - sparse_categorical_crossentropy: 4.4755
#
# Epoch 00006: acc_top50 improved from 0.73271 to 0.74822, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 7/98
#  - 822s - loss: 4.3504 - sparse_categorical_accuracy: 0.3056 - acc_top10: 0.6292 - acc_top50: 0.7609 - sparse_categorical_crossentropy: 4.3504
#
# Epoch 00007: acc_top50 improved from 0.74822 to 0.76093, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 8/98
#  - 889s - loss: 4.2469 - sparse_categorical_accuracy: 0.3150 - acc_top10: 0.6407 - acc_top50: 0.7716 - sparse_categorical_crossentropy: 4.2469
#
# Epoch 00008: acc_top50 improved from 0.76093 to 0.77158, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 9/98
#  - 833s - loss: 4.1556 - sparse_categorical_accuracy: 0.3236 - acc_top10: 0.6511 - acc_top50: 0.7814 - sparse_categorical_crossentropy: 4.1556
#
# Epoch 00009: acc_top50 improved from 0.77158 to 0.78143, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 10/98
#  - 833s - loss: 4.0736 - sparse_categorical_accuracy: 0.3313 - acc_top10: 0.6614 - acc_top50: 0.7894 - sparse_categorical_crossentropy: 4.0736
#
# Epoch 00010: acc_top50 improved from 0.78143 to 0.78942, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 11/98
#  - 837s - loss: 3.9989 - sparse_categorical_accuracy: 0.3395 - acc_top10: 0.6698 - acc_top50: 0.7967 - sparse_categorical_crossentropy: 3.9989
#
# Epoch 00011: acc_top50 improved from 0.78942 to 0.79665, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 12/98
#  - 816s - loss: 3.9326 - sparse_categorical_accuracy: 0.3464 - acc_top10: 0.6781 - acc_top50: 0.8037 - sparse_categorical_crossentropy: 3.9326
#
# Epoch 00012: acc_top50 improved from 0.79665 to 0.80372, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 13/98
#  - 709s - loss: 3.8756 - sparse_categorical_accuracy: 0.3519 - acc_top10: 0.6848 - acc_top50: 0.8098 - sparse_categorical_crossentropy: 3.8756
#
# Epoch 00013: acc_top50 improved from 0.80372 to 0.80977, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 14/98
#  - 830s - loss: 3.8198 - sparse_categorical_accuracy: 0.3585 - acc_top10: 0.6909 - acc_top50: 0.8146 - sparse_categorical_crossentropy: 3.8198
#
# Epoch 00014: acc_top50 improved from 0.80977 to 0.81461, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 15/98
#  - 720s - loss: 3.7678 - sparse_categorical_accuracy: 0.3635 - acc_top10: 0.6973 - acc_top50: 0.8199 - sparse_categorical_crossentropy: 3.7678
#
# Epoch 00015: acc_top50 improved from 0.81461 to 0.81991, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 16/98
#  - 719s - loss: 3.7201 - sparse_categorical_accuracy: 0.3687 - acc_top10: 0.7025 - acc_top50: 0.8245 - sparse_categorical_crossentropy: 3.7201
#
# Epoch 00016: acc_top50 improved from 0.81991 to 0.82451, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 17/98
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-1-6109e049518f> in <module>
#      14 #                    shuffle=False,
#      15 #                    callbacks=[earlystop, checkpoint]
# ---> 16                     callbacks=[checkpoint]
#      17                     )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3074
#    3075     fetched = self._callable_fn(*array_vals,
# -> 3076                                 run_metadata=self.run_metadata)
#    3077     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3078     return nest.pack_sequence_as(self._outputs_structure,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# ResourceExhaustedError: OOM when allocating tensor with shape[512,55608] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node training/Adam/Square_42}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %%
from expansion_policy_fn import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=98,
                    
#                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=16,
                    workers=2, 
                    use_multiprocessing=True, 
#                    max_queue_size = 12, 
#                    shuffle=False,
#                    callbacks=[earlystop, checkpoint]
                    callbacks=[checkpoint]
                    )
# Out:
# RDKit WARNING: [17:58:49] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 3143138it [00:07, 405186.87it/s]
# expansion: 55608it [00:00, 714575.89it/s]
# expansion training...
# data prep: 100%|██████████| 1093208/1093208 [00:00<00:00, 1194004.08it/s]
# total reactions: 100%|██████████| 1093208/1093208 [00:00<00:00, 2706321.05it/s]
# total products: 1093208
# total reactions: 1157488
# Training size: 1027181
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 23086)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               11820544
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_1 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_2 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_3 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_4 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# highway_5 (Highway)          (None, 512)               525312
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 55608)             28526904
# =================================================================
# Total params: 42,974,008
# Trainable params: 42,974,008
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 17/98
#  - 722s - loss: 3.6769 - sparse_categorical_accuracy: 0.3733 - acc_top10: 0.7078 - acc_top50: 0.8284 - sparse_categorical_crossentropy: 3.6769
#
# Epoch 00017: acc_top50 improved from -inf to 0.82836, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 18/98
#  - 727s - loss: 3.6379 - sparse_categorical_accuracy: 0.3776 - acc_top10: 0.7124 - acc_top50: 0.8320 - sparse_categorical_crossentropy: 3.6379
#
# Epoch 00018: acc_top50 improved from 0.82836 to 0.83200, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 19/98
#  - 719s - loss: 3.6014 - sparse_categorical_accuracy: 0.3820 - acc_top10: 0.7167 - acc_top50: 0.8356 - sparse_categorical_crossentropy: 3.6014
#
# Epoch 00019: acc_top50 improved from 0.83200 to 0.83556, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 20/98
#  - 729s - loss: 3.5674 - sparse_categorical_accuracy: 0.3855 - acc_top10: 0.7211 - acc_top50: 0.8385 - sparse_categorical_crossentropy: 3.5674
#
# Epoch 00020: acc_top50 improved from 0.83556 to 0.83850, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 21/98
#  - 725s - loss: 3.5316 - sparse_categorical_accuracy: 0.3895 - acc_top10: 0.7250 - acc_top50: 0.8417 - sparse_categorical_crossentropy: 3.5316
#
# Epoch 00021: acc_top50 improved from 0.83850 to 0.84174, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 22/98
#  - 729s - loss: 3.5023 - sparse_categorical_accuracy: 0.3932 - acc_top10: 0.7287 - acc_top50: 0.8442 - sparse_categorical_crossentropy: 3.5023
#
# Epoch 00022: acc_top50 improved from 0.84174 to 0.84421, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 23/98
#  - 731s - loss: 3.4710 - sparse_categorical_accuracy: 0.3972 - acc_top10: 0.7320 - acc_top50: 0.8468 - sparse_categorical_crossentropy: 3.4710
#
# Epoch 00023: acc_top50 improved from 0.84421 to 0.84683, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 24/98
#  - 722s - loss: 3.4431 - sparse_categorical_accuracy: 0.4004 - acc_top10: 0.7350 - acc_top50: 0.8497 - sparse_categorical_crossentropy: 3.4431
#
# Epoch 00024: acc_top50 improved from 0.84683 to 0.84971, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 25/98
#  - 720s - loss: 3.4173 - sparse_categorical_accuracy: 0.4037 - acc_top10: 0.7381 - acc_top50: 0.8516 - sparse_categorical_crossentropy: 3.4173
#
# Epoch 00025: acc_top50 improved from 0.84971 to 0.85156, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 26/98
#  - 720s - loss: 3.3908 - sparse_categorical_accuracy: 0.4066 - acc_top10: 0.7414 - acc_top50: 0.8540 - sparse_categorical_crossentropy: 3.3908
#
# Epoch 00026: acc_top50 improved from 0.85156 to 0.85399, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 27/98
#  - 730s - loss: 3.3687 - sparse_categorical_accuracy: 0.4095 - acc_top10: 0.7444 - acc_top50: 0.8557 - sparse_categorical_crossentropy: 3.3687
#
# Epoch 00027: acc_top50 improved from 0.85399 to 0.85572, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 28/98
#  - 724s - loss: 3.3441 - sparse_categorical_accuracy: 0.4123 - acc_top10: 0.7467 - acc_top50: 0.8580 - sparse_categorical_crossentropy: 3.3441
#
# Epoch 00028: acc_top50 improved from 0.85572 to 0.85796, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 29/98
#  - 729s - loss: 3.3191 - sparse_categorical_accuracy: 0.4151 - acc_top10: 0.7496 - acc_top50: 0.8601 - sparse_categorical_crossentropy: 3.3191
#
# Epoch 00029: acc_top50 improved from 0.85796 to 0.86010, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 30/98
#  - 730s - loss: 3.2993 - sparse_categorical_accuracy: 0.4183 - acc_top10: 0.7518 - acc_top50: 0.8616 - sparse_categorical_crossentropy: 3.2993
#
# Epoch 00030: acc_top50 improved from 0.86010 to 0.86163, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 31/98
#  - 728s - loss: 3.2809 - sparse_categorical_accuracy: 0.4203 - acc_top10: 0.7544 - acc_top50: 0.8629 - sparse_categorical_crossentropy: 3.2809
#
# Epoch 00031: acc_top50 improved from 0.86163 to 0.86288, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 32/98
#  - 728s - loss: 3.2589 - sparse_categorical_accuracy: 0.4230 - acc_top10: 0.7562 - acc_top50: 0.8649 - sparse_categorical_crossentropy: 3.2589
#
# Epoch 00032: acc_top50 improved from 0.86288 to 0.86488, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 33/98
#  - 728s - loss: 3.2414 - sparse_categorical_accuracy: 0.4249 - acc_top10: 0.7586 - acc_top50: 0.8663 - sparse_categorical_crossentropy: 3.2414
#
# Epoch 00033: acc_top50 improved from 0.86488 to 0.86633, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 34/98
#  - 719s - loss: 3.2205 - sparse_categorical_accuracy: 0.4278 - acc_top10: 0.7612 - acc_top50: 0.8678 - sparse_categorical_crossentropy: 3.2205
#
# Epoch 00034: acc_top50 improved from 0.86633 to 0.86778, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 35/98
#  - 719s - loss: 3.2023 - sparse_categorical_accuracy: 0.4303 - acc_top10: 0.7630 - acc_top50: 0.8691 - sparse_categorical_crossentropy: 3.2023
#
# Epoch 00035: acc_top50 improved from 0.86778 to 0.86912, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 36/98
#  - 719s - loss: 3.1852 - sparse_categorical_accuracy: 0.4326 - acc_top10: 0.7648 - acc_top50: 0.8708 - sparse_categorical_crossentropy: 3.1852
#
# Epoch 00036: acc_top50 improved from 0.86912 to 0.87080, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 37/98
#  - 720s - loss: 3.1702 - sparse_categorical_accuracy: 0.4346 - acc_top10: 0.7670 - acc_top50: 0.8719 - sparse_categorical_crossentropy: 3.1702
#
# Epoch 00037: acc_top50 improved from 0.87080 to 0.87185, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 38/98
#  - 720s - loss: 3.1534 - sparse_categorical_accuracy: 0.4364 - acc_top10: 0.7683 - acc_top50: 0.8732 - sparse_categorical_crossentropy: 3.1534
#
# Epoch 00038: acc_top50 improved from 0.87185 to 0.87323, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 39/98
#  - 720s - loss: 3.1379 - sparse_categorical_accuracy: 0.4385 - acc_top10: 0.7704 - acc_top50: 0.8744 - sparse_categorical_crossentropy: 3.1379
#
# Epoch 00039: acc_top50 improved from 0.87323 to 0.87445, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 40/98
#  - 720s - loss: 3.1227 - sparse_categorical_accuracy: 0.4402 - acc_top10: 0.7720 - acc_top50: 0.8760 - sparse_categorical_crossentropy: 3.1227
#
# Epoch 00040: acc_top50 improved from 0.87445 to 0.87598, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 41/98
#  - 720s - loss: 3.1060 - sparse_categorical_accuracy: 0.4425 - acc_top10: 0.7737 - acc_top50: 0.8770 - sparse_categorical_crossentropy: 3.1060
#
# Epoch 00041: acc_top50 improved from 0.87598 to 0.87696, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 42/98
#  - 720s - loss: 3.0930 - sparse_categorical_accuracy: 0.4443 - acc_top10: 0.7754 - acc_top50: 0.8778 - sparse_categorical_crossentropy: 3.0930
#
# Epoch 00042: acc_top50 improved from 0.87696 to 0.87776, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 43/98
#  - 720s - loss: 3.0808 - sparse_categorical_accuracy: 0.4467 - acc_top10: 0.7768 - acc_top50: 0.8783 - sparse_categorical_crossentropy: 3.0808
#
# Epoch 00043: acc_top50 improved from 0.87776 to 0.87834, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 44/98
#  - 720s - loss: 3.0660 - sparse_categorical_accuracy: 0.4475 - acc_top10: 0.7782 - acc_top50: 0.8797 - sparse_categorical_crossentropy: 3.0660
#
# Epoch 00044: acc_top50 improved from 0.87834 to 0.87969, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 45/98
#  - 720s - loss: 3.0550 - sparse_categorical_accuracy: 0.4496 - acc_top10: 0.7798 - acc_top50: 0.8806 - sparse_categorical_crossentropy: 3.0550
#
# Epoch 00045: acc_top50 improved from 0.87969 to 0.88058, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 46/98
#  - 719s - loss: 3.0418 - sparse_categorical_accuracy: 0.4510 - acc_top10: 0.7811 - acc_top50: 0.8813 - sparse_categorical_crossentropy: 3.0418
#
# Epoch 00046: acc_top50 improved from 0.88058 to 0.88132, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 47/98
#  - 719s - loss: 3.0298 - sparse_categorical_accuracy: 0.4529 - acc_top10: 0.7824 - acc_top50: 0.8820 - sparse_categorical_crossentropy: 3.0298
#
# Epoch 00047: acc_top50 improved from 0.88132 to 0.88202, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 48/98
#  - 719s - loss: 3.0147 - sparse_categorical_accuracy: 0.4550 - acc_top10: 0.7841 - acc_top50: 0.8833 - sparse_categorical_crossentropy: 3.0147
#
# Epoch 00048: acc_top50 improved from 0.88202 to 0.88325, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 49/98
#  - 720s - loss: 3.0059 - sparse_categorical_accuracy: 0.4562 - acc_top10: 0.7849 - acc_top50: 0.8838 - sparse_categorical_crossentropy: 3.0059
#
# Epoch 00049: acc_top50 improved from 0.88325 to 0.88384, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 50/98
#  - 719s - loss: 2.9927 - sparse_categorical_accuracy: 0.4579 - acc_top10: 0.7859 - acc_top50: 0.8847 - sparse_categorical_crossentropy: 2.9927
#
# Epoch 00050: acc_top50 improved from 0.88384 to 0.88467, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 51/98
#  - 719s - loss: 2.9824 - sparse_categorical_accuracy: 0.4588 - acc_top10: 0.7877 - acc_top50: 0.8857 - sparse_categorical_crossentropy: 2.9824
#
# Epoch 00051: acc_top50 improved from 0.88467 to 0.88573, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 52/98
#  - 719s - loss: 2.9683 - sparse_categorical_accuracy: 0.4603 - acc_top10: 0.7890 - acc_top50: 0.8866 - sparse_categorical_crossentropy: 2.9683
#
# Epoch 00052: acc_top50 improved from 0.88573 to 0.88660, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 53/98
#  - 720s - loss: 2.9580 - sparse_categorical_accuracy: 0.4619 - acc_top10: 0.7901 - acc_top50: 0.8873 - sparse_categorical_crossentropy: 2.9580
#
# Epoch 00053: acc_top50 improved from 0.88660 to 0.88730, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 54/98
#  - 720s - loss: 2.9468 - sparse_categorical_accuracy: 0.4632 - acc_top10: 0.7912 - acc_top50: 0.8881 - sparse_categorical_crossentropy: 2.9468
#
# Epoch 00054: acc_top50 improved from 0.88730 to 0.88810, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 55/98
#  - 720s - loss: 2.9345 - sparse_categorical_accuracy: 0.4647 - acc_top10: 0.7929 - acc_top50: 0.8890 - sparse_categorical_crossentropy: 2.9345
#
# Epoch 00055: acc_top50 improved from 0.88810 to 0.88901, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 56/98
#  - 719s - loss: 2.9235 - sparse_categorical_accuracy: 0.4662 - acc_top10: 0.7934 - acc_top50: 0.8897 - sparse_categorical_crossentropy: 2.9235
#
# Epoch 00056: acc_top50 improved from 0.88901 to 0.88966, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 57/98
#  - 720s - loss: 2.9135 - sparse_categorical_accuracy: 0.4673 - acc_top10: 0.7946 - acc_top50: 0.8903 - sparse_categorical_crossentropy: 2.9135
#
# Epoch 00057: acc_top50 improved from 0.88966 to 0.89029, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 58/98
#  - 720s - loss: 2.9037 - sparse_categorical_accuracy: 0.4687 - acc_top10: 0.7957 - acc_top50: 0.8909 - sparse_categorical_crossentropy: 2.9037
#
# Epoch 00058: acc_top50 improved from 0.89029 to 0.89092, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 59/98
#  - 719s - loss: 2.8931 - sparse_categorical_accuracy: 0.4700 - acc_top10: 0.7965 - acc_top50: 0.8916 - sparse_categorical_crossentropy: 2.8931
#
# Epoch 00059: acc_top50 improved from 0.89092 to 0.89161, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 60/98
#  - 720s - loss: 2.8840 - sparse_categorical_accuracy: 0.4713 - acc_top10: 0.7975 - acc_top50: 0.8922 - sparse_categorical_crossentropy: 2.8840
#
# Epoch 00060: acc_top50 improved from 0.89161 to 0.89220, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 61/98
#  - 719s - loss: 2.8730 - sparse_categorical_accuracy: 0.4721 - acc_top10: 0.7989 - acc_top50: 0.8930 - sparse_categorical_crossentropy: 2.8730
#
# Epoch 00061: acc_top50 improved from 0.89220 to 0.89298, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 62/98
#  - 719s - loss: 2.8631 - sparse_categorical_accuracy: 0.4732 - acc_top10: 0.7998 - acc_top50: 0.8934 - sparse_categorical_crossentropy: 2.8631
#
# Epoch 00062: acc_top50 improved from 0.89298 to 0.89344, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 63/98
#  - 720s - loss: 2.8544 - sparse_categorical_accuracy: 0.4746 - acc_top10: 0.8003 - acc_top50: 0.8939 - sparse_categorical_crossentropy: 2.8544
#
# Epoch 00063: acc_top50 improved from 0.89344 to 0.89388, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 64/98
#  - 719s - loss: 2.8470 - sparse_categorical_accuracy: 0.4752 - acc_top10: 0.8010 - acc_top50: 0.8944 - sparse_categorical_crossentropy: 2.8470
#
# Epoch 00064: acc_top50 improved from 0.89388 to 0.89444, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 65/98
#  - 719s - loss: 2.8361 - sparse_categorical_accuracy: 0.4771 - acc_top10: 0.8024 - acc_top50: 0.8949 - sparse_categorical_crossentropy: 2.8361
#
# Epoch 00065: acc_top50 improved from 0.89444 to 0.89494, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 66/98
#  - 720s - loss: 2.8269 - sparse_categorical_accuracy: 0.4780 - acc_top10: 0.8030 - acc_top50: 0.8958 - sparse_categorical_crossentropy: 2.8269
#
# Epoch 00066: acc_top50 improved from 0.89494 to 0.89580, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 67/98
#  - 719s - loss: 2.8191 - sparse_categorical_accuracy: 0.4787 - acc_top10: 0.8041 - acc_top50: 0.8965 - sparse_categorical_crossentropy: 2.8191
#
# Epoch 00067: acc_top50 improved from 0.89580 to 0.89647, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 68/98
#  - 719s - loss: 2.8100 - sparse_categorical_accuracy: 0.4801 - acc_top10: 0.8046 - acc_top50: 0.8968 - sparse_categorical_crossentropy: 2.8100
#
# Epoch 00068: acc_top50 improved from 0.89647 to 0.89679, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 69/98
#  - 719s - loss: 2.8019 - sparse_categorical_accuracy: 0.4807 - acc_top10: 0.8057 - acc_top50: 0.8975 - sparse_categorical_crossentropy: 2.8019
#
# Epoch 00069: acc_top50 improved from 0.89679 to 0.89751, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 70/98
#  - 719s - loss: 2.7940 - sparse_categorical_accuracy: 0.4820 - acc_top10: 0.8062 - acc_top50: 0.8977 - sparse_categorical_crossentropy: 2.7940
#
# Epoch 00070: acc_top50 improved from 0.89751 to 0.89771, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 71/98
#  - 719s - loss: 2.7845 - sparse_categorical_accuracy: 0.4834 - acc_top10: 0.8070 - acc_top50: 0.8981 - sparse_categorical_crossentropy: 2.7845
#
# Epoch 00071: acc_top50 improved from 0.89771 to 0.89814, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 72/98
#  - 719s - loss: 2.7759 - sparse_categorical_accuracy: 0.4842 - acc_top10: 0.8078 - acc_top50: 0.8989 - sparse_categorical_crossentropy: 2.7759
#
# Epoch 00072: acc_top50 improved from 0.89814 to 0.89894, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 73/98
#  - 719s - loss: 2.7684 - sparse_categorical_accuracy: 0.4846 - acc_top10: 0.8083 - acc_top50: 0.8993 - sparse_categorical_crossentropy: 2.7684
#
# Epoch 00073: acc_top50 improved from 0.89894 to 0.89928, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 74/98
#  - 719s - loss: 2.7633 - sparse_categorical_accuracy: 0.4852 - acc_top10: 0.8088 - acc_top50: 0.8996 - sparse_categorical_crossentropy: 2.7633
#
# Epoch 00074: acc_top50 improved from 0.89928 to 0.89963, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 75/98
#  - 719s - loss: 2.7533 - sparse_categorical_accuracy: 0.4863 - acc_top10: 0.8095 - acc_top50: 0.9005 - sparse_categorical_crossentropy: 2.7533
#
# Epoch 00075: acc_top50 improved from 0.89963 to 0.90053, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 76/98
#  - 719s - loss: 2.7457 - sparse_categorical_accuracy: 0.4867 - acc_top10: 0.8108 - acc_top50: 0.9007 - sparse_categorical_crossentropy: 2.7457
#
# Epoch 00076: acc_top50 improved from 0.90053 to 0.90075, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 77/98
#  - 719s - loss: 2.7390 - sparse_categorical_accuracy: 0.4880 - acc_top10: 0.8112 - acc_top50: 0.9011 - sparse_categorical_crossentropy: 2.7390
#
# Epoch 00077: acc_top50 improved from 0.90075 to 0.90109, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 78/98
#  - 719s - loss: 2.7290 - sparse_categorical_accuracy: 0.4886 - acc_top10: 0.8123 - acc_top50: 0.9019 - sparse_categorical_crossentropy: 2.7290
#
# Epoch 00078: acc_top50 improved from 0.90109 to 0.90193, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 79/98
#  - 719s - loss: 2.7227 - sparse_categorical_accuracy: 0.4896 - acc_top10: 0.8125 - acc_top50: 0.9023 - sparse_categorical_crossentropy: 2.7227
#
# Epoch 00079: acc_top50 improved from 0.90193 to 0.90230, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 80/98
#  - 719s - loss: 2.7208 - sparse_categorical_accuracy: 0.4906 - acc_top10: 0.8126 - acc_top50: 0.9021 - sparse_categorical_crossentropy: 2.7208
#
# Epoch 00080: acc_top50 did not improve from 0.90230
# Epoch 81/98
#  - 719s - loss: 2.7117 - sparse_categorical_accuracy: 0.4915 - acc_top10: 0.8134 - acc_top50: 0.9026 - sparse_categorical_crossentropy: 2.7117
#
# Epoch 00081: acc_top50 improved from 0.90230 to 0.90260, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 82/98
#  - 719s - loss: 2.7071 - sparse_categorical_accuracy: 0.4917 - acc_top10: 0.8139 - acc_top50: 0.9030 - sparse_categorical_crossentropy: 2.7072
#
# Epoch 00082: acc_top50 improved from 0.90260 to 0.90302, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 83/98
#  - 722s - loss: 2.6998 - sparse_categorical_accuracy: 0.4922 - acc_top10: 0.8144 - acc_top50: 0.9038 - sparse_categorical_crossentropy: 2.6998
#
# Epoch 00083: acc_top50 improved from 0.90302 to 0.90381, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 84/98
#  - 719s - loss: 2.6921 - sparse_categorical_accuracy: 0.4940 - acc_top10: 0.8154 - acc_top50: 0.9037 - sparse_categorical_crossentropy: 2.6921
#
# Epoch 00084: acc_top50 did not improve from 0.90381
# Epoch 85/98
#  - 719s - loss: 2.6849 - sparse_categorical_accuracy: 0.4949 - acc_top10: 0.8159 - acc_top50: 0.9041 - sparse_categorical_crossentropy: 2.6849
#
# Epoch 00085: acc_top50 improved from 0.90381 to 0.90409, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 86/98
#  - 719s - loss: 2.6797 - sparse_categorical_accuracy: 0.4945 - acc_top10: 0.8166 - acc_top50: 0.9048 - sparse_categorical_crossentropy: 2.6797
#
# Epoch 00086: acc_top50 improved from 0.90409 to 0.90484, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 87/98
#  - 719s - loss: 2.6739 - sparse_categorical_accuracy: 0.4957 - acc_top10: 0.8168 - acc_top50: 0.9050 - sparse_categorical_crossentropy: 2.6739
#
# Epoch 00087: acc_top50 improved from 0.90484 to 0.90503, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 88/98
#  - 719s - loss: 2.6682 - sparse_categorical_accuracy: 0.4961 - acc_top10: 0.8177 - acc_top50: 0.9050 - sparse_categorical_crossentropy: 2.6682
#
# Epoch 00088: acc_top50 did not improve from 0.90503
# Epoch 89/98
#  - 720s - loss: 2.6646 - sparse_categorical_accuracy: 0.4967 - acc_top10: 0.8177 - acc_top50: 0.9054 - sparse_categorical_crossentropy: 2.6646
#
# Epoch 00089: acc_top50 improved from 0.90503 to 0.90542, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 90/98
#  - 719s - loss: 2.6595 - sparse_categorical_accuracy: 0.4972 - acc_top10: 0.8176 - acc_top50: 0.9055 - sparse_categorical_crossentropy: 2.6595
#
# Epoch 00090: acc_top50 improved from 0.90542 to 0.90553, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 91/98
#  - 719s - loss: 2.6519 - sparse_categorical_accuracy: 0.4989 - acc_top10: 0.8186 - acc_top50: 0.9057 - sparse_categorical_crossentropy: 2.6519
#
# Epoch 00091: acc_top50 improved from 0.90553 to 0.90573, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 92/98
#  - 719s - loss: 2.6489 - sparse_categorical_accuracy: 0.4983 - acc_top10: 0.8192 - acc_top50: 0.9066 - sparse_categorical_crossentropy: 2.6489
#
# Epoch 00092: acc_top50 improved from 0.90573 to 0.90658, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 93/98
#  - 730s - loss: 2.6423 - sparse_categorical_accuracy: 0.4996 - acc_top10: 0.8194 - acc_top50: 0.9068 - sparse_categorical_crossentropy: 2.6423
#
# Epoch 00093: acc_top50 improved from 0.90658 to 0.90676, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 94/98
#  - 728s - loss: 2.6389 - sparse_categorical_accuracy: 0.4997 - acc_top10: 0.8199 - acc_top50: 0.9067 - sparse_categorical_crossentropy: 2.6389
#
# Epoch 00094: acc_top50 did not improve from 0.90676
# Epoch 95/98
#  - 729s - loss: 2.6323 - sparse_categorical_accuracy: 0.5005 - acc_top10: 0.8207 - acc_top50: 0.9071 - sparse_categorical_crossentropy: 2.6323
#
# Epoch 00095: acc_top50 improved from 0.90676 to 0.90709, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 96/98
#  - 726s - loss: 2.6271 - sparse_categorical_accuracy: 0.5011 - acc_top10: 0.8213 - acc_top50: 0.9075 - sparse_categorical_crossentropy: 2.6271
#
# Epoch 00096: acc_top50 improved from 0.90709 to 0.90754, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
# Epoch 97/98
#  - 719s - loss: 2.6239 - sparse_categorical_accuracy: 0.5017 - acc_top10: 0.8214 - acc_top50: 0.9074 - sparse_categorical_crossentropy: 2.6239
#
# Epoch 00097: acc_top50 did not improve from 0.90754
# Epoch 98/98
#  - 720s - loss: 2.6190 - sparse_categorical_accuracy: 0.5025 - acc_top10: 0.8216 - acc_top50: 0.9077 - sparse_categorical_crossentropy: 2.6190
#
# Epoch 00098: acc_top50 improved from 0.90754 to 0.90771, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_expansion_0
