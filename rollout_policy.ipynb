# %%
#belowing four line for reproduce results use(could make varialbe_initiator predictable)
#from numpy.random import seed
#seed(1)
#from tensorflow import set_random_seed
#set_random_seed(2)    
import os
import random
import numpy as np
import tensorflow as tf
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
from tqdm import tqdm, trange
from collections import defaultdict
from highway_layer import Highway
#匯入深度學習的框架函式庫：keras
import keras
from keras import backend as K
from keras.initializers import Constant
from keras.utils import plot_model
#keras用以建立模型架構的函數
from keras.models import Sequential, load_model, Model

#keras中建立深度學習layer的函數

from keras.layers import Dense, Dropout, BatchNormalization, Activation, Multiply, Add, Lambda, Input

#keras訓練演算法函數
from keras import regularizers
from keras.optimizers import Adam

#keras提早判停的函數
from keras.callbacks import EarlyStopping, ModelCheckpoint

#it's hard to reproduce results, so close all seeds
#os.environ['PYTHONHASHSEED'] = '0'
#np.random.seed(0)
#tf.set_random_seed(0)
#random.seed(0)

#to solve problem:Blas GEMM launch failed
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
#config = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
config.gpu_options.allocator_type = 'BFC' #A "Best-fit with coalescing" algorithm, simplified from a version of dlmalloc.
config.gpu_options.per_process_gpu_memory_fraction = 0.95
config.gpu_options.allow_growth = True
set_session(tf.Session(config=config)) 


def fps_to_arr(fps):
    """Faster conversion to ndarray"""
    arrs = []
    for fp in fps:
        onbits = list(fp.GetOnBits())
        arr = np.zeros(fp.GetNumBits())
        arr[onbits] = 1
        arrs.append(arr)
    arrs = np.array(arrs)
    return arrs




def fingerprint_mols(mols, fp_dim):
    fps = []
    for mol in mols:
        mol = Chem.MolFromSmiles(mol)

        # Necessary for fingerprinting
        # Chem.GetSymmSSSR(mol)

        # "When comparing the ECFP/FCFP fingerprints and
        # the Morgan fingerprints generated by the RDKit,
        # remember that the 4 in ECFP4 corresponds to the
        # diameter of the atom environments considered,
        # while the Morgan fingerprints take a radius parameter.
        # So the examples above, with radius=2, are roughly
        # equivalent to ECFP4 and FCFP4."
        # <http://www.rdkit.org/docs/GettingStartedInPython.html>
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=int(fp_dim), useChirality=1)
        # fold_factor = fp.GetNumBits()//fp_dim
        # fp = DataStructs.FoldFingerprint(fp, fold_factor)
        fps.append(fp)
    return fps
'''
def fps_to_arr(fps):
    """Faster conversion to ndarray"""
    arrs = []
    for fp, info in zip(fps[0],fps[1]):
        onbits = list(fp.GetOnBits())
        arr = np.zeros(fp.GetNumBits())
        for onbit in onbits:
            arr[onbit] = len(info[onbit])
        arrs.append(arr)
    arrs = np.array(arrs)
    return arrs




def fingerprint_mols(mols, fp_dim):
    fps = []
    infos = []
    for mol in mols:
        mol = Chem.MolFromSmiles(mol)
        info={}
        # Necessary for fingerprinting
        # Chem.GetSymmSSSR(mol)

        # "When comparing the ECFP/FCFP fingerprints and
        # the Morgan fingerprints generated by the RDKit,
        # remember that the 4 in ECFP4 corresponds to the
        # diameter of the atom environments considered,
        # while the Morgan fingerprints take a radius parameter.
        # So the examples above, with radius=2, are roughly
        # equivalent to ECFP4 and FCFP4."
        # <http://www.rdkit.org/docs/GettingStartedInPython.html>
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius=2, nBits=int(fp_dim), useChirality=1, bitInfo=info)
        # fold_factor = fp.GetNumBits()//fp_dim
        # fp = DataStructs.FoldFingerprint(fp, fold_factor)
        fps.append(fp)
        infos.append(info)
    return fps, infos
'''
def preprocess(X,fp_dim):
    # Compute fingerprints
    dataX = fps_to_arr(fingerprint_mols(X, fp_dim))
    FPs = np.log(dataX+1)
    return FPs

class DataGenerator(keras.utils.Sequence):
    
    def __init__(self, X, y, batch_size=1, shuffle=True, fp_dim=8192 ):
        self.batch_size = batch_size
        self.X = X
        self.y = y
        self.indexes = np.arange(len(self.X))
        self.shuffle = shuffle
        self.fp_dim = fp_dim

    def __len__(self):
        #计算每一个epoch的迭代次数
        return int(np.floor(len(self.X) / int(self.batch_size)))

    def __getitem__(self, index):
        #生成每个batch数据，这里就根据自己对数据的读取方式进行发挥了
        # 生成batch_size个索引
        batch_indexs = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # 根据索引获取datas集合中的数据
        batch_datasX = [self.X[k] for k in batch_indexs]
        batch_datasy = [self.y[k] for k in batch_indexs]
        # 生成数据
        X = preprocess(batch_datasX, self.fp_dim)
        y = np.array(batch_datasy)
#        y = y.astype(np.int64)
        return X, y

    def on_epoch_end(self):
        #在每一次epoch结束是否需要进行一次随机，重新随机一下index
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

#    def fps_to_arr(fps):
        """Faster conversion to ndarray"""
#        arrs = []
#        for fp in fps:
#            onbits = list(fp.GetOnBits())
#            arr = np.zeros(fp.GetNumBits())
#            arr[onbits] = 1
#            arrs.append(arr)
#        arrs = np.array(arrs)
#        return arrs




#    def fingerprint_mols(self,mols):
#        fps = []
#        for mol in mols:
#            mol = Chem.MolFromSmiles(mol)

        # Necessary for fingerprinting
        # Chem.GetSymmSSSR(mol)

        # "When comparing the ECFP/FCFP fingerprints and
        # the Morgan fingerprints generated by the RDKit,
        # remember that the 4 in ECFP4 corresponds to the
        # diameter of the atom environments considered,
        # while the Morgan fingerprints take a radius parameter.
        # So the examples above, with radius=2, are roughly
        # equivalent to ECFP4 and FCFP4."
        # <http://www.rdkit.org/docs/GettingStartedInPython.html>
#            fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=int(self.fp_dim))
        # fold_factor = fp.GetNumBits()//fp_dim
        # fp = DataStructs.FoldFingerprint(fp, fold_factor)
#            fps.append(fp)
#        return fps

#    def preprocess(self,X):
    # Compute fingerprints
#        return self.fps_to_arr(self.fingerprint_mols(X, self.fp_dim))


print('Loading data...')
prod_to_rules = defaultdict(set)
with open('data/templates_rollout.dat', 'r') as f:
    for l in tqdm(f, desc='products'):
        rule, prod = l.strip().split('\t')
        prod_to_rules[prod].add(rule)

rollout_rules = {}
with open('data/rollout_rollout.dat', 'r') as f:
    for i, l in tqdm(enumerate(f), desc='rollout'):
        rule = l.strip()
        rollout_rules[rule] = i
# Rollout training
print('Rollout training...')
X, y = [], []
for prod, rules in tqdm(prod_to_rules.items(), desc='data prep'):
    rules = [r for r in rules if r in rollout_rules]
    if not rules: continue
    rules.sort()
    # Ideally trained as multilabel,
    # but multiclass, single label is easier atm
    for r in rules:
        id = rollout_rules[r]
        y.append(id)
        X.append(prod)
        
totrec = 0
for prod, rules in tqdm(prod_to_rules.items(), desc='total reactions'):
    totrec += len(rules) 
        
print('total products:', len(prod_to_rules))
print('total reactions:', totrec)
print('Training size:', len(X))

#設定訓練參數和訓練模型存放路徑
batch_size = 256
#num_classes = 6
epochs = 100
seed=0
#validation spilt
spilt=0.1
fp_dim=8192
n_rules=len(rollout_rules)
model_name = 'trained_model_rollout_'+str(seed)
save_dir = os.path.join(os.getcwd(), 'saved_models')


# Shuffle
# p = np.random.permutation(len(X))
# X, y = X[p], y[p]
xy = list(zip(X, y))
xy.sort()
random.seed(seed)
random.shuffle(xy)
X, y = zip(*xy)
data_spilt= round(len(X)*(1-spilt))
x_train = X[:data_spilt]
x_test = X[data_spilt:]
y_train = y[:data_spilt]
y_test = y[data_spilt:]
print('shuffle is over...')


#將訓練資料轉成ndarray
#x_train=preprocess(X,fp_dim)
#y_train=np.array(y)
#print('preprocess is over...')

visible = Input(shape=(fp_dim,))
hidden = Dense(512, activation='elu')(visible)
hidden = Dropout(0.4)(hidden)

# only for expansion rule policynet
#for _ in range(5):
#    hidden = Highway()(hidden)
#    hidden = Dropout(0.4)(hidden)
    
output = Dense(n_rules, activation='softmax')(hidden)
    
model = Model(inputs=visible, outputs=output)
# summarize layers
print(model.summary())
# plot graph
#plot_model(model, to_file='rolloutpolicynet_graph.png')
# 初始化Adam optimizer
opt = keras.optimizers.Adam(lr=0.0001)

# 設定訓練方式，包含loss、optimizer..)
def acc_top50(y_true, y_pred):
    return keras.metrics.sparse_top_k_categorical_accuracy(y_true, y_pred, k=50)

def acc_top10(y_true, y_pred):
    return keras.metrics.sparse_top_k_categorical_accuracy(y_true, y_pred, k=10)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=opt,
              metrics=['sparse_categorical_accuracy',acc_top10 ,acc_top50])


# early stop存放模型設置


if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
checkpoint = ModelCheckpoint(model_path, monitor='val_acc_top10', save_best_only=True, verbose=1)

# early stop參數設定
earlystop = EarlyStopping(monitor='val_acc_top10', patience=6, verbose=1)

#continue training
#del model  # 删掉存在的模型

#返回一个编译好的模型
#与删掉的模型相同
#model = load_model(model_path, custom_objects={'acc_top10': acc_top10,'acc_top50': acc_top50})
##model.compile(loss='sparse_categorical_crossentropy',
##              optimizer=opt,
##              metrics=['sparse_categorical_accuracy',acc_top10,acc_top50])

# 開始訓練
training_generator = DataGenerator(X=x_train, y=y_train, batch_size=batch_size, shuffle=True, fp_dim=fp_dim)
validation_gen = DataGenerator(X=x_test, y=y_test, batch_size=batch_size*16, shuffle=True, fp_dim=fp_dim)
if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=1,
                    initial_epoch=0,
#                    workers=3, 
#                    use_multiprocessing=True, 
#                    shuffle=False,
#                    max_queue_size = 5, 
                    callbacks=[earlystop, checkpoint]
                    )

    #model_history = model.fit(x=x_train, 
#                    y=y_train,
#                    epochs=epochs,
#                    batch_size=batch_size,
#                    validation_split=0.2,
#                    verbose=1,
#                    callbacks=[earlystop, checkpoint])
# Out:
# Loading data...
# products: 1153338it [00:03, 288673.97it/s]

# %%
from rollout_policy import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=3, 
                    use_multiprocessing=True, 
#                    max_queue_size = 5, 
#                    shuffle=False,
                    callbacks=[earlystop, checkpoint]
                    )

#    print(y_train[0:2])
#    print(y_test [0:2])
#    print(x_train[0:2])
#    print(x_test [0:2])
# Out:
# RDKit WARNING: [16:39:19] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 3184835it [00:08, 358440.79it/s]
# rollout: 19728it [00:00, 706439.25it/s]
# Rollout training...
# data prep: 100%|██████████| 1108830/1108830 [00:00<00:00, 1372590.83it/s]
# total reactions: 100%|██████████| 1108830/1108830 [00:00<00:00, 2646987.40it/s]
# total products: 1108830
# total reactions: 1174933
# Training size: 844509
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 19728)             10120464
# =================================================================
# Total params: 14,315,280
# Trainable params: 14,315,280
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1
#  - 258s - loss: 7.2637 - sparse_categorical_accuracy: 0.1040 - acc_top10: 0.2445 - acc_top50: 0.3574 - val_loss: 5.9779 - val_sparse_categorical_accuracy: 0.1960 - val_acc_top10: 0.4239 - val_acc_top50: 0.5478
#
# Epoch 00001: val_acc_top10 improved from -inf to 0.42394, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# (1066, 17290)
# (2918, 11758)
# ('[O]=[C](-[OH])-[CH2]-[NH]-[C](=[O])-[c]1:[n]:[cH]:[c]2:[n]:[c](-[c]3:[cH]:[cH]:[c](-[Cl]):[cH]:[cH]:3):[s]:[c]:2:[c]:1-[OH]', '[NH2]-[C](=[O])-[c]1:[c](-[F]):[cH]:[cH]:[c](-[O]-[CH2]-[c]2:[n]:[c]3:[cH]:[cH]:[c](-[O]-[C](-[F])(-[F])-[F]):[cH]:[c]:3:[s]:2):[c]:1-[F]')
# ('[CH3]-[c]1:[cH]:[cH]:[c]2:[n]:[c](-[Cl]):[nH]:[c]:2:[cH]:1', '[CH3]-[CH2]-[C](-[CH2]-[CH3])(-[c]1:[cH]:[cH]:[c](/[CH]=[CH]/[C]2(-[OH])-[CH2]-[CH2]-[S]-[CH2]-[CH2]-2):[c](-[CH3]):[cH]:1)-[c]1:[cH]:[cH]:[c](-[c]2:[cH]:[n]:[cH]:[c](-[CH2]-[C](=[O])-[O]-[CH3]):[cH]:2):[c](-[CH3]):[cH]:1')

# %%
from rollout_policy import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=epochs,
                    
                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=3, 
                    use_multiprocessing=True, 
                   max_queue_size = 12, 
#                    shuffle=False,
                    callbacks=[earlystop, checkpoint]
                    )
# Out:
# RDKit WARNING: [09:49:45] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 3184835it [00:08, 359774.07it/s]
# rollout: 19728it [00:00, 682102.97it/s]
# Rollout training...
# data prep: 100%|██████████| 1108830/1108830 [00:00<00:00, 1307958.30it/s]
# total reactions: 100%|██████████| 1108830/1108830 [00:00<00:00, 2772568.46it/s]
# total products: 1108830
# total reactions: 1174933
# Training size: 844509
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 19728)             10120464
# =================================================================
# Total params: 14,315,280
# Trainable params: 14,315,280
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
#  - 260s - loss: 7.2689 - sparse_categorical_accuracy: 0.1034 - acc_top10: 0.2447 - acc_top50: 0.3581 - sparse_categorical_crossentropy: 7.2689 - val_loss: 5.7766 - val_sparse_categorical_accuracy: 0.1946 - val_acc_top10: 0.4242 - val_acc_top50: 0.5458 - val_sparse_categorical_crossentropy: 5.9920
#
# Epoch 00001: val_acc_top10 improved from -inf to 0.42424, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 2/100
#  - 245s - loss: 5.1461 - sparse_categorical_accuracy: 0.2461 - acc_top10: 0.5206 - acc_top50: 0.6533 - sparse_categorical_crossentropy: 5.1461 - val_loss: 4.5756 - val_sparse_categorical_accuracy: 0.2937 - val_acc_top10: 0.5995 - val_acc_top50: 0.7330 - val_sparse_categorical_crossentropy: 4.5110
#
# Epoch 00002: val_acc_top10 improved from 0.42424 to 0.59950, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 3/100
#  - 243s - loss: 4.0265 - sparse_categorical_accuracy: 0.3221 - acc_top10: 0.6527 - acc_top50: 0.7881 - sparse_categorical_crossentropy: 4.0265 - val_loss: 3.4809 - val_sparse_categorical_accuracy: 0.3519 - val_acc_top10: 0.6919 - val_acc_top50: 0.8195 - val_sparse_categorical_crossentropy: 3.7225
#
# Epoch 00003: val_acc_top10 improved from 0.59950 to 0.69193, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 4/100
#  - 244s - loss: 3.3755 - sparse_categorical_accuracy: 0.3736 - acc_top10: 0.7306 - acc_top50: 0.8587 - sparse_categorical_crossentropy: 3.3755 - val_loss: 3.4180 - val_sparse_categorical_accuracy: 0.3934 - val_acc_top10: 0.7456 - val_acc_top50: 0.8661 - val_sparse_categorical_crossentropy: 3.2482
#
# Epoch 00004: val_acc_top10 improved from 0.69193 to 0.74561, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 5/100
#  - 249s - loss: 2.9483 - sparse_categorical_accuracy: 0.4132 - acc_top10: 0.7815 - acc_top50: 0.9011 - sparse_categorical_crossentropy: 2.9483 - val_loss: 2.8016 - val_sparse_categorical_accuracy: 0.4226 - val_acc_top10: 0.7816 - val_acc_top50: 0.8945 - val_sparse_categorical_crossentropy: 2.9370
#
# Epoch 00005: val_acc_top10 improved from 0.74561 to 0.78162, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 6/100
#  - 245s - loss: 2.6449 - sparse_categorical_accuracy: 0.4444 - acc_top10: 0.8185 - acc_top50: 0.9276 - sparse_categorical_crossentropy: 2.6449 - val_loss: 2.8850 - val_sparse_categorical_accuracy: 0.4446 - val_acc_top10: 0.8068 - val_acc_top50: 0.9123 - val_sparse_categorical_crossentropy: 2.7165
#
# Epoch 00006: val_acc_top10 improved from 0.78162 to 0.80685, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 7/100
#  - 243s - loss: 2.4188 - sparse_categorical_accuracy: 0.4703 - acc_top10: 0.8459 - acc_top50: 0.9451 - sparse_categorical_crossentropy: 2.4188 - val_loss: 2.6788 - val_sparse_categorical_accuracy: 0.4618 - val_acc_top10: 0.8255 - val_acc_top50: 0.9248 - val_sparse_categorical_crossentropy: 2.5573
#
# Epoch 00007: val_acc_top10 improved from 0.80685 to 0.82547, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 8/100
#  - 244s - loss: 2.2430 - sparse_categorical_accuracy: 0.4919 - acc_top10: 0.8666 - acc_top50: 0.9573 - sparse_categorical_crossentropy: 2.2430 - val_loss: 2.4008 - val_sparse_categorical_accuracy: 0.4756 - val_acc_top10: 0.8391 - val_acc_top50: 0.9335 - val_sparse_categorical_crossentropy: 2.4349
#
# Epoch 00008: val_acc_top10 improved from 0.82547 to 0.83912, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 9/100
#  - 247s - loss: 2.0998 - sparse_categorical_accuracy: 0.5115 - acc_top10: 0.8831 - acc_top50: 0.9658 - sparse_categorical_crossentropy: 2.0998 - val_loss: 2.4575 - val_sparse_categorical_accuracy: 0.4869 - val_acc_top10: 0.8499 - val_acc_top50: 0.9395 - val_sparse_categorical_crossentropy: 2.3419
#
# Epoch 00009: val_acc_top10 improved from 0.83912 to 0.84992, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 10/100
#  - 244s - loss: 1.9802 - sparse_categorical_accuracy: 0.5282 - acc_top10: 0.8967 - acc_top50: 0.9721 - sparse_categorical_crossentropy: 1.9802 - val_loss: 2.2953 - val_sparse_categorical_accuracy: 0.4951 - val_acc_top10: 0.8584 - val_acc_top50: 0.9441 - val_sparse_categorical_crossentropy: 2.2669
#
# Epoch 00010: val_acc_top10 improved from 0.84992 to 0.85835, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 11/100
#  - 243s - loss: 1.8791 - sparse_categorical_accuracy: 0.5429 - acc_top10: 0.9079 - acc_top50: 0.9768 - sparse_categorical_crossentropy: 1.8791 - val_loss: 2.3923 - val_sparse_categorical_accuracy: 0.5030 - val_acc_top10: 0.8656 - val_acc_top50: 0.9480 - val_sparse_categorical_crossentropy: 2.2037
#
# Epoch 00011: val_acc_top10 improved from 0.85835 to 0.86562, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 12/100
#  - 244s - loss: 1.7903 - sparse_categorical_accuracy: 0.5575 - acc_top10: 0.9171 - acc_top50: 0.9804 - sparse_categorical_crossentropy: 1.7903 - val_loss: 2.4809 - val_sparse_categorical_accuracy: 0.5095 - val_acc_top10: 0.8704 - val_acc_top50: 0.9512 - val_sparse_categorical_crossentropy: 2.1540
#
# Epoch 00012: val_acc_top10 improved from 0.86562 to 0.87036, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 13/100
#  - 246s - loss: 1.7143 - sparse_categorical_accuracy: 0.5695 - acc_top10: 0.9249 - acc_top50: 0.9834 - sparse_categorical_crossentropy: 1.7143 - val_loss: 2.0018 - val_sparse_categorical_accuracy: 0.5150 - val_acc_top10: 0.8743 - val_acc_top50: 0.9532 - val_sparse_categorical_crossentropy: 2.1114
#
# Epoch 00013: val_acc_top10 improved from 0.87036 to 0.87435, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 14/100
#  - 243s - loss: 1.6464 - sparse_categorical_accuracy: 0.5810 - acc_top10: 0.9314 - acc_top50: 0.9855 - sparse_categorical_crossentropy: 1.6464 - val_loss: 2.0713 - val_sparse_categorical_accuracy: 0.5211 - val_acc_top10: 0.8788 - val_acc_top50: 0.9554 - val_sparse_categorical_crossentropy: 2.0725
#
# Epoch 00014: val_acc_top10 improved from 0.87435 to 0.87878, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 15/100
#  - 243s - loss: 1.5848 - sparse_categorical_accuracy: 0.5918 - acc_top10: 0.9372 - acc_top50: 0.9874 - sparse_categorical_crossentropy: 1.5848 - val_loss: 2.0098 - val_sparse_categorical_accuracy: 0.5254 - val_acc_top10: 0.8821 - val_acc_top50: 0.9567 - val_sparse_categorical_crossentropy: 2.0449
#
# Epoch 00015: val_acc_top10 improved from 0.87878 to 0.88211, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 16/100
#  - 244s - loss: 1.5284 - sparse_categorical_accuracy: 0.6021 - acc_top10: 0.9423 - acc_top50: 0.9890 - sparse_categorical_crossentropy: 1.5284 - val_loss: 2.0888 - val_sparse_categorical_accuracy: 0.5292 - val_acc_top10: 0.8851 - val_acc_top50: 0.9582 - val_sparse_categorical_crossentropy: 2.0179
#
# Epoch 00016: val_acc_top10 improved from 0.88211 to 0.88513, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 17/100
#  - 246s - loss: 1.4796 - sparse_categorical_accuracy: 0.6108 - acc_top10: 0.9467 - acc_top50: 0.9903 - sparse_categorical_crossentropy: 1.4796 - val_loss: 1.9783 - val_sparse_categorical_accuracy: 0.5328 - val_acc_top10: 0.8871 - val_acc_top50: 0.9595 - val_sparse_categorical_crossentropy: 1.9949
#
# Epoch 00017: val_acc_top10 improved from 0.88513 to 0.88705, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 18/100
#  - 243s - loss: 1.4316 - sparse_categorical_accuracy: 0.6204 - acc_top10: 0.9507 - acc_top50: 0.9913 - sparse_categorical_crossentropy: 1.4316 - val_loss: 1.9693 - val_sparse_categorical_accuracy: 0.5366 - val_acc_top10: 0.8894 - val_acc_top50: 0.9605 - val_sparse_categorical_crossentropy: 1.9757
#
# Epoch 00018: val_acc_top10 improved from 0.88705 to 0.88939, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 19/100
#  - 243s - loss: 1.3904 - sparse_categorical_accuracy: 0.6286 - acc_top10: 0.9540 - acc_top50: 0.9922 - sparse_categorical_crossentropy: 1.3904 - val_loss: 1.9890 - val_sparse_categorical_accuracy: 0.5388 - val_acc_top10: 0.8905 - val_acc_top50: 0.9613 - val_sparse_categorical_crossentropy: 1.9593
#
# Epoch 00019: val_acc_top10 improved from 0.88939 to 0.89054, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 20/100
#  - 244s - loss: 1.3509 - sparse_categorical_accuracy: 0.6363 - acc_top10: 0.9575 - acc_top50: 0.9928 - sparse_categorical_crossentropy: 1.3509 - val_loss: 1.9755 - val_sparse_categorical_accuracy: 0.5412 - val_acc_top10: 0.8923 - val_acc_top50: 0.9619 - val_sparse_categorical_crossentropy: 1.9459
#
# Epoch 00020: val_acc_top10 improved from 0.89054 to 0.89232, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 21/100
#  - 246s - loss: 1.3138 - sparse_categorical_accuracy: 0.6442 - acc_top10: 0.9603 - acc_top50: 0.9935 - sparse_categorical_crossentropy: 1.3138 - val_loss: 1.6667 - val_sparse_categorical_accuracy: 0.5440 - val_acc_top10: 0.8935 - val_acc_top50: 0.9624 - val_sparse_categorical_crossentropy: 1.9335
#
# Epoch 00021: val_acc_top10 improved from 0.89232 to 0.89352, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 22/100
#  - 243s - loss: 1.2803 - sparse_categorical_accuracy: 0.6510 - acc_top10: 0.9626 - acc_top50: 0.9940 - sparse_categorical_crossentropy: 1.2804 - val_loss: 1.9956 - val_sparse_categorical_accuracy: 0.5464 - val_acc_top10: 0.8951 - val_acc_top50: 0.9630 - val_sparse_categorical_crossentropy: 1.9210
#
# Epoch 00022: val_acc_top10 improved from 0.89352 to 0.89508, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 23/100
#  - 243s - loss: 1.2481 - sparse_categorical_accuracy: 0.6575 - acc_top10: 0.9650 - acc_top50: 0.9946 - sparse_categorical_crossentropy: 1.2481 - val_loss: 1.6971 - val_sparse_categorical_accuracy: 0.5487 - val_acc_top10: 0.8959 - val_acc_top50: 0.9633 - val_sparse_categorical_crossentropy: 1.9129
#
# Epoch 00023: val_acc_top10 improved from 0.89508 to 0.89586, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 24/100
#  - 244s - loss: 1.2176 - sparse_categorical_accuracy: 0.6640 - acc_top10: 0.9671 - acc_top50: 0.9949 - sparse_categorical_crossentropy: 1.2176 - val_loss: 1.9553 - val_sparse_categorical_accuracy: 0.5498 - val_acc_top10: 0.8968 - val_acc_top50: 0.9637 - val_sparse_categorical_crossentropy: 1.9071
#
# Epoch 00024: val_acc_top10 improved from 0.89586 to 0.89679, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 25/100
#  - 246s - loss: 1.1904 - sparse_categorical_accuracy: 0.6697 - acc_top10: 0.9690 - acc_top50: 0.9953 - sparse_categorical_crossentropy: 1.1904 - val_loss: 2.1142 - val_sparse_categorical_accuracy: 0.5517 - val_acc_top10: 0.8977 - val_acc_top50: 0.9639 - val_sparse_categorical_crossentropy: 1.8990
#
# Epoch 00025: val_acc_top10 improved from 0.89679 to 0.89770, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 26/100
#  - 243s - loss: 1.1615 - sparse_categorical_accuracy: 0.6764 - acc_top10: 0.9709 - acc_top50: 0.9956 - sparse_categorical_crossentropy: 1.1615 - val_loss: 1.8988 - val_sparse_categorical_accuracy: 0.5530 - val_acc_top10: 0.8979 - val_acc_top50: 0.9640 - val_sparse_categorical_crossentropy: 1.8923
#
# Epoch 00026: val_acc_top10 improved from 0.89770 to 0.89794, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 27/100
#  - 243s - loss: 1.1376 - sparse_categorical_accuracy: 0.6821 - acc_top10: 0.9723 - acc_top50: 0.9959 - sparse_categorical_crossentropy: 1.1376 - val_loss: 1.7272 - val_sparse_categorical_accuracy: 0.5543 - val_acc_top10: 0.8992 - val_acc_top50: 0.9643 - val_sparse_categorical_crossentropy: 1.8898
#
# Epoch 00027: val_acc_top10 improved from 0.89794 to 0.89917, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 28/100
#  - 244s - loss: 1.1137 - sparse_categorical_accuracy: 0.6877 - acc_top10: 0.9738 - acc_top50: 0.9961 - sparse_categorical_crossentropy: 1.1137 - val_loss: 2.0134 - val_sparse_categorical_accuracy: 0.5547 - val_acc_top10: 0.9004 - val_acc_top50: 0.9647 - val_sparse_categorical_crossentropy: 1.8840
#
# Epoch 00028: val_acc_top10 improved from 0.89917 to 0.90036, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 29/100
#  - 246s - loss: 1.0904 - sparse_categorical_accuracy: 0.6927 - acc_top10: 0.9751 - acc_top50: 0.9962 - sparse_categorical_crossentropy: 1.0904 - val_loss: 1.8790 - val_sparse_categorical_accuracy: 0.5560 - val_acc_top10: 0.9004 - val_acc_top50: 0.9648 - val_sparse_categorical_crossentropy: 1.8814
#
# Epoch 00029: val_acc_top10 did not improve from 0.90036
# Epoch 30/100
#  - 245s - loss: 1.0694 - sparse_categorical_accuracy: 0.6975 - acc_top10: 0.9765 - acc_top50: 0.9964 - sparse_categorical_crossentropy: 1.0694 - val_loss: 1.7958 - val_sparse_categorical_accuracy: 0.5571 - val_acc_top10: 0.9006 - val_acc_top50: 0.9651 - val_sparse_categorical_crossentropy: 1.8791
#
# Epoch 00030: val_acc_top10 improved from 0.90036 to 0.90055, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 31/100
#  - 243s - loss: 1.0486 - sparse_categorical_accuracy: 0.7018 - acc_top10: 0.9778 - acc_top50: 0.9966 - sparse_categorical_crossentropy: 1.0486 - val_loss: 1.7569 - val_sparse_categorical_accuracy: 0.5582 - val_acc_top10: 0.9009 - val_acc_top50: 0.9651 - val_sparse_categorical_crossentropy: 1.8770
#
# Epoch 00031: val_acc_top10 improved from 0.90055 to 0.90092, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 32/100
#  - 243s - loss: 1.0295 - sparse_categorical_accuracy: 0.7069 - acc_top10: 0.9786 - acc_top50: 0.9968 - sparse_categorical_crossentropy: 1.0295 - val_loss: 1.8591 - val_sparse_categorical_accuracy: 0.5588 - val_acc_top10: 0.9013 - val_acc_top50: 0.9649 - val_sparse_categorical_crossentropy: 1.8763
#
# Epoch 00032: val_acc_top10 improved from 0.90092 to 0.90126, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 33/100
#  - 246s - loss: 1.0102 - sparse_categorical_accuracy: 0.7114 - acc_top10: 0.9795 - acc_top50: 0.9969 - sparse_categorical_crossentropy: 1.0102 - val_loss: 1.7445 - val_sparse_categorical_accuracy: 0.5599 - val_acc_top10: 0.9016 - val_acc_top50: 0.9652 - val_sparse_categorical_crossentropy: 1.8754
#
# Epoch 00033: val_acc_top10 improved from 0.90126 to 0.90157, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 34/100
#  - 243s - loss: 0.9932 - sparse_categorical_accuracy: 0.7152 - acc_top10: 0.9804 - acc_top50: 0.9970 - sparse_categorical_crossentropy: 0.9932 - val_loss: 1.9952 - val_sparse_categorical_accuracy: 0.5603 - val_acc_top10: 0.9017 - val_acc_top50: 0.9653 - val_sparse_categorical_crossentropy: 1.8739
#
# Epoch 00034: val_acc_top10 improved from 0.90157 to 0.90167, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 35/100
#  - 243s - loss: 0.9747 - sparse_categorical_accuracy: 0.7199 - acc_top10: 0.9814 - acc_top50: 0.9971 - sparse_categorical_crossentropy: 0.9747 - val_loss: 1.8697 - val_sparse_categorical_accuracy: 0.5615 - val_acc_top10: 0.9020 - val_acc_top50: 0.9655 - val_sparse_categorical_crossentropy: 1.8742
#
# Epoch 00035: val_acc_top10 improved from 0.90167 to 0.90201, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 36/100
#  - 245s - loss: 0.9575 - sparse_categorical_accuracy: 0.7242 - acc_top10: 0.9822 - acc_top50: 0.9972 - sparse_categorical_crossentropy: 0.9575 - val_loss: 1.9119 - val_sparse_categorical_accuracy: 0.5621 - val_acc_top10: 0.9020 - val_acc_top50: 0.9653 - val_sparse_categorical_crossentropy: 1.8753
#
# Epoch 00036: val_acc_top10 did not improve from 0.90201
# Epoch 37/100
#  - 247s - loss: 0.9424 - sparse_categorical_accuracy: 0.7278 - acc_top10: 0.9829 - acc_top50: 0.9973 - sparse_categorical_crossentropy: 0.9424 - val_loss: 2.1297 - val_sparse_categorical_accuracy: 0.5630 - val_acc_top10: 0.9024 - val_acc_top50: 0.9652 - val_sparse_categorical_crossentropy: 1.8757
#
# Epoch 00037: val_acc_top10 improved from 0.90201 to 0.90241, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 38/100
#  - 244s - loss: 0.9289 - sparse_categorical_accuracy: 0.7308 - acc_top10: 0.9835 - acc_top50: 0.9973 - sparse_categorical_crossentropy: 0.9289 - val_loss: 1.9353 - val_sparse_categorical_accuracy: 0.5640 - val_acc_top10: 0.9025 - val_acc_top50: 0.9652 - val_sparse_categorical_crossentropy: 1.8746
#
# Epoch 00038: val_acc_top10 improved from 0.90241 to 0.90251, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 39/100
#  - 243s - loss: 0.9128 - sparse_categorical_accuracy: 0.7347 - acc_top10: 0.9844 - acc_top50: 0.9974 - sparse_categorical_crossentropy: 0.9128 - val_loss: 1.7196 - val_sparse_categorical_accuracy: 0.5648 - val_acc_top10: 0.9025 - val_acc_top50: 0.9652 - val_sparse_categorical_crossentropy: 1.8781
#
# Epoch 00039: val_acc_top10 did not improve from 0.90251
# Epoch 40/100
#  - 244s - loss: 0.9002 - sparse_categorical_accuracy: 0.7378 - acc_top10: 0.9848 - acc_top50: 0.9975 - sparse_categorical_crossentropy: 0.9002 - val_loss: 1.8352 - val_sparse_categorical_accuracy: 0.5650 - val_acc_top10: 0.9025 - val_acc_top50: 0.9652 - val_sparse_categorical_crossentropy: 1.8785
#
# Epoch 00040: val_acc_top10 did not improve from 0.90251
# Epoch 41/100
#  - 246s - loss: 0.8851 - sparse_categorical_accuracy: 0.7424 - acc_top10: 0.9854 - acc_top50: 0.9976 - sparse_categorical_crossentropy: 0.8851 - val_loss: 1.9168 - val_sparse_categorical_accuracy: 0.5661 - val_acc_top10: 0.9029 - val_acc_top50: 0.9650 - val_sparse_categorical_crossentropy: 1.8794
#
# Epoch 00041: val_acc_top10 improved from 0.90251 to 0.90287, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 42/100
#  - 244s - loss: 0.8730 - sparse_categorical_accuracy: 0.7450 - acc_top10: 0.9859 - acc_top50: 0.9976 - sparse_categorical_crossentropy: 0.8730 - val_loss: 1.8719 - val_sparse_categorical_accuracy: 0.5647 - val_acc_top10: 0.9030 - val_acc_top50: 0.9651 - val_sparse_categorical_crossentropy: 1.8854
#
# Epoch 00042: val_acc_top10 improved from 0.90287 to 0.90302, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 43/100
#  - 243s - loss: 0.8607 - sparse_categorical_accuracy: 0.7481 - acc_top10: 0.9864 - acc_top50: 0.9976 - sparse_categorical_crossentropy: 0.8607 - val_loss: 1.9608 - val_sparse_categorical_accuracy: 0.5655 - val_acc_top10: 0.9028 - val_acc_top50: 0.9650 - val_sparse_categorical_crossentropy: 1.8862
#
# Epoch 00043: val_acc_top10 did not improve from 0.90302
# Epoch 44/100
#  - 244s - loss: 0.8484 - sparse_categorical_accuracy: 0.7504 - acc_top10: 0.9870 - acc_top50: 0.9977 - sparse_categorical_crossentropy: 0.8484 - val_loss: 2.3093 - val_sparse_categorical_accuracy: 0.5660 - val_acc_top10: 0.9030 - val_acc_top50: 0.9647 - val_sparse_categorical_crossentropy: 1.8865
#
# Epoch 00044: val_acc_top10 did not improve from 0.90302
# Epoch 45/100
#  - 246s - loss: 0.8364 - sparse_categorical_accuracy: 0.7542 - acc_top10: 0.9874 - acc_top50: 0.9977 - sparse_categorical_crossentropy: 0.8364 - val_loss: 2.0766 - val_sparse_categorical_accuracy: 0.5661 - val_acc_top10: 0.9030 - val_acc_top50: 0.9649 - val_sparse_categorical_crossentropy: 1.8895
#
# Epoch 00045: val_acc_top10 did not improve from 0.90302
# Epoch 46/100
#  - 244s - loss: 0.8244 - sparse_categorical_accuracy: 0.7574 - acc_top10: 0.9878 - acc_top50: 0.9978 - sparse_categorical_crossentropy: 0.8244 - val_loss: 1.8045 - val_sparse_categorical_accuracy: 0.5668 - val_acc_top10: 0.9034 - val_acc_top50: 0.9649 - val_sparse_categorical_crossentropy: 1.8910
#
# Epoch 00046: val_acc_top10 improved from 0.90302 to 0.90339, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 47/100
#  - 242s - loss: 0.8137 - sparse_categorical_accuracy: 0.7601 - acc_top10: 0.9883 - acc_top50: 0.9978 - sparse_categorical_crossentropy: 0.8137 - val_loss: 1.9950 - val_sparse_categorical_accuracy: 0.5672 - val_acc_top10: 0.9030 - val_acc_top50: 0.9644 - val_sparse_categorical_crossentropy: 1.8948
#
# Epoch 00047: val_acc_top10 did not improve from 0.90339
# Epoch 48/100
#  - 244s - loss: 0.8033 - sparse_categorical_accuracy: 0.7629 - acc_top10: 0.9887 - acc_top50: 0.9978 - sparse_categorical_crossentropy: 0.8033 - val_loss: 1.9146 - val_sparse_categorical_accuracy: 0.5672 - val_acc_top10: 0.9034 - val_acc_top50: 0.9645 - val_sparse_categorical_crossentropy: 1.8979
#
# Epoch 00048: val_acc_top10 improved from 0.90339 to 0.90342, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 49/100
#  - 247s - loss: 0.7956 - sparse_categorical_accuracy: 0.7641 - acc_top10: 0.9889 - acc_top50: 0.9979 - sparse_categorical_crossentropy: 0.7956 - val_loss: 2.0887 - val_sparse_categorical_accuracy: 0.5682 - val_acc_top10: 0.9033 - val_acc_top50: 0.9644 - val_sparse_categorical_crossentropy: 1.9016
#
# Epoch 00049: val_acc_top10 did not improve from 0.90342
# Epoch 50/100
#  - 246s - loss: 0.7834 - sparse_categorical_accuracy: 0.7681 - acc_top10: 0.9892 - acc_top50: 0.9979 - sparse_categorical_crossentropy: 0.7834 - val_loss: 1.9534 - val_sparse_categorical_accuracy: 0.5678 - val_acc_top10: 0.9032 - val_acc_top50: 0.9643 - val_sparse_categorical_crossentropy: 1.9037
#
# Epoch 00050: val_acc_top10 did not improve from 0.90342
# Epoch 51/100
#  - 243s - loss: 0.7749 - sparse_categorical_accuracy: 0.7699 - acc_top10: 0.9897 - acc_top50: 0.9979 - sparse_categorical_crossentropy: 0.7749 - val_loss: 1.9045 - val_sparse_categorical_accuracy: 0.5680 - val_acc_top10: 0.9030 - val_acc_top50: 0.9640 - val_sparse_categorical_crossentropy: 1.9097
#
# Epoch 00051: val_acc_top10 did not improve from 0.90342
# Epoch 52/100
#  - 245s - loss: 0.7649 - sparse_categorical_accuracy: 0.7726 - acc_top10: 0.9900 - acc_top50: 0.9979 - sparse_categorical_crossentropy: 0.7649 - val_loss: 1.8680 - val_sparse_categorical_accuracy: 0.5679 - val_acc_top10: 0.9031 - val_acc_top50: 0.9639 - val_sparse_categorical_crossentropy: 1.9111
#
# Epoch 00052: val_acc_top10 did not improve from 0.90342
# Epoch 53/100
#  - 247s - loss: 0.7552 - sparse_categorical_accuracy: 0.7750 - acc_top10: 0.9903 - acc_top50: 0.9980 - sparse_categorical_crossentropy: 0.7552 - val_loss: 1.7690 - val_sparse_categorical_accuracy: 0.5685 - val_acc_top10: 0.9028 - val_acc_top50: 0.9637 - val_sparse_categorical_crossentropy: 1.9150
#
# Epoch 00053: val_acc_top10 did not improve from 0.90342
# Epoch 54/100
#  - 243s - loss: 0.7475 - sparse_categorical_accuracy: 0.7767 - acc_top10: 0.9905 - acc_top50: 0.9980 - sparse_categorical_crossentropy: 0.7475 - val_loss: 2.0469 - val_sparse_categorical_accuracy: 0.5684 - val_acc_top10: 0.9029 - val_acc_top50: 0.9634 - val_sparse_categorical_crossentropy: 1.9202
#
# Epoch 00054: val_acc_top10 did not improve from 0.90342
# Epoch 00054: early stopping

# %%
from rollout_policy import*

if __name__ == '__main__':
    model_history = model.fit_generator( 
                    generator=training_generator,
                    epochs=34,
                    
#                    validation_data=validation_gen,
                    verbose=2,
                    initial_epoch=0,
                    workers=3, 
                    use_multiprocessing=True, 
                   max_queue_size = 12, 
#                    shuffle=False,
                    callbacks=[checkpoint]
                    )
# Out:
# RDKit WARNING: [10:27:17] Enabling RDKit 2019.09.3 jupyter extensions
# Using TensorFlow backend.
# Loading data...
# products: 3184835it [00:08, 360708.43it/s]
# rollout: 19728it [00:00, 707115.40it/s]
# Rollout training...
# data prep: 100%|██████████| 1108830/1108830 [00:00<00:00, 1298790.51it/s]
# total reactions: 100%|██████████| 1108830/1108830 [00:00<00:00, 2772750.29it/s]
# total products: 1108830
# total reactions: 1174933
# Training size: 844509
# shuffle is over...
# WARNING:tensorflow:From C:\Users\i0947\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 19728)             10120464
# =================================================================
# Total params: 14,315,280
# Trainable params: 14,315,280
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/34
#  - 258s - loss: 7.1321 - sparse_categorical_accuracy: 0.1137 - acc_top10: 0.2634 - acc_top50: 0.3772 - sparse_categorical_crossentropy: 7.1321
#
# Epoch 00001: acc_top10 improved from -inf to 0.26336, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 2/34
#  - 256s - loss: 4.9274 - sparse_categorical_accuracy: 0.2598 - acc_top10: 0.5462 - acc_top50: 0.6801 - sparse_categorical_crossentropy: 4.9274
#
# Epoch 00002: acc_top10 improved from 0.26336 to 0.54619, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 3/34
#  - 259s - loss: 3.8371 - sparse_categorical_accuracy: 0.3373 - acc_top10: 0.6752 - acc_top50: 0.8083 - sparse_categorical_crossentropy: 3.8371
#
# Epoch 00003: acc_top10 improved from 0.54619 to 0.67518, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 4/34
#  - 254s - loss: 3.2185 - sparse_categorical_accuracy: 0.3878 - acc_top10: 0.7489 - acc_top50: 0.8741 - sparse_categorical_crossentropy: 3.2185
#
# Epoch 00004: acc_top10 improved from 0.67518 to 0.74886, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 5/34
#  - 256s - loss: 2.8200 - sparse_categorical_accuracy: 0.4262 - acc_top10: 0.7975 - acc_top50: 0.9119 - sparse_categorical_crossentropy: 2.8200
#
# Epoch 00005: acc_top10 improved from 0.74886 to 0.79750, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 6/34
#  - 256s - loss: 2.5384 - sparse_categorical_accuracy: 0.4564 - acc_top10: 0.8310 - acc_top50: 0.9359 - sparse_categorical_crossentropy: 2.5384
#
# Epoch 00006: acc_top10 improved from 0.79750 to 0.83103, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 7/34
#  - 255s - loss: 2.3283 - sparse_categorical_accuracy: 0.4812 - acc_top10: 0.8562 - acc_top50: 0.9510 - sparse_categorical_crossentropy: 2.3283
#
# Epoch 00007: acc_top10 improved from 0.83103 to 0.85623, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 8/34
#  - 258s - loss: 2.1645 - sparse_categorical_accuracy: 0.5022 - acc_top10: 0.8754 - acc_top50: 0.9614 - sparse_categorical_crossentropy: 2.1645
#
# Epoch 00008: acc_top10 improved from 0.85623 to 0.87541, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 9/34
#  - 255s - loss: 2.0296 - sparse_categorical_accuracy: 0.5216 - acc_top10: 0.8909 - acc_top50: 0.9690 - sparse_categorical_crossentropy: 2.0296
#
# Epoch 00009: acc_top10 improved from 0.87541 to 0.89087, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 10/34
#  - 255s - loss: 1.9201 - sparse_categorical_accuracy: 0.5370 - acc_top10: 0.9030 - acc_top50: 0.9744 - sparse_categorical_crossentropy: 1.9201
#
# Epoch 00010: acc_top10 improved from 0.89087 to 0.90300, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 11/34
#  - 258s - loss: 1.8251 - sparse_categorical_accuracy: 0.5515 - acc_top10: 0.9129 - acc_top50: 0.9788 - sparse_categorical_crossentropy: 1.8251
#
# Epoch 00011: acc_top10 improved from 0.90300 to 0.91289, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 12/34
#  - 254s - loss: 1.7427 - sparse_categorical_accuracy: 0.5645 - acc_top10: 0.9215 - acc_top50: 0.9818 - sparse_categorical_crossentropy: 1.7427
#
# Epoch 00012: acc_top10 improved from 0.91289 to 0.92155, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 13/34
#  - 255s - loss: 1.6708 - sparse_categorical_accuracy: 0.5766 - acc_top10: 0.9289 - acc_top50: 0.9843 - sparse_categorical_crossentropy: 1.6708
#
# Epoch 00013: acc_top10 improved from 0.92155 to 0.92886, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 14/34
#  - 255s - loss: 1.6087 - sparse_categorical_accuracy: 0.5876 - acc_top10: 0.9349 - acc_top50: 0.9862 - sparse_categorical_crossentropy: 1.6087
#
# Epoch 00014: acc_top10 improved from 0.92886 to 0.93485, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 15/34
#  - 255s - loss: 1.5513 - sparse_categorical_accuracy: 0.5978 - acc_top10: 0.9402 - acc_top50: 0.9879 - sparse_categorical_crossentropy: 1.5513
#
# Epoch 00015: acc_top10 improved from 0.93485 to 0.94025, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 16/34
#  - 258s - loss: 1.4986 - sparse_categorical_accuracy: 0.6070 - acc_top10: 0.9448 - acc_top50: 0.9893 - sparse_categorical_crossentropy: 1.4986
#
# Epoch 00016: acc_top10 improved from 0.94025 to 0.94475, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 17/34
#  - 254s - loss: 1.4509 - sparse_categorical_accuracy: 0.6163 - acc_top10: 0.9489 - acc_top50: 0.9905 - sparse_categorical_crossentropy: 1.4509
#
# Epoch 00017: acc_top10 improved from 0.94475 to 0.94889, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 18/34
#  - 255s - loss: 1.4092 - sparse_categorical_accuracy: 0.6248 - acc_top10: 0.9522 - acc_top50: 0.9915 - sparse_categorical_crossentropy: 1.4092
#
# Epoch 00018: acc_top10 improved from 0.94889 to 0.95220, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 19/34
#  - 258s - loss: 1.3692 - sparse_categorical_accuracy: 0.6326 - acc_top10: 0.9558 - acc_top50: 0.9923 - sparse_categorical_crossentropy: 1.3692
#
# Epoch 00019: acc_top10 improved from 0.95220 to 0.95578, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 20/34
#  - 254s - loss: 1.3327 - sparse_categorical_accuracy: 0.6401 - acc_top10: 0.9585 - acc_top50: 0.9929 - sparse_categorical_crossentropy: 1.3327
#
# Epoch 00020: acc_top10 improved from 0.95578 to 0.95845, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 21/34
#  - 255s - loss: 1.2981 - sparse_categorical_accuracy: 0.6468 - acc_top10: 0.9611 - acc_top50: 0.9936 - sparse_categorical_crossentropy: 1.2981
#
# Epoch 00021: acc_top10 improved from 0.95845 to 0.96106, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 22/34
#  - 255s - loss: 1.2662 - sparse_categorical_accuracy: 0.6530 - acc_top10: 0.9634 - acc_top50: 0.9941 - sparse_categorical_crossentropy: 1.2662
#
# Epoch 00022: acc_top10 improved from 0.96106 to 0.96336, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 23/34
#  - 258s - loss: 1.2345 - sparse_categorical_accuracy: 0.6603 - acc_top10: 0.9657 - acc_top50: 0.9946 - sparse_categorical_crossentropy: 1.2345
#
# Epoch 00023: acc_top10 improved from 0.96336 to 0.96571, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 24/34
#  - 263s - loss: 1.2079 - sparse_categorical_accuracy: 0.6658 - acc_top10: 0.9676 - acc_top50: 0.9949 - sparse_categorical_crossentropy: 1.2079
#
# Epoch 00024: acc_top10 improved from 0.96571 to 0.96764, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 25/34
#  - 262s - loss: 1.1825 - sparse_categorical_accuracy: 0.6714 - acc_top10: 0.9691 - acc_top50: 0.9953 - sparse_categorical_crossentropy: 1.1825
#
# Epoch 00025: acc_top10 improved from 0.96764 to 0.96913, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 26/34
#  - 259s - loss: 1.1552 - sparse_categorical_accuracy: 0.6776 - acc_top10: 0.9709 - acc_top50: 0.9956 - sparse_categorical_crossentropy: 1.1552
#
# Epoch 00026: acc_top10 improved from 0.96913 to 0.97087, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 27/34
#  - 263s - loss: 1.1329 - sparse_categorical_accuracy: 0.6826 - acc_top10: 0.9723 - acc_top50: 0.9958 - sparse_categorical_crossentropy: 1.1329
#
# Epoch 00027: acc_top10 improved from 0.97087 to 0.97232, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 28/34
#  - 258s - loss: 1.1084 - sparse_categorical_accuracy: 0.6878 - acc_top10: 0.9741 - acc_top50: 0.9960 - sparse_categorical_crossentropy: 1.1084
#
# Epoch 00028: acc_top10 improved from 0.97232 to 0.97406, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 29/34
#  - 257s - loss: 1.0875 - sparse_categorical_accuracy: 0.6927 - acc_top10: 0.9751 - acc_top50: 0.9962 - sparse_categorical_crossentropy: 1.0875
#
# Epoch 00029: acc_top10 improved from 0.97406 to 0.97507, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 30/34
#  - 260s - loss: 1.0681 - sparse_categorical_accuracy: 0.6970 - acc_top10: 0.9763 - acc_top50: 0.9963 - sparse_categorical_crossentropy: 1.0681
#
# Epoch 00030: acc_top10 improved from 0.97507 to 0.97630, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 31/34
#  - 257s - loss: 1.0482 - sparse_categorical_accuracy: 0.7020 - acc_top10: 0.9775 - acc_top50: 0.9965 - sparse_categorical_crossentropy: 1.0482
#
# Epoch 00031: acc_top10 improved from 0.97630 to 0.97753, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 32/34
#  - 258s - loss: 1.0288 - sparse_categorical_accuracy: 0.7065 - acc_top10: 0.9786 - acc_top50: 0.9967 - sparse_categorical_crossentropy: 1.0288
#
# Epoch 00032: acc_top10 improved from 0.97753 to 0.97864, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 33/34
#  - 255s - loss: 1.0121 - sparse_categorical_accuracy: 0.7100 - acc_top10: 0.9795 - acc_top50: 0.9968 - sparse_categorical_crossentropy: 1.0121
#
# Epoch 00033: acc_top10 improved from 0.97864 to 0.97954, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
# Epoch 34/34
#  - 255s - loss: 0.9961 - sparse_categorical_accuracy: 0.7139 - acc_top10: 0.9802 - acc_top50: 0.9968 - sparse_categorical_crossentropy: 0.9961
#
# Epoch 00034: acc_top10 improved from 0.97954 to 0.98018, saving model to C:\Users\i0947\Desktop\retrosynthesis_planner-master\saved_models\trained_model_rollout_0
